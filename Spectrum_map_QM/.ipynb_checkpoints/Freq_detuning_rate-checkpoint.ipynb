# %% [markdown]
# # Import package

# %%
from qm.QuantumMachinesManager import QuantumMachinesManager
from qm.octave import *
from qm.qua import *
from qm import generate_qua_script

#General os library 
import os
import time
import sys


import matplotlib.pyplot as plt
from qualang_tools.units import unit
from set_octave import get_L0_and_IF
from configuration_first_jump_sticky import *
from qm import SimulationConfig, LoopbackInterface
from qualang_tools.units import unit
from qualang_tools.loops import from_array
u = unit()
from qualang_tools.plot import interrupt_on_close
from qualang_tools.results import progress_counter, fetching_tool
from qualang_tools.addons.variables import assign_variables_to_element

#Path for HQCPC7 
sys.path.append(r'C:\Users\HQClabo\Documents\Code\QuantumMachine\Guillaume\NonLinearRes_calib_30_03_2023\Analysis_Function\NonLinearRes')
sys.path.append(r'C:\Users\HQClabo\Documents\Code\QuantumMachine\Guillaume\NonLinearRes_calib_30_03_2023\Drivers\Drivers') #path for the analysis function

#Path for HQC PC15 
# sys.path.append(r'C:\Users\hqclabo\Documents\Code\gbeaulieu\Analysis_Function\NonLinearRes')
# sys.path.append(r'C:\Users\hqclabo\Documents\Code\gbeaulieu\Drivers')
import AnFunc as an # analysis function
#import AnFunc as an 
import scipy.io
from scipy import signal 
from scipy.optimize import curve_fit

# %%
def update_readout_lenght(Readout_Len,config,qmm):
    """ Macro to update the readout length in the configuration file"""
    
    config["pulses"]["zero_pulse"]["length"]=Readout_Len
    config["integration_weights"]["cosine_weights"]["cosine"][0]=(1.0, Readout_Len)
    config["integration_weights"]["cosine_weights"]["sine"][0]=(0.0, Readout_Len)
    config["integration_weights"]["sine_weights"]["cosine"][0]=(0.0, Readout_Len)
    config["integration_weights"]["sine_weights"]["sine"][0]=(1.0, Readout_Len)
    config["integration_weights"]["minus_sine_weights"]["cosine"][0]=(0.0, Readout_Len)
    config["integration_weights"]["minus_sine_weights"]["sine"][0]=(-1.0, Readout_Len)


    #Update the config with the modified values above 
    qm = qmm.open_qm(config)
    
    return config, qm


def update_pulse_amplitude(pulse_amp,config,qmm):
    config["waveforms"]["twoPhoton_wf"]['sample']=pulse_amp
    
    #Update the config with the modified values above 
    qm = qmm.open_qm(config)
    
    return config, qm

def update_two_photon_lenght(twoPhoton_len,config,qmm):
    """ Update the length of the fluxline pulse in the configuration file"""
    config["pulses"]["twoPhoton"]["length"]=twoPhoton_len


    #Update the config with the modified values above 
    qm = qmm.open_qm(config)
    
    return config, qm

def update_time_of_flight(time_of_flight,config,qmm):
    """ Update the time_of_flight of the qm in the configuration file """
    config["elements"]["resonator"]["time_of_flight"]=time_of_flight
    
    qm=qmm.open_qm(config)
    
    return config, qm


def update_offset(offset_1, offset_2,config,qmm):
    """ Update the input offsets of the qm in the configuration file """
    
    config['controllers']["con1"]["analog_inputs"][1]['offset']=offset_1
    config['controllers']["con1"]["analog_inputs"][2]['offset']=offset_2
    
    
    qm=qmm.open_qm(config)
    
    return config, qm

# %% [markdown]
# # OPX configuration

# %%
#Octave & OPX configuration 
Saving_Path=r"\\sb1files\HQC\Users\beaulieu\Data\Run01\131\\"
Cooldown_Date="2023_06_01"


opx_ip = '128.178.175.167'
opx_port = 81
octave_ip = '128.178.175.167'
octave_port = 53


octave_config = QmOctaveConfig()
octave_config.set_calibration_db(os.getcwd()) #Path to the calibration database 

octave_config.add_device_info('octave1', octave_ip, octave_port) #Add a device refered to as octave 1
octave_config.set_opx_octave_mapping([('con1', 'octave1')])  # set default mapping between analog outputs of OPX and the octave


qmm = QuantumMachinesManager(host=opx_ip, port=opx_port, octave=octave_config)
qm = qmm.open_qm(config)


#Mixers for the fluxline 
octave_output_gain=-10

qmm.octave_manager.set_clock("octave1", ClockType.External, ClockFrequency.MHZ_10) # External clock on the octave 
qm.octave.set_lo_source("fluxline", OctaveLOSource.Internal) # Use internal LO for the fluxline 
qm.octave.set_lo_frequency("fluxline", LO_fluxline)  # Set the frequency of the LO 
qm.octave.set_rf_output_gain("fluxline", octave_output_gain)  # can set gain from -10dB to 20dB
qm.octave.set_rf_output_mode("fluxline", RFOutputMode.on)  # The LO output is always on (could change to a trigger)  #RFOutputMode.trig_normal

#Mixers for the resonator 
qm.octave.set_qua_element_octave_rf_in_port("resonator", "octave1", 1) #input port 1 is set for the resonator 
qm.octave.set_downconversion("resonator", lo_source=RFInputLOSource.Internal)  # The LO for the demodulation is the interal LO  
qm.octave.set_lo_frequency("resonator", LO_readout)  # assign the LO inside the octave to element
# Out:
# 2023-06-21 10:14:48,350 - qm - INFO - Performing health check
# 2023-06-21 10:14:48,362 - qm - WARNING -   HC Warning: Potential hardware issue with QSync in controller con1, multiple controllers sync cannot be guaranteed, please inform QM
# 2023-06-21 10:14:48,363 - qm - INFO - Health check passed

# %%
#Setting the gain
gain=0
config['controllers']['con1']['analog_inputs'][1]["gain_db"]=gain
config['controllers']['con1']['analog_inputs'][2]["gain_db"]=gain
qm = qmm.open_qm(config)

time_of_flight=24

config, qm=update_time_of_flight(time_of_flight,config,qmm)

pulse_amp=0.125
config,qm=update_pulse_amplitude(pulse_amp,config,qmm)


#Based on the other setting
offset_1=0.0180632734375
offset_2=0.015605841992187498
config,qm=update_offset(offset_1, offset_2,config,qmm)

# %% [markdown]
# # Display parameters

# %%
print("LO of resonator : {} GHz".format(config['elements']['resonator']["mixInputs"]["lo_frequency"]/1e9))
print("IF of resonator : {} GHz".format(config['elements']['resonator']['intermediate_frequency']/1e9))
print("Time of flight of resonator : {} ns".format(config['elements']['resonator']['time_of_flight']))
print("Readout time resonator : {} ns".format(config["pulses"]["zero_pulse"]["length"]))
print("LO of fluxline: {} GHz".format(config['elements']['fluxline']["mixInputs"]["lo_frequency"]/1e9))
print("IF of fluxline : {} GHz".format(config['elements']['fluxline']['intermediate_frequency']/1e9))
print("Ramping time of fluxline : {} ns".format(config['elements']['fluxline']['hold_offset']))
print("Fluxline pulse time : {} ns".format(config["pulses"]["twoPhoton"]["length"]))
print("Fluxline amplitude : {} V".format(config["waveforms"]["twoPhoton_wf"]['sample']))

#print("Input attenuation: {} dB".format(config['controllers']['con1']['analog_inputs'][1]["gain_db"]))
# Out:
# LO of resonator : 4.3 GHz
# IF of resonator : 0.318 GHz
# Time of flight of resonator : 24 ns
# Readout time resonator : 10000 ns
# LO of fluxline: 8.6 GHz
# IF of fluxline : 0.0995 GHz
# Ramping time of fluxline : {'duration': 5000} ns
# Fluxline pulse time : 1000 ns
# Fluxline amplitude : 0.125 V

# %% [markdown]
# # Testing the pump

# %%
#Mixer Calibration 
#Calibration of the fluxline mixer for the pump 
qm.octave.calibrate_element("fluxline", [get_L0_and_IF(config, "fluxline")])  
qm = qmm.open_qm(config)

qm.octave.calibrate_element("resonator", [get_L0_and_IF(config, "resonator")])  
qm = qmm.open_qm(config)
# Out:
# 2023-06-21 00:25:01,930 - qm - INFO - Flags:
# 2023-06-21 00:25:01,930 - qm - INFO - Compiling program
# 2023-06-21 00:25:04,512 - qm - INFO - Sending pre-compiled program to QOP
# 2023-06-21 00:25:07,937 - qm - INFO - Flags:
# 2023-06-21 00:25:07,938 - qm - INFO - Compiling program
# 2023-06-21 00:25:10,283 - qm - INFO - Sending pre-compiled program to QOP

# %%
# Testing the pump 
with program() as TwoPhoton:
    with infinite_loop_():
        play("pumping"*amp(0.1), 'fluxline')
        
job = qm.execute(TwoPhoton)
# Out:
# 2023-04-21 16:14:28,195 - qm - INFO - Flags:
# 2023-04-21 16:14:28,196 - qm - INFO - Sending program to QOP
# 2023-04-21 16:14:28,224 - qm - INFO - Executing program

# %%
#Two stop the two photon pumping 
job.halt()
# Out:
# True

# %% [markdown]
# # Downsweep

# %% [markdown]
# ## Single downsweep
#
# ![image.png](attachment:c669d38c-ead4-41a4-b727-629f1a9a6e24.png)
#
# ![image.png](attachment:38802645-71a1-46cb-9950-1bbe6a420f23.png)
#
# ![image.png](attachment:cdd5abb8-725a-4caa-a09c-df5f9fd18e08.png)
#
# In this code, we create a pulse and update its frequency. At each frequency step, the pulse is played for its full pulse length. Simultaenously, we perform a readout.We can modify the time delay between the pulse and the readout. by applying the readout delay. If for exmaple readout_len is 5000, puls elength is 5000 and the readout delay is 20_000. Then, we start the pulse and play if of 5000s. Simultaneously, we wait before taking the readout if 20_000 seconds. Then, we take the readout. Wait for the waiting time between pulses and restart.
#
# Then, there is a waiting time and we update the next frequency. In this case, the readout time can be very short because we do not need to wait until we reach the steady state. Addtionnally, it should be shorter than the typical jumping rate otherwise, we will average out some jumps. The length of the pulse doesn't matter much, it should only me the same length or shorter then the readout. If it is shorter without delay, it still stays on until the readout is completed

# %%
#Set the readout length and photon length 
Readout_Len=10_000
config,qm=update_readout_lenght(Readout_Len,config,qmm)

twoPhoton_len=1_000
config,qm=update_two_photon_lenght(twoPhoton_len,config,qmm)

amp_factor=1.05

n_repetition=1000

IF_pump=98.9e6 #Ending frequency 
IF_right=99.9e6 # Starting frequency  
pump_step=0.02e6 # frequency step 


readout_delay=16//4 #time delay before making the readout (while pump is still on) 
wait_pump_step=16//4 #w aiting time after having played the pump 

number_frequency=int(np.ceil((IF_right-IF_pump)/pump_step)) # number of frequency 

LO_diff=LO_fluxline/2-LO_readout # need to perform this substraction outside of the qua program to avoid having numbers larger than the int allowed 

time_per_iteration=((wait_pump_step+twoPhoton_len+readout_delay*4)*number_frequency)*1e-9
Total_time=time_per_iteration*n_repetition/60
print("Time per iteration : {} s".format(time_per_iteration))
print("Total time : {} min".format(Total_time))
print("Number of frequencies {}".format(number_frequency))
# Out:
# Time per iteration : 5.1000000000000006e-05 s
# Total time : 0.0008500000000000001 min
# Number of frequencies 50

# %%
# %matplotlib qt


with program() as hello_qua:
    
    f = declare(int)
    f_readout= declare(int)
    
    n_rep = declare(int)
    I = declare(fixed)
    Q = declare(fixed)
    
    I_st = declare_stream()
    Q_st = declare_stream()
    n_rep_st=declare_stream()
    f_st = declare_stream() #frequency at which I am measuring 
    
    assign_variables_to_element("resonator", I,Q) 
    
    # loop over multiple frequencies 
    with for_(n_rep, 0, n_rep < n_repetition, n_rep + 1): 
        
        #Play the first pulse of the sticky to set the pump frequency and the amplitude 
        update_frequency("fluxline", IF_right)
        play("pumping"*amp(amp_factor), "fluxline") 
        
        #Freuqnecy steps 
        with for_(f, IF_right, f>IF_pump, f-pump_step):

            assign(f_readout,LO_diff+f/2) #update the readout frequency 
            update_frequency("resonator",f_readout) # Change the IF frequency of the resonator to demodulate more precisely 
            
            #update the sticky 
            update_frequency("fluxline", f, keep_phase=True)
            play("pumping"*amp(0), "fluxline")
            
            wait(readout_delay)
        #Continously measure in paralell
            measure(
                "fake_readout",
                "resonator",
                None,
                dual_demod.full("cos", "out1", "sin", "out2", I),
                dual_demod.full("minus_sin", "out1", "cos", "out2", Q),
            )

            wait(wait_pump_step, "fluxline") #time that will be waited after playing the pump 
            
            #Take absolute value of I and Q
            assign(I,Math.abs(I))
            assign(Q,Math.abs(Q))

            save(I, I_st)
            save(Q, Q_st)  
            save(f, f_st)
        
        #ramp to zero 
        ramp_to_zero("fluxline")

        save(n_rep, n_rep_st)   

    with stream_processing():
        I_st.buffer(number_frequency).average().save("I")
        Q_st.buffer(number_frequency).average().save("Q")
        f_st.buffer(number_frequency).save("f")
        n_rep_st.save("n_rep")
    
    

simulation = False    

if simulation:
    simulation_config = SimulationConfig(
        duration=50000, simulation_interface=LoopbackInterface([("con1", 3, "con1", 1)])
    )

    job = qmm.simulate(config, hello_qua, simulation_config)
    job.get_simulated_samples().con1.plot(analog_ports={'1','2','3','4' },digital_ports={'3',"1"})
    
    # Get the frequency map 
    sample=job.get_simulated_samples()
    x=sample.con1.analog["4"] # get analog 4
    NFFT = 2**10
    Fs = 1e9
    fig = plt.figure()
    ax1 = plt.subplot(111)
    Pxx, freqs, bins, im = plt.specgram(x, NFFT=NFFT, Fs=Fs, noverlap=100, cmap=plt.cm.gist_heat)
    plt.show()
    ax1.set_xticklabels((ax1.get_xticks() * 1e6).astype(int))
    #ax1.set_yticklabels((ax1.get_yticks() / 1e6).astype(int))
    plt.xlabel("t [us]")
    plt.ylabel("f [MHz]")

else:
    job = qm.execute(hello_qua)
    results = fetching_tool(job, data_list=["I","Q","f","n_rep"], mode="live")

    fig = plt.figure()
    interrupt_on_close(fig, job)  #  Interrupts the job when closing the figure

    while results.is_processing():
        
        I,Q,f, n_rep = results.fetch_all()

        Id = u.demod2volts(I, Readout_Len) ## that is why i want to demodulate .... diviser par la duree du pulse Readout_lEN 
        Qd = u.demod2volts(Q, Readout_Len)
        
        plt.subplot(111)
        fig.suptitle(str(n_rep))
        plt.cla()
        plt.plot(f/1e6,np.sqrt(Id**2+Qd**2)*1e3,".", markersize=2)
        plt.xlabel("Pump frequency [MHz]")
        plt.ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")
        plt.pause(0.1)
# Out:
# 2023-05-30 20:08:38,964 - qm - INFO - Flags:
# 2023-05-30 20:08:38,964 - qm - INFO - Sending program to QOP
# 2023-05-30 20:08:39,230 - qm - INFO - Executing program
# Execution stopped by user!

# %% [markdown]
# ## Down sweep map

# %%
#Set the readout length and photon length 
Readout_Len=10_000
config,qm=update_readout_lenght(Readout_Len,config,qmm)

twoPhoton_len=10_000
config,qm=update_two_photon_lenght(twoPhoton_len,config,qmm)


a_min=0.3
a_max=1.65
da=0.01
amp_factor=np.arange(a_min,a_max,da)

n_repetition=4_000


IF_pump=88e6 #88e6 #Ending frequency 
IF_right=99.88e6 # Starting frequency  
pump_step=0.02e6 # frequency step 

readout_delay=16//4
wait_pump_step=16//4 #w aiting time after having played the pump 

number_frequency=int(np.ceil((IF_right-IF_pump)/pump_step)) # number of frequency 

LO_diff=LO_fluxline/2-LO_readout # need to perform this substraction outside of the qua program to avoid having numbers larger than the int allowed 

time_per_iteration=((wait_pump_step+twoPhoton_len+readout_delay*4)*number_frequency)*1e-9
Total_time=time_per_iteration*n_repetition*len(amp_factor)/60
print("Time per iteration : {} s".format(time_per_iteration))
print("Total time : {} min".format(Total_time))
# Out:
# Time per iteration : 0.0059518800000000005 s
# Total time : 53.56692000000001 min

# %%
# %matplotlib qt


with program() as hello_qua:
    
    f = declare(int)
    f_readout= declare(int)
    
    n_rep = declare(int)
    I = declare(fixed)
    Q = declare(fixed)
    a= declare(fixed)
    I_st = declare_stream()
    Q_st = declare_stream()
    n_rep_st=declare_stream()
    f_st = declare_stream() #frequency at which I am measuring 
    
    assign_variables_to_element("resonator", I,Q) 
    
    # Averaging loop  
    with for_(n_rep, 0, n_rep < n_repetition, n_rep + 1): 
        
        #loop over amplitude 
        with for_(*from_array(a, amp_factor)):
        
            #Play the first pulse of the sticky to set the pump frequency and the amplitude 
            update_frequency("fluxline", IF_right)
            play("pumping"*amp(a), "fluxline") 

            #loop over frequencies  
            with for_(f, IF_right, f>IF_pump, f-pump_step):

                assign(f_readout,LO_diff+f/2) #update the readout frequency 
                update_frequency("resonator",f_readout) # Change the IF frequency of the resonator to demodulate more precisely 

                #update the sticky 
                update_frequency("fluxline", f, keep_phase=True)
                play("pumping"*amp(0), "fluxline")
                
                wait(readout_delay)

            #Continously measure in paralell
                measure(
                    "fake_readout",
                    "resonator",
                    None,
                    dual_demod.full("cos", "out1", "sin", "out2", I),
                    dual_demod.full("minus_sin", "out1", "cos", "out2", Q),
                )

                wait(wait_pump_step, "fluxline") #time that will be waited after playing the pump 

                #Take absolute value of I and Q
                assign(I,Math.abs(I))
                assign(Q,Math.abs(Q))

                save(I, I_st)
                save(Q, Q_st)  
                save(f, f_st)

            #ramp to zero 
            ramp_to_zero("fluxline")

        save(n_rep, n_rep_st)   

    with stream_processing():
        I_st.buffer(number_frequency).buffer(len(amp_factor)).average().save_all("I")
        Q_st.buffer(number_frequency).buffer(len(amp_factor)).average().save_all("Q")
        f_st.buffer(number_frequency).save("f")
        n_rep_st.save("n_rep")
    
    

simulation = False  

if simulation:
    simulation_config = SimulationConfig(
        duration=50000, simulation_interface=LoopbackInterface([("con1", 3, "con1", 1)])
    )

    job = qmm.simulate(config, hello_qua, simulation_config)
    job.get_simulated_samples().con1.plot(analog_ports={'1','2','3','4' },digital_ports={'3',"1"})
    
    # Get the frequency map 
    sample=job.get_simulated_samples()
    x=sample.con1.analog["4"] # get analog 4
    NFFT = 2**10
    Fs = 1e9
    fig = plt.figure()
    ax1 = plt.subplot(111)
    Pxx, freqs, bins, im = plt.specgram(x, NFFT=NFFT, Fs=Fs, noverlap=100, cmap=plt.cm.gist_heat)
    plt.show()
    ax1.set_xticklabels((ax1.get_xticks() * 1e6).astype(int))
    #ax1.set_yticklabels((ax1.get_yticks() / 1e6).astype(int))
    plt.xlabel("t [us]")
    plt.ylabel("f [MHz]")

else:
    job = qm.execute(hello_qua)
    results = fetching_tool(job, data_list=["I","Q","f","n_rep"], mode="live")

    fig = plt.figure()
    interrupt_on_close(fig, job)  #  Interrupts the job when closing the figure

    while results.is_processing():
        
        I,Q,f, n_rep = results.fetch_all()

        I = u.demod2volts(I, Readout_Len) ## that is why i want to demodulate .... diviser par la duree du pulse Readout_lEN 
        Q = u.demod2volts(Q, Readout_Len)
        
        #transpose the element 
        I_mat = np.transpose(I,(1, 2, 0))


        Q_mat = np.transpose(Q,(1, 2, 0))


        #take the average 
        I_av=np.mean(I_mat,axis=2)
        Q_av=np.mean(Q_mat,axis=2)

        #variance :
        I_var=np.var(I_mat, axis=2)
        Q_var=np.var(Q_mat,axis=2)


        norm=I_av**2+Q_av**2
        
        
        plt.subplot(111)
        fig.suptitle(str(n_rep))
        plt.cla()
        plt.pcolor(f / u.MHz, amp_factor, norm*1e6)
       # plt.plot(f/1e6,np.sqrt(Id**2+Qd**2)*1e3,".", markersize=2)
        plt.xlabel("Pump frequency [MHz]")
        plt.ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")
        plt.pause(0.1)
        
    #take the average 
    I_av=np.mean(I_mat,axis=2)
    Q_av=np.mean(Q_mat,axis=2)

    #variance :
    I_var=np.var(I_mat, axis=2)
    Q_var=np.var(Q_mat,axis=2)
# Out:
# 2023-06-21 10:30:13,507 - qm - INFO - Flags:
# 2023-06-21 10:30:13,508 - qm - INFO - Sending program to QOP
# 2023-06-21 10:30:14,188 - qm - INFO - Executing program

# %%
# %matplotlib inline

plt.clf()
fig, ax = plt.subplots(1, 1)

ax.set_title("Down sweep")
c=ax.pcolor(f / u.MHz, amp_factor, np.sqrt(I**2+Q**2)*1e3) # What is shown is normalized by dividing by the amplitude 
ax.set_xlabel("Frequency [MHz]")
ax.set_ylabel("Amplitude factor")
fig.colorbar(c,ax=ax, label="Amplitude [mv]")

# %% [markdown]
# ### Saving downseep

# %%
#Saving the data
cooldown_date=Cooldown_Date #top folder 
device="Spectrum_QM" #second folder 
name="Map_downsweep" # third folder 
meastype="21_06_2023_larger_10_000_4_000_avg" #Final file name 

datadict={}
#Configuration file copy 
datadict["LO_fluxline"]=LO_fluxline
datadict["octave_gain"]=octave_output_gain

#Saving of parameters 
datadict["n_repetition"]=n_rep
datadict["readout_delay"]=readout_delay
datadict["amp_factor"]=amp_factor
datadict["Readout_Len"]=Readout_Len
datadict["wait_pump_step"]=wait_pump_step
datadict["IF_pump"]=IF_pump
datadict["IF_right"]=IF_right
datadict["pump_step"]=pump_step

#Saving of data 
datadict["freqs"]=f

datadict["I"]=I_av
datadict["Q"]=Q_av
datadict["I_mat"]=I_mat
datadict["Q_mat"]=Q_mat
datadict["I_var"]=I_var
datadict["Q_var"]=Q_var

datadict["config"]=config

an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)
# Out:
# saving in new directory

# %%
#loading 
filepath=r"Z:\Users\beaulieu\Data\Run01\104\2023_04_14\Spectrum_QM\Map_downsweep\downsweep_pi6_large_0_delay.npz"

npzfile=np.load(filepath,allow_pickle=True)
npzfile["multidata"][()]
f=npzfile["multidata"][()]["freqs"]
I=npzfile["multidata"][()]["I"]
Q=npzfile["multidata"][()]["Q"]
amp_factor=npzfile["multidata"][()]["amp_factor"]

# %% [markdown]
# ## Downsweep varying readout

# %% [markdown]
# ### Single Readout delay, multiple amplitudes

# %%
#Set the readout length and photon length 
Readout_Len=10_000
config,qm=update_readout_lenght(Readout_Len,config,qmm)

twoPhoton_len=10_000
config,qm=update_two_photon_lenght(twoPhoton_len,config,qmm)

amp_factor=np.array([0.85,0.95,1.05,1.15,1.25,1.35])

n_repetition=5_000

IF_pump=88e6 #Ending frequency 
IF_right=99.9e6 # Starting frequency  
pump_step=0.02e6 # frequency step 

readout_delay=16//4

wait_pump_step=16//4 #w aiting time after having played the pump 

number_frequency=int(np.ceil((IF_right-IF_pump)/pump_step)) # number of frequency 

LO_diff=LO_fluxline/2-LO_readout # need to perform this substraction outside of the qua program to avoid having numbers larger than the int allowed 

time_per_iteration=((wait_pump_step+twoPhoton_len+readout_delay*4)*number_frequency)*1e-9
Total_time=time_per_iteration*n_repetition*len(amp_factor)/60
print("Time per iteration : {} s".format(time_per_iteration))
print("Total time : {} min".format(Total_time))
amp_factor_list=amp_factor.tolist() #convert as a list to use for_each in qm
# Out:
# Time per iteration : 0.0059619 s
# Total time : 2.484125 min

# %%
# %matplotlib qt


with program() as hello_qua:
    
    f = declare(int)
    f_readout= declare(int)
    
    n_rep = declare(int)
    I = declare(fixed)
    Q = declare(fixed)
    a= declare(fixed)
    I_st = declare_stream()
    Q_st = declare_stream()
    n_rep_st=declare_stream()
    f_st = declare_stream() #frequency at which I am measuring 
    
    assign_variables_to_element("resonator", I,Q) 
    
    # Averaging loop  
    with for_(n_rep, 0, n_rep < n_repetition, n_rep + 1): 
        
        #loop over amplitude 
        with for_each_(a, amp_factor_list):
        
            #Play the first pulse of the sticky to set the pump frequency and the amplitude 
            update_frequency("fluxline", IF_right)
            play("pumping"*amp(a), "fluxline") 

            #loop over frequencies  
            with for_(f, IF_right, f>IF_pump, f-pump_step):

                assign(f_readout,LO_diff+f/2) #update the readout frequency 
                update_frequency("resonator",f_readout) # Change the IF frequency of the resonator to demodulate more precisely 

                #update the sticky 
                update_frequency("fluxline", f, keep_phase=True)
                play("pumping"*amp(0), "fluxline")
                
                wait(readout_delay)

            #Continously measure in paralell
                measure(
                    "fake_readout",
                    "resonator",
                    None,
                    dual_demod.full("cos", "out1", "sin", "out2", I),
                    dual_demod.full("minus_sin", "out1", "cos", "out2", Q),
                )

                wait(wait_pump_step, "fluxline") #time that will be waited after playing the pump 

                #Take absolute value of I and Q
                assign(I,Math.abs(I))
                assign(Q,Math.abs(Q))

                save(I, I_st)
                save(Q, Q_st)  
                save(f, f_st)

            #ramp to zero 
            ramp_to_zero("fluxline")

        save(n_rep, n_rep_st)   

    with stream_processing():
        I_st.buffer(number_frequency).buffer(len(amp_factor)).average().save("I")
        Q_st.buffer(number_frequency).buffer(len(amp_factor)).average().save("Q")
        f_st.buffer(number_frequency).save("f")
        n_rep_st.save("n_rep")
    
    

simulation = False     

if simulation:
    simulation_config = SimulationConfig(
        duration=50000, simulation_interface=LoopbackInterface([("con1", 3, "con1", 1)])
    )

    job = qmm.simulate(config, hello_qua, simulation_config)
    job.get_simulated_samples().con1.plot(analog_ports={'1','2','3','4' },digital_ports={'3'})
    
    # Get the frequency map 
    sample=job.get_simulated_samples()
    x=sample.con1.analog["4"] # get analog 4
    NFFT = 2**10
    Fs = 1e9
    fig = plt.figure()
    ax1 = plt.subplot(111)
    Pxx, freqs, bins, im = plt.specgram(x, NFFT=NFFT, Fs=Fs, noverlap=100, cmap=plt.cm.gist_heat)
    plt.show()
    ax1.set_xticklabels((ax1.get_xticks() * 1e6).astype(int))
    #ax1.set_yticklabels((ax1.get_yticks() / 1e6).astype(int))
    plt.xlabel("t [us]")
    plt.ylabel("f [MHz]")

else:
    job = qm.execute(hello_qua)
    results = fetching_tool(job, data_list=["I","Q","f","n_rep"], mode="live")

    fig = plt.figure()
    interrupt_on_close(fig, job)  #  Interrupts the job when closing the figure

    while results.is_processing():
        
        I,Q,f, n_rep = results.fetch_all()

        I = u.demod2volts(I, Readout_Len) ## that is why i want to demodulate .... diviser par la duree du pulse Readout_lEN 
        Q = u.demod2volts(Q, Readout_Len)
        
        norm=np.sqrt(I**2+Q**2)
        
        plt.subplot(111)
        plt.cla()
        for i in range(norm.shape[0]):
            plt.plot(f,norm[i,:],'.-',label=f'amp={amp_factor[i]:1f}', alpha=.9, lw=.5, ms=8)

        plt.xlabel("Pump freq")
        plt.ylabel("Amplitudes")
        plt.legend()
        fig.suptitle(str(n_rep))
        
        plt.pause(0.1)
# Out:
# 2023-05-23 14:47:17,333 - qm - INFO - Flags:
# 2023-05-23 14:47:17,333 - qm - INFO - Sending program to QOP
# 2023-05-23 14:47:17,523 - qm - INFO - Executing program

# %% [markdown]
# #### Saving single readout delay

# %%
# Out:
# (5, 495)

# %%
#Saving the data
coreadout_delay_date=Cooldown_Date #top folder 
device="Spectrum_QM" #second folder 
name="cuts_downsweep" # third folder 
meastype="run02_1000_0p02" #Final file name 

datadict={}
#Configuration file copy 
datadict["LO_fluxline"]=LO_fluxline
datadict["octave_gain"]=octave_output_gain

#Saving of parameters 
datadict["n_repetition"]=n_rep
datadict["readout_delay"]=readout_delay
datadict["amp_factor"]=amp_factor
datadict["Readout_Len"]=Readout_Len
datadict["wait_pump_step"]=wait_pump_step
datadict["IF_pump"]=IF_pump
datadict["IF_right"]=IF_right
datadict["pump_step"]=pump_step

#Saving of data 
datadict["freqs"]=f
datadict["I"]=I
datadict["Q"]=Q
datadict["config"]=config

an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)
# Out:
# saving in new directory

# %%
#loading 
filepath=r"Z:\Users\beaulieu\Data\Run01\104\2023_04_14\Spectrum_QM\Map_downsweep\downsweep_pi6_large_0_delay.npz"

npzfile=np.load(filepath,allow_pickle=True)
npzfile["multidata"][()]
f=npzfile["multidata"][()]["freqs"]
I=npzfile["multidata"][()]["I"]
Q=npzfile["multidata"][()]["Q"]
amp_factor=npzfile["multidata"][()]["amp_factor"]

# %% [markdown]
# ### Multiple readout delay

# %%
((np.geomspace(1000,500_00_000,num=30,endpoint=True)[7:20])//4*4)
# Out:
# array([0.01362 , 0.01978 , 0.028724, 0.041716, 0.060584, 0.08798 ,
#        0.127768, 0.185552, 0.269464, 0.39132 , 0.568288, 0.82528 ,
#        1.198492])

# %%
np.geomspace(10016,1e6,num=40,endpoint=True)//4*4
# Out:
# array([  10016.,   11268.,   12680.,   14272.,   16060.,   18072.,
#          20336.,   22884.,   25748.,   28976.,   32608.,   36692.,
#          41288.,   46464.,   52284.,   58836.,   66208.,   74504.,
#          83836.,   94344.,  106164.,  119464.,  134432.,  151276.,
#         170228.,  191556.,  215556.,  242564.,  272956.,  307152.,
#         345636.,  388940.,  437672.,  492508.,  554212.,  623652.,
#         701788.,  789716.,  888660., 1000000.])

# %%
((np.geomspace(10016,92440,num=20,endpoint=True))//4*4)
# Out:
# array([10016., 11256., 12652., 14224., 15988., 17972., 20204., 22712.,
#        25528., 28696., 32260., 36260., 40760., 45820., 51504., 57896.,
#        65080., 73156., 82232., 92440.])

# %%
a=np.geomspace(10016,1e6,num=30,endpoint=True))//4*4)[0:14], ((np.geomspace(10000,1e6,num=30,endpoint=True))//4*4)[26::2]))

a
# Out:
#   File "C:\Users\HQClabo\AppData\Local\Temp\ipykernel_23812\3169206866.py", line 1
#     a=np.geomspace(10016,1e6,num=30,endpoint=True))//4*4)[13], ((np.geomspace(10000,1e6,num=30,endpoint=True))//4*4)[26::2]))
#                                                   ^
# SyntaxError: invalid syntax

# %%
#true time delay 

#a=((np.geomspace(10016,1e6,num=30,endpoint=True))//4*4)
a=np.concatenate(  (((np.geomspace(10016,92440,num=20,endpoint=True))//4*4), ((np.geomspace(10016,1e6,num=30,endpoint=True))//4*4)[15::2]))

fig, ax = plt.subplots(1, 1)
ax.plot(a,".")
 
ax.set_yscale('log')
#ax.set_xscale('log')
ax.set_xlabel("Time delay (ns)")
ax.set_ylabel("Integral")

g=number_frequency*4000*(a)*1e-9/60*len(amp_factor)
print(g)
print(a)

sum(g)
# Out:
# [  1.15184   1.29444   1.45498   1.63576   1.83862   2.06678   2.32346
#    2.61188   2.93572   3.30004   3.7099    4.1699    4.6874    5.2693
#    5.92296   6.65804   7.4842    8.41294   9.45668  10.6306   12.45956
#   17.11568  23.51152  32.29706  44.36562  60.94402  83.71678 115.     ]
# [  10016.   11256.   12652.   14224.   15988.   17972.   20204.   22712.
#    25528.   28696.   32260.   36260.   40760.   45820.   51504.   57896.
#    65080.   73156.   82232.   92440.  108344.  148832.  204448.  280844.
#   385788.  529948.  727972. 1000000.]
# 476.42568000000006

# %%
# %matplotlib qt
#Set the readout length and photon length 
Readout_Len=10_000
config,qm=update_readout_lenght(Readout_Len,config,qmm)

twoPhoton_len=1_000
config,qm=update_two_photon_lenght(twoPhoton_len,config,qmm)


amp_factor=np.array([0.85,0.95,1.05,1.15,1.25,1.35])


n_repetition=4000

IF_pump=92.9e6 #Ending frequency 
IF_right=99.9e6 # Starting frequency  
pump_step=0.02e6 # frequency step 

#readout_delay_array=((np.geomspace(1000,100_00_000,num=30,endpoint=True)[20:30]-10_000)//4*4)//4
delay_array=np.concatenate(  (((np.geomspace(10016,92440,num=20,endpoint=True))//4*4), ((np.geomspace(10016,1e6,num=30,endpoint=True))//4*4)[15::2]))
readout_delay_array=(delay_array-10_000)//4
readout_delay_array=readout_delay_array.astype(int)
wait_pump_step=16//4 #w aiting time after having played the pump 

number_frequency=int(np.ceil((IF_right-IF_pump)/pump_step)) # number of frequency 

LO_diff=LO_fluxline/2-LO_readout # need to perform this substraction outside of the qua program to avoid having numbers larger than the int allowed 

time_array=[]
for i in range(len(readout_delay_array)):
    readout_delay=readout_delay_array[i]
    time_array.append(((wait_pump_step+Readout_Len+readout_delay*4)*1e-9*number_frequency*n_repetition*len(amp_factor))/60)
    
print("expected time : {}".format(sum(time_array)))
amp_factor_list=amp_factor.tolist() #convert as a list to use for_each in qm 

readout_delay_array*4+10_000
# Out:
# expected time : 580.01216
# array([  10016,   11256,   12652,   14224,   15988,   17972,   20204,
#          22712,   25528,   28696,   32260,   36260,   40760,   45820,
#          51504,   57896,   65080,   73156,   82232,   92440,  108344,
#         148832,  204448,  280844,  385788,  529948,  727972, 1000000])

# %%
# %%time
# modified version for variance 
Data={} #dictionnary to hold all the data 
for i in range(len(readout_delay_array)):
    
    readout_delay=readout_delay_array[i]
    Data[readout_delay]={} 
    
    #np.zeros(len(amp_factor),
    
    with program() as hello_qua:

        f = declare(int)
        f_readout= declare(int)

        n_rep = declare(int)
        I = declare(fixed)
        Q = declare(fixed)
        a= declare(fixed)
        I_st = declare_stream()
        Q_st = declare_stream()
        n_rep_st=declare_stream()
        f_st = declare_stream() #frequency at which I am measuring 

        assign_variables_to_element("resonator", I,Q) 

        # Averaging loop  
        with for_(n_rep, 0, n_rep < n_repetition, n_rep + 1): 

            #loop over amplitude 
            with for_each_(a, amp_factor_list):

                #Play the first pulse of the sticky to set the pump frequency and the amplitude 
                update_frequency("fluxline", IF_right)
                play("pumping"*amp(a), "fluxline") 

                #loop over frequencies  
                with for_(f, IF_right, f>IF_pump, f-pump_step):

                    assign(f_readout,LO_diff+f/2) #update the readout frequency 
                    update_frequency("resonator",f_readout) # Change the IF frequency of the resonator to demodulate more precisely 

                    #update the sticky 
                    update_frequency("fluxline", f, keep_phase=True)
                    play("pumping"*amp(0), "fluxline")

                    wait(readout_delay)

                #Continously measure in paralell
                    measure(
                        "fake_readout",
                        "resonator",
                        None,
                        dual_demod.full("cos", "out1", "sin", "out2", I),
                        dual_demod.full("minus_sin", "out1", "cos", "out2", Q),
                    )

                    wait(wait_pump_step, "fluxline") #time that will be waited after playing the pump 

                    #Take absolute value of I and Q
                    assign(I,Math.abs(I))
                    assign(Q,Math.abs(Q))

                    save(I, I_st)
                    save(Q, Q_st)  
                    save(f, f_st)

                #ramp to zero 
                ramp_to_zero("fluxline")

            save(n_rep, n_rep_st)   

        with stream_processing():
            I_st.buffer(number_frequency).buffer(len(amp_factor)).save_all("I")
            Q_st.buffer(number_frequency).buffer(len(amp_factor)).save_all("Q")
            f_st.buffer(number_frequency).save("f")
            n_rep_st.save("n_rep")



    simulation = False     

    if simulation:
        simulation_config = SimulationConfig(
            duration=50000, simulation_interface=LoopbackInterface([("con1", 3, "con1", 1)])
        )

        job = qmm.simulate(config, hello_qua, simulation_config)
        job.get_simulated_samples().con1.plot(analog_ports={'1','2','3','4' },digital_ports={'3'})

        # Get the frequency map 
        sample=job.get_simulated_samples()
        x=sample.con1.analog["4"] # get analog 4
        NFFT = 2**10
        Fs = 1e9
        fig = plt.figure()
        ax1 = plt.subplot(111)
        Pxx, freqs, bins, im = plt.specgram(x, NFFT=NFFT, Fs=Fs, noverlap=100, cmap=plt.cm.gist_heat)
        plt.show()
        ax1.set_xticklabels((ax1.get_xticks() * 1e6).astype(int))
        #ax1.set_yticklabels((ax1.get_yticks() / 1e6).astype(int))
        plt.xlabel("t [us]")
        plt.ylabel("f [MHz]")

    else:
        job = qm.execute(hello_qua)
        results = fetching_tool(job, data_list=["I","Q","f","n_rep"], mode="live")

        fig = plt.figure()
        interrupt_on_close(fig, job)  #  Interrupts the job when closing the figure

        while results.is_processing():

            I,Q,f, n_rep = results.fetch_all()

            I = u.demod2volts(I, Readout_Len) ## that is why i want to demodulate .... diviser par la duree du pulse Readout_lEN 
            Q = u.demod2volts(Q, Readout_Len)
            
            
            #transpose the element 
            I_mat = np.transpose(I,(1, 2, 0))
            
            
            Q_mat = np.transpose(Q,(1, 2, 0))
            
            
            #take the average 
            I_av=np.mean(I_mat,axis=2)
            Q_av=np.mean(Q_mat,axis=2)
            
            #variance :
            I_var=np.var(I_mat, axis=2)
            Q_var=np.var(Q_mat,axis=2)
            
 
            
            
            norm=I_av**2+Q_av**2

            plt.subplot(111)
            plt.cla()
            for i in range(norm.shape[0]):
                plt.plot(f,norm[i,:],'.-',label=f'amp={amp_factor[i]:1f}', alpha=.9, lw=.5, ms=8)

            plt.xlabel("Pump freq")
            plt.ylabel("Amplitudes")
            plt.legend()
            fig.suptitle("Readout delay :" +str(readout_delay) +" Iteration: "+str(n_rep))
            plt.pause(0.1)
            
    #take the average 
    I_av=np.mean(I_mat,axis=2)
    Q_av=np.mean(Q_mat,axis=2)

    #variance :
    I_var=np.var(I_mat, axis=2)
    Q_var=np.var(Q_mat,axis=2)
            
     
    Data[readout_delay]["I_mat"]=I_mat
    Data[readout_delay]["Q_mat"]=Q_mat   
    Data[readout_delay]["I"]=I_av
    Data[readout_delay]["Q"]=Q_av
    Data[readout_delay]["I_var"]=I_var
    Data[readout_delay]["Q_var"]=Q_var
        
    plt.close()
# Out:
# 2023-05-30 22:58:21,955 - qm - INFO - Flags:
# 2023-05-30 22:58:21,956 - qm - INFO - Sending program to QOP
# 2023-05-30 22:58:22,600 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-30 22:59:40,525 - qm - INFO - Flags:
# 2023-05-30 22:59:40,526 - qm - INFO - Sending program to QOP
# 2023-05-30 22:59:40,809 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-30 23:01:07,789 - qm - INFO - Flags:
# 2023-05-30 23:01:07,789 - qm - INFO - Sending program to QOP
# 2023-05-30 23:01:08,469 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-30 23:02:44,925 - qm - INFO - Flags:
# 2023-05-30 23:02:44,926 - qm - INFO - Sending program to QOP
# 2023-05-30 23:02:45,181 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-30 23:04:34,219 - qm - INFO - Flags:
# 2023-05-30 23:04:34,219 - qm - INFO - Sending program to QOP
# 2023-05-30 23:04:34,489 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-30 23:06:34,460 - qm - INFO - Flags:
# 2023-05-30 23:06:34,461 - qm - INFO - Sending program to QOP
# 2023-05-30 23:06:34,719 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-30 23:08:49,122 - qm - INFO - Flags:
# 2023-05-30 23:08:49,123 - qm - INFO - Sending program to QOP
# 2023-05-30 23:08:49,401 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-30 23:11:19,761 - qm - INFO - Flags:
# 2023-05-30 23:11:19,761 - qm - INFO - Sending program to QOP
# 2023-05-30 23:11:20,034 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-30 23:14:08,435 - qm - INFO - Flags:
# 2023-05-30 23:14:08,435 - qm - INFO - Sending program to QOP
# 2023-05-30 23:14:09,108 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-30 23:17:15,718 - qm - INFO - Flags:
# 2023-05-30 23:17:15,719 - qm - INFO - Sending program to QOP
# 2023-05-30 23:17:15,984 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-30 23:20:46,198 - qm - INFO - Flags:
# 2023-05-30 23:20:46,198 - qm - INFO - Sending program to QOP
# 2023-05-30 23:20:46,454 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-30 23:24:41,338 - qm - INFO - Flags:
# 2023-05-30 23:24:41,339 - qm - INFO - Sending program to QOP
# 2023-05-30 23:24:41,606 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-30 23:29:04,359 - qm - INFO - Flags:
# 2023-05-30 23:29:04,359 - qm - INFO - Sending program to QOP
# 2023-05-30 23:29:04,616 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-30 23:33:59,287 - qm - INFO - Flags:
# 2023-05-30 23:33:59,288 - qm - INFO - Sending program to QOP
# 2023-05-30 23:33:59,556 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-30 23:39:28,722 - qm - INFO - Flags:
# 2023-05-30 23:39:28,722 - qm - INFO - Sending program to QOP
# 2023-05-30 23:39:29,337 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-30 23:45:38,771 - qm - INFO - Flags:
# 2023-05-30 23:45:38,772 - qm - INFO - Sending program to QOP
# 2023-05-30 23:45:39,050 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-30 23:52:33,418 - qm - INFO - Flags:
# 2023-05-30 23:52:33,419 - qm - INFO - Sending program to QOP
# 2023-05-30 23:52:33,706 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 00:00:17,888 - qm - INFO - Flags:
# 2023-05-31 00:00:17,889 - qm - INFO - Sending program to QOP
# 2023-05-31 00:00:18,159 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 00:08:59,167 - qm - INFO - Flags:
# 2023-05-31 00:08:59,168 - qm - INFO - Sending program to QOP
# 2023-05-31 00:08:59,441 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 00:18:44,016 - qm - INFO - Flags:
# 2023-05-31 00:18:44,017 - qm - INFO - Sending program to QOP
# 2023-05-31 00:18:44,269 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 00:29:40,145 - qm - INFO - Flags:
# 2023-05-31 00:29:40,145 - qm - INFO - Sending program to QOP
# 2023-05-31 00:29:40,415 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 00:42:27,547 - qm - INFO - Flags:
# 2023-05-31 00:42:27,548 - qm - INFO - Sending program to QOP
# 2023-05-31 00:42:27,812 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 00:59:58,037 - qm - INFO - Flags:
# 2023-05-31 00:59:58,038 - qm - INFO - Sending program to QOP
# 2023-05-31 00:59:58,686 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 01:23:57,933 - qm - INFO - Flags:
# 2023-05-31 01:23:57,933 - qm - INFO - Sending program to QOP
# 2023-05-31 01:23:58,576 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 01:56:53,187 - qm - INFO - Flags:
# 2023-05-31 01:56:53,187 - qm - INFO - Sending program to QOP
# 2023-05-31 01:56:53,467 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 02:42:03,388 - qm - INFO - Flags:
# 2023-05-31 02:42:03,389 - qm - INFO - Sending program to QOP
# 2023-05-31 02:42:03,667 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 03:44:01,770 - qm - INFO - Flags:
# 2023-05-31 03:44:01,771 - qm - INFO - Sending program to QOP
# 2023-05-31 03:44:02,038 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 05:09:06,764 - qm - INFO - Flags:
# 2023-05-31 05:09:06,765 - qm - INFO - Sending program to QOP
# 2023-05-31 05:09:07,036 - qm - INFO - Executing program
# Execution stopped by user!
# Wall time: 8h 7min 34s

# %% [markdown]
# #### Saving donweep varying readout

# %%
f
# Out:
# array([99900000, 99880000, 99860000, 99840000, 99820000, 99800000,
#        99780000, 99760000, 99740000, 99720000, 99700000, 99680000,
#        99660000, 99640000, 99620000, 99600000, 99580000, 99560000,
#        99540000, 99520000, 99500000, 99480000, 99460000, 99440000,
#        99420000, 99400000, 99380000, 99360000, 99340000, 99320000,
#        99300000, 99280000, 99260000, 99240000, 99220000, 99200000,
#        99180000, 99160000, 99140000, 99120000, 99100000, 99080000,
#        99060000, 99040000, 99020000, 99000000, 98980000, 98960000,
#        98940000, 98920000, 98900000, 98880000, 98860000, 98840000,
#        98820000, 98800000, 98780000, 98760000, 98740000, 98720000,
#        98700000, 98680000, 98660000, 98640000, 98620000, 98600000,
#        98580000, 98560000, 98540000, 98520000, 98500000, 98480000,
#        98460000, 98440000, 98420000, 98400000, 98380000, 98360000,
#        98340000, 98320000, 98300000, 98280000, 98260000, 98240000,
#        98220000, 98200000, 98180000, 98160000, 98140000, 98120000,
#        98100000, 98080000, 98060000, 98040000, 98020000, 98000000,
#        97980000, 97960000, 97940000, 97920000, 97900000, 97880000,
#        97860000, 97840000, 97820000, 97800000, 97780000, 97760000,
#        97740000, 97720000, 97700000, 97680000, 97660000, 97640000,
#        97620000, 97600000, 97580000, 97560000, 97540000, 97520000,
#        97500000, 97480000, 97460000, 97440000, 97420000, 97400000,
#        97380000, 97360000, 97340000, 97320000, 97300000, 97280000,
#        97260000, 97240000, 97220000, 97200000, 97180000, 97160000,
#        97140000, 97120000, 97100000, 97080000, 97060000, 97040000,
#        97020000, 97000000, 96980000, 96960000, 96940000, 96920000,
#        96900000, 96880000, 96860000, 96840000, 96820000, 96800000,
#        96780000, 96760000, 96740000, 96720000, 96700000, 96680000,
#        96660000, 96640000, 96620000, 96600000, 96580000, 96560000,
#        96540000, 96520000, 96500000, 96480000, 96460000, 96440000,
#        96420000, 96400000, 96380000, 96360000, 96340000, 96320000,
#        96300000, 96280000, 96260000, 96240000, 96220000, 96200000,
#        96180000, 96160000, 96140000, 96120000, 96100000, 96080000,
#        96060000, 96040000, 96020000, 96000000, 95980000, 95960000,
#        95940000, 95920000, 95900000, 95880000, 95860000, 95840000,
#        95820000, 95800000, 95780000, 95760000, 95740000, 95720000,
#        95700000, 95680000, 95660000, 95640000, 95620000, 95600000,
#        95580000, 95560000, 95540000, 95520000, 95500000, 95480000,
#        95460000, 95440000, 95420000, 95400000, 95380000, 95360000,
#        95340000, 95320000, 95300000, 95280000, 95260000, 95240000,
#        95220000, 95200000, 95180000, 95160000, 95140000, 95120000,
#        95100000, 95080000, 95060000, 95040000, 95020000, 95000000,
#        94980000, 94960000, 94940000, 94920000, 94900000, 94880000,
#        94860000, 94840000, 94820000, 94800000, 94780000, 94760000,
#        94740000, 94720000, 94700000, 94680000, 94660000, 94640000,
#        94620000, 94600000, 94580000, 94560000, 94540000, 94520000,
#        94500000, 94480000, 94460000, 94440000, 94420000, 94400000,
#        94380000, 94360000, 94340000, 94320000, 94300000, 94280000,
#        94260000, 94240000, 94220000, 94200000, 94180000, 94160000,
#        94140000, 94120000, 94100000, 94080000, 94060000, 94040000,
#        94020000, 94000000, 93980000, 93960000, 93940000, 93920000,
#        93900000, 93880000, 93860000, 93840000, 93820000, 93800000,
#        93780000, 93760000, 93740000, 93720000, 93700000, 93680000,
#        93660000, 93640000, 93620000, 93600000, 93580000, 93560000,
#        93540000, 93520000, 93500000, 93480000, 93460000, 93440000,
#        93420000, 93400000, 93380000, 93360000, 93340000, 93320000,
#        93300000, 93280000, 93260000, 93240000, 93220000, 93200000,
#        93180000, 93160000, 93140000, 93120000, 93100000, 93080000,
#        93060000, 93040000, 93020000, 93000000, 92980000, 92960000,
#        92940000, 92920000], dtype=int64)

# %%
#Saving the data
cooldown_date=Cooldown_Date #top folder 
device="Spectrum_QM" #second folder 
name="Map_downsweep_readout" # third folder 
meastype="run03_4000_part_freq" #Final file name 

datadict={}
#Configuration file copy 
datadict["LO_fluxline"]=LO_fluxline
datadict["LO_readout"]=LO_readout
datadict["octave_gain"]=octave_output_gain

#Saving of parameters 
datadict["n_repetition"]=n_rep
datadict["readout_delay_array"]=readout_delay_array
datadict["amp_factor"]=amp_factor
datadict["Readout_Len"]=Readout_Len
datadict["wait_pump_step"]=wait_pump_step
datadict["IF_pump"]=IF_pump
datadict["IF_right"]=IF_right
datadict["pump_step"]=pump_step

#Saving of data 
datadict["freqs"]=f
datadict["Data"]=Data
datadict["config"]=config

an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)
# Out:
# saving

# %%
#loading 
filepath=r"X:\Users\beaulieu\Data\Run01\131\2023_05_05\Spectrum_QM\Map_downsweep_readout\test.npz"

npzfile=np.load(filepath,allow_pickle=True)
npzfile["multidata"][()]
f=npzfile["multidata"][()]["freqs"]
Data=npzfile["multidata"][()]["Data"]
amp_factor=npzfile["multidata"][()]["amp_factor"]
readout_delay_array=npzfile["multidata"][()]["readout_delay_array"]

# %% [markdown]
# #### Analysis of multiple down sweep

# %%
# %matplotlib inline
idx=0
readout_delay=readout_delay_array[idx]
I=Data[readout_delay]["I"]
Q=Data[readout_delay]["Q"]

I_var=Data[readout_delay]["I_var"]
Q_var=Data[readout_delay]["Q_var"]
var_error=I_var**2+Q_var**2


norm=I**2+Q**2
plt.subplot(111)
plt.cla()
for i in range(norm.shape[0]):
    plt.errorbar(f,norm[i,:],yerr=var_error[i,:],marker=".",label=f'amp={amp_factor[i]:1f}', alpha=.9, lw=.5, ms=8)

plt.xlabel("Pump freq")
plt.ylabel("Amplitudes")
plt.legend()
fig.suptitle("Readout delay :" +str(readout_delay) +" Iteration: "+str(n_rep))
plt.pause(0.1)

# %%
# %matplotlib qt 

#Need to multiply the time by 4 for the clock cycle 
integrate=np.zeros((len(amp_factor),len(readout_delay_array)))

df=f[0]-f[1]

for i in range(len(readout_delay_array)):
    
    #You have a 2d matrix with different amplitudes 
    I=Data[readout_delay_array[i]]["I"] 
    Q=Data[readout_delay_array[i]]["Q"]
    
    norm=I**2+Q**2
    
    for j in range(norm.shape[0]):
        integrate[j,i]=np.trapz(norm[j,:],dx=df)  #sum(norm[j,:]) #np.trapz(norm[j,:],dx=df)
        
fig, ax = plt.subplots(1, 1)
for i in range(integrate.shape[0]):
    ax.plot(readout_delay_array*4+10_000,integrate[i,:],".-",label=f'Pump={amp_factor[i]:.1f}', alpha=.9, lw=.5, ms=8)
 
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_xlabel("Time delay (ns)")
ax.set_ylabel("Integral")
ax.legend()

# %% [markdown]
# # Upsweep

# %% [markdown]
# ## Upsweep single

# %%
Readout_Len=50_000
config,qm=update_readout_lenght(Readout_Len,config,qmm)

twoPhoton_len=10_000
config,qm=update_two_photon_lenght(twoPhoton_len,config,qmm)

amp_factor=0.4

n_repetition=1

IF_pump=99.9e6  #where we go  
IF_left=98.8e6   # whre we start
pump_step=0.2e6

wait_pump_step=400//4 #waiting time after having played the pump 

number_frequency=int(np.ceil((IF_pump-IF_left)/pump_step))

LO_diff=LO_fluxline/2-LO_readout # need to perform this substraction outside of the qua program to avoid having numbers larger than the int allowed 

readout_delay=5000//4 #time delay before making the readout (while pump is still on) 

time_per_iteration=((wait_pump_step+twoPhoton_len+readout_delay*4)*number_frequency)*1e-9
Total_time=time_per_iteration*n_repetition/60
print("Time per iteration : {} s".format(time_per_iteration))
print("Total time : {} min".format(Total_time))
print("Number of frequencies {}".format(number_frequency))
# Out:
# Time per iteration : 9.06e-05 s
# Total time : 1.5100000000000002e-06 min
# Number of frequencies 6

# %%
# %matplotlib qt


with program() as hello_qua:
    
    f = declare(int)
    f_readout= declare(int)
    
    n_rep = declare(int)
    I = declare(fixed)
    Q = declare(fixed)
    
    I_st = declare_stream()
    Q_st = declare_stream()
    n_rep_st=declare_stream()
    f_st = declare_stream() #frequency at which I am measuring 
    
    assign_variables_to_element("resonator", I,Q) 
    

    with for_(n_rep, 0, n_rep < n_repetition, n_rep + 1): 
        
        update_frequency("fluxline", IF_left)
        play("pumping"*amp(amp_factor), "fluxline") #play a first pump to define the initial frequency and amplitude factor

        with for_(f, IF_left, f<IF_pump, f+pump_step):

            assign(f_readout,LO_diff+f/2) #update the readout frequency 
            update_frequency("resonator",f_readout) # Change the IF frequency of the resonator to demodulate more precisely 

            update_frequency("fluxline", f, keep_phase=True)


            play("pumping"*amp(0), "fluxline")


            wait(readout_delay)
    
        #Continously measure in paralell
            measure(
                "fake_readout",
                "resonator",
                None,
                dual_demod.full("cos", "out1", "sin", "out2", I),
                dual_demod.full("minus_sin", "out1", "cos", "out2", Q),
            )

            wait(wait_pump_step, "fluxline") #time that will be waited after playing the pump 

            assign(I,Math.abs(I))
            assign(Q,Math.abs(Q))

            save(I, I_st)
            save(Q, Q_st)  
            save(f, f_st)

        ramp_to_zero("fluxline")

        save(n_rep, n_rep_st)   

    with stream_processing():
        I_st.buffer(number_frequency).average().save("I")
        Q_st.buffer(number_frequency).average().save("Q")
        f_st.buffer(number_frequency).save("f")
        n_rep_st.save("n_rep")
    
    

simulation = True    

if simulation:
    simulation_config = SimulationConfig(
        duration=50000, simulation_interface=LoopbackInterface([("con1", 3, "con1", 1)])
    )

    job = qmm.simulate(config, hello_qua, simulation_config)
    job.get_simulated_samples().con1.plot(analog_ports={'1','2','3','4' },digital_ports={'3',"1"})
    
    # Get the frequency map 
    sample=job.get_simulated_samples()
    x=sample.con1.analog["4"] # get analog 4
    NFFT = 2**10
    Fs = 1e9
    fig = plt.figure()
    ax1 = plt.subplot(111)
    Pxx, freqs, bins, im = plt.specgram(x, NFFT=NFFT, Fs=Fs, noverlap=100, cmap=plt.cm.gist_heat)
    plt.show()
    ax1.set_xticklabels((ax1.get_xticks() * 1e6).astype(int))
    #ax1.set_yticklabels((ax1.get_yticks() / 1e6).astype(int))
    plt.xlabel("t [us]")
    plt.ylabel("f [MHz]")

else:
    job = qm.execute(hello_qua)
    results = fetching_tool(job, data_list=["I","Q","f","n_rep"], mode="live")

    fig = plt.figure()
    interrupt_on_close(fig, job)  #  Interrupts the job when closing the figure

    while results.is_processing():
        
        I,Q,f, n_rep = results.fetch_all()

        Id = u.demod2volts(I, Readout_Len) ## that is why i want to demodulate .... diviser par la duree du pulse Readout_lEN 
        Qd = u.demod2volts(Q, Readout_Len)
        
        plt.subplot(111)
        fig.suptitle(str(n_rep))
        plt.cla()
        plt.plot(f,np.sqrt(Id**2+Qd**2),".", markersize=2)
        plt.xlabel("Nb points")
        plt.ylabel("phase")
        plt.pause(0.1)
# Out:
# 2023-05-10 10:28:33,176 - qm - INFO - Flags:
# 2023-05-10 10:28:33,176 - qm - INFO - Simulating program
# C:\Users\HQClabo\Anaconda3\envs\Labber\lib\site-packages\ipykernel_launcher.py:88: UserWarning: FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# ## Up sweep map

# %%
# %matplotlib qt
Readout_Len=10_000
config,qm=update_readout_lenght(Readout_Len,config,qmm)

twoPhoton_len=10_000
config,qm=update_two_photon_lenght(twoPhoton_len,config,qmm)

a_min=0.3
a_max=1.65
da=0.01
amp_factor=np.arange(a_min,a_max,da)

n_repetition=5_000

IF_pump=99.9e6  #where we go  
IF_left=99e6   # whre we start
pump_step=0.02e6

wait_pump_step=16//4 #waiting time after having played the pump 

number_frequency=int(np.ceil((IF_pump-IF_left)/pump_step))

LO_diff=LO_fluxline/2-LO_readout # need to perform this substraction outside of the qua program to avoid having numbers larger than the int allowed 

time_per_iteration=((wait_pump_step+twoPhoton_len)*number_frequency)*1e-9
Total_time=time_per_iteration*n_repetition*len(amp_factor)/60
print("Time per iteration : {} s".format(time_per_iteration))
print("Total time : {} min".format(Total_time))
# Out:
# Execution stopped by user!
# Time per iteration : 0.00045018 s
# Total time : 5.064525000000001 min

# %%
with program() as hello_qua:
    
    f = declare(int)
    f_readout= declare(int)
    
    n_rep = declare(int)
    I = declare(fixed)
    Q = declare(fixed)
    a= declare(fixed)
    I_st = declare_stream()
    Q_st = declare_stream()
    n_rep_st=declare_stream()
    f_st = declare_stream() #frequency at which I am measuring 
    
    assign_variables_to_element("resonator", I,Q) 
    
    # Averaging loop  
    with for_(n_rep, 0, n_rep < n_repetition, n_rep + 1): 
        
        #loop over amplitude 
        with for_(*from_array(a, amp_factor)):
        
            #Play the first pulse of the sticky to set the pump frequency and the amplitude 
            update_frequency("fluxline", IF_left)
            play("pumping"*amp(a), "fluxline") 

            #loop over frequencies  
            with for_(f, IF_left, f<IF_pump, f+pump_step):

                assign(f_readout,LO_diff+f/2) #update the readout frequency 
                update_frequency("resonator",f_readout) # Change the IF frequency of the resonator to demodulate more precisely 

                #update the sticky 
                update_frequency("fluxline", f, keep_phase=True)
                play("pumping"*amp(0), "fluxline")

            #Continously measure in paralell
                measure(
                    "fake_readout",
                    "resonator",
                    None,
                    dual_demod.full("cos", "out1", "sin", "out2", I),
                    dual_demod.full("minus_sin", "out1", "cos", "out2", Q),
                )

                wait(wait_pump_step, "fluxline") #time that will be waited after playing the pump 

                #Take absolute value of I and Q
                assign(I,Math.abs(I))
                assign(Q,Math.abs(Q))

                save(I, I_st)
                save(Q, Q_st)  
                save(f, f_st)

            #ramp to zero 
            ramp_to_zero("fluxline")

        save(n_rep, n_rep_st)   

    with stream_processing():
        I_st.buffer(number_frequency).buffer(len(amp_factor)).average().save_all("I")
        Q_st.buffer(number_frequency).buffer(len(amp_factor)).average().save_all("Q")
        f_st.buffer(number_frequency).save("f")
        n_rep_st.save("n_rep")
    
    

simulation = False     

if simulation:
    simulation_config = SimulationConfig(
        duration=50000, simulation_interface=LoopbackInterface([("con1", 3, "con1", 1)])
    )

    job = qmm.simulate(config, hello_qua, simulation_config)
    job.get_simulated_samples().con1.plot(analog_ports={'1','2','3','4' },digital_ports={'3'})
    
    # Get the frequency map 
    sample=job.get_simulated_samples()
    x=sample.con1.analog["4"] # get analog 4
    NFFT = 2**10
    Fs = 1e9
    fig = plt.figure()
    ax1 = plt.subplot(111)
    Pxx, freqs, bins, im = plt.specgram(x, NFFT=NFFT, Fs=Fs, noverlap=100, cmap=plt.cm.gist_heat)
    plt.show()
    ax1.set_xticklabels((ax1.get_xticks() * 1e6).astype(int))
    #ax1.set_yticklabels((ax1.get_yticks() / 1e6).astype(int))
    plt.xlabel("t [us]")
    plt.ylabel("f [MHz]")

else:
    job = qm.execute(hello_qua)
    results = fetching_tool(job, data_list=["I","Q","f","n_rep"], mode="live")

    fig = plt.figure()
    interrupt_on_close(fig, job)  #  Interrupts the job when closing the figure

    while results.is_processing():
        
       

        I,Q,f, n_rep = results.fetch_all()

        I = u.demod2volts(I, Readout_Len) ## that is why i want to demodulate .... diviser par la duree du pulse Readout_lEN 
        Q = u.demod2volts(Q, Readout_Len)
        
        #transpose the element 
        I_mat = np.transpose(I,(1, 2, 0))


        Q_mat = np.transpose(Q,(1, 2, 0))


        #take the average 
        I_av=np.mean(I_mat,axis=2)
        Q_av=np.mean(Q_mat,axis=2)

        #variance :
        I_var=np.var(I_mat, axis=2)
        Q_var=np.var(Q_mat,axis=2)


        norm=I_av**2+Q_av**2
        
        plt.subplot(111)
        fig.suptitle(str(n_rep))
        plt.cla()
        plt.pcolor(f / u.MHz, amp_factor, norm*1e6)
       # plt.plot(f/1e6,np.sqrt(Id**2+Qd**2)*1e3,".", markersize=2)
        plt.xlabel("Pump frequency [MHz]")
        plt.ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")
        plt.pause(0.1)
        
     #take the average 
    I_av=np.mean(I_mat,axis=2)
    Q_av=np.mean(Q_mat,axis=2)

    #variance :
    I_var=np.var(I_mat, axis=2)
    Q_var=np.var(Q_mat,axis=2)
# Out:
# 2023-06-21 10:17:42,471 - qm - INFO - Flags:
# 2023-06-21 10:17:42,472 - qm - INFO - Sending program to QOP
# 2023-06-21 10:17:43,372 - qm - INFO - Executing program
# Execution stopped by user!

# %%
# %matplotlib inline
plt.clf()
fig, ax = plt.subplots(1, 1)

ax.set_title("Up sweep")
c=ax.pcolor(f / u.MHz, amp_factor, np.sqrt(I**2+Q**2)*1e3) # What is shown is normalized by dividing by the amplitude 
ax.set_xlabel("Frequency [MHz]")
ax.set_ylabel("Amplitude factor")
fig.colorbar(c,ax=ax, label="Amplitude [mv]")

# %% [markdown]
# ### Saving upsweep

# %%
#Saving the data
cooldown_date=Cooldown_Date #top folder 
device="Spectrum_QM" #second folder 
name="Map_upsweep" # third folder 
meastype="21_06_2023_larger_10_000_2_000_avg" #Final file name 

datadict={}
#Configuration file copy 
datadict["LO_fluxline"]=LO_fluxline
datadict["IF_fluxline"]=IF_pump
datadict["LO_readout"]=LO_readout
datadict["octave_gain"]=octave_output_gain

#Saving of parameters 
datadict["n_repetition"]=n_rep
datadict["amp_factor"]=amp_factor
datadict["Readout_Len"]=Readout_Len
datadict["wait_pump_step"]=wait_pump_step
datadict["IF_pump"]=IF_pump
datadict["IF_left"]=IF_left
datadict["pump_step"]=pump_step

#Saving of data 
datadict["freqs"]=f
datadict["I"]=I_av
datadict["Q"]=Q_av
datadict["I_mat"]=I_mat
datadict["Q_mat"]=Q_mat
datadict["I_var"]=I_var
datadict["Q_var"]=Q_var
datadict["config"]=config

an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)
# Out:
# saving in new directory

# %%
#loading 
filepath=r"Z:\Users\beaulieu\Data\Run01\104\2023_04_14\Spectrum_QM\Map_upsweep\upsweep_pip6.npz"

npzfile=np.load(filepath,allow_pickle=True)
npzfile["multidata"][()]
f=npzfile["multidata"][()]["freqs"]
I=npzfile["multidata"][()]["I"]
Q=npzfile["multidata"][()]["Q"]
amp_factor=npzfile["multidata"][()]["amp_factor"]

# %% [markdown]
# ## Upsweep varying readout

# %% [markdown]
# ### Single Readout delay, multiple amplitudes

# %%
#Set the readout length and photon length 
Readout_Len=10_000
config,qm=update_readout_lenght(Readout_Len,config,qmm)

twoPhoton_len=10_000
config,qm=update_two_photon_lenght(twoPhoton_len,config,qmm)

amp_factor=np.array([0.85,0.95,1.05,1.15,1.25])

n_repetition=10_000


IF_pump=99.9e6  #where we go  
IF_left=98.9e6   # whre we start
pump_step=0.02e6

readout_delay=16//4

wait_pump_step=400//4 #w aiting time after having played the pump 

number_frequency=int(np.ceil((IF_pump-IF_left)/pump_step))

LO_diff=LO_fluxline/2-LO_readout # need to perform this substraction outside of the qua program to avoid having numbers larger than the int allowed 

time_per_iteration=((wait_pump_step+twoPhoton_len+readout_delay*4)*number_frequency)*1e-9
Total_time=time_per_iteration*n_repetition*len(amp_factor)/60
print("Time per iteration : {} s".format(time_per_iteration))
print("Total time : {} min".format(Total_time))
amp_factor_list=amp_factor.tolist() #convert as a list to use for_each in qm
# Out:
# Time per iteration : 0.0005058 s
# Total time : 0.6744000000000001 min

# %%
# %matplotlib qt


with program() as hello_qua:
    
    f = declare(int)
    f_readout= declare(int)
    
    n_rep = declare(int)
    I = declare(fixed)
    Q = declare(fixed)
    a= declare(fixed)
    I_st = declare_stream()
    Q_st = declare_stream()
    n_rep_st=declare_stream()
    f_st = declare_stream() #frequency at which I am measuring 
    
    assign_variables_to_element("resonator", I,Q) 
    
    # Averaging loop  
    with for_(n_rep, 0, n_rep < n_repetition, n_rep + 1): 
        
        #loop over amplitude 
        with for_each_(a, amp_factor_list):
        
            #Play the first pulse of the sticky to set the pump frequency and the amplitude 
            update_frequency("fluxline", IF_right)
            play("pumping"*amp(a), "fluxline") 

            #loop over frequencies  
            with for_(f, IF_left, f<IF_pump, f+pump_step):

                assign(f_readout,LO_diff+f/2) #update the readout frequency 
                update_frequency("resonator",f_readout) # Change the IF frequency of the resonator to demodulate more precisely 

                #update the sticky 
                update_frequency("fluxline", f, keep_phase=True)
                play("pumping"*amp(0), "fluxline")
                
                wait(readout_delay)

            #Continously measure in paralell
                measure(
                    "fake_readout",
                    "resonator",
                    None,
                    dual_demod.full("cos", "out1", "sin", "out2", I),
                    dual_demod.full("minus_sin", "out1", "cos", "out2", Q),
                )

                wait(wait_pump_step, "fluxline") #time that will be waited after playing the pump 

                #Take absolute value of I and Q
                assign(I,Math.abs(I))
                assign(Q,Math.abs(Q))

                save(I, I_st)
                save(Q, Q_st)  
                save(f, f_st)

            #ramp to zero 
            ramp_to_zero("fluxline")

        save(n_rep, n_rep_st)   

    with stream_processing():
        I_st.buffer(number_frequency).buffer(len(amp_factor)).average().save("I")
        Q_st.buffer(number_frequency).buffer(len(amp_factor)).average().save("Q")
        f_st.buffer(number_frequency).save("f")
        n_rep_st.save("n_rep")
    
    

simulation = False     

if simulation:
    simulation_config = SimulationConfig(
        duration=50000, simulation_interface=LoopbackInterface([("con1", 3, "con1", 1)])
    )

    job = qmm.simulate(config, hello_qua, simulation_config)
    job.get_simulated_samples().con1.plot(analog_ports={'1','2','3','4' },digital_ports={'3'})
    
    # Get the frequency map 
    sample=job.get_simulated_samples()
    x=sample.con1.analog["4"] # get analog 4
    NFFT = 2**10
    Fs = 1e9
    fig = plt.figure()
    ax1 = plt.subplot(111)
    Pxx, freqs, bins, im = plt.specgram(x, NFFT=NFFT, Fs=Fs, noverlap=100, cmap=plt.cm.gist_heat)
    plt.show()
    ax1.set_xticklabels((ax1.get_xticks() * 1e6).astype(int))
    #ax1.set_yticklabels((ax1.get_yticks() / 1e6).astype(int))
    plt.xlabel("t [us]")
    plt.ylabel("f [MHz]")

else:
    job = qm.execute(hello_qua)
    results = fetching_tool(job, data_list=["I","Q","f","n_rep"], mode="live")

    fig = plt.figure()
    interrupt_on_close(fig, job)  #  Interrupts the job when closing the figure

    while results.is_processing():
        
        I,Q,f, n_rep = results.fetch_all()

        I = u.demod2volts(I, Readout_Len) ## that is why i want to demodulate .... diviser par la duree du pulse Readout_lEN 
        Q = u.demod2volts(Q, Readout_Len)
        
        norm=np.sqrt(I**2+Q**2)
        
        plt.subplot(111)
        plt.cla()
        for i in range(norm.shape[0]):
            plt.plot(f,norm[i,:],'.-',label=f'amp={amp_factor[i]:1f}', alpha=.9, lw=.5, ms=8)

        plt.xlabel("Pump freq")
        plt.ylabel("Amplitudes")
        plt.legend()
        fig.suptitle(str(n_rep))
        
        plt.pause(0.1)
# Out:
# 2023-05-10 10:43:40,456 - qm - INFO - Flags:
# 2023-05-10 10:43:40,457 - qm - INFO - Sending program to QOP
# 2023-05-10 10:43:40,766 - qm - INFO - Executing program
# Execution stopped by user!

# %% [markdown]
# #### Saving single readout delay

# %%
#Saving the data
coreadout_delay_date=Cooldown_Date #top folder 
device="Spectrum_QM" #second folder 
name="cuts_upsweep" # third folder 
meastype="cut_downsweep_pi6_large_500micros_delay" #Final file name 

datadict={}
#Configuration file copy 
datadict["LO_fluxline"]=LO_fluxline
datadict["octave_gain"]=octave_output_gain

#Saving of parameters 
datadict["n_repetition"]=n_rep
datadict["readout_delay"]=readout_delay
datadict["amp_factor"]=amp_factor
datadict["Readout_Len"]=Readout_Len
datadict["wait_pump_step"]=wait_pump_step
datadict["IF_pump"]=IF_pump
datadict["IF_left"]=IF_left
datadict["pump_step"]=pump_step

#Saving of data 
datadict["freqs"]=f
datadict["I"]=I
datadict["Q"]=Q
datadict["config"]=config

an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)

# %%
#loading 
filepath=r"Z:\Users\beaulieu\Data\Run01\104\2023_04_14\Spectrum_QM\Map_downsweep\downsweep_pi6_large_0_delay.npz"

npzfile=np.load(filepath,allow_pickle=True)
npzfile["multidata"][()]
f=npzfile["multidata"][()]["freqs"]
I=npzfile["multidata"][()]["I"]
Q=npzfile["multidata"][()]["Q"]
amp_factor=npzfile["multidata"][()]["amp_factor"]

# %% [markdown]
# ### Multiple readout delay

# %%
((np.geomspace(1000,500_00_000,num=30,endpoint=True)[25:30]-10_000)//4*4)
# Out:
# array([11231808., 16315616., 23698444., 34419960., 49990000.])

# %%
# %matplotlib qt
#Set the readout length and photon length 
Readout_Len=10_000
config,qm=update_readout_lenght(Readout_Len,config,qmm)

twoPhoton_len=1_000
config,qm=update_two_photon_lenght(twoPhoton_len,config,qmm)


amp_factor=np.array([0.85,0.95,1.05,1.15,1.25,1.35])

n_repetition=4000

IF_pump= 99.92e6  #where we go  
IF_left=  92.92e6  #99e6   # whre we start
pump_step=0.02e6


delay_array=np.concatenate(  (((np.geomspace(10016,92440,num=20,endpoint=True))//4*4), ((np.geomspace(10016,1e6,num=30,endpoint=True))//4*4)[15::2]))

readout_delay_array=(delay_array-10_000)//4
readout_delay_array=readout_delay_array.astype(int)

wait_pump_step=16//4 #w aiting time after having played the pump 
number_frequency=int(np.ceil((IF_pump-IF_left)/pump_step))

LO_diff=LO_fluxline/2-LO_readout # need to perform this substraction outside of the qua program to avoid having numbers larger than the int allowed 

time_array=[]
for i in range(len(readout_delay_array)):
    readout_delay=readout_delay_array[i]
    time_array.append(((wait_pump_step+Readout_Len+readout_delay*4)*1e-9*number_frequency*n_repetition*len(amp_factor))/60)
    
print("expected time : {}".format(sum(time_array)))
amp_factor_list=amp_factor.tolist() #convert as a list to use for_each in qm 

readout_delay_array*4+10_000

time_array
readout_delay_array
# Out:
# expected time : 580.01216
# array([     4,    314,    663,   1056,   1497,   1993,   2551,   3178,
#          3882,   4674,   5565,   6565,   7690,   8955,  10376,  11974,
#         13770,  15789,  18058,  20610,  24586,  34708,  48612,  67711,
#         93947, 129987, 179493, 247500])

# %%
# %%time

Data={} #dictionnary to hold all the data 
for i in range(len(readout_delay_array)):
    
    readout_delay=readout_delay_array[i]
    Data[readout_delay]={} 
    
    with program() as hello_qua:

        f = declare(int)
        f_readout= declare(int)

        n_rep = declare(int)
        I = declare(fixed)
        Q = declare(fixed)
        a= declare(fixed)
        I_st = declare_stream()
        Q_st = declare_stream()
        n_rep_st=declare_stream()
        f_st = declare_stream() #frequency at which I am measuring 

        assign_variables_to_element("resonator", I,Q) 

        # Averaging loop  
        with for_(n_rep, 0, n_rep < n_repetition, n_rep + 1): 

            #loop over amplitude 
            with for_each_(a, amp_factor_list):

                #Play the first pulse of the sticky to set the pump frequency and the amplitude 
                update_frequency("fluxline", IF_left)
                play("pumping"*amp(a), "fluxline") 

                #loop over frequencies  
                #loop over frequencies  
                with for_(f, IF_left, f<IF_pump, f+pump_step):

                    assign(f_readout,LO_diff+f/2) #update the readout frequency 
                    update_frequency("resonator",f_readout) # Change the IF frequency of the resonator to demodulate more precisely 

                    #update the sticky 
                    update_frequency("fluxline", f, keep_phase=True)
                    play("pumping"*amp(0), "fluxline")

                    wait(readout_delay)

                #Continously measure in paralell
                    measure(
                        "fake_readout",
                        "resonator",
                        None,
                        dual_demod.full("cos", "out1", "sin", "out2", I),
                        dual_demod.full("minus_sin", "out1", "cos", "out2", Q),
                    )

                    wait(wait_pump_step, "fluxline") #time that will be waited after playing the pump 

                    #Take absolute value of I and Q
                    assign(I,Math.abs(I))
                    assign(Q,Math.abs(Q))

                    save(I, I_st)
                    save(Q, Q_st)  
                    save(f, f_st)

                #ramp to zero 
                ramp_to_zero("fluxline")

            save(n_rep, n_rep_st)   

        with stream_processing():
            I_st.buffer(number_frequency).buffer(len(amp_factor)).save_all("I")
            Q_st.buffer(number_frequency).buffer(len(amp_factor)).save_all("Q")
            #I_st.buffer(number_frequency).buffer(len(amp_factor)).average().save("I")
            #Q_st.buffer(number_frequency).buffer(len(amp_factor)).average().save("Q")
            f_st.buffer(number_frequency).save("f")
            n_rep_st.save("n_rep")



    simulation = False     

    if simulation:
        simulation_config = SimulationConfig(
            duration=50000, simulation_interface=LoopbackInterface([("con1", 3, "con1", 1)])
        )

        job = qmm.simulate(config, hello_qua, simulation_config)
        job.get_simulated_samples().con1.plot(analog_ports={'1','2','3','4' },digital_ports={'3'})

        # Get the frequency map 
        sample=job.get_simulated_samples()
        x=sample.con1.analog["4"] # get analog 4
        NFFT = 2**10
        Fs = 1e9
        fig = plt.figure()
        ax1 = plt.subplot(111)
        Pxx, freqs, bins, im = plt.specgram(x, NFFT=NFFT, Fs=Fs, noverlap=100, cmap=plt.cm.gist_heat)
        plt.show()
        ax1.set_xticklabels((ax1.get_xticks() * 1e6).astype(int))
        #ax1.set_yticklabels((ax1.get_yticks() / 1e6).astype(int))
        plt.xlabel("t [us]")
        plt.ylabel("f [MHz]")

    else:
        job = qm.execute(hello_qua)
        results = fetching_tool(job, data_list=["I","Q","f","n_rep"], mode="live")

        fig = plt.figure()
        interrupt_on_close(fig, job)  #  Interrupts the job when closing the figure

        while results.is_processing():

            I,Q,f, n_rep = results.fetch_all()

            I = u.demod2volts(I, Readout_Len) ## that is why i want to demodulate .... diviser par la duree du pulse Readout_lEN 
            Q = u.demod2volts(Q, Readout_Len)
            
            
            #transpose the element 
            I_mat = np.transpose(I,(1, 2, 0))
            
            
            Q_mat = np.transpose(Q,(1, 2, 0))
            
            
            #take the average 
            I_av=np.mean(I_mat,axis=2)
            Q_av=np.mean(Q_mat,axis=2)
            
            #variance :
            I_var=np.var(I_mat, axis=2)
            Q_var=np.var(Q_mat,axis=2)
            
 
            
            
            norm=I_av**2+Q_av**2

            plt.subplot(111)
            plt.cla()
            for i in range(norm.shape[0]):
                plt.plot(f,norm[i,:],'.-',label=f'amp={amp_factor[i]:1f}', alpha=.9, lw=.5, ms=8)

            plt.xlabel("Pump freq")
            plt.ylabel("Amplitudes")
            plt.legend()
            fig.suptitle("Readout delay :" +str(readout_delay) +" Iteration: "+str(n_rep))
            plt.pause(0.1)
            
    #take the average 
    I_av=np.mean(I_mat,axis=2)
    Q_av=np.mean(Q_mat,axis=2)

    #variance :
    I_var=np.var(I_mat, axis=2)
    Q_var=np.var(Q_mat,axis=2)
            
    Data[readout_delay]["I_mat"]=I_mat
    Data[readout_delay]["Q_mat"]=Q_mat      
    Data[readout_delay]["I"]=I_av
    Data[readout_delay]["Q"]=Q_av
    Data[readout_delay]["I_var"]=I_var
    Data[readout_delay]["Q_var"]=Q_var
        
    plt.close()
# Out:
# 2023-05-31 08:07:09,993 - qm - INFO - Flags:
# 2023-05-31 08:07:09,994 - qm - INFO - Sending program to QOP
# 2023-05-31 08:07:10,271 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 08:08:29,141 - qm - INFO - Flags:
# 2023-05-31 08:08:29,142 - qm - INFO - Sending program to QOP
# 2023-05-31 08:08:29,782 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 08:09:57,050 - qm - INFO - Flags:
# 2023-05-31 08:09:57,051 - qm - INFO - Sending program to QOP
# 2023-05-31 08:09:57,683 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 08:11:34,900 - qm - INFO - Flags:
# 2023-05-31 08:11:34,900 - qm - INFO - Sending program to QOP
# 2023-05-31 08:11:35,166 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 08:13:24,238 - qm - INFO - Flags:
# 2023-05-31 08:13:24,239 - qm - INFO - Sending program to QOP
# 2023-05-31 08:13:24,501 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 08:15:25,217 - qm - INFO - Flags:
# 2023-05-31 08:15:25,217 - qm - INFO - Sending program to QOP
# 2023-05-31 08:15:25,819 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 08:17:39,401 - qm - INFO - Flags:
# 2023-05-31 08:17:39,402 - qm - INFO - Sending program to QOP
# 2023-05-31 08:17:39,665 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 08:20:09,652 - qm - INFO - Flags:
# 2023-05-31 08:20:09,653 - qm - INFO - Sending program to QOP
# 2023-05-31 08:20:10,274 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 08:22:57,369 - qm - INFO - Flags:
# 2023-05-31 08:22:57,370 - qm - INFO - Sending program to QOP
# 2023-05-31 08:22:57,637 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 08:26:05,442 - qm - INFO - Flags:
# 2023-05-31 08:26:05,442 - qm - INFO - Sending program to QOP
# 2023-05-31 08:26:05,706 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 08:29:35,329 - qm - INFO - Flags:
# 2023-05-31 08:29:35,329 - qm - INFO - Sending program to QOP
# 2023-05-31 08:29:35,940 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 08:33:30,525 - qm - INFO - Flags:
# 2023-05-31 08:33:30,526 - qm - INFO - Sending program to QOP
# 2023-05-31 08:33:30,806 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 08:37:52,669 - qm - INFO - Flags:
# 2023-05-31 08:37:52,669 - qm - INFO - Sending program to QOP
# 2023-05-31 08:37:52,940 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 08:42:46,387 - qm - INFO - Flags:
# 2023-05-31 08:42:46,388 - qm - INFO - Sending program to QOP
# 2023-05-31 08:42:47,071 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 08:48:15,259 - qm - INFO - Flags:
# 2023-05-31 08:48:15,259 - qm - INFO - Sending program to QOP
# 2023-05-31 08:48:15,535 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 08:54:25,493 - qm - INFO - Flags:
# 2023-05-31 08:54:25,493 - qm - INFO - Sending program to QOP
# 2023-05-31 08:54:25,783 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 09:01:19,629 - qm - INFO - Flags:
# 2023-05-31 09:01:19,629 - qm - INFO - Sending program to QOP
# 2023-05-31 09:01:20,275 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 09:09:03,666 - qm - INFO - Flags:
# 2023-05-31 09:09:03,667 - qm - INFO - Sending program to QOP
# 2023-05-31 09:09:03,934 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 09:17:44,830 - qm - INFO - Flags:
# 2023-05-31 09:17:44,831 - qm - INFO - Sending program to QOP
# 2023-05-31 09:17:45,087 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 09:27:28,702 - qm - INFO - Flags:
# 2023-05-31 09:27:28,703 - qm - INFO - Sending program to QOP
# 2023-05-31 09:27:28,959 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 09:38:24,598 - qm - INFO - Flags:
# 2023-05-31 09:38:24,598 - qm - INFO - Sending program to QOP
# 2023-05-31 09:38:24,884 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 09:51:12,755 - qm - INFO - Flags:
# 2023-05-31 09:51:12,756 - qm - INFO - Sending program to QOP
# 2023-05-31 09:51:13,019 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 10:08:43,478 - qm - INFO - Flags:
# 2023-05-31 10:08:43,478 - qm - INFO - Sending program to QOP
# 2023-05-31 10:08:43,748 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 10:32:43,383 - qm - INFO - Flags:
# 2023-05-31 10:32:43,384 - qm - INFO - Sending program to QOP
# 2023-05-31 10:32:44,060 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 11:05:38,266 - qm - INFO - Flags:
# 2023-05-31 11:05:38,267 - qm - INFO - Sending program to QOP
# 2023-05-31 11:05:38,549 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 11:50:47,423 - qm - INFO - Flags:
# 2023-05-31 11:50:47,423 - qm - INFO - Sending program to QOP
# 2023-05-31 11:50:48,137 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 12:52:45,479 - qm - INFO - Flags:
# 2023-05-31 12:52:45,480 - qm - INFO - Sending program to QOP
# 2023-05-31 12:52:45,752 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-05-31 14:17:49,690 - qm - INFO - Flags:
# 2023-05-31 14:17:49,691 - qm - INFO - Sending program to QOP
# 2023-05-31 14:17:49,968 - qm - INFO - Executing program
# Execution stopped by user!
# Wall time: 8h 7min 29s

# %% [markdown]
# #### Saving upsweep varying readout

# %%
#Saving the data
cooldown_date=Cooldown_Date #top folder 
device="Spectrum_QM" #second folder 
name="Map_upsweep_readout" # third folder 
meastype="run03_4000_full_freq" #Final file name 

datadict={}
#Configuration file copy 
datadict["LO_fluxline"]=LO_fluxline
datadict["LO_readout"]=LO_readout
datadict["octave_gain"]=octave_output_gain

#Saving of parameters 
datadict["n_repetition"]=n_rep
datadict["readout_delay_array"]=readout_delay_array
datadict["amp_factor"]=amp_factor
datadict["Readout_Len"]=Readout_Len
datadict["wait_pump_step"]=wait_pump_step
datadict["IF_pump"]=IF_pump
datadict["IF_left"]=IF_left
datadict["pump_step"]=pump_step

#Saving of data 
datadict["freqs"]=f
datadict["Data"]=Data
datadict["config"]=config

an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)
# Out:
# saving

# %%
#loading 
filepath=r"\\sb1files\HQC\Users\beaulieu\Data\Run01\104\2023_04_14\vac_to_excit\Single_trace\filename.npz"

npzfile=np.load(filepath,allow_pickle=True)
npzfile["multidata"][()]
f=npzfile["multidata"][()]["freqs"]
Data=npzfile["multidata"][()]["Data"]
amp_factor=npzfile["multidata"][()]["amp_factor"]
readout_delay_array=npzfile["multidata"][()]["readout_delay_array"]

# %% [markdown]
# #### Analysis of multiple upsweep

# %%
plt.plot(Data[4]["I"][0,:]**2+Data[4]["Q"][0,:]**2)

# %%
# %matplotlib inline
idx=0
readout_delay=readout_delay_array[idx]
I=Data[readout_delay]["I"]
Q=Data[readout_delay]["Q"]

I_var=Data[readout_delay]["I_var"]
Q_var=Data[readout_delay]["Q_var"]
var_error=I_var**2+Q_var**2


norm=I**2+Q**2
plt.subplot(111)
plt.cla()
for i in range(norm.shape[0]):
    plt.errorbar(f,norm[i,:],yerr=var_error[i,:],marker=".",label=f'amp={amp_factor[i]:1f}', alpha=.9, lw=.5, ms=8)

plt.xlabel("Pump freq")
plt.ylabel("Amplitudes")
plt.legend()
fig.suptitle("Readout delay :" +str(readout_delay) +" Iteration: "+str(n_rep))
plt.pause(0.1)

# %%
# %matplotlib qt 

#Need to multiply the time by 4 for the clock cycle 
integrate=np.zeros((len(amp_factor),len(readout_delay_array)))

df=f[1]-f[0]

for i in range(len(readout_delay_array)):
    
    #You have a 2d matrix with different amplitudes 
    I=Data[readout_delay_array[i]]["I"] 
    Q=Data[readout_delay_array[i]]["Q"]
    
    norm=I**2+Q**2
    
    for j in range(norm.shape[0]):
        integrate[j,i]=np.trapz(norm[j,:],dx=df)  #sum(norm[j,:]) #np.trapz(norm[j,:],dx=df)
        
fig, ax = plt.subplots(1, 1)
for i in range(integrate.shape[0]):
    ax.plot((readout_delay_array*4+10_000),integrate[i,:],".-",label=f'Pump={amp_factor[i]:.1f}', alpha=.9, lw=.5, ms=8)
 
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_xlabel("Time delay (ns)")
ax.set_ylabel("Integral")
ax.legend()

# %% [markdown]
# # Spectrum Analyzer
#
# Not ready

# %%
# %matplotlib qt
from scipy import signal

n_runs = 1000

cooldown_time = 16000 // 4 # Waiting time before playing the new pulse 

amp_factor=0.4 #amplitude factor 

# Frequency sweep in Hz
span=10 * u.kHz
df = 100 * u.Hz
freqs = np.arange(IF_readout-span, IF_readout+span, df) 

# Resonance frequency 
IF_pump=0.19575e9
IF_resonator=(LO_fluxline+IF_pump)/2-LO_readout #demodulate at half of the pump IF by default 

LO_diff=LO_fluxline/2-LO_readout

i_runs = n_runs * len(freqs)


with program() as IQ_blobs:
    
    n = declare(int)
    i = declare(int)
    I = declare(fixed)
    Q = declare(fixed)
    I_st = declare_stream()
    Q_st = declare_stream()
    f = declare(int)

    # Starts playing on the fluxline 
    with infinite_loop_():
        play("pumping"*amp(amp_factor), 'fluxline_unstick') #Play the pulse on the fluxline  
    
    with for_(n, 0, n < n_runs, n + 1):
        
        #Sweep the domudlation frequency 
        with for_(*from_array(f,freqs)):
            
            #Update the demodulation frequency 
            update_frequency("resonator",IF_resonator+Offset_IF) 
            
            
            update_frequency("resonator",f) #change the demodulation frequency 
            reset_phase("resonator")
            
            #Measure at the output 
            measure(
                "fake_readout",
                "resonator",
                None,
                dual_demod.full("cos", "out1", "sin", "out2", I),
                dual_demod.full("minus_sin", "out1", "cos", "out2", Q),
            )

            save(I, I_st)
            save(Q, Q_st)
            wait(cooldown_time, "resonator")

    with stream_processing():
        I_st.buffer(len(freqs)).average().save("I") #Continously average the different buffers of size len(freqs)
        Q_st.buffer(len(freqs)).average().save("Q")

        
        
simulation = False
if simulation:
    simulation_config = SimulationConfig(
        duration=80000, simulation_interface=LoopbackInterface([("con1", 3, "con1", 1)])
    )
    job = qmm.simulate(config, IQ_blobs, simulation_config)
    job.get_simulated_samples().con1.plot()
    
else:
  

    job = qm.execute(IQ_blobs)
    results = fetching_tool(job, data_list=["I", "Q"], mode="live")
    # Live plotting
    fig = plt.figure()
    interrupt_on_close(fig, job)  #  Interrupts the job when closing the figure
    
    while results.is_processing():
        I, Q = results.fetch_all()
        I = u.demod2volts(I, pulse_len)
        Q = u.demod2volts(Q, pulse_len)

        #plt.subplot(211)
        
        plt.title("IQ blobs")
        plt.subplot(211)
        plt.cla()
        plt.plot(freqs-IF_readout, np.sqrt(Q**2+I**2), "-", markersize=2) #Plot the power vs IF frequency readout 
        plt.xlabel("freqs")
        plt.ylabel("Power")
        plt.subplot(212)
        plt.cla()
        plt.plot(freqs-IF_readout, signal.detrend(np.unwrap(np.angle(I+1j*Q))), "-", markersize=2) #plot the phase 
        plt.pause(0.1)
        #plt.axis("equal")
        #job.halt()

# %% [markdown]
# # Previous

# %%
# %matplotlib qt


Readout_Len=1_000_000
config,qm=update_readout_lenght(Readout_Len,config,qmm)

twoPhoton_len=1_000_000
config,qm=update_two_photon_lenght(twoPhoton_len,config,qmm)


# Test sticky

amp_factor=0.3
freqs_array=np.array([[ 0.1950e9]]) # defines the IF of the pump  0.19565
IF_pump=freqs_array[0,0] #select the desired pump frequency 


IF_pump=191.5e6 
IF_right=197.5e6 # Pump IF very much on the right 
pump_step=0.0357e6
wait_pump_step=400//4 #waiting time after having played the pump 


LO_diff=LO_fluxline/2-LO_readout # need to perform this substraction outside of the qua program to avoid having numbers larger than the int allowed 


with program() as hello_qua:
    
    f = declare(int)
    f_readout= declare(int)
    
    I = declare(fixed)
    Q = declare(fixed)
    
    I_st = declare_stream()
    Q_st = declare_stream()
    f_st = declare_stream() #frequency at which I am measuring 
    
    assign_variables_to_element("resonator", I,Q) 
    
    update_frequency("fluxline", IF_right)
    play("pumping"*amp(amp_factor), "fluxline") #play a first pump to define the initial frequency and amplitude factor
   
    with for_(f, IF_right, f>IF_pump, f-pump_step):
        
        assign(f_readout,LO_diff+f/2) #update the readout frequency 
        update_frequency("resonator",f_readout) # Change the IF frequency of the resonator to demodulate more precisely 
  
        update_frequency("fluxline", f, keep_phase=True)
        
        
        play("pumping"*amp(0), "fluxline")
        
        
    #Continously measure in paralell
        measure(
            "fake_readout",
            "resonator",
            None,
            dual_demod.full("cos", "out1", "sin", "out2", I),
            dual_demod.full("minus_sin", "out1", "cos", "out2", Q),
        )

        wait(wait_pump_step, "fluxline") #time that will be waited after playing the pump 
        
        
        save(I, I_st)
        save(Q, Q_st)
        save(f, f_st)
       
    ramp_to_zero("fluxline")


    with stream_processing():
        I_st.save_all("I")
        Q_st.save_all("Q")
        f_st.save_all("f")

    
    

simulation = False     

if simulation:
    simulation_config = SimulationConfig(
        duration=50000, simulation_interface=LoopbackInterface([("con1", 3, "con1", 1)])
    )

    job = qmm.simulate(config, hello_qua, simulation_config)
    job.get_simulated_samples().con1.plot(analog_ports={'1','2','3','4' },digital_ports={'3'})
    
    # Get the frequency map 
    sample=job.get_simulated_samples()
    x=sample.con1.analog["4"] # get analog 4
    NFFT = 2**10
    Fs = 1e9
    fig = plt.figure()
    ax1 = plt.subplot(111)
    Pxx, freqs, bins, im = plt.specgram(x, NFFT=NFFT, Fs=Fs, noverlap=100, cmap=plt.cm.gist_heat)
    plt.show()
    ax1.set_xticklabels((ax1.get_xticks() * 1e6).astype(int))
    #ax1.set_yticklabels((ax1.get_yticks() / 1e6).astype(int))
    plt.xlabel("t [us]")
    plt.ylabel("f [MHz]")

else:
    job = qm.execute(hello_qua)
    results = fetching_tool(job, data_list=["I", "Q","f"], mode="live")

    fig = plt.figure()
    interrupt_on_close(fig, job)  #  Interrupts the job when closing the figure

    while results.is_processing():
        
        I, Q,f = results.fetch_all()

        Id = u.demod2volts(I, Readout_Len) #diviser par la duree du pulse Readout_lEN 
        Qd = u.demod2volts(Q, Readout_Len)
        
        plt.subplot(111)
        #fig.suptitle("IF_pump "+str(IF_pump)+" ite :"+str(n_rep))
        plt.cla()
        plt.plot(f,np.sqrt(Id**2+Qd**2),".", markersize=2)
        plt.xlabel("Nb points")
        plt.ylabel("phase")
        plt.pause(0.1)
# Out:
# Execution stopped by user!
# 2023-04-25 19:38:29,486 - qm - INFO - Flags:
# 2023-04-25 19:38:29,487 - qm - INFO - Sending program to QOP
# 2023-04-25 19:38:44,820 - qm - INFO - Executing program

# %%
len(Id)
IF_pump=191.5e6 
IF_right=197.5e6 # Pump IF very much on the right 
pump_step=0.0357e6

int(np.ceil((IF_right-IF_pump)/pump_step))
# Out:
# 169

# %%
len(Id)
# Out:
# 169

# %%
# %matplotlib qt

Readout_Len=5_000
config,qm=update_readout_lenght(Readout_Len,config,qmm)


amp_factor_array=np.array([0.3]) #Prefactor of the amplitude 
amp_factor=amp_factor_array[0]

amp_factor_high_array=np.array([1.0]) #Prefactor of the amplitude 
amp_factor_high=amp_factor_high_array[0]


#Update the pump IF frequency 
freqs_array=np.array([[ 0.1950e9]]) # defines the IF of the pump  0.19565
IF_pump=freqs_array[0,0] #select the frequency from the array 
IF_resonator=(LO_fluxline+IF_pump)/2-LO_readout #demodulate at half of the pump IF by default 

n_repetition=2 #number of repetitions 

n_empty=3#number of vaccum readout to do 
Pump_Delay = n_empty*(Readout_Len+300)//4  #time for the pump to be on low amp 
n_full=4 #number of pump on readout to do 
n_runs=n_empty+n_full # Total number of readout to do 

cooldown_time=10_000//4 #cooldown time before each repetition to go back to vacuum  #cooldown time before each repetition to go back to vacuum 
Offset_IF=0  

twoPhoton_len=1_000
config,qm=update_two_photon_lenght(twoPhoton_len,config,qmm)

with program() as IQ_blobs:

    n = declare(int)
    n_rep = declare(int)
    i = declare(int)
    I = declare(fixed)
    Q = declare(fixed)
    I_st = declare_stream()
    Q_st = declare_stream()
    f = declare(int)
    n_rep_st=declare_stream()

    assign_variables_to_element("resonator", I,Q) 

    #Update the demodulation frequency 
    update_frequency("resonator",IF_resonator+Offset_IF) 
    update_frequency("fluxline",IF_pump)

    #Loop on the repetition 
    with for_(n_rep, 0, n_rep < n_repetition, n_rep + 1):

        #Loop on the repetition 
        
        #play("pumping" * amp(amp_factor_high), 'fluxline', chirp=(250, 'Hz/nsec'))  
        
        with for_(i, 0, i < np.round((n_empty*(Readout_Len+300))/twoPhoton_len)+1, i + 1):
            play("pumping" * amp(amp_factor_high), 'fluxline')  

        with for_(i, 0, i < np.round((n_full*(Readout_Len+300))/twoPhoton_len)+1, i + 1):
            play("pumping" * amp(amp_factor), 'fluxline')  



        #Demodulation measurements 
        with for_(n, 0, n < n_runs, n + 1):

            #Demodulate n time 
            measure(
                "fake_readout",
                "resonator",
                None,
                dual_demod.full("cos", "out1", "sin", "out2", I),
                dual_demod.full("minus_sin", "out1", "cos", "out2", Q),
            )

            save(I, I_st)
            save(Q, Q_st)

        save(n_rep, n_rep_st)

        wait(cooldown_time) #wait the cooldown 

    with stream_processing():
        I_st.with_timestamps().save_all("I")
        Q_st.with_timestamps().save_all("Q")
        n_rep_st.save("n_rep")



simulation = True      

if simulation:
    simulation_config = SimulationConfig(
        duration=50000, simulation_interface=LoopbackInterface([("con1", 3, "con1", 1)])
    )

    job = qmm.simulate(config, IQ_blobs, simulation_config)
    job.get_simulated_samples().con1.plot(analog_ports={'1','2','3','4' },digital_ports={'1','3'})
    
    # Get the frequency map 
    sample=job.get_simulated_samples()
    x=sample.con1.analog["4"] # get analog 4
    NFFT = 2**10
    Fs = 1e9
    fig = plt.figure()
    ax1 = plt.subplot(111)
    Pxx, freqs, bins, im = plt.specgram(x, NFFT=NFFT, Fs=Fs, noverlap=100, cmap=plt.cm.gist_heat)
    plt.show()
    ax1.set_ylim((100e6,300e6))
    ax1.set_xticklabels((ax1.get_xticks() * 1e6).astype(int))
    #ax1.set_yticklabels((ax1.get_yticks() / 1e6).astype(int))
    plt.xlabel("t [us]")
    plt.ylabel("f [MHz]")

else:

    job = qm.execute(IQ_blobs)
    results = fetching_tool(job, data_list=["I", "Q","n_rep"], mode="live")

    fig = plt.figure()
    interrupt_on_close(fig, job)  #  Interrupts the job when closing the figure

    while results.is_processing():

        I, Q, n_rep = results.fetch_all()

        time_vec=I["timestamp"]
        I = u.demod2volts(I["value"], Readout_Len) #diviser par la duree du pulse Readout_lEN 
        Q = u.demod2volts(Q["value"], Readout_Len)


        #Plotting the average 
        if len(I)>n_runs:

            #Datas are capted continously and then transfer into a 2D matrix and averaged
            it=len(I)//n_runs
            I_2d=I[0:it*n_runs].reshape((it,n_runs))
            Q_2d=Q[0:it*n_runs].reshape((it,n_runs))
            norm_2d=np.sqrt(I_2d**2+Q_2d**2)

            plt.subplot(211)
            fig.suptitle("IF_pump "+str(IF_pump)+" ite :"+str(n_rep))
            plt.cla()
            plt.plot(np.angle(I_2d[it-1,:]+1j*Q_2d[it-1,:]), ".", markersize=2)
            plt.plot([n_empty,n_empty], [-np.pi, np.pi],'r')
            plt.xlabel("Nb points")
            plt.ylabel("phase")
            plt.pause(0.1)


            plt.subplot(212)
            av=np.mean(norm_2d,axis=0) 
            plt.subplot(313)
            plt.cla()
            plt.plot(time[0:n_runs]*1e-9,av*1e3,".",markersize=2)
            plt.xlabel("time [s]")
            plt.ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")
# Out:
# 2023-04-25 17:22:52,810 - qm - INFO - Flags:
# 2023-04-25 17:22:52,810 - qm - INFO - Simulating program
# C:\Users\hqclabo\Anaconda3\envs\Measurement\lib\site-packages\ipykernel_launcher.py:111: UserWarning: FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# ## Plotting for single frequency

# %%
time
# Out:
# <module 'time' (built-in)>

# %%
# %matplotlib inline
number_avg=10
Processed_Data=an.Extract_vac_exc_gap(Data,amp_factor_array,freqs_array,Pump_Delay,number_avg)

amp_factor=amp_factor_array[0]
freqs=freqs_array[0,:]

for idx in range(len(freqs)):
    
    if Processed_Data[amp_factor][freqs[idx]]["fit"]:

        gap=Processed_Data[amp_factor][freqs[idx]]["gap"]
        coeff=Processed_Data[amp_factor][freqs[idx]]["fit_coeff"]
        time_fit=Processed_Data[amp_factor][freqs[idx]]["time_fit"]
        y_fitted=Processed_Data[amp_factor][freqs[idx]]["y_fitted"]
        av_fit=Processed_Data[amp_factor][freqs[idx]]["av_fit"]

        fontsize=8
        fig, axs = plt.subplots( nrows=2, ncols=1, figsize=(8,10),dpi=100)

        #Plotting the measurement 
        ax=axs[0]
        ax.set_title("Average "+str(n_repetition))
        ax.plot(time*1e-9,av*1e3,".")
        #ax.plot([Pump_Delay*4*1e-9,Pump_Delay*4*1e-9],[0, max(av*1e3)],"r")
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")

        ax=axs[1]
        ax.set_title("$\lambda= $"+str(gap))
        ax.plot(time_fit,av_fit,".")
        ax.plot(time_fit,y_fitted)
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")



    else:
        print("No fit")
        time_fit=Processed_Data[amp_factor][freqs[idx]]["time_fit"]
        av_fit=Processed_Data[amp_factor][freqs[idx]]["av_fit"]
        
        fontsize=8
        fig, axs = plt.subplots( nrows=2, ncols=1, figsize=(8,10),dpi=100)

        #Plotting the measurement 
        ax=axs[0]
        ax.set_title("Average "+str(n_repetition))
        ax.plot(time*1e-9,av*1e3)
        #ax.plot([Pump_Delay*4*1e-9,Pump_Delay*4*1e-9],[0, max(av*1e3)],"r")
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")

        ax=axs[1]
        ax.set_title("Pump= "+str(freqs[idx]) +" Iteration :" +str(idx) + " No fit")
        ax.plot(time_fit,av_fit)
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")

# %%
# %matplotlib qt

Readout_Len=50_000
config,qm=update_readout_lenght(Readout_Len,config,qmm)


amp_factor_array=np.array([0.6]) #Prefactor of the amplitude 
amp_factor=amp_factor_array[0]

amp_factor_high_array=np.array([1]) #Prefactor of the amplitude 
amp_factor_high=amp_factor_high_array[0]


#Update the pump IF frequency 
freqs_array=np.array([[ 0.19565e9]]) # defines the IF of the pump  
IF_pump=freqs_array[0,0]
IF_resonator=(LO_fluxline+IF_pump)/2-LO_readout #demodulate at half of the pump IF by default 

n_repetition=20 #number of repetitions 

n_empty=5_000 #number of vaccum readout to do 
Pump_Delay = n_empty*(Readout_Len+300)//4  #time for the pump to be off 
n_full=30_000 #number of pump on readout to do 
n_runs=n_empty+n_full # Total number of readout to do 

cooldown_time=5_000_000//4 #cooldown time before each repetition to go back to vacuum 
Offset_IF=0  


with program() as IQ_blobs:

    n = declare(int)
    n_rep = declare(int)
    i = declare(int)
    I = declare(fixed)
    Q = declare(fixed)
    I_st = declare_stream()
    Q_st = declare_stream()
    f = declare(int)
    n_rep_st=declare_stream()

    assign_variables_to_element("resonator", I,Q) 

    #Update the demodulation frequency 
    update_frequency("resonator",IF_resonator+Offset_IF) 
    update_frequency("fluxline",IF_pump)
    
    #Loop on the repetition 
    with for_(n_rep, 0, n_rep < n_repetition, n_rep + 1):

        #Loop on the repetition 
        with for_(i, 0, i < np.round((n_empty*(Readout_Len+300))/twoPhoton_len)+1, i + 1):
            play("pumping" * amp(amp_factor_high), 'fluxline')  

        with for_(i, 0, i < np.round((n_full*(Readout_Len+300))/twoPhoton_len)+1, i + 1):
            play("pumping" * amp(amp_factor), 'fluxline')  



        #Demodulation measurements 
        with for_(n, 0, n < n_runs, n + 1):

            #Demodulate n time 
            measure(
                "fake_readout",
                "resonator",
                None,
                dual_demod.full("cos", "out1", "sin", "out2", I),
                dual_demod.full("minus_sin", "out1", "cos", "out2", Q),
            )

            save(I, I_st)
            save(Q, Q_st)

        save(n_rep, n_rep_st)

        wait(cooldown_time) #wait the cooldown 

    with stream_processing():
        I_st.with_timestamps().save_all("I")
        Q_st.with_timestamps().save_all("Q")
        n_rep_st.save("n_rep")



simulation = False     

if simulation:
    simulation_config = SimulationConfig(
        duration=50000, simulation_interface=LoopbackInterface([("con1", 3, "con1", 1)])
    )

    job = qmm.simulate(config, IQ_blobs, simulation_config)
    job.get_simulated_samples().con1.plot(analog_ports={'1','2','3','4' },digital_ports={'1','3'})

else:

    job = qm.execute(IQ_blobs)
    results = fetching_tool(job, data_list=["I", "Q","n_rep"], mode="live")

    fig = plt.figure()
    interrupt_on_close(fig, job)  #  Interrupts the job when closing the figure

    while results.is_processing():
        I, Q, n_rep = results.fetch_all()

        #dt=(I["timestamp"][1]-I["timestamp"][0])*1e-9 #time between sucessive points
        time=I["timestamp"]
        I = u.demod2volts(I["value"], Readout_Len) #diviser par la duree du pulse Readout_lEN 
        Q = u.demod2volts(Q["value"], Readout_Len)

        plt.subplot(211)
        plt.cla()
        fig.suptitle("IF_pump "+str(IF_pump)+" ite :"+str(n_rep))
        plt.plot(I[:min(len(I), len(Q))], Q[:min(len(I), len(Q))], ".", markersize=2)
        plt.xlabel("I")
        plt.ylabel("Q")
        plt.axis("equal")
        plt.subplot(212)
        plt.cla()
        plt.plot(np.angle(I[:min(len(I), len(Q))]+1j*Q[:min(len(I), len(Q))]), ".", markersize=2)
        #plt.plot(I**2+Q**2,".",markersize=2)
        plt.plot([n_empty,n_empty], [-np.pi, np.pi],'r')
        plt.xlabel("Nb points")
        plt.ylabel("phase")
        plt.pause(0.1)
# Out:
# 2023-04-21 18:02:13,192 - qm - INFO - Flags:
# 2023-04-21 18:02:13,193 - qm - INFO - Sending program to QOP
# 2023-04-21 18:02:13,748 - qm - INFO - Executing program
# Execution stopped by user!

# %%
I_2d=I.reshape((n_repetition,n_runs))
Q_2d=Q.reshape((n_repetition,n_runs))
time_2d=time.reshape((n_repetition,n_runs))

norm_2d=np.sqrt(I_2d**2+Q_2d**2)
#We reset the timer to zero for each idx
time_2d=(time_2d.transpose()-time_2d[:,0]).transpose()

# %%
# %matplotlib inline
idx=4
fontsize=7
fig, axs = plt.subplots( nrows=2, ncols=1, figsize=(5,10),dpi=100)

ax=axs[0]
ax.set_title("Iteration :" + str(idx))
ax.plot(time_2d[idx,:]*1e-9,norm_2d[idx,:])
ax.plot([Pump_Delay*4*1e-9,Pump_Delay*4*1e-9],[0, max(norm_2d[idx,:])],"r")
ax.set_ylabel(r'$I^2 + Q^2$ (single traj) [V]',fontsize=fontsize)
ax.set_xlabel("time [s]",fontsize=fontsize)
#average over all axis :
ax=axs[1]
ax.set_title("Average")
av=np.mean(norm_2d,axis=0)
ax.plot(time_2d[0,:]*1e-9,av)
ax.plot([Pump_Delay*4*1e-9,Pump_Delay*4*1e-9],[0, max(norm_2d[idx,:])],"r")
ax.set_xlabel("time [s]")
ax.set_ylabel("r'$I^2 + Q^2$ (average) [V]")
# Out:
# Text(0, 0.5, "r'$I^2 + Q^2$ (average) [V]")
