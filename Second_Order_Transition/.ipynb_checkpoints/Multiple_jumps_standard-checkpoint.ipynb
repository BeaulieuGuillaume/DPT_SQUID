# %% [markdown]
# # Package and functions

# %%
from qm.QuantumMachinesManager import QuantumMachinesManager
from qm.octave import *
from qm.qua import *


#General os library 
import os
import time as time_package
import sys

sys.path.append(r"C:\Users\HQClabo\Documents\Code\QuantumMachine\Guillaume\NonLinearRes_calib_30_03_2023\QM_NonLinRes\Calibration_Script")
dll_path=r"C:\\Program Files\\Signal Hound\\Spike\\sa_api.dll"

import matplotlib.pyplot as plt
from qualang_tools.units import unit
from set_octave import get_L0_and_IF
from configuration import *
from qm import SimulationConfig, LoopbackInterface
from qualang_tools.units import unit
from qualang_tools.loops import from_array
u = unit()
from qualang_tools.plot import interrupt_on_close
from qualang_tools.results import progress_counter, fetching_tool
from qualang_tools.addons.variables import assign_variables_to_element



#Path for HQCPC7 
sys.path.append(r'C:\Users\HQClabo\Documents\Code\QuantumMachine\Guillaume\NonLinearRes_calib_30_03_2023\Analysis_Function\NonLinearRes')
sys.path.append(r'C:\Users\HQClabo\Documents\Code\QuantumMachine\Guillaume\NonLinearRes_calib_30_03_2023\Drivers\Drivers') #path for the analysis function

#Path for HQC PC15 
# sys.path.append(r'C:\Users\hqclabo\Documents\Code\gbeaulieu\Analysis_Function\NonLinearRes')
# sys.path.append(r'C:\Users\hqclabo\Documents\Code\gbeaulieu\Drivers')

from lmfit.models import LinearModel
from Signal_hound_driver import Signalhound 
import Calibration_function as calib
import update_config as cfg


import AnFunc as an # analysis function
import imageio
import scipy.io
from scipy import signal
from scipy.optimize import curve_fit

# %%
def plot_init_av_single(I,Q,time,n_avg,bin_size,n_angle,figsize,fontsize,dpi):

    fig, axs = plt.subplots( nrows=3, ncols=2, figsize=figsize,dpi=dpi)

    #Plot without reducing 
    ax=axs[0,0]
    ax.plot(I,Q,".",markersize=2)
    ax.set_title('Pump Frequency '+str(IF_pump)+" Amplitude"+str(amp_factor),fontsize=fontsize)
    ax.set_xlabel("I [$V$]",fontsize=fontsize)
    ax.set_ylabel("Q [$V$]",fontsize=fontsize)
    ax.tick_params(axis='x', labelsize=fontsize)
    ax.tick_params(axis='y', labelsize=fontsize)
    ax.axis("equal")

    ax=axs[1,0]
    ax.plot(time,I, ".", markersize=2)
    ax.set_xlabel("Time [s]",fontsize=fontsize)
    ax.set_ylabel("I",fontsize=fontsize)
    ax.tick_params(axis='x', labelsize=fontsize)
    ax.tick_params(axis='y', labelsize=fontsize)

    ax=axs[2,0]
    ax.hist2d(I,Q,bins=bin_size)
    ax.set_xlabel("I [$V$]",fontsize=fontsize)
    ax.set_ylabel("Q [$V$]",fontsize=fontsize)
    ax.set_facecolor(color=(68/255,1/255,84/255))
    ax.tick_params(axis='x', labelsize=fontsize)
    ax.tick_params(axis='y', labelsize=fontsize)
    ax.axis("equal")

    #Plot with reducing 
    average_I, average_Q, time_average=rot_and_av_single(I,Q,time,n_angle,n_avg)

    ax=axs[0,1]
    ax.plot(average_I.transpose(),average_Q.transpose(),".",markersize=2)
    ax.set_title('Pump Frequency '+str(IF_pump)+" Amplitude"+str(amp_factor),fontsize=fontsize)
    ax.set_xlabel("I [$V$]",fontsize=fontsize)
    ax.set_ylabel("Q [$V$]",fontsize=fontsize)
    ax.tick_params(axis='x', labelsize=fontsize)
    ax.tick_params(axis='y', labelsize=fontsize)
    ax.axis("equal")


    ax=axs[1,1]
    ax.plot(time_average,average_I[0,:], ".", markersize=2)
    ax.set_xlabel("Time [s]",fontsize=fontsize)
    ax.set_ylabel("I",fontsize=fontsize)
    ax.tick_params(axis='x', labelsize=fontsize)
    ax.tick_params(axis='y', labelsize=fontsize)


    ax=axs[2,1]
    ax.hist2d(average_I[0,:],average_Q[0,:],bins=bin_size)
    ax.set_xlabel("I [$V$]",fontsize=fontsize)
    ax.set_ylabel("Q [$V$]",fontsize=fontsize)
    ax.set_facecolor(color=(68/255,1/255,84/255))
    ax.tick_params(axis='x', labelsize=fontsize)
    ax.tick_params(axis='y', labelsize=fontsize)
    ax.axis("equal")

    print("Average signal : {}".format(np.mean(abs(I))))
    
    
    
    
def plot_init_av_single_without_full(I,Q,time,n_avg,bin_size,n_angle,figsize,fontsize,dpi):

    fig, axs = plt.subplots( nrows=3, ncols=2, figsize=figsize,dpi=dpi)

    #Plot without reducing 
    ax=axs[0,0]
    # ax.plot(I,Q,".",markersize=2)
    # ax.set_title('Pump Frequency '+str(IF_pump)+" Amplitude"+str(amp_factor),fontsize=fontsize)
    # ax.set_xlabel("I [$V$]",fontsize=fontsize)
    # ax.set_ylabel("Q [$V$]",fontsize=fontsize)
    # ax.tick_params(axis='x', labelsize=fontsize)
    # ax.tick_params(axis='y', labelsize=fontsize)
    # ax.axis("equal")

    ax=axs[1,0]
    # ax.plot(time,I, ".", markersize=2)
    # ax.set_xlabel("Time [s]",fontsize=fontsize)
    # ax.set_ylabel("I",fontsize=fontsize)
    # ax.tick_params(axis='x', labelsize=fontsize)
    # ax.tick_params(axis='y', labelsize=fontsize)

    ax=axs[2,0]
    # ax.hist2d(I,Q,bins=bin_size)
    # ax.set_xlabel("I [$V$]",fontsize=fontsize)
    # ax.set_ylabel("Q [$V$]",fontsize=fontsize)
    # ax.set_facecolor(color=(68/255,1/255,84/255))
    # ax.tick_params(axis='x', labelsize=fontsize)
    # ax.tick_params(axis='y', labelsize=fontsize)
    # ax.axis("equal")

    #Plot with reducing 
    average_I, average_Q, time_average=rot_and_av_single(I,Q,time,n_angle,n_avg)

    ax=axs[0,1]
    ax.plot(average_I.transpose(),average_Q.transpose(),".",markersize=2)
    ax.set_title('Pump Frequency '+str(IF_pump)+" Amplitude"+str(amp_factor),fontsize=fontsize)
    ax.set_xlabel("I [$V$]",fontsize=fontsize)
    ax.set_ylabel("Q [$V$]",fontsize=fontsize)
    ax.tick_params(axis='x', labelsize=fontsize)
    ax.tick_params(axis='y', labelsize=fontsize)
    ax.axis("equal")


    ax=axs[1,1]
    ax.plot(time_average,average_I[0,:], ".", markersize=2)
    ax.set_xlabel("Time [s]",fontsize=fontsize)
    ax.set_ylabel("I",fontsize=fontsize)
    ax.tick_params(axis='x', labelsize=fontsize)
    ax.tick_params(axis='y', labelsize=fontsize)


    ax=axs[2,1]
    ax.hist2d(average_I[0,:],average_Q[0,:],bins=bin_size)
    ax.set_xlabel("I [$V$]",fontsize=fontsize)
    ax.set_ylabel("Q [$V$]",fontsize=fontsize)
    ax.set_facecolor(color=(68/255,1/255,84/255))
    ax.tick_params(axis='x', labelsize=fontsize)
    ax.tick_params(axis='y', labelsize=fontsize)
    ax.set_xlim(-0.002,0.002)
    ax.set_ylim(-0.002,0.002)
    ax.axis("equal")

    print("Average signal : {}".format(np.mean(abs(I))))
    
    
def rot_and_av_single(I,Q,time,nb_angle,n_avg):
    
    #reshape the data to fit into the initial function
    I_2d=np.reshape(I, (1, I.shape[0])) 
    Q_2d=np.reshape(Q, (1, Q.shape[0]))
    rot_I,rot_Q=an.rotate_data(I_2d,Q_2d,nb_angle)
    average_I,average_Q,time_average=an.average_data(rot_I,rot_Q,time,n_avg)

    return average_I, average_Q, time_average




def single_IQ_trace(IF_pump,IF_resonator,Offset_IF,amp_factor,n_runs,Readout_Delay,points_delay,Readout_Len,qm):
    
    """ gets the IQ values for a given pump frequency and amplitude 
    IF_Pump : If frequency of the pump 
    IF_resonator : IF frequency of the resonator (should be calculated before such that it gives half of the pump total frequency (LO_fluxline+IF_pump)/2-LO_readout
    Offset_IF : in case the down converted frequency is not perfectly centered around 0. This is typically kept to zero
    amp_facot amplitude factor of the pump
    n_runs : number of points 
    Readout_delay : waiting time before the first readout in clock cycle
    Readout_Len : time in ns of each readout 
    points_delay: waiting time between collected points 
    qm : quantum manager 

    returns :

    I: vector n_runs components of the frist quadrature
    Q : vector of n_runs compontents of the second quadrature
    time : vector of the time """


    with program() as IQ_blobs:

        n = declare(int)
        i = declare(int)
        I = declare(fixed)
        Q = declare(fixed)
        assign_variables_to_element("resonator", I,Q) #This line forces the OPX to assign I and Q to the resonator element such that the loops can happen in parallel as intented
        I_st = declare_stream()
        Q_st = declare_stream()
        f = declare(int)
        
        it_numb_st=declare_stream()

        # Change the of the pump and resonator to demodulate better
        update_frequency("resonator",IF_resonator+Offset_IF) 
        update_frequency("fluxline",IF_pump)

        #Play a continuous loop sending a pulse through the fluxline 
        

        #Delay time before the first readout 
        wait(Readout_Delay,"resonator")
        
        with for_(i, 0, i < np.round((n_runs*(Readout_Len+300+points_delay*4)+Readout_Delay*4)/twoPhoton_len)+1, i + 1): # the 300 is added because there is a time delay associated to saving the data in the steam. The *4 is necessary because the waiting time is in clockcycle 
            play("pumping" * amp(amp_factor), 'fluxline')  # Play the pulse on the fluxline

        with for_(n, 0, n < n_runs, n + 1):

            #Demodulate for the length 
            measure(
                "fake_readout",
                "resonator",
                None,
                dual_demod.full("cos", "out1", "sin", "out2", I),
                dual_demod.full("minus_sin", "out1", "cos", "out2", Q),
            )

            save(I, I_st)
            save(Q, Q_st)
            
            save(n,it_numb_st)

            wait(points_delay,"resonator")
        

        with stream_processing():
            I_st.with_timestamps().save_all("I")
            Q_st.with_timestamps().save_all("Q")
            it_numb_st.save("iteration")


    simulation = False
    if simulation:

        simulation_config = SimulationConfig(
            duration=80000, simulation_interface=LoopbackInterface([("con1", 3, "con1", 1)])
        )
        job = qmm.simulate(config, IQ_blobs, simulation_config)
        job.get_simulated_samples().con1.plot(analog_ports={'1','2','3','4' },digital_ports={'1','3'})

    else: 



        job = qm.execute(IQ_blobs)
        results = fetching_tool(job, data_list=["I", "Q","iteration"], mode="live")

        fig = plt.figure()
        interrupt_on_close(fig, job)
        while results.is_processing():

            I, Q,iteration = results.fetch_all()

            time=I["timestamp"]
            I = u.demod2volts(I["value"], Readout_Len) #diviser par la duree du pulse 
            Q = u.demod2volts(Q["value"], Readout_Len)

            #plt.subplot(211)
            plt.subplot(211)
            plt.cla()
            fig.suptitle("IF_pump "+str(IF_pump) +" Progress :"+str(round(iteration/n_runs,2)))
            plt.plot(I[:min(len(I), len(Q))], Q[:min(len(I), len(Q))], ".", markersize=2)
            plt.xlabel("I")
            plt.ylabel("Q")
            plt.axis("equal")
            plt.subplot(212)
            plt.cla()
            tau=np.linspace(1,min(len(I), len(Q)),min(len(I), len(Q)))
            plt.plot(tau,np.angle(I[:min(len(I), len(Q))]+1j*Q[:min(len(I), len(Q))]), ".", markersize=2)
            plt.xlabel("nb_points")
            plt.ylabel("phase")
            plt.pause(0.1)

        I, Q, iteration = results.fetch_all()
        time=I["timestamp"]
        I = u.demod2volts(I["value"], Readout_Len) #diviser par la duree du pulse 
        Q = u.demod2volts(Q["value"], Readout_Len)

      
    return time, I, Q






def single_IQ_trace_without_plot(IF_pump,IF_resonator,Offset_IF,amp_factor,n_runs,Readout_Delay,points_delay,Readout_Len,qm):
    
    """ gets the IQ values for a given pump frequency and amplitude 
    IF_Pump : If frequency of the pump 
    IF_resonator : IF frequency of the resonator (should be calculated before such that it gives half of the pump total frequency (LO_fluxline+IF_pump)/2-LO_readout
    Offset_IF : in case the down converted frequency is not perfectly centered around 0. This is typically kept to zero
    amp_facot amplitude factor of the pump
    n_runs : number of points 
    Readout_delay : waiting time before the first readout in clock cycle
    Readout_Len : time in ns of each readout 
    points_delay: waiting time between collected points 
    qm : quantum manager 

    returns :

    I: vector n_runs components of the frist quadrature
    Q : vector of n_runs compontents of the second quadrature
    time : vector of the time """


    with program() as IQ_blobs:

        n = declare(int)
        i = declare(int)
        I = declare(fixed)
        Q = declare(fixed)
        assign_variables_to_element("resonator", I,Q) #This line forces the OPX to assign I and Q to the resonator element such that the loops can happen in parallel as intented
        I_st = declare_stream()
        Q_st = declare_stream()
        f = declare(int)
        
        it_numb_st=declare_stream()

        # Change the of the pump and resonator to demodulate better
        update_frequency("resonator",IF_resonator+Offset_IF) 
        update_frequency("fluxline",IF_pump)

        #Play a continuous loop sending a pulse through the fluxline 
        

        #Delay time before the first readout 
        wait(Readout_Delay,"resonator")
        
        with for_(i, 0, i < np.round((n_runs*(Readout_Len+300+points_delay*4)+Readout_Delay*4)/twoPhoton_len)+1, i + 1): # the 300 is added because there is a time delay associated to saving the data in the steam. The *4 is necessary because the waiting time is in clockcycle 
            play("pumping" * amp(amp_factor), 'fluxline')  # Play the pulse on the fluxline

        with for_(n, 0, n < n_runs, n + 1):

            #Demodulate for the length 
            measure(
                "fake_readout",
                "resonator",
                None,
                dual_demod.full("cos", "out1", "sin", "out2", I),
                dual_demod.full("minus_sin", "out1", "cos", "out2", Q),
            )

            save(I, I_st)
            save(Q, Q_st)
            
            save(n,it_numb_st)

            #wait(points_delay,"resonator")
        

        with stream_processing():
            I_st.with_timestamps().save_all("I")
            Q_st.with_timestamps().save_all("Q")
            it_numb_st.save("iteration")


    simulation = False
    if simulation:

        simulation_config = SimulationConfig(
            duration=80000, simulation_interface=LoopbackInterface([("con1", 3, "con1", 1)])
        )
        job = qmm.simulate(config, IQ_blobs, simulation_config)
        job.get_simulated_samples().con1.plot(analog_ports={'1','2','3','4' },digital_ports={'1','3'})

    else: 



        job = qm.execute(IQ_blobs)
        results = fetching_tool(job, data_list=["I", "Q","iteration"], mode="live")

        # fig = plt.figure()
        # interrupt_on_close(fig, job)
        # while results.is_processing():

          

            #plt.subplot(211)
            # plt.subplot(211)
            # plt.cla()
            # fig.suptitle("IF_pump "+str(IF_pump) +" Progress :"+str(round(iteration/n_runs,2)))
            # plt.plot(I[:min(len(I), len(Q))], Q[:min(len(I), len(Q))], ".", markersize=2)
            # plt.xlabel("I")
            # plt.ylabel("Q")
            # plt.axis("equal")
            # plt.subplot(212)
            # plt.cla()
            # tau=np.linspace(1,min(len(I), len(Q)),min(len(I), len(Q)))
            # plt.plot(tau,np.angle(I[:min(len(I), len(Q))]+1j*Q[:min(len(I), len(Q))]), ".", markersize=2)
            # plt.xlabel("nb_points")
            # plt.ylabel("phase")
            # plt.pause(0.1)
            

        I, Q, iteration = results.fetch_all()
        time=I["timestamp"]
        I = u.demod2volts(I["value"], Readout_Len) #diviser par la duree du pulse 
        Q = u.demod2volts(Q["value"], Readout_Len)

      
    return time, I, Q

# %% [markdown]
# # OPX configuration

# %%
#Octave & OPX configuration 
Saving_Path=r"\\sb1files\HQC\Users\beaulieu\Data\Run01\131\\"
Cooldown_Date="2023_07_10"

calibration_path='C:\\Users\\HQClabo\\Documents\\Code\\QuantumMachine\\Guillaume\\NonLinearRes_calib_30_03_2023\\QM_NonLinRes\\Calibration_Script'


opx_ip = '128.178.175.167'
opx_port = 81
octave_ip = '128.178.175.167'
octave_port = 53


octave_config = QmOctaveConfig()
octave_config.set_calibration_db(calibration_path) #Path to the calibration database 

octave_config.add_device_info('octave1', octave_ip, octave_port) #Add a device refered to as octave 1
octave_config.set_opx_octave_mapping([('con1', 'octave1')])  # set default mapping between analog outputs of OPX and the octave


qmm = QuantumMachinesManager(host=opx_ip, port=opx_port, octave=octave_config)
qm = qmm.open_qm(config)


#Mixers for the fluxline 
octave_output_gain=-10

#Mixers for the fluxline 
qmm.octave_manager.set_clock("octave1", ClockType.External, ClockFrequency.MHZ_10) # External clock on the octave 

qm.octave.set_lo_source("fluxline", OctaveLOSource.Internal) # Use internal LO for the fluxline 
qm.octave.set_lo_frequency("fluxline", LO_fluxline)  # Set the frequency of the LO 
qm.octave.set_rf_output_gain("fluxline", octave_output_gain)  # can set gain from -10dB to 20dB
qm.octave.set_rf_output_mode("fluxline", RFOutputMode.on)  # The LO output is always on (could change to a trigger)  #RFOutputMode.trig_normal

#Mixers for the resonator 
qm.octave.set_qua_element_octave_rf_in_port("resonator", "octave1", 1) #input port 1 is set for the resonator 
qm.octave.set_downconversion("resonator", lo_source=RFInputLOSource.Internal)  # The LO for the demodulation is the interal LO  

qm.octave.set_lo_source("resonator", OctaveLOSource.Internal) # Use internal LO for the fluxline 
qm.octave.set_lo_frequency("resonator", LO_readout)  # Set the frequency of the LO 
qm.octave.set_rf_output_gain("resonator", octave_output_gain)  # can set gain from -10dB to 20dB
qm.octave.set_rf_output_mode("resonator", RFOutputMode.trig_normal)  # The LO output is always on (could change to a trigger)RFOutputMode.trig_normal


offset_1=0.01783981341796875
offset_2=0.01553899095214844
config,qm=cfg.update_offset(offset_1, offset_2,config,qmm)
# Out:
# 2023-07-25 15:59:45,452 - qm - INFO - Performing health check
# 2023-07-25 15:59:45,466 - qm - WARNING -   HC Warning: Potential hardware issue with QSync in controller con1, multiple controllers sync cannot be guaranteed, please inform QM
# 2023-07-25 15:59:45,466 - qm - INFO - Health check passed

# %% [markdown]
# # Display the parameters

# %%
print("LO of resonator : {} GHz".format(config['elements']['resonator']["mixInputs"]["lo_frequency"]/1e9))
print("IF of resonator : {} GHz".format(config['elements']['resonator']['intermediate_frequency']/1e9))
print("Time of flight of resonator : {} ns".format(config['elements']['resonator']['time_of_flight']))
print("Readout time resonator : {} ns".format(config["pulses"]["zero_pulse"]["length"]))
print("LO of fluxline: {} GHz".format(config['elements']['fluxline']["mixInputs"]["lo_frequency"]/1e9))
print("IF of fluxline : {} GHz".format(config['elements']['fluxline']['intermediate_frequency']/1e9))
print("Fluxline pulse time : {} ns".format(config["pulses"]["twoPhoton"]["length"]))
print("Fluxline amplitude : {} V".format(config["waveforms"]["twoPhoton_wf"]['sample']))
# Out:
# LO of resonator : 4.2 GHz
# IF of resonator : 0.1 GHz
# Time of flight of resonator : 24 ns
# Readout time resonator : 50000 ns
# LO of fluxline: 8.6 GHz
# IF of fluxline : 0.0995 GHz
# Fluxline pulse time : 10000 ns
# Fluxline amplitude : 0.185 V

# %% [markdown]
# # Testing the Pump

# %%
#Mixer Calibration 
#Calibration of the fluxline mixer for the pump 
qm.octave.calibrate_element("fluxline", [get_L0_and_IF(config, "fluxline")])  
qm = qmm.open_qm(config)

qm.octave.calibrate_element("resonator", [get_L0_and_IF(config, "resonator")])  
qm = qmm.open_qm(config)
# Out:
# 2023-06-21 00:23:40,013 - qm - INFO - Flags:
# 2023-06-21 00:23:40,014 - qm - INFO - Compiling program
# 2023-06-21 00:23:42,535 - qm - INFO - Sending pre-compiled program to QOP
# 2023-06-21 00:23:46,268 - qm - INFO - Flags:
# 2023-06-21 00:23:46,268 - qm - INFO - Compiling program
# 2023-06-21 00:23:48,790 - qm - INFO - Sending pre-compiled program to QOP

# %%
# Applies an infinite loop pump for testing 

amp_factor=0.1

pulse_amp=0.125/2
config,qm=update_pulse_amplitude(pulse_amp,config,qmm) 

twoPhoton_len=1000
config,qm=update_two_photon_lenght(twoPhoton_len,config,qmm)

with program() as TwoPhoton:
    with infinite_loop_():
        play("pumping"*amp(amp_factor), 'fluxline')
           
job = qm.execute(TwoPhoton)

# %%
#Two stop the two photon pumping 
job.halt()

# %% [markdown]
# # Single frequency IQ blob
#
# Runs the IQ blob program for a single pump frequency that can be dfined with IF pump. The demodulation frequency is automatically taken as half of the total pump frequency
#
# Need to make sure that the new updated IF frequency doesn't go over 350 MHz.
#
# ![image.png](attachment:9f6a090c-6ac9-4226-9cd4-4d8bc623c7b2.png)

# %%
# %matplotlib qt 
freqs_dict={}

#Update the readout pulse 
Readout_Len= 50_000   #length of the readout pulse in ns 
config,qm=cfg.update_readout_lenght(Readout_Len,config,qmm)


amp_factor_array=np.array([1.25]) #Prefactor of the amplitude 
amp_factor=amp_factor_array[0]

n_runs = 500_000 #Number of readout to do 


freqs_dict[amp_factor]=np.array([ 99.05e6]) # 
IF_pump=freqs_dict[amp_factor][0]

IF_resonator=(LO_fluxline+IF_pump)/2-LO_readout #demodulate at half of the pump IF by default 


Readout_Delay = 200_000//4 # Delay before the first readout in ns (convert from clockcycle)


Offset_IF=0  

points_delay=200_000//4 #Delay between readouts 


Expected_time=n_runs *(Readout_Len+points_delay*4)/60
print("Expected time {}".format(Expected_time*1e-9))
# Out:
# Expected time 2.0833333333333335

# %%
# %%time 
time,I,Q=single_IQ_trace(IF_pump,IF_resonator,Offset_IF,amp_factor,n_runs,Readout_Delay,points_delay,Readout_Len,qm)

Data={}
Data[amp_factor]={}
Data[amp_factor][IF_pump]={}
Data[amp_factor][IF_pump]["I"]=I
Data[amp_factor][IF_pump]["Q"]=Q
Data[amp_factor][IF_pump]["time"]=time
# Out:
# 2023-07-21 00:09:43,213 - qm - INFO - Flags:
# 2023-07-21 00:09:43,214 - qm - INFO - Sending program to QOP
# 2023-07-21 00:09:43,649 - qm - INFO - Executing program
# Execution stopped by user!
# Wall time: 38.8 s

# %% [markdown]
# ## Plotting single frequency

# %%
#loading the data 
filepath=r"X:\Users\beaulieu\Data\Run01\131\2023_05_05\second_order_IQ\second_order_1p45_100\1p45_100_corrected_99660000.0.npz"

npzfile=np.load(filepath,allow_pickle=True)
npzfile["multidata"][()]
freqs_dict=npzfile["multidata"][()]["freqs_dict"]
Data=npzfile["multidata"][()]["Data"]
amp_factor_array=npzfile["multidata"][()]["amp_factor_array"]

# %%
freqs_dict[amp_factor][22]
# Out:
# 99680000.0

# %%
#Plotting with and without the noise reduction, would be better to get a single plotting function 

# %matplotlib inline
idx=0

n_bin=50 #bin size for the histogram 
figsize=(14,15)
fontsize=4
n_angle=1 #number of angles for the rotation 
n_avg=200 #number of average
dpi=300

amp_factor=amp_factor_array[0]
IF_pump=freqs_dict[amp_factor][idx]
IF_pump=99660000.0

I=Data[amp_factor][IF_pump]["I"]
Q=Data[amp_factor][IF_pump]["Q"]
time=Data[amp_factor][IF_pump]["time"]

plot_init_av_single_without_full(I,Q,time*1e-9,n_avg,n_bin,n_angle,figsize,fontsize,dpi)
# Out:
# Average signal : 0.00518158255187989

# %%
# %matplotlib inline

nb_angle=150
n_avg=1
corr_length=100

Processed_Data=an.Extract_second_order_gap(Data,amp_factor_array,freqs_dict,nb_angle,n_avg,corr_length)
amp_factor=amp_factor_array[0]
freqs=freqs_dict[amp_factor]

for idx in range(len(freqs)):
    
    if Processed_Data[amp_factor][freqs[idx]]["fit"]:

        gap=Processed_Data[amp_factor][freqs[idx]]["gap"]
        coeff=Processed_Data[amp_factor][freqs[idx]]["fit_coeff"]
        time=Processed_Data[amp_factor][freqs[idx]]["time"]
        I=Processed_Data[amp_factor][freqs[idx]]["I"]
        y_fitted=Processed_Data[amp_factor][freqs[idx]]["y_fitted"]
        corr_list=Processed_Data[amp_factor][freqs[idx]]["corr_list"]

        fontsize=8
        fig, axs = plt.subplots( nrows=2, ncols=1, figsize=(5,10),dpi=100)
        ax=axs[1]
        ax.set_title("$\lambda= $"+str(round(gap,2)))
        ax.plot(time[0:corr_length],corr_list[0:corr_length],".")
        ax.plot(time[0:corr_length],y_fitted)
        ax.set_xlabel("time [s]")
        ax.set_ylabel("Autocorelation [Normalized]")
        
        ax=axs[0]
        ax.set_title("Pump= "+str(freqs[idx]) +" Iteration :" +str(idx))
        ax.plot(time,I*1e3,".")
        ax.set_xlabel("time [s]")
        ax.set_ylabel("I [mv]")


    else:
        print("No fit")
        time=Processed_Data[amp_factor][freqs[idx]]["time"]
        corr_list=Processed_Data[amp_factor][freqs[idx]]["corr_list"]
        
        
        
        fontsize=8
        fig, axs = plt.subplots( nrows=1, ncols=1, figsize=(5,5),dpi=100)
        ax=axs
        ax.set_title("Pump= "+str(freqs[idx]) +" Iteration :" +str(idx) + " No fit")
        ax.plot(time[0:corr_length],corr_list[0:corr_length])
        ax.set_xlabel("time [s]")
        ax.set_ylabel("Autocorelation [Normalized]")
# Out:
# Execution stopped by user!
# 0

# %% [markdown]
# ## Saving for single frequency

# %%
#Saving the data
cooldown_date=Cooldown_Date #top folder   
device="second_order" #second folder 
name="measurement_freq" # third folder 
meastype="1p35_992_50jumps" #Final file name 

datadict={}

datadict={}
datadict["freqs_dict"]=freqs_dict
datadict["Readout_Len"]=Readout_Len
datadict["Readout_Delay"]=Readout_Delay*4
datadict["octave_output_gain"]=octave_output_gain
datadict["amp_factor_array"]=amp_factor_array 
datadict["points_delay"]=points_delay
datadict["Data"]=Data
datadict["config"]=config

#Configuration file copy 
datadict["LO_fluxline"]=LO_fluxline
datadict["IF_readout"]=IF_resonator
datadict["LO_readout"]=LO_readout

an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)
# Out:
# saving

# %%
#loading the data 
filepath=r"X:\Users\beaulieu\Data\Run01\131\2023_05_05\second_order_IQ\second_order_test\test_99600000.0.npz"

npzfile=np.load(filepath,allow_pickle=True)
npzfile["multidata"][()]
freqs_dict=npzfile["multidata"][()]["freqs_dict"]
Data=npzfile["multidata"][()]["Data"]
amp_factor_array=npzfile["multidata"][()]["amp_factor_array"]

# %%
freqs_dict
# Out:
# {1.25: array([99600000., 99605000.])}

# %% [markdown]
# # Multiple frequencies of single measurement with dual demodualtion

# %%
#Select the frequencies 
freqs_dict={}

amp_factor_array=np.array([1.25]) #Prefactor of the amplitude 
amp_factor=amp_factor_array[0]

fmin= 99.4e6
fmax=99.9e6
df=0.02* u.MHz
freqs=np.arange(fmin, fmax+df/2, df)


freqs_dict[amp_factor]=freqs
print(freqs)
# Out:
# [99400000. 99420000. 99440000. 99460000. 99480000. 99500000. 99520000.
#  99540000. 99560000. 99580000. 99600000. 99620000. 99640000. 99660000.
#  99680000. 99700000. 99720000. 99740000. 99760000. 99780000. 99800000.
#  99820000. 99840000. 99860000. 99880000. 99900000.]

# %%
# %matplotlib qt 

#Update the readout pulse 
Readout_Len=10_000 
config,qm=cfg.update_readout_lenght(Readout_Len,config,qmm)

n_runs =5000000

Readout_Delay = 100_0000//4# Delay before the first readout in ns (convert from clockcycle)

Offset_IF=0  #

points_delay= 16//4  #Delay between readouts 


save_Data=False
#Saving the data
cooldown_date=Cooldown_Date #top folder 
device="second_order_IQ" #second folder 
name="second_order_0p95_500" # third folder 
meastype="0p95_500_corrected" 

print(amp_factor)

print("The different frequency {}".format(freqs))
Expected_time=((Readout_Len+points_delay*4)*n_runs*len(freqs))*1e-9/60
print("The expected time : {} min".format(Expected_time))
# Out:
# 1.25
# The different frequency [99400000. 99420000. 99440000. 99460000. 99480000. 99500000. 99520000.
#  99540000. 99560000. 99580000. 99600000. 99620000. 99640000. 99660000.
#  99680000. 99700000. 99720000. 99740000. 99760000. 99780000. 99800000.
#  99820000. 99840000. 99860000. 99880000. 99900000.]
# The expected time : 21.701333333333334 min

# %%
calib_dict={}

calib_amp_array_res=np.array([0.1, 0.5,1])
calib_amp_array_pump=np.array([0.85,0.95,1.05,1.15,1.25])

calib_amp_pump, calib_amp_res=calib.full_power_calibration(qm,dll_path,calib_amp_array_res, calib_amp_array_pump, IF_readout, LO_readout, IF_fluxline, LO_fluxline)

calib_dict["calib_amp_array_res"]=calib_amp_array_res
calib_dict["calib_amp_array_pump"]= calib_amp_array_pump
calib_dict["calib_amp_pump"]=calib_amp_pump
calib_dict["calib_amp_res"]=calib_amp_res
# Out:
# 2023-07-20 12:51:05,921 - qm - INFO - Flags:
# 2023-07-20 12:51:05,922 - qm - INFO - Sending program to QOP
# 2023-07-20 12:51:05,951 - qm - INFO - Executing program
# 0
# 1
# 2
# Variation relative to the first calibration [1.0061745  1.00528775 1.0055075 ]
# Slope relative to the first intercept 1.0054447977990888
# Intercept relative to the first intercept 1.0714009105495692
# 2023-07-20 12:51:14,035 - qm - INFO - Flags:
# 2023-07-20 12:51:14,036 - qm - INFO - Sending program to QOP
# 2023-07-20 12:51:14,063 - qm - INFO - Executing program
# 0
# 1
# 2
# 3
# 4
# Variation relative to the first calibration [1.01081998 1.01069836 1.01092368 1.01030568 1.01117301]
# Slope relative to the first intercept 1.0112791377534596
# Intercept relative to the first intercept 0.8411303948409716

# %%
# %%time

Data={} #dictionnary to hold all the data 
Data[amp_factor]={}
freqs=freqs_dict[amp_factor]


Data={} #dictionnary to hold all the data 
Data[amp_factor]={}
freqs=freqs_dict[amp_factor]
calib_dict["res_freq"]={}
    

for idx,IF_pump in enumerate(freqs) :
    
    #Frequency calibration
    calib_pulse_len=50_000
    config,qm=cfg.update_readout_lenght(calib_pulse_len,config,qmm)

    calib_n_avg = 1000

    calib_cooldown_time = 50_000 // 4

    calib_f_min =149.75e6-0.25e6
    calib_f_max =149.75e6+0.25e6
    calib_df = 0.0025e6   #0.001e6 #0.001e6
    calib_amp_factor=0.01 #amplitude factor 

    calib_freqs,calib_I,calib_Q,calib_resonance_frequency, calib_error_frequency=calib.SingleResonatorSpec(qm,calib_n_avg,calib_pulse_len, calib_cooldown_time, calib_f_min, calib_f_max, calib_df, calib_amp_factor,LO_readout,plot=True)
    plt.close()
    
    calib_dict["res_freq"][IF_pump]={}
    calib_dict["res_freq"][IF_pump]["calib_freqs"]=calib_freqs
    calib_dict["res_freq"][IF_pump]["calib_I"]= calib_I
    calib_dict["res_freq"][IF_pump]["calib_Q"]=calib_Q
    calib_dict["res_freq"][IF_pump]["calib_resonance_frequency"]=calib_resonance_frequency
    calib_dict["res_freq"][IF_pump]["calib_error_frequency"]=calib_error_frequency

    #re update the readout length 
    config,qm=cfg.update_readout_lenght(Readout_Len,config,qmm)
    
    print("########################### Frequency "+str(IF_pump+LO_fluxline)+"########################### "+str(idx/len(freqs)))

    IF_resonator=(LO_fluxline+IF_pump)/2-LO_readout #demodulate at half of the pump IF by default 
    
    time,I,Q=single_IQ_trace(IF_pump,IF_resonator,Offset_IF,amp_factor,n_runs,Readout_Delay,points_delay,Readout_Len,qm)
    
    plt.close()
    
    Data[amp_factor][IF_pump]={}
    Data[amp_factor][IF_pump]["I"]=I
    Data[amp_factor][IF_pump]["Q"]=Q
    Data[amp_factor][IF_pump]["time"]=time
    
    
    if save_Data:
        datadict={}
        meastype_n=meastype+"_" +str(IF_pump)

        datadict["freqs_dict"]=freqs_dict
        datadict["Readout_Len"]=Readout_Len
        datadict["Readout_Delay"]=Readout_Delay*4
        datadict["octave_output_gain"]=octave_output_gain
        datadict["amp_factor_array"]=amp_factor_array
        datadict["points_delay"]=points_delay
        datadict["Data"]=Data
        datadict["config"]=config

        #Configuration file copy 
        datadict["LO_fluxline"]=LO_fluxline
        datadict["IF_readout"]=IF_resonator
        datadict["LO_readout"]=LO_readout
        
        datadict["calib"]=calib_dict

        an.save_with_numpy(datadict,  meastype_n, name, device, cooldown_date, filepath=Saving_Path)
        time_package.sleep(4)
# Out:
# 2023-07-20 12:51:39,075 - qm - INFO - Flags:
# 2023-07-20 12:51:39,075 - qm - INFO - Sending program to QOP
# 2023-07-20 12:51:40,085 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.08s
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.27s
# The measured resonance frequency is 4.349750189395766 GHz with an error of 1.1620708017929953e-06 GHz
# ########################### Frequency 8699400000.0########################### 0.0
# 2023-07-20 12:52:00,806 - qm - INFO - Flags:
# 2023-07-20 12:52:00,807 - qm - INFO - Sending program to QOP
# 2023-07-20 12:52:01,295 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 12:53:00,740 - qm - INFO - Flags:
# 2023-07-20 12:53:00,740 - qm - INFO - Sending program to QOP
# 2023-07-20 12:53:01,555 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.09s
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.28s
# The measured resonance frequency is 4.349752137297454 GHz with an error of 7.387369496786237e-07 GHz
# ########################### Frequency 8699420000.0########################### 0.038461538461538464
# 2023-07-20 12:53:22,497 - qm - INFO - Flags:
# 2023-07-20 12:53:22,498 - qm - INFO - Sending program to QOP
# 2023-07-20 12:53:22,621 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 12:54:23,437 - qm - INFO - Flags:
# 2023-07-20 12:54:23,437 - qm - INFO - Sending program to QOP
# 2023-07-20 12:54:24,471 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.15s
# The measured resonance frequency is 4.349752440179873 GHz with an error of 7.833925454553277e-07 GHz
# ########################### Frequency 8699440000.0########################### 0.07692307692307693
# 2023-07-20 12:54:45,077 - qm - INFO - Flags:
# 2023-07-20 12:54:45,077 - qm - INFO - Sending program to QOP
# 2023-07-20 12:54:45,583 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 12:55:49,620 - qm - INFO - Flags:
# 2023-07-20 12:55:49,620 - qm - INFO - Sending program to QOP
# 2023-07-20 12:55:50,446 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.09s
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.28s
# The measured resonance frequency is 4.3497503140474825 GHz with an error of 7.903955489286334e-07 GHz
# ########################### Frequency 8699460000.0########################### 0.11538461538461539
# 2023-07-20 12:56:11,417 - qm - INFO - Flags:
# 2023-07-20 12:56:11,418 - qm - INFO - Sending program to QOP
# 2023-07-20 12:56:11,540 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 12:57:11,896 - qm - INFO - Flags:
# 2023-07-20 12:57:11,897 - qm - INFO - Sending program to QOP
# 2023-07-20 12:57:12,847 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.08s
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.27s
# The measured resonance frequency is 4.34975093172282 GHz with an error of 7.307052866435355e-07 GHz
# ########################### Frequency 8699480000.0########################### 0.15384615384615385
# 2023-07-20 12:57:33,556 - qm - INFO - Flags:
# 2023-07-20 12:57:33,556 - qm - INFO - Sending program to QOP
# 2023-07-20 12:57:33,667 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 12:58:33,529 - qm - INFO - Flags:
# 2023-07-20 12:58:33,530 - qm - INFO - Sending program to QOP
# 2023-07-20 12:58:34,546 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.26s
# The measured resonance frequency is 4.349751167506661 GHz with an error of 1.0359101806687393e-06 GHz
# ########################### Frequency 8699500000.0########################### 0.19230769230769232
# 2023-07-20 12:58:55,234 - qm - INFO - Flags:
# 2023-07-20 12:58:55,234 - qm - INFO - Sending program to QOP
# 2023-07-20 12:58:55,351 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 12:59:58,568 - qm - INFO - Flags:
# 2023-07-20 12:59:58,568 - qm - INFO - Sending program to QOP
# 2023-07-20 12:59:59,393 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.19s
# The measured resonance frequency is 4.34975309461395 GHz with an error of 9.91735611012632e-07 GHz
# ########################### Frequency 8699520000.0########################### 0.23076923076923078
# 2023-07-20 13:00:20,240 - qm - INFO - Flags:
# 2023-07-20 13:00:20,240 - qm - INFO - Sending program to QOP
# 2023-07-20 13:00:20,364 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 13:01:19,939 - qm - INFO - Flags:
# 2023-07-20 13:01:19,940 - qm - INFO - Sending program to QOP
# 2023-07-20 13:01:20,972 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.28s
# The measured resonance frequency is 4.3497507400614825 GHz with an error of 7.945969922991629e-07 GHz
# ########################### Frequency 8699540000.0########################### 0.2692307692307692
# 2023-07-20 13:01:41,727 - qm - INFO - Flags:
# 2023-07-20 13:01:41,727 - qm - INFO - Sending program to QOP
# 2023-07-20 13:01:41,842 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 13:02:43,874 - qm - INFO - Flags:
# 2023-07-20 13:02:43,875 - qm - INFO - Sending program to QOP
# 2023-07-20 13:02:44,677 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.13s
# The measured resonance frequency is 4.349751769593037 GHz with an error of 7.451097136861567e-07 GHz
# ########################### Frequency 8699560000.0########################### 0.3076923076923077
# 2023-07-20 13:03:05,511 - qm - INFO - Flags:
# 2023-07-20 13:03:05,512 - qm - INFO - Sending program to QOP
# 2023-07-20 13:03:05,631 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 13:04:07,281 - qm - INFO - Flags:
# 2023-07-20 13:04:07,281 - qm - INFO - Sending program to QOP
# 2023-07-20 13:04:08,101 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.11s
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.28s
# The measured resonance frequency is 4.349753240441253 GHz with an error of 8.410981346719576e-07 GHz
# ########################### Frequency 8699580000.0########################### 0.34615384615384615
# 2023-07-20 13:04:29,060 - qm - INFO - Flags:
# 2023-07-20 13:04:29,061 - qm - INFO - Sending program to QOP
# 2023-07-20 13:04:29,188 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 13:05:30,469 - qm - INFO - Flags:
# 2023-07-20 13:05:30,469 - qm - INFO - Sending program to QOP
# 2023-07-20 13:05:31,293 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.16s
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.35s
# The measured resonance frequency is 4.349750886951389 GHz with an error of 1.096937617235544e-06 GHz
# ########################### Frequency 8699600000.0########################### 0.38461538461538464
# 2023-07-20 13:05:52,304 - qm - INFO - Flags:
# 2023-07-20 13:05:52,305 - qm - INFO - Sending program to QOP
# 2023-07-20 13:05:52,428 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 13:06:53,743 - qm - INFO - Flags:
# 2023-07-20 13:06:53,743 - qm - INFO - Sending program to QOP
# 2023-07-20 13:06:54,475 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.25s
# The measured resonance frequency is 4.349751417134786 GHz with an error of 8.793769399148572e-07 GHz
# ########################### Frequency 8699620000.0########################### 0.4230769230769231
# 2023-07-20 13:07:15,387 - qm - INFO - Flags:
# 2023-07-20 13:07:15,387 - qm - INFO - Sending program to QOP
# 2023-07-20 13:07:15,862 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 13:08:17,871 - qm - INFO - Flags:
# 2023-07-20 13:08:17,871 - qm - INFO - Sending program to QOP
# 2023-07-20 13:08:18,706 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.23s
# The measured resonance frequency is 4.349752816752877 GHz with an error of 8.788314906778154e-07 GHz
# ########################### Frequency 8699640000.0########################### 0.46153846153846156
# 2023-07-20 13:08:39,576 - qm - INFO - Flags:
# 2023-07-20 13:08:39,576 - qm - INFO - Sending program to QOP
# 2023-07-20 13:08:39,700 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 13:09:41,951 - qm - INFO - Flags:
# 2023-07-20 13:09:41,951 - qm - INFO - Sending program to QOP
# 2023-07-20 13:09:42,962 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.20s
# The measured resonance frequency is 4.349753117083227 GHz with an error of 1.0498191341129364e-06 GHz
# ########################### Frequency 8699660000.0########################### 0.5
# 2023-07-20 13:10:03,607 - qm - INFO - Flags:
# 2023-07-20 13:10:03,607 - qm - INFO - Sending program to QOP
# 2023-07-20 13:10:03,717 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 13:11:05,604 - qm - INFO - Flags:
# 2023-07-20 13:11:05,605 - qm - INFO - Sending program to QOP
# 2023-07-20 13:11:06,422 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.13s
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.30s
# The measured resonance frequency is 4.349751950594149 GHz with an error of 7.535014292355614e-07 GHz
# ########################### Frequency 8699680000.0########################### 0.5384615384615384
# 2023-07-20 13:11:27,368 - qm - INFO - Flags:
# 2023-07-20 13:11:27,369 - qm - INFO - Sending program to QOP
# 2023-07-20 13:11:27,821 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 13:12:30,995 - qm - INFO - Flags:
# 2023-07-20 13:12:30,996 - qm - INFO - Sending program to QOP
# 2023-07-20 13:12:31,990 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 19.77s
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 19.95s
# The measured resonance frequency is 4.349751528524071 GHz with an error of 7.57320322775145e-07 GHz
# ########################### Frequency 8699700000.0########################### 0.5769230769230769
# 2023-07-20 13:12:52,736 - qm - INFO - Flags:
# 2023-07-20 13:12:52,736 - qm - INFO - Sending program to QOP
# 2023-07-20 13:12:52,856 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 13:13:55,514 - qm - INFO - Flags:
# 2023-07-20 13:13:55,515 - qm - INFO - Sending program to QOP
# 2023-07-20 13:13:56,336 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.11s
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.28s
# The measured resonance frequency is 4.349751627620004 GHz with an error of 1.011391187002521e-06 GHz
# ########################### Frequency 8699720000.0########################### 0.6153846153846154
# 2023-07-20 13:14:17,213 - qm - INFO - Flags:
# 2023-07-20 13:14:17,213 - qm - INFO - Sending program to QOP
# 2023-07-20 13:14:17,663 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 13:15:19,409 - qm - INFO - Flags:
# 2023-07-20 13:15:19,410 - qm - INFO - Sending program to QOP
# 2023-07-20 13:15:20,224 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.15s
# The measured resonance frequency is 4.349751725731603 GHz with an error of 7.549463869000991e-07 GHz
# ########################### Frequency 8699740000.0########################### 0.6538461538461539
# 2023-07-20 13:15:41,039 - qm - INFO - Flags:
# 2023-07-20 13:15:41,039 - qm - INFO - Sending program to QOP
# 2023-07-20 13:15:41,161 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 13:16:43,678 - qm - INFO - Flags:
# 2023-07-20 13:16:43,678 - qm - INFO - Sending program to QOP
# 2023-07-20 13:16:44,414 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.19s
# The measured resonance frequency is 4.3497506651105535 GHz with an error of 9.533270576499378e-07 GHz
# ########################### Frequency 8699760000.0########################### 0.6923076923076923
# 2023-07-20 13:17:05,220 - qm - INFO - Flags:
# 2023-07-20 13:17:05,220 - qm - INFO - Sending program to QOP
# 2023-07-20 13:17:05,341 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 13:18:09,265 - qm - INFO - Flags:
# 2023-07-20 13:18:09,266 - qm - INFO - Sending program to QOP
# 2023-07-20 13:18:10,101 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.13s
# The measured resonance frequency is 4.3497508691302835 GHz with an error of 7.682846106962069e-07 GHz
# ########################### Frequency 8699780000.0########################### 0.7307692307692307
# 2023-07-20 13:18:30,924 - qm - INFO - Flags:
# 2023-07-20 13:18:30,924 - qm - INFO - Sending program to QOP
# 2023-07-20 13:18:31,049 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 13:19:34,508 - qm - INFO - Flags:
# 2023-07-20 13:19:34,508 - qm - INFO - Sending program to QOP
# 2023-07-20 13:19:35,338 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.19s
# The measured resonance frequency is 4.349753157924952 GHz with an error of 1.27392501735941e-06 GHz
# ########################### Frequency 8699800000.0########################### 0.7692307692307693
# 2023-07-20 13:19:56,167 - qm - INFO - Flags:
# 2023-07-20 13:19:56,168 - qm - INFO - Sending program to QOP
# 2023-07-20 13:19:56,298 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 13:20:56,158 - qm - INFO - Flags:
# 2023-07-20 13:20:56,159 - qm - INFO - Sending program to QOP
# 2023-07-20 13:20:56,983 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.17s
# The measured resonance frequency is 4.349751309430488 GHz with an error of 7.402958400278399e-07 GHz
# ########################### Frequency 8699820000.0########################### 0.8076923076923077
# 2023-07-20 13:21:17,851 - qm - INFO - Flags:
# 2023-07-20 13:21:17,852 - qm - INFO - Sending program to QOP
# 2023-07-20 13:21:17,978 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 13:22:20,610 - qm - INFO - Flags:
# 2023-07-20 13:22:20,611 - qm - INFO - Sending program to QOP
# 2023-07-20 13:22:21,379 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.13s
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.31s
# The measured resonance frequency is 4.349750005848616 GHz with an error of 7.228769630827092e-07 GHz
# ########################### Frequency 8699840000.0########################### 0.8461538461538461
# 2023-07-20 13:22:42,323 - qm - INFO - Flags:
# 2023-07-20 13:22:42,324 - qm - INFO - Sending program to QOP
# 2023-07-20 13:22:42,832 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 13:23:47,018 - qm - INFO - Flags:
# 2023-07-20 13:23:47,019 - qm - INFO - Sending program to QOP
# 2023-07-20 13:23:47,830 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.09s
# The measured resonance frequency is 4.349750716070923 GHz with an error of 8.243927820034461e-07 GHz
# ########################### Frequency 8699860000.0########################### 0.8846153846153846
# 2023-07-20 13:24:08,605 - qm - INFO - Flags:
# 2023-07-20 13:24:08,606 - qm - INFO - Sending program to QOP
# 2023-07-20 13:24:08,730 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 13:25:10,223 - qm - INFO - Flags:
# 2023-07-20 13:25:10,224 - qm - INFO - Sending program to QOP
# 2023-07-20 13:25:11,051 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.23s
# The measured resonance frequency is 4.349751949574732 GHz with an error of 6.996908578901607e-07 GHz
# ########################### Frequency 8699880000.0########################### 0.9230769230769231
# 2023-07-20 13:25:31,938 - qm - INFO - Flags:
# 2023-07-20 13:25:31,938 - qm - INFO - Sending program to QOP
# 2023-07-20 13:25:32,451 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-20 13:26:34,841 - qm - INFO - Flags:
# 2023-07-20 13:26:34,841 - qm - INFO - Sending program to QOP
# 2023-07-20 13:26:35,566 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.24s
# The measured resonance frequency is 4.349751534301096 GHz with an error of 7.078839596566132e-07 GHz
# ########################### Frequency 8699900000.0########################### 0.9615384615384616
# 2023-07-20 13:26:56,465 - qm - INFO - Flags:
# 2023-07-20 13:26:56,466 - qm - INFO - Sending program to QOP
# 2023-07-20 13:26:56,574 - qm - INFO - Executing program
# Execution stopped by user!
# Wall time: 36min 21s

# %% [markdown]
# ## Saving

# %%
#Saving the data 
cooldown_date=Cooldown_Date #top folder 
device="second_order_Transition" #second folder 
name="measurement_freq" # third folder 
meastype="1p25_994_to_999_fast" #Final file name 

datadict={}

datadict["freqs_dict"]=freqs_dict
datadict["Readout_Len"]=Readout_Len
datadict["Readout_Delay"]=Readout_Delay*4
datadict["octave_output_gain"]=octave_output_gain
datadict["amp_factor_array"]=amp_factor_array
datadict["points_delay"]=points_delay
datadict["Data"]=Data
datadict["config"]=config

#Configuration file copy 
datadict["LO_fluxline"]=LO_fluxline
datadict["IF_readout"]=IF_resonator
datadict["LO_readout"]=LO_readout

datadict["calib"]=calib_dict

an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)
# Out:
# saving

# %%
#Loading the data 

filepath= r"\\sb1files\HQC\Users\beaulieu\Data\Run01\104\2023_04_14\excit_to_vac\Multiple_freq\0p3_amp_test.npz"

npzfile=np.load(filepath,allow_pickle=True)
#npzfile["multidata"][()]

Pump_Delay=npzfile["multidata"][()]["Pump_Delay"]
Data=npzfile["multidata"][()]["Data"]
freqs_array=npzfile["multidata"][()]["freqs_array"]
amp_factor_array=npzfile["multidata"][()]["amp_factor_array"]
amp_factor_array_high=npzfile["multidata"][()]["amp_factor_array_high"]

# %% [markdown]
# ## Plotting for multiple frequencies

# %%
# %matplotlib qt 

n_bin=250 #bin size for the histogram 
figsize=(14,15)
fontsize=4
n_angle=100 #number of angles for the rotation 
n_avg=10 #number of average
dpi=300


amp_factor=amp_factor_array[0]
freqs=freqs_dict[amp_factor]

for idx in range(29,30):  #len(freqs)
    
    IF_pump=freqs[idx]
    I=Data[amp_factor][freqs[idx]]["I"]
    Q=Data[amp_factor][freqs[idx]]["Q"]
    time=Data[amp_factor][freqs[idx]]["time"]

    plot_init_av_single(I,Q,time*1e-9,n_avg,n_bin,n_angle,figsize,fontsize,dpi)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_40460\4214387371.py in <module>
#      15
#      16     IF_pump=freqs[idx]
# ---> 17     I=Data[amp_factor][freqs[idx]]["I"]
#      18     Q=Data[amp_factor][freqs[idx]]["Q"]
#      19     time=Data[amp_factor][freqs[idx]]["time"]
#
# KeyError: 99195000.0

# %%
plt.close("all")

# %%
# %matplotlib qt
nb_angle=150
n_avg=10
corr_length=500

Processed_Data=an.Extract_second_order_gap(Data,amp_factor_array,freqs_dict,nb_angle,n_avg,corr_length)
amp_factor=amp_factor_array[0]
freqs=freqs_dict[amp_factor]

for idx in range(len(freqs)):
    
    if Processed_Data[amp_factor][freqs[idx]]["fit"]:

        gap=Processed_Data[amp_factor][freqs[idx]]["gap"]
        coeff=Processed_Data[amp_factor][freqs[idx]]["fit_coeff"]
        time=Processed_Data[amp_factor][freqs[idx]]["time"]
        I=Processed_Data[amp_factor][freqs[idx]]["I"]
        y_fitted=Processed_Data[amp_factor][freqs[idx]]["y_fitted"]
        corr_list=Processed_Data[amp_factor][freqs[idx]]["corr_list"]

        fontsize=8
        fig, axs = plt.subplots( nrows=2, ncols=1, figsize=(5,10),dpi=100)
        ax=axs[1]
        ax.set_title("$\lambda= $"+str(round(gap,2)))
        ax.plot(time[0:corr_length],corr_list[0:corr_length],".")
        ax.plot(time[0:corr_length],y_fitted)
        ax.set_xlabel("time [s]")
        ax.set_ylabel("Autocorelation [Normalized]")
        
        ax=axs[0]
        ax.set_title("Pump= "+str(freqs[idx]) +" Iteration :" +str(idx))
        ax.plot(time,I*1e3,".")
        ax.set_xlabel("time [s]")
        ax.set_ylabel("I [mv]")


    else:
        print("No fit")
        time=Processed_Data[amp_factor][freqs[idx]]["time"]
        corr_list=Processed_Data[amp_factor][freqs[idx]]["corr_list"]
        
        
        
        fontsize=8
        fig, axs = plt.subplots( nrows=1, ncols=1, figsize=(5,5),dpi=100)
        ax=axs
        ax.set_title("Pump= "+str(freqs[idx]) +" Iteration :" +str(idx) + " No fit")
        ax.plot(time[0:corr_length],corr_list[0:corr_length])
        ax.set_xlabel("time [s]")
        ax.set_ylabel("Autocorelation [Normalized]")
# Out:
# 0
# No fit

# %% [markdown]
# ## Extracting the Liouvillian gap

# %%
# %matplotlib inline

amp_factor=amp_factor_array[0]
freqs=freqs_dict[amp_factor]

gap_array=[]
freq_gap_array=[]

for idx in range(len(freqs)):
    
    if Processed_Data[amp_factor][freqs[idx]]["fit"]:
        gap_array.append(Processed_Data[amp_factor][freqs[idx]]["gap"])
        freq_gap_array.append(freqs[idx])
        
gap_array=np.array(gap_array)
freq_gap_array=np.array(freq_gap_array)
        
        

# figsize=(5,4)

fontsize=8
figsize=(5,4)
fig, axs = plt.subplots( nrows=1, ncols=1, figsize=(5,5),dpi=200)

axs.plot(freq_gap_array/1e9,gap_array,'.-',alpha=.9, lw=.5, ms=8)
axs.set_xlabel("Pump frequency (IF)",fontsize=fontsize)
axs.set_ylabel("Louivillian gap",fontsize=fontsize)
axs.tick_params(axis='x', labelsize=fontsize)
axs.tick_params(axis='y', labelsize=fontsize)
axs.set_yscale('log')

# %% [markdown]
# # Multiple frequencies for first-order transition

# %%
#Select the frequencies 
freqs_dict={}

amp_factor_array=np.array([1.25]) #Prefactor of the amplitude 
amp_factor=amp_factor_array[0]

fmin= 98.95e6
fmax=99.05e6
df=0.005* u.MHz
freqs=np.arange(fmin, fmax+df/2, df)

freqs_dict[amp_factor]=freqs
print(freqs)
# Out:
# [98950000. 98955000. 98960000. 98965000. 98970000. 98975000. 98980000.
#  98985000. 98990000. 98995000. 99000000. 99005000. 99010000. 99015000.
#  99020000. 99025000. 99030000. 99035000. 99040000. 99045000. 99050000.]

# %%
# %matplotlib qt 

#Update the readout pulse 
Readout_Len=50_000 
config,qm=cfg.update_readout_lenght(Readout_Len,config,qmm)

n_runs =1_000_000 

Readout_Delay = 100_0000//4# Delay before the first readout in ns (convert from clockcycle)

Offset_IF=0  #

points_delay= 200_000  #Delay between readouts 


save_Data=False
#Saving the data
cooldown_date=Cooldown_Date #top folder 
device="second_order_IQ" #second folder 
name="second_order_0p95_500" # third folder 
meastype="0p95_500_corrected" 

print(amp_factor)

print("The different frequency {}".format(freqs))
Expected_time=((Readout_Len+points_delay*4)*n_runs*len(freqs))*1e-9/60
print("The expected time : {} min".format(Expected_time))
# Out:
# 1.25
# The different frequency [98950000. 98955000. 98960000. 98965000. 98970000. 98975000. 98980000.
#  98985000. 98990000. 98995000. 99000000. 99005000. 99010000. 99015000.
#  99020000. 99025000. 99030000. 99035000. 99040000. 99045000. 99050000.]
# The expected time : 297.5 min

# %%
calib_dict={}

calib_amp_array_res=np.array([0.1, 0.5,1])
calib_amp_array_pump=np.array([0.85,0.95,1.05,1.15,1.25])

calib_amp_pump, calib_amp_res=calib.full_power_calibration(qm,dll_path,calib_amp_array_res, calib_amp_array_pump, IF_readout, LO_readout, IF_fluxline, LO_fluxline)

calib_dict["calib_amp_array_res"]=calib_amp_array_res
calib_dict["calib_amp_array_pump"]= calib_amp_array_pump
calib_dict["calib_amp_pump"]=calib_amp_pump
calib_dict["calib_amp_res"]=calib_amp_res
# Out:
# 2023-07-26 18:45:26,964 - qm - INFO - Flags:
# 2023-07-26 18:45:26,965 - qm - INFO - Sending program to QOP
# 2023-07-26 18:45:26,995 - qm - INFO - Executing program
# 0
# 1
# 2
# Variation relative to the first calibration [1.00862931 1.00777553 1.00617534]
# Slope relative to the first intercept 1.005847394928626
# Intercept relative to the first intercept 3.101902553226181
# 2023-07-26 18:45:35,058 - qm - INFO - Flags:
# 2023-07-26 18:45:35,059 - qm - INFO - Sending program to QOP
# 2023-07-26 18:45:35,086 - qm - INFO - Executing program
# 0
# 1
# 2
# 3
# 4
# Variation relative to the first calibration [1.01414467 1.01438817 1.01456069 1.01366204 1.01449186]
# Slope relative to the first intercept 1.014278008092703
# Intercept relative to the first intercept 1.0218088332356976

# %%
# %%time

Data={} #dictionnary to hold all the data 
Data[amp_factor]={}
freqs=freqs_dict[amp_factor]


Data={} #dictionnary to hold all the data 
Data[amp_factor]={}
freqs=freqs_dict[amp_factor]
calib_dict["res_freq"]={}
    

for idx,IF_pump in enumerate(freqs) :
    
    #Frequency calibration
    calib_pulse_len=50_000
    config,qm=cfg.update_readout_lenght(calib_pulse_len,config,qmm)

    calib_n_avg = 1000

    calib_cooldown_time = 50_000 // 4

    calib_f_min =149.75e6-0.25e6
    calib_f_max =149.75e6+0.25e6
    calib_df = 0.0025e6   #0.001e6 #0.001e6
    calib_amp_factor=0.01 #amplitude factor 

    calib_freqs,calib_I,calib_Q,calib_resonance_frequency, calib_error_frequency=calib.SingleResonatorSpec(qm,calib_n_avg,calib_pulse_len, calib_cooldown_time, calib_f_min, calib_f_max, calib_df, calib_amp_factor,LO_readout,plot=True)
    plt.close()
    
    calib_dict["res_freq"][IF_pump]={}
    calib_dict["res_freq"][IF_pump]["calib_freqs"]=calib_freqs
    calib_dict["res_freq"][IF_pump]["calib_I"]= calib_I
    calib_dict["res_freq"][IF_pump]["calib_Q"]=calib_Q
    calib_dict["res_freq"][IF_pump]["calib_resonance_frequency"]=calib_resonance_frequency
    calib_dict["res_freq"][IF_pump]["calib_error_frequency"]=calib_error_frequency

    #re update the readout length 
    config,qm=cfg.update_readout_lenght(Readout_Len,config,qmm)
    
    print("########################### Frequency "+str(IF_pump+LO_fluxline)+"########################### "+str(idx/len(freqs)))

    IF_resonator=(LO_fluxline+IF_pump)/2-LO_readout #demodulate at half of the pump IF by default 
    
    time,I,Q=single_IQ_trace(IF_pump,IF_resonator,Offset_IF,amp_factor,n_runs,Readout_Delay,points_delay,Readout_Len,qm)
    
    plt.close()
    
    Data[amp_factor][IF_pump]={}
    Data[amp_factor][IF_pump]["I"]=I
    Data[amp_factor][IF_pump]["Q"]=Q
    Data[amp_factor][IF_pump]["time"]=time
    
    
    if save_Data:
        datadict={}
        meastype_n=meastype+"_" +str(IF_pump)

        datadict["freqs_dict"]=freqs_dict
        datadict["Readout_Len"]=Readout_Len
        datadict["Readout_Delay"]=Readout_Delay*4
        datadict["octave_output_gain"]=octave_output_gain
        datadict["amp_factor_array"]=amp_factor_array
        datadict["points_delay"]=points_delay
        datadict["Data"]=Data
        datadict["config"]=config

        #Configuration file copy 
        datadict["LO_fluxline"]=LO_fluxline
        datadict["IF_readout"]=IF_resonator
        datadict["LO_readout"]=LO_readout
        
        datadict["calib"]=calib_dict

        an.save_with_numpy(datadict,  meastype_n, name, device, cooldown_date, filepath=Saving_Path)
        time_package.sleep(4)
# Out:
# 2023-07-26 11:13:53,602 - qm - INFO - Flags:
# 2023-07-26 11:13:53,603 - qm - INFO - Sending program to QOP
# 2023-07-26 11:13:54,374 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.10s
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.28s
# The measured resonance frequency is 4.349736451093167 GHz with an error of 9.209253521345665e-07 GHz
# ########################### Frequency 8699000000.0########################### 0.0
# 2023-07-26 11:14:15,271 - qm - INFO - Flags:
# 2023-07-26 11:14:15,272 - qm - INFO - Sending program to QOP
# 2023-07-26 11:14:16,025 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-26 11:28:28,777 - qm - INFO - Flags:
# 2023-07-26 11:28:28,778 - qm - INFO - Sending program to QOP
# 2023-07-26 11:28:29,597 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.21s
# The measured resonance frequency is 4.349739460550266 GHz with an error of 1.0780913915620128e-06 GHz
# ########################### Frequency 8699005000.0########################### 0.09090909090909091
# 2023-07-26 11:28:50,501 - qm - INFO - Flags:
# 2023-07-26 11:28:50,501 - qm - INFO - Sending program to QOP
# 2023-07-26 11:28:50,918 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-26 11:43:04,069 - qm - INFO - Flags:
# 2023-07-26 11:43:04,070 - qm - INFO - Sending program to QOP
# 2023-07-26 11:43:04,834 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.17s
# The measured resonance frequency is 4.349741614859592 GHz with an error of 9.6754338684913e-07 GHz
# ########################### Frequency 8699010000.0########################### 0.18181818181818182
# 2023-07-26 11:43:25,680 - qm - INFO - Flags:
# 2023-07-26 11:43:25,680 - qm - INFO - Sending program to QOP
# 2023-07-26 11:43:26,107 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-26 11:57:38,646 - qm - INFO - Flags:
# 2023-07-26 11:57:38,647 - qm - INFO - Sending program to QOP
# 2023-07-26 11:57:39,661 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.18s
# The measured resonance frequency is 4.349739065479231 GHz with an error of 7.160174962030637e-07 GHz
# ########################### Frequency 8699015000.0########################### 0.2727272727272727
# 2023-07-26 11:58:00,308 - qm - INFO - Flags:
# 2023-07-26 11:58:00,309 - qm - INFO - Sending program to QOP
# 2023-07-26 11:58:00,755 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-26 12:12:13,810 - qm - INFO - Flags:
# 2023-07-26 12:12:13,810 - qm - INFO - Sending program to QOP
# 2023-07-26 12:12:14,656 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.21s
# The measured resonance frequency is 4.349739846343083 GHz with an error of 8.716581730349628e-07 GHz
# ########################### Frequency 8699020000.0########################### 0.36363636363636365
# 2023-07-26 12:12:35,538 - qm - INFO - Flags:
# 2023-07-26 12:12:35,538 - qm - INFO - Sending program to QOP
# 2023-07-26 12:12:35,969 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-26 12:26:49,173 - qm - INFO - Flags:
# 2023-07-26 12:26:49,174 - qm - INFO - Sending program to QOP
# 2023-07-26 12:26:50,007 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.12s
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.30s
# The measured resonance frequency is 4.349742493824591 GHz with an error of 1.0596777716042605e-06 GHz
# ########################### Frequency 8699025000.0########################### 0.45454545454545453
# 2023-07-26 12:27:10,987 - qm - INFO - Flags:
# 2023-07-26 12:27:10,987 - qm - INFO - Sending program to QOP
# 2023-07-26 12:27:11,425 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-26 12:41:24,218 - qm - INFO - Flags:
# 2023-07-26 12:41:24,219 - qm - INFO - Sending program to QOP
# 2023-07-26 12:41:25,272 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.12s
# The measured resonance frequency is 4.349739901224239 GHz with an error of 7.274739124663133e-07 GHz
# ########################### Frequency 8699030000.0########################### 0.5454545454545454
# 2023-07-26 12:41:45,866 - qm - INFO - Flags:
# 2023-07-26 12:41:45,867 - qm - INFO - Sending program to QOP
# 2023-07-26 12:41:46,290 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-26 12:55:59,514 - qm - INFO - Flags:
# 2023-07-26 12:55:59,514 - qm - INFO - Sending program to QOP
# 2023-07-26 12:56:00,311 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.09s
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.27s
# The measured resonance frequency is 4.349741363321156 GHz with an error of 1.009774880918584e-06 GHz
# ########################### Frequency 8699035000.0########################### 0.6363636363636364
# 2023-07-26 12:56:21,281 - qm - INFO - Flags:
# 2023-07-26 12:56:21,282 - qm - INFO - Sending program to QOP
# 2023-07-26 12:56:21,726 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-26 13:10:34,199 - qm - INFO - Flags:
# 2023-07-26 13:10:34,200 - qm - INFO - Sending program to QOP
# 2023-07-26 13:10:35,008 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.18s
# The measured resonance frequency is 4.349742388262871 GHz with an error of 8.457977921076787e-07 GHz
# ########################### Frequency 8699040000.0########################### 0.7272727272727273
# 2023-07-26 13:10:55,828 - qm - INFO - Flags:
# 2023-07-26 13:10:55,828 - qm - INFO - Sending program to QOP
# 2023-07-26 13:10:56,646 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-26 13:25:08,998 - qm - INFO - Flags:
# 2023-07-26 13:25:08,999 - qm - INFO - Sending program to QOP
# 2023-07-26 13:25:10,020 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.19s
# The measured resonance frequency is 4.34973888583901 GHz with an error of 6.714456715288263e-07 GHz
# ########################### Frequency 8699045000.0########################### 0.8181818181818182
# 2023-07-26 13:25:30,674 - qm - INFO - Flags:
# 2023-07-26 13:25:30,674 - qm - INFO - Sending program to QOP
# 2023-07-26 13:25:31,079 - qm - INFO - Executing program
# Execution stopped by user!
# 2023-07-26 13:39:43,646 - qm - INFO - Flags:
# 2023-07-26 13:39:43,647 - qm - INFO - Sending program to QOP
# 2023-07-26 13:39:44,618 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 20.21s
# The measured resonance frequency is 4.3497386263067845 GHz with an error of 7.373752155674529e-07 GHz
# ########################### Frequency 8699050000.0########################### 0.9090909090909091
# 2023-07-26 13:40:05,299 - qm - INFO - Flags:
# 2023-07-26 13:40:05,300 - qm - INFO - Sending program to QOP
# 2023-07-26 13:40:05,735 - qm - INFO - Executing program
# Execution stopped by user!
# Wall time: 2h 40min 24s

# %% [markdown]
# ## Saving

# %%
#Saving the data 
cooldown_date=Cooldown_Date #top folder 
device="first_order_Transition" #second folder 
name="measurement_freq" # third folder 
meastype="1p25_9905_to_99_more_points" #Final file name 

datadict={}

datadict["freqs_dict"]=freqs_dict
datadict["Readout_Len"]=Readout_Len
datadict["Readout_Delay"]=Readout_Delay*4
datadict["octave_output_gain"]=octave_output_gain
datadict["amp_factor_array"]=amp_factor_array
datadict["points_delay"]=points_delay
datadict["Data"]=Data
datadict["config"]=config

#Configuration file copy 
datadict["LO_fluxline"]=LO_fluxline
datadict["IF_readout"]=IF_resonator
datadict["LO_readout"]=LO_readout

datadict["calib"]=calib_dict

an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)
# Out:
# Warning select a new file name

# %%
#Loading the data 

filepath= r"\\sb1files\HQC\Users\beaulieu\Data\Run01\104\2023_04_14\excit_to_vac\Multiple_freq\0p3_amp_test.npz"

npzfile=np.load(filepath,allow_pickle=True)
#npzfile["multidata"][()]

Pump_Delay=npzfile["multidata"][()]["Pump_Delay"]
Data=npzfile["multidata"][()]["Data"]
freqs_array=npzfile["multidata"][()]["freqs_array"]
amp_factor_array=npzfile["multidata"][()]["amp_factor_array"]
amp_factor_array_high=npzfile["multidata"][()]["amp_factor_array_high"]

# %% [markdown]
# # Multiple amplitudes

# %%
#Select the frequencies & amplitudes factors 

#Sets of amplitude factors 
amp_factor_array=np.array([0.4,0.5, 0.6,0.7]) 

fmin= 196.1e6
fmax=196.6e6
df=0.025* u.MHz
freqs_array_1=np.arange(fmin, fmax+df/2, df)

fmin= 196.1e6
fmax=196.6e6
df=0.025* u.MHz
freqs_array_2=np.arange(fmin, fmax+df/2, df)

freqs_dict={}
freqs_dict[0.5]=freqs_array_1
freqs_dict[0.6]=freqs_array_2
freqs_dict[0.4]=freqs_array_2
freqs_dict[0.7]=freqs_array_2

#calculate the total number of frequencies 
number_frequencies=0
for i in range(len(amp_factor_array)):
    number_frequencies+=len(freqs_dict[amp_factor_array[i]])



freqs_dict
# Out:
# {0.5: array([1.96100e+08, 1.96125e+08, 1.96150e+08, 1.96175e+08, 1.96200e+08,
#         1.96225e+08, 1.96250e+08, 1.96275e+08, 1.96300e+08, 1.96325e+08,
#         1.96350e+08, 1.96375e+08, 1.96400e+08, 1.96425e+08, 1.96450e+08,
#         1.96475e+08, 1.96500e+08, 1.96525e+08, 1.96550e+08, 1.96575e+08,
#         1.96600e+08]),
#  0.6: array([1.96100e+08, 1.96125e+08, 1.96150e+08, 1.96175e+08, 1.96200e+08,
#         1.96225e+08, 1.96250e+08, 1.96275e+08, 1.96300e+08, 1.96325e+08,
#         1.96350e+08, 1.96375e+08, 1.96400e+08, 1.96425e+08, 1.96450e+08,
#         1.96475e+08, 1.96500e+08, 1.96525e+08, 1.96550e+08, 1.96575e+08,
#         1.96600e+08]),
#  0.4: array([1.96100e+08, 1.96125e+08, 1.96150e+08, 1.96175e+08, 1.96200e+08,
#         1.96225e+08, 1.96250e+08, 1.96275e+08, 1.96300e+08, 1.96325e+08,
#         1.96350e+08, 1.96375e+08, 1.96400e+08, 1.96425e+08, 1.96450e+08,
#         1.96475e+08, 1.96500e+08, 1.96525e+08, 1.96550e+08, 1.96575e+08,
#         1.96600e+08]),
#  0.7: array([1.96100e+08, 1.96125e+08, 1.96150e+08, 1.96175e+08, 1.96200e+08,
#         1.96225e+08, 1.96250e+08, 1.96275e+08, 1.96300e+08, 1.96325e+08,
#         1.96350e+08, 1.96375e+08, 1.96400e+08, 1.96425e+08, 1.96450e+08,
#         1.96475e+08, 1.96500e+08, 1.96525e+08, 1.96550e+08, 1.96575e+08,
#         1.96600e+08])}

# %%
# %matplotlib qt
#Update the readout pulse 
Readout_Len= 50_000     #6_557_763 #length of the readout pulse in ns 
config,qm=update_readout_lenght(Readout_Len,config,qmm)

n_runs = 500_000 #Number of readout to do 

Readout_Delay = 5000 //4 # Delay before the first readout in ns (convert from clockcycle)

Offset_IF=0  #

points_delay=16//4 #Delay between readouts 


save_Data=False
#Saving the data
cooldown_date=Cooldown_Date #top folder 
device="second_order_jumps" #second folder 
name="Multiple_amplitude" # third folder 
meastype="0p6_amp_test" #Final file name 


print("The different frequency {}".format(freqs_dict))
Expected_time=((Readout_Len+points_delay*4)*n_runs*number_frequencies)*1e-9/60
print("The expected time : {} min".format(Expected_time))
# Out:
# The different frequency {0.5: array([1.96100e+08, 1.96125e+08, 1.96150e+08, 1.96175e+08, 1.96200e+08,
#        1.96225e+08, 1.96250e+08, 1.96275e+08, 1.96300e+08, 1.96325e+08,
#        1.96350e+08, 1.96375e+08, 1.96400e+08, 1.96425e+08, 1.96450e+08,
#        1.96475e+08, 1.96500e+08, 1.96525e+08, 1.96550e+08, 1.96575e+08,
#        1.96600e+08]), 0.6: array([1.96100e+08, 1.96125e+08, 1.96150e+08, 1.96175e+08, 1.96200e+08,
#        1.96225e+08, 1.96250e+08, 1.96275e+08, 1.96300e+08, 1.96325e+08,
#        1.96350e+08, 1.96375e+08, 1.96400e+08, 1.96425e+08, 1.96450e+08,
#        1.96475e+08, 1.96500e+08, 1.96525e+08, 1.96550e+08, 1.96575e+08,
#        1.96600e+08]), 0.4: array([1.96100e+08, 1.96125e+08, 1.96150e+08, 1.96175e+08, 1.96200e+08,
#        1.96225e+08, 1.96250e+08, 1.96275e+08, 1.96300e+08, 1.96325e+08,
#        1.96350e+08, 1.96375e+08, 1.96400e+08, 1.96425e+08, 1.96450e+08,
#        1.96475e+08, 1.96500e+08, 1.96525e+08, 1.96550e+08, 1.96575e+08,
#        1.96600e+08]), 0.7: array([1.96100e+08, 1.96125e+08, 1.96150e+08, 1.96175e+08, 1.96200e+08,
#        1.96225e+08, 1.96250e+08, 1.96275e+08, 1.96300e+08, 1.96325e+08,
#        1.96350e+08, 1.96375e+08, 1.96400e+08, 1.96425e+08, 1.96450e+08,
#        1.96475e+08, 1.96500e+08, 1.96525e+08, 1.96550e+08, 1.96575e+08,
#        1.96600e+08])}
# The expected time : 35.0112 min

# %%
# %%time
Data={} #dictionnary to hold all the data 

for i in range(len(amp_factor_array)):

    amp_factor=amp_factor_array[i]
    freqs=freqs_dict[amp_factor] 
    
    print("####################################### Amplitude "+str(amp_factor)+"######################################## ")
   
    Data[amp_factor]={}
          
    for idx,IF_pump in enumerate(freqs):

        print("########################### Frequency "+str(IF_pump+LO_fluxline)+"########################### "+str(idx/len(freqs)))

        IF_resonator=(LO_fluxline+IF_pump)/2-LO_readout #demodulate at half of the pump IF by default 

        time,I,Q=single_IQ_trace(IF_pump,IF_resonator,Offset_IF,amp_factor,n_runs,Readout_Delay,points_delay,Readout_Len,qm)
        plt.close()
        
        Data[amp_factor][IF_pump]={}
        Data[amp_factor][IF_pump]["time"]=time
        Data[amp_factor][IF_pump]["I"]=I
        Data[amp_factor][IF_pump]["Q"]=Q
    
    
if save_Data:
    
    datadict={}
    datadict["freqs_dict"]=freqs_dict
    datadict["Readout_Len"]=Readout_Len
    datadict["Readout_Delay"]=Readout_Delay*4
    datadict["octave_output_gain"]=octave_output_gain
    datadict["amp_factor_array"]=amp_factor_array
    datadict["config"]["points_delay"]=points_delay
    datadict["Data"]=Data
    datadict["config"]=config

    #Configuration file copy 
    datadict["LO_fluxline"]=LO_fluxline
    datadict["IF_readout"]=IF_resonator
    datadict["LO_readout"]=LO_readout
    
    
    an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)
# Out:
# ####################################### Amplitude 0.4########################################
# ########################### Frequency 8696100000.0########################### 0.0
# 2023-05-01 11:35:24,045 - qm - INFO - Flags:
# 2023-05-01 11:35:24,045 - qm - INFO - Sending program to QOP
# 2023-05-01 11:35:24,930 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696125000.0########################### 0.047619047619047616
# 2023-05-01 11:35:51,355 - qm - INFO - Flags:
# 2023-05-01 11:35:51,356 - qm - INFO - Sending program to QOP
# 2023-05-01 11:35:51,819 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696150000.0########################### 0.09523809523809523
# 2023-05-01 11:36:19,020 - qm - INFO - Flags:
# 2023-05-01 11:36:19,021 - qm - INFO - Sending program to QOP
# 2023-05-01 11:36:19,849 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696175000.0########################### 0.14285714285714285
# 2023-05-01 11:36:46,395 - qm - INFO - Flags:
# 2023-05-01 11:36:46,396 - qm - INFO - Sending program to QOP
# 2023-05-01 11:36:47,286 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696200000.0########################### 0.19047619047619047
# 2023-05-01 11:37:13,618 - qm - INFO - Flags:
# 2023-05-01 11:37:13,619 - qm - INFO - Sending program to QOP
# 2023-05-01 11:37:14,025 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696225000.0########################### 0.23809523809523808
# 2023-05-01 11:37:40,957 - qm - INFO - Flags:
# 2023-05-01 11:37:40,958 - qm - INFO - Sending program to QOP
# 2023-05-01 11:37:41,398 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696250000.0########################### 0.2857142857142857
# 2023-05-01 11:38:08,513 - qm - INFO - Flags:
# 2023-05-01 11:38:08,514 - qm - INFO - Sending program to QOP
# 2023-05-01 11:38:09,342 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696275000.0########################### 0.3333333333333333
# 2023-05-01 11:38:35,990 - qm - INFO - Flags:
# 2023-05-01 11:38:35,992 - qm - INFO - Sending program to QOP
# 2023-05-01 11:38:36,448 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696300000.0########################### 0.38095238095238093
# 2023-05-01 11:39:03,327 - qm - INFO - Flags:
# 2023-05-01 11:39:03,328 - qm - INFO - Sending program to QOP
# 2023-05-01 11:39:03,791 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696325000.0########################### 0.42857142857142855
# 2023-05-01 11:39:30,437 - qm - INFO - Flags:
# 2023-05-01 11:39:30,438 - qm - INFO - Sending program to QOP
# 2023-05-01 11:39:30,894 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696350000.0########################### 0.47619047619047616
# 2023-05-01 11:39:58,180 - qm - INFO - Flags:
# 2023-05-01 11:39:58,181 - qm - INFO - Sending program to QOP
# 2023-05-01 11:39:58,640 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696375000.0########################### 0.5238095238095238
# 2023-05-01 11:40:25,452 - qm - INFO - Flags:
# 2023-05-01 11:40:25,453 - qm - INFO - Sending program to QOP
# 2023-05-01 11:40:25,910 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696400000.0########################### 0.5714285714285714
# 2023-05-01 11:40:53,358 - qm - INFO - Flags:
# 2023-05-01 11:40:53,359 - qm - INFO - Sending program to QOP
# 2023-05-01 11:40:53,810 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696425000.0########################### 0.6190476190476191
# 2023-05-01 11:41:20,673 - qm - INFO - Flags:
# 2023-05-01 11:41:20,674 - qm - INFO - Sending program to QOP
# 2023-05-01 11:41:21,093 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696450000.0########################### 0.6666666666666666
# 2023-05-01 11:41:47,875 - qm - INFO - Flags:
# 2023-05-01 11:41:47,876 - qm - INFO - Sending program to QOP
# 2023-05-01 11:41:48,726 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696475000.0########################### 0.7142857142857143
# 2023-05-01 11:42:15,487 - qm - INFO - Flags:
# 2023-05-01 11:42:15,488 - qm - INFO - Sending program to QOP
# 2023-05-01 11:42:16,251 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696500000.0########################### 0.7619047619047619
# 2023-05-01 11:42:42,544 - qm - INFO - Flags:
# 2023-05-01 11:42:42,545 - qm - INFO - Sending program to QOP
# 2023-05-01 11:42:43,381 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696525000.0########################### 0.8095238095238095
# 2023-05-01 11:43:10,148 - qm - INFO - Flags:
# 2023-05-01 11:43:10,149 - qm - INFO - Sending program to QOP
# 2023-05-01 11:43:10,605 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696550000.0########################### 0.8571428571428571
# 2023-05-01 11:43:37,933 - qm - INFO - Flags:
# 2023-05-01 11:43:37,934 - qm - INFO - Sending program to QOP
# 2023-05-01 11:43:38,392 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696575000.0########################### 0.9047619047619048
# 2023-05-01 11:44:05,342 - qm - INFO - Flags:
# 2023-05-01 11:44:05,343 - qm - INFO - Sending program to QOP
# 2023-05-01 11:44:06,187 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696600000.0########################### 0.9523809523809523
# 2023-05-01 11:44:33,151 - qm - INFO - Flags:
# 2023-05-01 11:44:33,152 - qm - INFO - Sending program to QOP
# 2023-05-01 11:44:33,602 - qm - INFO - Executing program
# Execution stopped by user!
# ####################################### Amplitude 0.5########################################
# ########################### Frequency 8696100000.0########################### 0.0
# 2023-05-01 11:45:00,686 - qm - INFO - Flags:
# 2023-05-01 11:45:00,687 - qm - INFO - Sending program to QOP
# 2023-05-01 11:45:01,187 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696125000.0########################### 0.047619047619047616
# 2023-05-01 11:45:28,461 - qm - INFO - Flags:
# 2023-05-01 11:45:28,462 - qm - INFO - Sending program to QOP
# 2023-05-01 11:45:29,232 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696150000.0########################### 0.09523809523809523
# 2023-05-01 11:45:56,243 - qm - INFO - Flags:
# 2023-05-01 11:45:56,244 - qm - INFO - Sending program to QOP
# 2023-05-01 11:45:57,107 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696175000.0########################### 0.14285714285714285
# 2023-05-01 11:46:23,505 - qm - INFO - Flags:
# 2023-05-01 11:46:23,506 - qm - INFO - Sending program to QOP
# 2023-05-01 11:46:23,958 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696200000.0########################### 0.19047619047619047
# 2023-05-01 11:46:50,629 - qm - INFO - Flags:
# 2023-05-01 11:46:50,630 - qm - INFO - Sending program to QOP
# 2023-05-01 11:46:51,495 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696225000.0########################### 0.23809523809523808
# 2023-05-01 11:47:18,049 - qm - INFO - Flags:
# 2023-05-01 11:47:18,050 - qm - INFO - Sending program to QOP
# 2023-05-01 11:47:18,500 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696250000.0########################### 0.2857142857142857
# 2023-05-01 11:47:45,689 - qm - INFO - Flags:
# 2023-05-01 11:47:45,690 - qm - INFO - Sending program to QOP
# 2023-05-01 11:47:46,158 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696275000.0########################### 0.3333333333333333
# 2023-05-01 11:48:13,295 - qm - INFO - Flags:
# 2023-05-01 11:48:13,296 - qm - INFO - Sending program to QOP
# 2023-05-01 11:48:13,740 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696300000.0########################### 0.38095238095238093
# 2023-05-01 11:48:40,570 - qm - INFO - Flags:
# 2023-05-01 11:48:40,570 - qm - INFO - Sending program to QOP
# 2023-05-01 11:48:41,017 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696325000.0########################### 0.42857142857142855
# 2023-05-01 11:49:07,904 - qm - INFO - Flags:
# 2023-05-01 11:49:07,906 - qm - INFO - Sending program to QOP
# 2023-05-01 11:49:08,311 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696350000.0########################### 0.47619047619047616
# 2023-05-01 11:49:35,257 - qm - INFO - Flags:
# 2023-05-01 11:49:35,258 - qm - INFO - Sending program to QOP
# 2023-05-01 11:49:35,689 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696375000.0########################### 0.5238095238095238
# 2023-05-01 11:50:02,740 - qm - INFO - Flags:
# 2023-05-01 11:50:02,741 - qm - INFO - Sending program to QOP
# 2023-05-01 11:50:03,196 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696400000.0########################### 0.5714285714285714
# 2023-05-01 11:50:30,028 - qm - INFO - Flags:
# 2023-05-01 11:50:30,029 - qm - INFO - Sending program to QOP
# 2023-05-01 11:50:30,867 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696425000.0########################### 0.6190476190476191
# 2023-05-01 11:50:57,918 - qm - INFO - Flags:
# 2023-05-01 11:50:57,919 - qm - INFO - Sending program to QOP
# 2023-05-01 11:50:58,369 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696450000.0########################### 0.6666666666666666
# 2023-05-01 11:51:25,318 - qm - INFO - Flags:
# 2023-05-01 11:51:25,319 - qm - INFO - Sending program to QOP
# 2023-05-01 11:51:26,131 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696475000.0########################### 0.7142857142857143
# 2023-05-01 11:51:52,490 - qm - INFO - Flags:
# 2023-05-01 11:51:52,491 - qm - INFO - Sending program to QOP
# 2023-05-01 11:51:52,937 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696500000.0########################### 0.7619047619047619
# 2023-05-01 11:52:19,856 - qm - INFO - Flags:
# 2023-05-01 11:52:19,857 - qm - INFO - Sending program to QOP
# 2023-05-01 11:52:20,683 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696525000.0########################### 0.8095238095238095
# 2023-05-01 11:52:47,248 - qm - INFO - Flags:
# 2023-05-01 11:52:47,249 - qm - INFO - Sending program to QOP
# 2023-05-01 11:52:47,668 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696550000.0########################### 0.8571428571428571
# 2023-05-01 11:53:14,510 - qm - INFO - Flags:
# 2023-05-01 11:53:14,511 - qm - INFO - Sending program to QOP
# 2023-05-01 11:53:14,961 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696575000.0########################### 0.9047619047619048
# 2023-05-01 11:53:42,391 - qm - INFO - Flags:
# 2023-05-01 11:53:42,391 - qm - INFO - Sending program to QOP
# 2023-05-01 11:53:43,196 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696600000.0########################### 0.9523809523809523
# 2023-05-01 11:54:09,910 - qm - INFO - Flags:
# 2023-05-01 11:54:09,910 - qm - INFO - Sending program to QOP
# 2023-05-01 11:54:10,751 - qm - INFO - Executing program
# Execution stopped by user!
# ####################################### Amplitude 0.6########################################
# ########################### Frequency 8696100000.0########################### 0.0
# 2023-05-01 11:54:37,636 - qm - INFO - Flags:
# 2023-05-01 11:54:37,637 - qm - INFO - Sending program to QOP
# 2023-05-01 11:54:38,463 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696125000.0########################### 0.047619047619047616
# 2023-05-01 11:55:04,853 - qm - INFO - Flags:
# 2023-05-01 11:55:04,854 - qm - INFO - Sending program to QOP
# 2023-05-01 11:55:05,672 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696150000.0########################### 0.09523809523809523
# 2023-05-01 11:55:32,744 - qm - INFO - Flags:
# 2023-05-01 11:55:32,745 - qm - INFO - Sending program to QOP
# 2023-05-01 11:55:33,186 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696175000.0########################### 0.14285714285714285
# 2023-05-01 11:56:00,363 - qm - INFO - Flags:
# 2023-05-01 11:56:00,364 - qm - INFO - Sending program to QOP
# 2023-05-01 11:56:00,841 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696200000.0########################### 0.19047619047619047
# 2023-05-01 11:56:27,766 - qm - INFO - Flags:
# 2023-05-01 11:56:27,767 - qm - INFO - Sending program to QOP
# 2023-05-01 11:56:28,171 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696225000.0########################### 0.23809523809523808
# 2023-05-01 11:56:55,488 - qm - INFO - Flags:
# 2023-05-01 11:56:55,489 - qm - INFO - Sending program to QOP
# 2023-05-01 11:56:56,277 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696250000.0########################### 0.2857142857142857
# 2023-05-01 11:57:23,013 - qm - INFO - Flags:
# 2023-05-01 11:57:23,014 - qm - INFO - Sending program to QOP
# 2023-05-01 11:57:23,472 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696275000.0########################### 0.3333333333333333
# 2023-05-01 11:57:50,843 - qm - INFO - Flags:
# 2023-05-01 11:57:50,843 - qm - INFO - Sending program to QOP
# 2023-05-01 11:57:51,682 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696300000.0########################### 0.38095238095238093
# 2023-05-01 11:58:18,283 - qm - INFO - Flags:
# 2023-05-01 11:58:18,284 - qm - INFO - Sending program to QOP
# 2023-05-01 11:58:18,749 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696325000.0########################### 0.42857142857142855
# 2023-05-01 11:58:45,388 - qm - INFO - Flags:
# 2023-05-01 11:58:45,389 - qm - INFO - Sending program to QOP
# 2023-05-01 11:58:45,835 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696350000.0########################### 0.47619047619047616
# 2023-05-01 11:59:12,608 - qm - INFO - Flags:
# 2023-05-01 11:59:12,609 - qm - INFO - Sending program to QOP
# 2023-05-01 11:59:13,087 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696375000.0########################### 0.5238095238095238
# 2023-05-01 11:59:40,066 - qm - INFO - Flags:
# 2023-05-01 11:59:40,067 - qm - INFO - Sending program to QOP
# 2023-05-01 11:59:40,484 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696400000.0########################### 0.5714285714285714
# 2023-05-01 12:00:07,720 - qm - INFO - Flags:
# 2023-05-01 12:00:07,721 - qm - INFO - Sending program to QOP
# 2023-05-01 12:00:08,156 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696425000.0########################### 0.6190476190476191
# 2023-05-01 12:00:34,975 - qm - INFO - Flags:
# 2023-05-01 12:00:34,976 - qm - INFO - Sending program to QOP
# 2023-05-01 12:00:35,434 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696450000.0########################### 0.6666666666666666
# 2023-05-01 12:01:02,578 - qm - INFO - Flags:
# 2023-05-01 12:01:02,579 - qm - INFO - Sending program to QOP
# 2023-05-01 12:01:03,024 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696475000.0########################### 0.7142857142857143
# 2023-05-01 12:01:30,245 - qm - INFO - Flags:
# 2023-05-01 12:01:30,246 - qm - INFO - Sending program to QOP
# 2023-05-01 12:01:30,694 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696500000.0########################### 0.7619047619047619
# 2023-05-01 12:01:57,788 - qm - INFO - Flags:
# 2023-05-01 12:01:57,789 - qm - INFO - Sending program to QOP
# 2023-05-01 12:01:58,233 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696525000.0########################### 0.8095238095238095
# 2023-05-01 12:02:24,905 - qm - INFO - Flags:
# 2023-05-01 12:02:24,906 - qm - INFO - Sending program to QOP
# 2023-05-01 12:02:25,364 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696550000.0########################### 0.8571428571428571
# 2023-05-01 12:02:52,334 - qm - INFO - Flags:
# 2023-05-01 12:02:52,335 - qm - INFO - Sending program to QOP
# 2023-05-01 12:02:52,762 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696575000.0########################### 0.9047619047619048
# 2023-05-01 12:03:20,077 - qm - INFO - Flags:
# 2023-05-01 12:03:20,078 - qm - INFO - Sending program to QOP
# 2023-05-01 12:03:20,531 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696600000.0########################### 0.9523809523809523
# 2023-05-01 12:03:47,572 - qm - INFO - Flags:
# 2023-05-01 12:03:47,573 - qm - INFO - Sending program to QOP
# 2023-05-01 12:03:48,450 - qm - INFO - Executing program
# Execution stopped by user!
# ####################################### Amplitude 0.7########################################
# ########################### Frequency 8696100000.0########################### 0.0
# 2023-05-01 12:04:14,857 - qm - INFO - Flags:
# 2023-05-01 12:04:14,858 - qm - INFO - Sending program to QOP
# 2023-05-01 12:04:15,278 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696125000.0########################### 0.047619047619047616
# 2023-05-01 12:04:41,974 - qm - INFO - Flags:
# 2023-05-01 12:04:41,976 - qm - INFO - Sending program to QOP
# 2023-05-01 12:04:42,412 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696150000.0########################### 0.09523809523809523
# 2023-05-01 12:05:09,590 - qm - INFO - Flags:
# 2023-05-01 12:05:09,591 - qm - INFO - Sending program to QOP
# 2023-05-01 12:05:10,028 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696175000.0########################### 0.14285714285714285
# 2023-05-01 12:05:36,896 - qm - INFO - Flags:
# 2023-05-01 12:05:36,897 - qm - INFO - Sending program to QOP
# 2023-05-01 12:05:37,353 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696200000.0########################### 0.19047619047619047
# 2023-05-01 12:06:04,441 - qm - INFO - Flags:
# 2023-05-01 12:06:04,441 - qm - INFO - Sending program to QOP
# 2023-05-01 12:06:05,285 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696225000.0########################### 0.23809523809523808
# 2023-05-01 12:06:31,579 - qm - INFO - Flags:
# 2023-05-01 12:06:31,580 - qm - INFO - Sending program to QOP
# 2023-05-01 12:06:32,029 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696250000.0########################### 0.2857142857142857
# 2023-05-01 12:06:59,088 - qm - INFO - Flags:
# 2023-05-01 12:06:59,089 - qm - INFO - Sending program to QOP
# 2023-05-01 12:06:59,543 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696275000.0########################### 0.3333333333333333
# 2023-05-01 12:07:26,461 - qm - INFO - Flags:
# 2023-05-01 12:07:26,461 - qm - INFO - Sending program to QOP
# 2023-05-01 12:07:27,324 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696300000.0########################### 0.38095238095238093
# 2023-05-01 12:07:53,730 - qm - INFO - Flags:
# 2023-05-01 12:07:53,731 - qm - INFO - Sending program to QOP
# 2023-05-01 12:07:54,138 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696325000.0########################### 0.42857142857142855
# 2023-05-01 12:08:21,081 - qm - INFO - Flags:
# 2023-05-01 12:08:21,082 - qm - INFO - Sending program to QOP
# 2023-05-01 12:08:21,928 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696350000.0########################### 0.47619047619047616
# 2023-05-01 12:08:48,875 - qm - INFO - Flags:
# 2023-05-01 12:08:48,876 - qm - INFO - Sending program to QOP
# 2023-05-01 12:08:49,326 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696375000.0########################### 0.5238095238095238
# 2023-05-01 12:09:16,595 - qm - INFO - Flags:
# 2023-05-01 12:09:16,596 - qm - INFO - Sending program to QOP
# 2023-05-01 12:09:17,052 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696400000.0########################### 0.5714285714285714
# 2023-05-01 12:09:44,333 - qm - INFO - Flags:
# 2023-05-01 12:09:44,333 - qm - INFO - Sending program to QOP
# 2023-05-01 12:09:45,153 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696425000.0########################### 0.6190476190476191
# 2023-05-01 12:10:11,912 - qm - INFO - Flags:
# 2023-05-01 12:10:11,913 - qm - INFO - Sending program to QOP
# 2023-05-01 12:10:12,739 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696450000.0########################### 0.6666666666666666
# 2023-05-01 12:10:39,459 - qm - INFO - Flags:
# 2023-05-01 12:10:39,460 - qm - INFO - Sending program to QOP
# 2023-05-01 12:10:40,288 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696475000.0########################### 0.7142857142857143
# 2023-05-01 12:11:06,756 - qm - INFO - Flags:
# 2023-05-01 12:11:06,757 - qm - INFO - Sending program to QOP
# 2023-05-01 12:11:07,237 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696500000.0########################### 0.7619047619047619
# 2023-05-01 12:11:34,492 - qm - INFO - Flags:
# 2023-05-01 12:11:34,493 - qm - INFO - Sending program to QOP
# 2023-05-01 12:11:35,266 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696525000.0########################### 0.8095238095238095
# 2023-05-01 12:12:02,161 - qm - INFO - Flags:
# 2023-05-01 12:12:02,162 - qm - INFO - Sending program to QOP
# 2023-05-01 12:12:02,605 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696550000.0########################### 0.8571428571428571
# 2023-05-01 12:12:29,233 - qm - INFO - Flags:
# 2023-05-01 12:12:29,234 - qm - INFO - Sending program to QOP
# 2023-05-01 12:12:29,675 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696575000.0########################### 0.9047619047619048
# 2023-05-01 12:12:56,406 - qm - INFO - Flags:
# 2023-05-01 12:12:56,407 - qm - INFO - Sending program to QOP
# 2023-05-01 12:12:56,889 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696600000.0########################### 0.9523809523809523
# 2023-05-01 12:13:23,637 - qm - INFO - Flags:
# 2023-05-01 12:13:23,638 - qm - INFO - Sending program to QOP
# 2023-05-01 12:13:24,479 - qm - INFO - Executing program
# Execution stopped by user!
# Wall time: 38min 27s

# %% [markdown]
# ## Saving

# %%
#Saving the data 
cooldown_date=Cooldown_Date #top folder 
device="second_order" #second folder 
name="Multiple_amp" # third folder 
meastype="small_map_test" #Final file name 

datadict={}

datadict["freqs_dict"]=freqs_dict
datadict["Readout_Len"]=Readout_Len
datadict["Readout_Delay"]=Readout_Delay*4
datadict["octave_output_gain"]=octave_output_gain
datadict["amp_factor_array"]=amp_factor_array
datadict["points_delay"]=points_delay
datadict["Data"]=Data
datadict["config"]=config

#Configuration file copy 
datadict["LO_fluxline"]=LO_fluxline
datadict["IF_readout"]=IF_resonator
datadict["LO_readout"]=LO_readout

an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)
# Out:
# saving in new directory

# %% [markdown]
# ## Ploting for different frequencies

# %%
# %matplotlib qt
nb_angle=150
n_avg=10
corr_length=1000

Processed_Data=an.Extract_second_order_gap(Data,amp_factor_array,freqs_dict,nb_angle,n_avg,corr_length)
# Out:
# 0
# 1
# 2
# 3
# No fit
# No fit

# %%
# %matplotlib qt
idx=2
amp_factor=amp_factor_array[idx]
freqs=freqs_dict[amp_factor]

for idx in range(len(freqs)):
    
    if Processed_Data[amp_factor][freqs[idx]]["fit"]:

        gap=Processed_Data[amp_factor][freqs[idx]]["gap"]
        coeff=Processed_Data[amp_factor][freqs[idx]]["fit_coeff"]
        time=Processed_Data[amp_factor][freqs[idx]]["time"]
        I=Processed_Data[amp_factor][freqs[idx]]["I"]
        y_fitted=Processed_Data[amp_factor][freqs[idx]]["y_fitted"]
        corr_list=Processed_Data[amp_factor][freqs[idx]]["corr_list"]

        fontsize=8
        fig, axs = plt.subplots( nrows=2, ncols=1, figsize=(5,10),dpi=100)
        ax=axs[1]
        ax.set_title("$\lambda= $"+str(round(gap,2)))
        ax.plot(time[0:corr_length],corr_list[0:corr_length],".")
        ax.plot(time[0:corr_length],y_fitted)
        ax.set_xlabel("time [s]")
        ax.set_ylabel("Autocorelation [Normalized]")
        
        ax=axs[0]
        ax.set_title("Pump= "+str(freqs[idx]) +" Iteration :" +str(idx))
        ax.plot(time,I*1e3,".")
        ax.set_xlabel("time [s]")
        ax.set_ylabel("I [mv]")


    else:
        print("No fit")
        time=Processed_Data[amp_factor][freqs[idx]]["time"]
        corr_list=Processed_Data[amp_factor][freqs[idx]]["corr_list"]
        
        
        
        fontsize=8
        fig, axs = plt.subplots( nrows=1, ncols=1, figsize=(5,5),dpi=100)
        ax=axs
        ax.set_title("Pump= "+str(freqs[idx]) +" Iteration :" +str(idx) + " No fit")
        ax.plot(time[0:corr_length],corr_list[0:corr_length])
        ax.set_xlabel("time [s]")
        ax.set_ylabel("Autocorelation [Normalized]")
# Out:
# No fit

# %% [markdown]
# ## Extracting the Liouivillian gap

# %%
# %matplotlib inline

center_freq=4.34799e9*2
Gi=0.6

fontsize=8
figsize=(5,4)
fig, axs = plt.subplots( ncols=2, figsize=(14,6))

for j in range(len(amp_factor_array)):
    
    amp_factor=amp_factor_array[j]
    freqs=freqs_dict[amp_factor]
    gap_array=[]
    freq_gap_array=[]
    
    for idx in range(len(freqs)):

        if Processed_Data[amp_factor][freqs[idx]]["fit"]:
            gap_array.append(Processed_Data[amp_factor][freqs[idx]]["gap"])
            freq_gap_array.append(freqs[idx])
        
    gap_array=np.array(gap_array)
    freq_gap_array=np.array(freq_gap_array)
    
    ax=axs[0]
    ax.plot(freq_gap_array/1e9,gap_array,".-",label=f'Pump={amp_factor:.1f}', alpha=.9, lw=.5, ms=8)    
    ax=axs[1]
    Gx=amp_factor
    ax.plot( ((freq_gap_array+LO_fluxline)-center_freq)*Gi/Gx,gap_array,".-",label=f'Pump={amp_factor:.1f}', alpha=.9, lw=.5, ms=8)
  
ax=axs[0]
ax.set_xlabel("Pump frequency (IF)",fontsize=fontsize)
ax.set_ylabel("Louivillian gap",fontsize=fontsize)
ax.tick_params(axis='x', labelsize=fontsize)
ax.tick_params(axis='y', labelsize=fontsize)  
ax.legend(fontsize=fontsize)
ax.set_yscale('log')

ax=axs[1]
ax.set_title("Normalized")
ax.set_ylabel("Louivillian gap",fontsize=fontsize)
ax.tick_params(axis='x', labelsize=fontsize)
ax.tick_params(axis='y', labelsize=fontsize) 
ax.set_xlabel('$\Delta\cdot$F')
ax.legend(fontsize=fontsize)
ax.set_yscale('log')

# %% [markdown]
# # Multiple frequencies for second-order transition

# %%
#Select the frequencies 
freqs_dict={}

amp_factor_array=np.array([1.15]) #Prefactor of the amplitude 
amp_factor=amp_factor_array[0]

fmin= 99.57e6
fmax=99.72e6
df=0.0025* u.MHz
freqs=np.arange(fmin, fmax+df/2, df)

freqs=np.array([99715000.0, 99577500.0,99610000.0])  

freqs_dict[amp_factor]=freqs
print(freqs)
# Out:
# [99715000. 99577500. 99610000.]

# %%
# %matplotlib qt 

#Update the readout pulse 
Readout_Len=500 
config,qm=cfg.update_readout_lenght(Readout_Len,config,qmm)

n_runs =10_000_000 

Readout_Delay = 100_0000//4# Delay before the first readout in ns (convert from clockcycle)

Offset_IF=0  #

points_delay= 16//4  #Delay between readouts 


save_Data=True 
#Saving the data
cooldown_date=Cooldown_Date #top folder device="second_order_IQ" #second folder 
name="second_order_1p15_500" # third folder 
meastype="1p15" 

print(amp_factor)

print("The different frequency {}".format(freqs))
Expected_time=((Readout_Len+points_delay*4)*n_runs*len(freqs))*1e-9/60
print("The expected time : {} min".format(Expected_time))
# Out:
# 1.15
# The different frequency [99715000. 99577500. 99610000.]
# The expected time : 0.258 min

# %%
calib_dict={}

calib_amp_array_res=np.array([0.1, 0.5,1])
calib_amp_array_pump=np.array([0.85,0.95,1.05,1.15,1.25])

calib_amp_pump, calib_amp_res=calib.full_power_calibration(qm,dll_path,calib_amp_array_res, calib_amp_array_pump, IF_readout, LO_readout, IF_fluxline, LO_fluxline)

calib_dict["calib_amp_array_res"]=calib_amp_array_res
calib_dict["calib_amp_array_pump"]= calib_amp_array_pump
calib_dict["calib_amp_pump"]=calib_amp_pump
calib_dict["calib_amp_res"]=calib_amp_res
# Out:
# 2023-07-19 12:52:34,195 - qm - INFO - Flags:
# 2023-07-19 12:52:34,196 - qm - INFO - Sending program to QOP
# 2023-07-19 12:52:34,443 - qm - INFO - Executing program
# 0
# 1
# 2
# Variation relative to the first calibration [0.99862842 1.00062573 1.00156262]
# Slope relative to the first intercept 1.0019133913504303
# Intercept relative to the first intercept -0.7837130766704418
# 2023-07-19 12:52:42,273 - qm - INFO - Flags:
# 2023-07-19 12:52:42,274 - qm - INFO - Sending program to QOP
# 2023-07-19 12:52:42,302 - qm - INFO - Executing program
# 0
# 1
# 2
# 3
# 4
# Variation relative to the first calibration [1.00579467 1.00553011 1.00623439 1.00504019 1.00622529]
# Slope relative to the first intercept 1.0063071015554423
# Intercept relative to the first intercept 0.8182556933131135

# %%
# %%time

Data={} #dictionnary to hold all the data 
Data[amp_factor]={}
freqs=freqs_dict[amp_factor]



freqs=freqs_dict[amp_factor]
calib_dict["res_freq"]={}
    

for idx,IF_pump in enumerate(freqs) :
    
    #Frequency calibration
    calib_pulse_len=50_000
    config,qm=cfg.update_readout_lenght(calib_pulse_len,config,qmm)

    calib_n_avg = 1000

    calib_cooldown_time = 50_000 // 4

    calib_f_min =149.75e6-0.25e6
    calib_f_max =149.75e6+0.25e6
    calib_df = 0.0025e6   #0.001e6 #0.001e6
    calib_amp_factor=0.01 #amplitude factor 

    calib_freqs,calib_I,calib_Q,calib_resonance_frequency, calib_error_frequency=calib.SingleResonatorSpec(qm,calib_n_avg,calib_pulse_len, calib_cooldown_time, calib_f_min, calib_f_max, calib_df, calib_amp_factor,LO_readout,plot=True)
    plt.close()
    
    calib_dict["res_freq"][IF_pump]={}
    calib_dict["res_freq"][IF_pump]["calib_freqs"]=calib_freqs
    calib_dict["res_freq"][IF_pump]["calib_I"]= calib_I
    calib_dict["res_freq"][IF_pump]["calib_Q"]=calib_Q
    calib_dict["res_freq"][IF_pump]["calib_resonance_frequency"]=calib_resonance_frequency
    calib_dict["res_freq"][IF_pump]["calib_error_frequency"]=calib_error_frequency

    #re update the readout length 
    config,qm=cfg.update_readout_lenght(Readout_Len,config,qmm)
    
    print("########################### Frequency "+str(IF_pump+LO_fluxline)+"########################### "+str(idx/len(freqs)))

    IF_resonator=(LO_fluxline+IF_pump)/2-LO_readout #demodulate at half of the pump IF by default 
    
    time,I,Q=single_IQ_trace_without_plot(IF_pump,IF_resonator,Offset_IF,amp_factor,n_runs,Readout_Delay,points_delay,Readout_Len,qm)
    
    plt.close()
    
    Data={} #dictionnary to hold all the data 
    Data[amp_factor]={}
    Data[amp_factor][IF_pump]={}
    Data[amp_factor][IF_pump]["I"]=I
    Data[amp_factor][IF_pump]["Q"]=Q
    Data[amp_factor][IF_pump]["time"]=time
    
    
    if save_Data:
        datadict={}
        meastype_n=meastype+"_" +str(IF_pump)

        datadict["freqs_dict"]=freqs_dict
        datadict["Readout_Len"]=Readout_Len
        datadict["Readout_Delay"]=Readout_Delay*4
        datadict["octave_output_gain"]=octave_output_gain
        datadict["amp_factor_array"]=amp_factor_array
        datadict["points_delay"]=points_delay
        datadict["Data"]=Data
        datadict["config"]=config

        #Configuration file copy 
        datadict["LO_fluxline"]=LO_fluxline
        datadict["IF_readout"]=IF_resonator
        datadict["LO_readout"]=LO_readout
        
        datadict["res_freq"]=calib_resonance_frequency
        
        
        #datadict["calib"]=calib_dict
        datadict["calib_amp_pump"]=calib_amp_pump
        datadict["calib_amp_res"]=calib_amp_res
        datadict["calib_freqs"]=calib_freqs
        datadict["calib_I"]= calib_I
        datadict["calib_Q"]=calib_Q

        

        an.save_with_numpy(datadict,  meastype_n, name, device, cooldown_date, filepath=Saving_Path)
        time_package.sleep(6)
# Out:
# 2023-07-19 15:00:43,047 - qm - INFO - Flags:
# 2023-07-19 15:00:43,048 - qm - INFO - Sending program to QOP
# 2023-07-19 15:00:43,868 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 19.68s
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 19.85s
# The measured resonance frequency is 4.349753335574955 GHz with an error of 1.089839808793797e-06 GHz
# ########################### Frequency 8699715000.0########################### 0.0
# 2023-07-19 15:01:04,717 - qm - INFO - Flags:
# 2023-07-19 15:01:04,717 - qm - INFO - Sending program to QOP
# 2023-07-19 15:01:05,169 - qm - INFO - Executing program
# saving
# 2023-07-19 15:01:53,762 - qm - INFO - Flags:
# 2023-07-19 15:01:53,763 - qm - INFO - Sending program to QOP
# 2023-07-19 15:01:54,581 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 18.63s
# The measured resonance frequency is 4.349753514807805 GHz with an error of 7.556124084549494e-07 GHz
# ########################### Frequency 8699577500.0########################### 0.3333333333333333
# 2023-07-19 15:02:15,354 - qm - INFO - Flags:
# 2023-07-19 15:02:15,355 - qm - INFO - Sending program to QOP
# 2023-07-19 15:02:15,405 - qm - INFO - Executing program
# saving
# 2023-07-19 15:03:05,098 - qm - INFO - Flags:
# 2023-07-19 15:03:05,099 - qm - INFO - Sending program to QOP
# 2023-07-19 15:03:05,923 - qm - INFO - Executing program
# Progress: [##################################################] 100.0% (n=1000/1000) --> elapsed time: 18.72s
# The measured resonance frequency is 4.3497502936371735 GHz with an error of 7.009963690384488e-07 GHz
# ########################### Frequency 8699610000.0########################### 0.6666666666666666
# 2023-07-19 15:03:26,827 - qm - INFO - Flags:
# 2023-07-19 15:03:26,827 - qm - INFO - Sending program to QOP
# 2023-07-19 15:03:26,874 - qm - INFO - Executing program
# saving
# Wall time: 3min 33s
