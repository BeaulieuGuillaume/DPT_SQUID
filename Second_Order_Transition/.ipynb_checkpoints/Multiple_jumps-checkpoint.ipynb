# %% [markdown]
# # Package and functions

# %%
from qm.QuantumMachinesManager import QuantumMachinesManager
from qm.octave import *
from qm.qua import *


#General os library 
import os
import time as time_package
import sys


import matplotlib.pyplot as plt
from qualang_tools.units import unit
from set_octave import get_L0_and_IF
from configuration_multiple_jumps import *
from qm import SimulationConfig, LoopbackInterface
from qualang_tools.units import unit
from qualang_tools.loops import from_array
u = unit()
from qualang_tools.plot import interrupt_on_close
from qualang_tools.results import progress_counter, fetching_tool
from qualang_tools.addons.variables import assign_variables_to_element



#Path for HQCPC7 
sys.path.append(r'C:\Users\HQClabo\Documents\Code\QuantumMachine\Guillaume\NonLinearRes_calib_30_03_2023\Analysis_Function\NonLinearRes')
sys.path.append(r'C:\Users\HQClabo\Documents\Code\QuantumMachine\Guillaume\NonLinearRes_calib_30_03_2023\Drivers\Drivers') #path for the analysis function

#Path for HQC PC15 
# sys.path.append(r'C:\Users\hqclabo\Documents\Code\gbeaulieu\Analysis_Function\NonLinearRes')
# sys.path.append(r'C:\Users\hqclabo\Documents\Code\gbeaulieu\Drivers')
import AnFunc as an # analysis function
import imageio
import scipy.io
from scipy import signal

# %%
def update_two_photon_lenght(twoPhoton_len,config,qmm):
    """ Update the length of the fluxline pulse in the configuration file"""

    config["pulses"]["twoPhoton"]["length"]=twoPhoton_len


    #Update the config with the modified values above 
    qm = qmm.open_qm(config)
    
    return config, qm


def update_readout_lenght(Readout_Len,config,qmm):
    """ Macro to update the readout length in the configuration file"""
    
    config["pulses"]["zero_pulse"]["length"]=Readout_Len
    config["integration_weights"]["cosine_weights"]["cosine"][0]=(1.0, Readout_Len)
    config["integration_weights"]["cosine_weights"]["sine"][0]=(0.0, Readout_Len)
    config["integration_weights"]["sine_weights"]["cosine"][0]=(0.0, Readout_Len)
    config["integration_weights"]["sine_weights"]["sine"][0]=(1.0, Readout_Len)
    config["integration_weights"]["minus_sine_weights"]["cosine"][0]=(0.0, Readout_Len)
    config["integration_weights"]["minus_sine_weights"]["sine"][0]=(-1.0, Readout_Len)


    #Update the config with the modified values above 
    qm = qmm.open_qm(config)
    
    return config, qm


def update_pulse_amplitude(pulse_amp,config,qmm):
    config["waveforms"]["const_wf"]['sample']=pulse_amp
    
    #Update the config with the modified values above 
    qm = qmm.open_qm(config)
    
    return config, qm

def update_offset(offset_1, offset_2,config,qmm):
    """ Update the input offsets of the qm in the configuration file """
    
    config['controllers']["con1"]["analog_inputs"][1]['offset']=offset_1
    config['controllers']["con1"]["analog_inputs"][2]['offset']=offset_2
    
    
    qm=qmm.open_qm(config)
    
    return config, qm

def update_time_of_flight(time_of_flight,config,qmm):
    """ Update the time_of_flight of the qm in the configuration file """
    config["elements"]["resonator"]["time_of_flight"]=time_of_flight
    
    qm=qmm.open_qm(config)
    
    return config, qm


def plot_init_av_single(I,Q,time,n_avg,bin_size,n_angle,figsize,fontsize,dpi):

    fig, axs = plt.subplots( nrows=3, ncols=2, figsize=figsize,dpi=dpi)

    #Plot without reducing 
    ax=axs[0,0]
    ax.plot(I,Q,".",markersize=2)
    ax.set_title('Pump Frequency '+str(IF_pump)+" Amplitude"+str(amp_factor),fontsize=fontsize)
    ax.set_xlabel("I [$V$]",fontsize=fontsize)
    ax.set_ylabel("Q [$V$]",fontsize=fontsize)
    ax.tick_params(axis='x', labelsize=fontsize)
    ax.tick_params(axis='y', labelsize=fontsize)
    ax.axis("equal")

    ax=axs[1,0]
    ax.plot(time,I, ".", markersize=2)
    ax.set_xlabel("Time [s]",fontsize=fontsize)
    ax.set_ylabel("I",fontsize=fontsize)
    ax.tick_params(axis='x', labelsize=fontsize)
    ax.tick_params(axis='y', labelsize=fontsize)

    ax=axs[2,0]
    ax.hist2d(I,Q,bins=bin_size)
    ax.set_xlabel("I [$V$]",fontsize=fontsize)
    ax.set_ylabel("Q [$V$]",fontsize=fontsize)
    ax.set_facecolor(color=(68/255,1/255,84/255))
    ax.tick_params(axis='x', labelsize=fontsize)
    ax.tick_params(axis='y', labelsize=fontsize)
    ax.axis("equal")

    #Plot with reducing 
    average_I, average_Q, time_average=rot_and_av_single(I,Q,time,n_angle,n_avg)

    ax=axs[0,1]
    ax.plot(average_I.transpose(),average_Q.transpose(),".",markersize=2)
    ax.set_title('Pump Frequency '+str(IF_pump)+" Amplitude"+str(amp_factor),fontsize=fontsize)
    ax.set_xlabel("I [$V$]",fontsize=fontsize)
    ax.set_ylabel("Q [$V$]",fontsize=fontsize)
    ax.tick_params(axis='x', labelsize=fontsize)
    ax.tick_params(axis='y', labelsize=fontsize)
    ax.axis("equal")


    ax=axs[1,1]
    ax.plot(time_average,average_I[0,:], ".", markersize=2)
    ax.set_xlabel("Time [s]",fontsize=fontsize)
    ax.set_ylabel("I",fontsize=fontsize)
    ax.tick_params(axis='x', labelsize=fontsize)
    ax.tick_params(axis='y', labelsize=fontsize)


    ax=axs[2,1]
    ax.hist2d(average_I[0,:],average_Q[0,:],bins=bin_size)
    ax.set_xlabel("I [$V$]",fontsize=fontsize)
    ax.set_ylabel("Q [$V$]",fontsize=fontsize)
    ax.set_facecolor(color=(68/255,1/255,84/255))
    ax.tick_params(axis='x', labelsize=fontsize)
    ax.tick_params(axis='y', labelsize=fontsize)
    ax.axis("equal")

    print("Average signal : {}".format(np.mean(abs(I))))
    
    
def rot_and_av_single(I,Q,time,nb_angle,n_avg):
    
    #reshape the data to fit into the initial function
    I_2d=np.reshape(I, (1, I.shape[0])) 
    Q_2d=np.reshape(Q, (1, Q.shape[0]))
    rot_I,rot_Q=an.rotate_data(I_2d,Q_2d,nb_angle)
    average_I,average_Q,time_average=an.average_data(rot_I,rot_Q,time,n_avg)

    return average_I, average_Q, time_average




def single_IQ_trace(IF_pump,IF_resonator,Offset_IF,amp_factor,n_runs,Readout_Delay,points_delay,Readout_Len,qm):
    
    """ gets the IQ values for a given pump frequency and amplitude 
    IF_Pump : If frequency of the pump 
    IF_resonator : IF frequency of the resonator (should be calculated before such that it gives half of the pump total frequency (LO_fluxline+IF_pump)/2-LO_readout
    Offset_IF : in case the down converted frequency is not perfectly centered around 0. This is typically kept to zero
    amp_facot amplitude factor of the pump
    n_runs : number of points 
    Readout_delay : waiting time before the first readout in clock cycle
    Readout_Len : time in ns of each readout 
    points_delay: waiting time between collected points 
    qm : quantum manager 

    returns :

    I: vector n_runs components of the frist quadrature
    Q : vector of n_runs compontents of the second quadrature
    time : vector of the time """


    with program() as IQ_blobs:

        n = declare(int)
        i = declare(int)
        I = declare(fixed)
        Q = declare(fixed)
        assign_variables_to_element("resonator", I,Q) #This line forces the OPX to assign I and Q to the resonator element such that the loops can happen in parallel as intented
        I_st = declare_stream()
        Q_st = declare_stream()
        f = declare(int)
        
        it_numb_st=declare_stream()

        # Change the of the pump and resonator to demodulate better
        update_frequency("resonator",IF_resonator+Offset_IF) 
        update_frequency("fluxline",IF_pump)

        #Play a continuous loop sending a pulse through the fluxline 
        

        #Delay time before the first readout 
        wait(Readout_Delay,"resonator")
        
        with for_(i, 0, i < np.round((n_runs*(Readout_Len+300+points_delay*4)+Readout_Delay*4)/twoPhoton_len)+1, i + 1): # the 300 is added because there is a time delay associated to saving the data in the steam. The *4 is necessary because the waiting time is in clockcycle 
            play("pumping" * amp(amp_factor), 'fluxline')  # Play the pulse on the fluxline

        with for_(n, 0, n < n_runs, n + 1):

            #Demodulate for the length 
            measure(
                "fake_readout",
                "resonator",
                None,
                dual_demod.full("cos", "out1", "sin", "out2", I),
                dual_demod.full("minus_sin", "out1", "cos", "out2", Q),
            )

            save(I, I_st)
            save(Q, Q_st)
            
            save(n,it_numb_st)

            wait(points_delay,"resonator")
        

        with stream_processing():
            I_st.with_timestamps().save_all("I")
            Q_st.with_timestamps().save_all("Q")
            it_numb_st.save("iteration")


    simulation = False
    if simulation:

        simulation_config = SimulationConfig(
            duration=80000, simulation_interface=LoopbackInterface([("con1", 3, "con1", 1)])
        )
        job = qmm.simulate(config, IQ_blobs, simulation_config)
        job.get_simulated_samples().con1.plot(analog_ports={'1','2','3','4' },digital_ports={'1','3'})

    else: 



        job = qm.execute(IQ_blobs)
        results = fetching_tool(job, data_list=["I", "Q","iteration"], mode="live")

        fig = plt.figure()
        interrupt_on_close(fig, job)
        while results.is_processing():

            I, Q,iteration = results.fetch_all()

            time=I["timestamp"]
            I = u.demod2volts(I["value"], Readout_Len) #diviser par la duree du pulse 
            Q = u.demod2volts(Q["value"], Readout_Len)

            #plt.subplot(211)
            plt.subplot(211)
            plt.cla()
            fig.suptitle("IF_pump "+str(IF_pump) +" Progress :"+str(round(iteration/n_runs,2)))
            plt.plot(I[:min(len(I), len(Q))], Q[:min(len(I), len(Q))], ".", markersize=2)
            plt.xlabel("I")
            plt.ylabel("Q")
            plt.axis("equal")
            plt.subplot(212)
            plt.cla()
            tau=np.linspace(1,min(len(I), len(Q)),min(len(I), len(Q)))
            plt.plot(tau,np.angle(I[:min(len(I), len(Q))]+1j*Q[:min(len(I), len(Q))]), ".", markersize=2)
            plt.xlabel("nb_points")
            plt.ylabel("phase")
            plt.pause(0.1)

        I, Q, iteration = results.fetch_all()
        time=I["timestamp"]
        I = u.demod2volts(I["value"], Readout_Len) #diviser par la duree du pulse 
        Q = u.demod2volts(Q["value"], Readout_Len)

      
    return time, I, Q




def single_IQ_trace_infinite(IF_pump,IF_resonator,Offset_IF,amp_factor,n_runs,Readout_Delay,points_delay,Readout_Len,qm):
    
    """ gets the IQ values for a given pump frequency and amplitude 
    IF_Pump : If frequency of the pump 
    IF_resonator : IF frequency of the resonator (should be calculated before such that it gives half of the pump total frequency (LO_fluxline+IF_pump)/2-LO_readout
    Offset_IF : in case the down converted frequency is not perfectly centered around 0. This is typically kept to zero
    amp_facot amplitude factor of the pump
    n_runs : number of points 
    Readout_delay : waiting time before the first readout in clock cycle
    Readout_Len : time in ns of each readout 
    points_delay: waiting time between collected points 
    qm : quantum manager 

    returns :

    I: vector n_runs components of the frist quadrature
    Q : vector of n_runs compontents of the second quadrature
    time : vector of the time """


    with program() as IQ_blobs:

        n = declare(int)
        i = declare(int)
        I = declare(fixed)
        Q = declare(fixed)
        assign_variables_to_element("resonator", I,Q) #This line forces the OPX to assign I and Q to the resonator element such that the loops can happen in parallel as intented
        I_st = declare_stream()
        Q_st = declare_stream()
        f = declare(int)
        
        it_numb_st=declare_stream()

        # Change the of the pump and resonator to demodulate better
        update_frequency("resonator",IF_resonator+Offset_IF) 
        update_frequency("fluxline",IF_pump)

        #Play a continuous loop sending a pulse through the fluxline 
        

        #Delay time before the first readout 
        wait(Readout_Delay,"resonator")
       
        with infinite_loop_(): # the 300 is added because there is a time delay associated to saving the data in the steam. The *4 is necessary because the waiting time is in clockcycle 
            play("pumping" * amp(amp_factor), 'fluxline')  # Play the pulse on the fluxline

        with for_(n, 0, n < n_runs, n + 1):

            #Demodulate for the length 
            measure(
                "fake_readout",
                "resonator",
                None,
                dual_demod.full("cos", "out1", "sin", "out2", I),
                dual_demod.full("minus_sin", "out1", "cos", "out2", Q),
            )

            save(I, I_st)
            save(Q, Q_st)
            
            save(n,it_numb_st)

            wait(points_delay,"resonator")
        

        with stream_processing():
            I_st.with_timestamps().save_all("I")
            Q_st.with_timestamps().save_all("Q")
            it_numb_st.save("iteration")


    simulation = False
    if simulation:

        simulation_config = SimulationConfig(
            duration=80000, simulation_interface=LoopbackInterface([("con1", 3, "con1", 1)])
        )
        job = qmm.simulate(config, IQ_blobs, simulation_config)
        job.get_simulated_samples().con1.plot(analog_ports={'1','2','3','4' },digital_ports={'1','3'})

    else: 



        job = qm.execute(IQ_blobs)
        results = fetching_tool(job, data_list=["I", "Q","iteration"], mode="live")

        fig = plt.figure()
        interrupt_on_close(fig, job)
        while results.is_processing():

            I, Q,iteration = results.fetch_all()

            time=I["timestamp"]
            I = u.demod2volts(I["value"], Readout_Len) #diviser par la duree du pulse 
            Q = u.demod2volts(Q["value"], Readout_Len)

            #plt.subplot(211)
            plt.subplot(211)
            plt.cla()
            fig.suptitle("IF_pump "+str(IF_pump) +" Progress :"+str(round(iteration/n_runs,2)))
            plt.plot(I[:min(len(I), len(Q))], Q[:min(len(I), len(Q))], ".", markersize=2)
            plt.xlabel("I")
            plt.ylabel("Q")
            plt.axis("equal")
            plt.subplot(212)
            plt.cla()
            tau=np.linspace(1,min(len(I), len(Q)),min(len(I), len(Q)))
            plt.plot(tau,np.angle(I[:min(len(I), len(Q))]+1j*Q[:min(len(I), len(Q))]), ".", markersize=2)
            plt.xlabel("nb_points")
            plt.ylabel("phase")
            plt.pause(0.1)

        I, Q, iteration = results.fetch_all()
        time=I["timestamp"]
        I = u.demod2volts(I["value"], Readout_Len) #diviser par la duree du pulse 
        Q = u.demod2volts(Q["value"], Readout_Len)

      
    return time, I, Q






def Update_single_IQ_trace(config,IF_pump,IF_resonator,Offset_IF,amp_factor,qm,nb_desired_jumps,nb_points_between_jumps,init_points_delay=16,nb_angle=100,n_avg=10,init_Readout_Len=50_000,init_nruns=100000,threshold=1e-5 ):

    counter=0
    jumps=[] 
    stop=False
    vaccum=False

    Readout_Len= init_Readout_Len    # Sets the readout to the initial wanted value 
    config,qm=update_readout_lenght(Readout_Len,config,qmm)


    n_runs=init_nruns # set the number_runsto the initial wanted number of runs 
    points_delay=init_points_delay//4 #initial points delay is set to the minimum 

    #First estimate of the total time 
    Total_time=n_runs*(Readout_Len+points_delay*4)*1e-9

    counter+=1

    print("########### Iteration number : {} ##########".format(counter))
    print("The program is initalized with :")
    print("A readout length of {} ns".format(Readout_Len))
    print("The Number of points  {}".format(n_runs))   
    print("An initial point delay  {} ms".format(init_points_delay*4*1e-6))  
    print("Time for iteration  {} min".format(Total_time/60)) 


    # Begins the loop that is stopped under the following conditions : we have more then 90 % of the number of desired jumps but less than twice (otherwise, we might not have the optimal readout length)
    # stop is set to true 

    while stop==False:

        time_package.sleep(1)
        time, I, Q=single_IQ_trace(IF_pump,IF_resonator,Offset_IF,amp_factor,n_runs,Readout_Delay,points_delay,Readout_Len,qm)

        print("Out_of_qm")
        plt.close()
        
        I_2d=np.reshape(I, (1, I.shape[0])) 
        Q_2d=np.reshape(Q, (1, Q.shape[0]))
        rot_I,rot_Q=an.rotate_data(I_2d,Q_2d,nb_angle)
        average_I,average_Q,time_average=an.average_data(rot_I,rot_Q,time,n_avg)

        # average_I,average_Q,time_average=rot_and_av_single(I,Q,time,nb_angle,n_avg)
        av = np.mean(abs(average_I))
        print("signal average {} uV".format(av*1e6))




        # We look if the average value is above our threshold. Being blow this threshold tells use that we should measure with the minimum readout len anyway so we can stop 
        if av>threshold:

            #normalize the signal and finding the crossings 
            average_I_norm = average_I/np.max(abs(average_I))

            average_I_reduced=average_I_norm[(average_I_norm>=0.25) + (average_I_norm<=-0.25)]

            jumps = np.where(np.diff(np.sign(average_I_reduced)))[0] #finds the idx of crossing through zero 

            print("Jumps found {}".format(len(jumps)))

            #Check if we have succed. If yes, the program is stoped
            if nb_desired_jumps*0.9<len(jumps):
                stop=True 
                print("Success")
            # if not, we start a new iteration
            else:
                counter+=1
                print("########### Iteration number : {} ##########".format(counter))

        #If we are below threshold, we stop 
        else: 
            vaccum=True
            print("vaccum state")
            stop=True 

        # If the program is not stopped, we continue 
        if stop==False: 

            #If we have found zero jump, we increase the parameters  
            if (len(jumps)==0):

                print("no jumps found found")

                if points_delay/4<1000 :
                    points_delay=(points_delay*100)
                else :
                    points_delay=(points_delay*10)

                Total_time=(Readout_Len+points_delay*4)*n_runs*1e-9
                print("New number of points  {}".format(n_runs))   
                print("New points delay  {} ms".format(points_delay*4*1e-6))   
                print("Time for iteration  {} min".format(Total_time/60)) 

                if Total_time>10*60: #If the total time is larger than 10 minutes 
                    stop=True 

            # In the case we find some jumps 
            else:

                time_per_jump=(time[-1]-time[0])/len(jumps) #average time per jump in ns 
                Total_time= time_per_jump*nb_desired_jumps #total time I should measure to get the number of desired jumps 

                points_delay= int((time_per_jump/ nb_points_between_jumps-Readout_Len)//4)

                #smallest delay that we can have 
                if points_delay<4:
                    points_delay=int(16//4) # we keep the smallest delay 
                    print("We are at the minimum delay")

                    #If we have less jumps due to our initial guess 

                    if (len(jumps))<nb_desired_jumps:
                        nb_points_between_jumps=round(n_runs/len(jumps)) #number of points between jumps currently 
                        n_runs=nb_points_between_jumps*nb_desired_jumps*2 # we increase the number of runs to have twice the number of desired jumps/ could be set to a special value 
                        stop=True      
                    #If we already have more than desired, we stop  
                    else :
                        stop=True 


                else:
                    n_runs=int(nb_points_between_jumps*nb_desired_jumps)


                Total_time=(Readout_Len+points_delay*4)*n_runs*1e-9
                print("New number of points  {}".format(n_runs))   
                print("New points delay  {} ms".format(points_delay*4*1e-6))   
                print("Time for iteration  {} min".format(Total_time/60)) 

                if Total_time>10*60: #If the total propsed time is larger than 10 minutes
                    stop=True 

   
    return I,Q,rot_I,rot_Q,time, points_delay*4, vaccum, n_runs, jumps, counter

# %% [markdown]
# # OPX configuration

# %%
#Octave & OPX configuration 

opx_ip = '128.178.175.167'
opx_port = 81
octave_ip = '128.178.175.167'
octave_port = 53

Saving_Path=r"\\sb1files\HQC\Users\beaulieu\Data\Run01\131\\"
Cooldown_Date="2023_05_05"

octave_config = QmOctaveConfig()
octave_config.set_calibration_db(os.getcwd()) #Path to the calibration database 

octave_config.add_device_info('octave1', octave_ip, octave_port) #Add a device refered to as octave 1
octave_config.set_opx_octave_mapping([('con1', 'octave1')])  # set default mapping between analog outputs of OPX and the octave

qmm = QuantumMachinesManager(host=opx_ip, port=opx_port, octave=octave_config)
qm = qmm.open_qm(config)

octave_output_gain=-10

#Mixers for the fluxline 
qmm.octave_manager.set_clock("octave1", ClockType.External, ClockFrequency.MHZ_10) # External clock on the octave 
qm.octave.set_lo_source("fluxline", OctaveLOSource.Internal) # Use internal LO for the fluxline 
qm.octave.set_lo_frequency("fluxline", LO_fluxline)  # Set the frequency of the LO 
qm.octave.set_rf_output_gain("fluxline", octave_output_gain)  # can set gain from -10dB to 20dB
qm.octave.set_rf_output_mode("fluxline", RFOutputMode.on)  # The LO output is always on (could change to a trigger)

#Mixers for the resonator 
qm.octave.set_qua_element_octave_rf_in_port("resonator", "octave1", 1) #input port 1 is set for the resonator 
qm.octave.set_downconversion("resonator", lo_source=RFInputLOSource.Internal)  # The LO for the demodulation is the interal LO  
qm.octave.set_lo_frequency("resonator", LO_readout)  # assign the LO inside the octave to element
# Out:
# 2023-05-14 09:28:33,215 - qm - INFO - Performing health check
# 2023-05-14 09:28:33,228 - qm - WARNING -   HC Warning: Potential hardware issue with QSync in controller con1, multiple controllers sync cannot be guaranteed, please inform QM
# 2023-05-14 09:28:33,228 - qm - INFO - Health check passed

# %%
#Setting the gain
gain=0
config['controllers']['con1']['analog_inputs'][1]["gain_db"]=gain
config['controllers']['con1']['analog_inputs'][2]["gain_db"]=gain
qm = qmm.open_qm(config)

#Pump length 
twoPhoton_len=10_000
config,qm=update_two_photon_lenght(twoPhoton_len,config,qmm)

time_of_flight=24
config, qm=update_time_of_flight(time_of_flight,config,qmm)

pulse_amp=0.125
config,qm=update_pulse_amplitude(pulse_amp,config,qmm)


#Based on the other setting
offset_1=0.0180632734375
offset_2=0.015605841992187498
config,qm=update_offset(offset_1, offset_2,config,qmm)

# %% [markdown]
# # Testing the pump

# %%
#Mixer Calibration 
#Calibration of the fluxline mixer for the pump 
qm.octave.calibrate_element("fluxline", [get_L0_and_IF(config, "fluxline")])  
qm = qmm.open_qm(config)

qm.octave.calibrate_element("resonator", [get_L0_and_IF(config, "resonator")])  
qm = qmm.open_qm(config)
# Out:
# 2023-05-14 09:28:41,801 - qm - INFO - Flags:
# 2023-05-14 09:28:41,801 - qm - INFO - Compiling program
# 2023-05-14 09:28:44,330 - qm - INFO - Sending pre-compiled program to QOP
# 2023-05-14 09:28:47,828 - qm - INFO - Flags:
# 2023-05-14 09:28:47,829 - qm - INFO - Compiling program
# 2023-05-14 09:28:50,204 - qm - INFO - Sending pre-compiled program to QOP

# %%
# Applies an infinite loop pump for testing 

amp_factor=0.1

pulse_amp=0.125
config,qm=update_pulse_amplitude(pulse_amp,config,qmm) 

twoPhoton_len=1000
config,qm=update_two_photon_lenght(twoPhoton_len,config,qmm)

with program() as TwoPhoton:
    with infinite_loop_():
        play("pumping"*amp(amp_factor), 'fluxline')
           
job = qm.execute(TwoPhoton)
# Out:
# 2023-05-10 18:13:13,830 - qm - INFO - Flags:
# 2023-05-10 18:13:13,830 - qm - INFO - Sending program to QOP
# 2023-05-10 18:13:13,856 - qm - INFO - Executing program

# %%
#Two stop the two photon pumping 
job.halt()
# Out:
# True

# %%
2**31
# Out:
# 2147483648

# %% [markdown]
# # Checking the ADC
# This allows checking that the ADC is not saturated to set a proper gain, correct for DC offsets and define the time of flight.
#
# For this, we send a Twophoton pulse and look at the the raw adc
#
# ![image.png](attachment:54500901-e92c-496c-97c3-642e45d8869c.png)

# %%
# %matplotlib qt

#Sets the pulse length and the pulse amplitude at the resonator 
pulse_len=100_000
config,qm=update_readout_lenght(pulse_len,config,qmm)

pulse_amp=0.125
config,qm=update_pulse_amplitude(pulse_amp,config,qmm) 

twoPhoton_len=100_000
config,qm=update_two_photon_lenght(twoPhoton_len,config,qmm)

Readout_Delay = 5000 //4 # Delay before the first readout in ns (convert from clockcycle)

IF_pump=99.5e6   # defines the IF of the pump 

amp_factor=1 #Amplitude factor of the pump 

n_avg = 100  # Number of averaging loops

cooldown_time = 100_000 // 4 #cooldown time between the averages

offset_1=0
offset_2=0
config,qm=update_offset(offset_1, offset_2,config,qmm)


with program() as raw_trace_prog:
    
    n = declare(int)
    adc_st = declare_stream(adc_trace=True)
    
    update_frequency("fluxline",IF_pump)

    with for_(n, 0, n < n_avg, n + 1):
        
        play("pumping"*amp(amp_factor), 'fluxline')
        
        #Delay time before the first readout 
        wait(Readout_Delay,"resonator")
        measure("fake_readout", "resonator", adc_st)
        
        wait(cooldown_time, "resonator") #Maybe need to cooldown both resonator and fluxline

    with stream_processing():
        
        # Will save average:
        adc_st.input1().average().save("adc1")
        adc_st.input2().average().save("adc2")
        
        # Will save only last run:
        adc_st.input1().save("adc1_single_run")
        adc_st.input2().save("adc2_single_run")

        
simulation = False
if simulation:
    
    simulation_config = SimulationConfig(
        duration=80000, simulation_interface=LoopbackInterface([("con1", 3, "con1", 1)])
    )
    job = qmm.simulate(config, raw_trace_prog, simulation_config)
    job.get_simulated_samples().con1.plot()
    
else: 
    #Execute the program     
    qm = qmm.open_qm(config)
    job = qm.execute(raw_trace_prog)

    results = fetching_tool(job, data_list=["adc1", "adc2", "adc1_single_run","adc2_single_run"], mode="wait_for_all")

    adc1, adc2, adc1_single_run, adc2_single_run = results.fetch_all()

    adc1 = u.raw2volts(adc1)
    adc2 = u.raw2volts(adc2)
    adc1_single_run = u.raw2volts(adc1_single_run)
    adc2_single_run = u.raw2volts(adc2_single_run)

    #Plotting 
    plt.figure()
    plt.subplot(121)
    plt.title("Single run")
    plt.plot(adc1_single_run, label="Input 1")
    plt.plot(adc2_single_run, label="Input 2")
    plt.xlabel("Time [ns]")
    plt.ylabel("Signal amplitude [V]")
    plt.legend()

    plt.subplot(122)
    plt.title("Averaged run")
    plt.plot(adc1, label="Input 1")
    plt.plot(adc2, label="Input 2")
    plt.xlabel("Time [ns]")
    plt.legend()
    plt.tight_layout()

    print("The mean offset of port 1 is: {}".format(np.mean(adc1)))
    print("The mean offset of port 2 is: {}".format(np.mean(adc2)))
# Out:
# 2023-05-10 18:12:55,714 - qm - INFO - Flags:
# 2023-05-10 18:12:55,716 - qm - INFO - Sending program to QOP
# 2023-05-10 18:12:55,806 - qm - INFO - Executing program
# The mean offset of port 1 is: -0.018058606030273438
# The mean offset of port 2 is: -0.015598489282226562

# %% [markdown]
# # Single frequency IQ blob
#
# Runs the IQ blob program for a single pump frequency that can be dfined with IF pump. The demodulation frequency is automatically taken as half of the total pump frequency
#
# Need to make sure that the new updated IF frequency doesn't go over 350 MHz.
#
# ![image.png](attachment:c0f18881-dc9b-45e8-89a9-08188df16bcf.png)

# %% [markdown]
# # Display Parameters

# %%
print("LO of resonator : {} GHz".format(config['elements']['resonator']["mixInputs"]["lo_frequency"]/1e9))
print("IF of resonator : {} GHz".format(config['elements']['resonator']['intermediate_frequency']/1e9))
print("Time of flight of resonator : {} ns".format(config['elements']['resonator']['time_of_flight']))
print("Readout time resonator : {} ns".format(config["pulses"]["zero_pulse"]["length"]))
print("LO of fluxline: {} GHz".format(config['elements']['fluxline']["mixInputs"]["lo_frequency"]/1e9))
print("IF of fluxline : {} GHz".format(config['elements']['fluxline']['intermediate_frequency']/1e9))
print("Fluxline pulse time : {} ns".format(config["pulses"]["twoPhoton"]["length"]))
print("Fluxline amplitude : {} V".format(config["waveforms"]["twoPhoton_wf"]['sample']))
# Out:
# LO of resonator : 4.3 GHz
# IF of resonator : 0.318 GHz
# Time of flight of resonator : 24 ns
# Readout time resonator : 2000000 ns
# LO of fluxline: 8.6 GHz
# IF of fluxline : 0.0995 GHz
# Fluxline pulse time : 10000 ns
# Fluxline amplitude : 0.125 V

# %% [markdown]
# # Single frequency

# %%
center_freq=4.34975e9*2
a=(99.4e6+LO_fluxline-center_freq)*1/1.35
-1e5*1.45+center_freq-LO_fluxline
# Out:
# 99355000.0

# %%
# %matplotlib qt 

#Update the readout pulse 
Readout_Len= 50_000     #6_557_763 #length of the readout pulse in ns 
config,qm=update_readout_lenght(Readout_Len,config,qmm)

n_runs =  5000000 #Number of readout to do 

#Update the pump IF frequency 
IF_pump=99.355e6# defines the IF of the pump 
IF_resonator=(LO_fluxline+IF_pump)/2-LO_readout #demodulate at half of the pump IF by default 


Readout_Delay = 5000 //4 # Delay before the first readout in ns (convert from clockcycle)
amp_factor=1.45 #Prefactor of the amplitude 
Offset_IF=0  #

points_delay=175000*2 #Delay between readouts 

Expected_time=n_runs *(Readout_Len+points_delay*4)/60
print("Expected time {}".format(Expected_time*1e-9))

Data={}
Data[amp_factor]={}
Data[amp_factor][IF_pump]={}

freqs_dict={}
freqs_dict[amp_factor]=np.array([IF_pump])
amp_factor_array=np.array([amp_factor])
# Out:
# Expected time 120.83333333333334

# %%
# %%time
time,I,Q=single_IQ_trace_infinite(IF_pump,IF_resonator,Offset_IF,amp_factor,n_runs,Readout_Delay,points_delay,Readout_Len,qm)

Data[amp_factor][IF_pump]["I"]=I
Data[amp_factor][IF_pump]["Q"]=Q
Data[amp_factor][IF_pump]["time"]=time
# Out:
# 2023-05-14 18:25:54,282 - qm - INFO - Flags:
# 2023-05-14 18:25:54,283 - qm - INFO - Sending program to QOP
# 2023-05-14 18:25:54,755 - qm - INFO - Executing program
# Execution stopped by user!
# Wall time: 2h 56min 27s

# %% [markdown]
# ## Saving

# %%
#Saving the data
cooldown_date=Cooldown_Date #top folder   
device="second_order" #second folder 
name="measurement_freq" # third folder 
meastype="1p45_99355_2h" #Final file name 

datadict={}

datadict={}
datadict["freqs_dict"]=freqs_dict
datadict["Readout_Len"]=Readout_Len
datadict["Readout_Delay"]=Readout_Delay*4
datadict["octave_output_gain"]=octave_output_gain
datadict["amp_factor_array"]=amp_factor_array 
datadict["points_delay"]=points_delay
datadict["Data"]=Data
datadict["config"]=config

#Configuration file copy 
datadict["LO_fluxline"]=LO_fluxline
datadict["IF_readout"]=IF_resonator
datadict["LO_readout"]=LO_readout

an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)
# Out:
# saving

# %% [markdown]
# ## Plotting single frequency

# %%
#Plotting with and without the noise reduction, would be better to get a single plotting function 

# %matplotlib inline

n_bin=250 #bin size for the histogram 
figsize=(14,15)
fontsize=4
n_angle=100 #number of angles for the rotation 
n_avg=10 #number of average
dpi=300

plot_init_av_single(I,Q,time*1e-9,n_avg,n_bin,n_angle,figsize,fontsize,dpi)
# Out:
# Average signal : 0.0017336327363281247

# %% [markdown]
# ## Jumps Fabrizio single frequency

# %%
# %%time
# %matplotlib inline 

figsize=(6,5)
fontsize=8
nb_angle=100
n_avg=10

average_I,average_Q,time_average=rot_and_av_single(I,Q,time,nb_angle,n_avg)

#renormalize the data and find jumps 
length_array=average_I.shape[1] 
av = np.mean(abs(average_I))
jumps=an.find_jumps(average_I[0]/av,length_array)

#Plot I vs time and the identified jumps  jumps 
fig, axs = plt.subplots( nrows=1, ncols=1, figsize=figsize,dpi=100)
ax=axs
ax.plot(time_average, average_I[0])
for j in jumps:
    ax.axvline(time_average[int(j)], c='r', lw=1, ls='--')
    
ax.set_xlabel("Time [s]",fontsize=fontsize)
ax.set_ylabel("I",fontsize=fontsize)
ax.tick_params(axis='x', labelsize=fontsize)
ax.tick_params(axis='y', labelsize=fontsize)
ax.set_title("Number of jumps: " +str(len(jumps)))
# Out:
# Wall time: 1min 23s
# Text(0.5, 1.0, 'Number of jumps: 401')

# %% [markdown]
# ## Jumps Guillaume single frequency

# %%
# %%time 
# %matplotlib inline


figsize=(6,5)
fontsize=8
nb_angle=100
n_avg=10


average_I,average_Q,time_average=rot_and_av_single(I,Q,time,nb_angle,n_avg)
time_average=time_average.reshape(1,time_average.shape[0])

#normalize 
average_I_norm = average_I/np.max(abs(average_I))

average_I_reduced=average_I_norm[(average_I_norm>=0.25) + (average_I_norm<=-0.25)]
time_average_reduced=time_average[(average_I_norm>=0.25) + (average_I_norm<=-0.25)]

zero_crossings = np.where(np.diff(np.sign(average_I_reduced)))[0] #finds the idx of crossing through zero 

fig, axs = plt.subplots( nrows=1, ncols=1, figsize=figsize,dpi=100)
ax=axs
ax.plot(time_average[0], average_I[0])
for j in zero_crossings:
    ax.axvline(time_average[0,int(j)], c='r', lw=1, ls='--')
    
ax.set_xlabel("Time [s]",fontsize=fontsize)
ax.set_ylabel("I",fontsize=fontsize)
ax.tick_params(axis='x', labelsize=fontsize)
ax.tick_params(axis='y', labelsize=fontsize)
ax.set_title("Number of jumps: " +str(len(zero_crossings)))
# Out:
# Wall time: 126 ms
# Text(0.5, 1.0, 'Number of jumps: 313')

# %% [markdown]
# # Update single frequency IQ - Find parameters

# %%
# %matplotlib qt
#Update the readout pulse 
Readout_Len= 50_000     #6_557_763 #length of the readout pulse in ns 
init_Readout_Len=Readout_Len

#Update the pump IF frequency 
IF_pump= 99.22e6# defines the IF of the pump 
IF_resonator=(LO_fluxline+IF_pump)/2-LO_readout #demodulate at half of the pump IF by default 


Readout_Delay = 1_000_000 //4 # Delay before the first readout in ns (convert from clockcycle)
amp_factor=1.25 #Prefactor of the amplitude 
Offset_IF=0  #


nb_desired_jumps=5
nb_points_between_jumps=5000


nb_angle=100
n_avg=10
init_points_delay=16
init_nruns=250_000
threshold=5e-4



I,Q,rot_I,rot_Q,time, points_delay, vaccum, n_runs, jumps, counter=Update_single_IQ_trace(config,IF_pump,IF_resonator,Offset_IF,amp_factor,qm,nb_desired_jumps,nb_points_between_jumps,init_points_delay=init_points_delay,nb_angle=100,n_avg=10,init_Readout_Len=init_Readout_Len,init_nruns=init_nruns,threshold=threshold )
# Out:
# ########### Iteration number : 1 ##########
# The program is initalized with :
# A readout length of 50000 ns
# The Number of points  250000
# An initial point delay  6.4e-05 ms
# Time for iteration  0.20840000000000003 min
# 2023-05-10 23:08:30,041 - qm - INFO - Flags:
# 2023-05-10 23:08:30,042 - qm - INFO - Sending program to QOP
# 2023-05-10 23:08:30,506 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1935.088183462474 uV
# Jumps found 0
# ########### Iteration number : 2 ##########
# no jumps found found
# New number of points  250000
# New points delay  0.0015999999999999999 ms
# Time for iteration  0.215 min
# 2023-05-10 23:08:45,253 - qm - INFO - Flags:
# 2023-05-10 23:08:45,254 - qm - INFO - Sending program to QOP
# 2023-05-10 23:08:45,725 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1932.067589321962 uV
# Jumps found 0
# ########### Iteration number : 3 ##########
# no jumps found found
# New number of points  250000
# New points delay  0.16 ms
# Time for iteration  0.875 min
# 2023-05-10 23:09:01,273 - qm - INFO - Flags:
# 2023-05-10 23:09:01,273 - qm - INFO - Sending program to QOP
# 2023-05-10 23:09:01,731 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1934.9991450080502 uV
# Jumps found 1
# ########### Iteration number : 4 ##########
# New number of points  25000
# New points delay  10.449956 ms
# Time for iteration  4.374981666666667 min
# 2023-05-10 23:09:56,694 - qm - INFO - Flags:
# 2023-05-10 23:09:56,695 - qm - INFO - Sending program to QOP
# 2023-05-10 23:09:57,174 - qm - INFO - Executing program
# Execution stopped by user!
# Out_of_qm
# signal average 1919.9866499327293 uV
# Jumps found 1
# ########### Iteration number : 5 ##########
# New number of points  25000
# New points delay  5.433076 ms
# Time for iteration  2.284615 min
# 2023-05-10 23:10:26,488 - qm - INFO - Flags:
# 2023-05-10 23:10:26,489 - qm - INFO - Sending program to QOP
# 2023-05-10 23:10:26,912 - qm - INFO - Executing program
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19476\126144093.py in <module>
#      26
#      27
# ---> 28 I,Q,rot_I,rot_Q,time, points_delay, vaccum, n_runs, jumps, counter=Update_single_IQ_trace(config,IF_pump,IF_resonator,Offset_IF,amp_factor,qm,nb_desired_jumps,nb_points_between_jumps,init_points_delay=init_points_delay,nb_angle=100,n_avg=10,init_Readout_Len=init_Readout_Len,init_nruns=init_nruns,threshold=threshold )
#
# ~\AppData\Local\Temp\ipykernel_19476\586003280.py in Update_single_IQ_trace(config, IF_pump, IF_resonator, Offset_IF, amp_factor, qm, nb_desired_jumps, nb_points_between_jumps, init_points_delay, nb_angle, n_avg, init_Readout_Len, init_nruns, threshold)
#     289
#     290         time_package.sleep(1)
# --> 291         time, I, Q=single_IQ_trace(IF_pump,IF_resonator,Offset_IF,amp_factor,n_runs,Readout_Delay,points_delay,Readout_Len,qm)
#     292
#     293         print("Out_of_qm")
#
# ~\AppData\Local\Temp\ipykernel_19476\586003280.py in single_IQ_trace(IF_pump, IF_resonator, Offset_IF, amp_factor, n_runs, Readout_Delay, points_delay, Readout_Len, qm)
#     244             plt.xlabel("nb_points")
#     245             plt.ylabel("phase")
# --> 246             plt.pause(0.1)
#     247
#     248         I, Q, iteration = results.fetch_all()
#
# ~\Anaconda3\envs\Labber\lib\site-packages\matplotlib\pyplot.py in pause(interval)
#     565             canvas.draw_idle()
#     566         show(block=False)
# --> 567         canvas.start_event_loop(interval)
#     568     else:
#     569         time.sleep(interval)
#
# ~\Anaconda3\envs\Labber\lib\site-packages\matplotlib\backends\backend_qt.py in start_event_loop(self, timeout)
#     429
#     430         with _maybe_allow_interrupt(event_loop):
# --> 431             qt_compat._exec(event_loop)
#     432
#     433     def stop_event_loop(self, event=None):
#
# ~\Anaconda3\envs\Labber\lib\contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~\Anaconda3\envs\Labber\lib\site-packages\matplotlib\backends\qt_compat.py in _maybe_allow_interrupt(qapp)
#     274             signal.signal(signal.SIGINT, old_sigint_handler)
#     275             if handler_args is not None:
# --> 276                 old_sigint_handler(*handler_args)
#     277
#     278
#
# KeyboardInterrupt:

# %%
jumps
# Out:
# array([ 184,  250,  560, 1075, 1567, 1886], dtype=int64)

# %% [markdown]
# # Update multiple frequency IQ- Find parameters

# %%
#Frequency and amplitude 

# span=0.8 * u.MHz # Span of the pumping 
# df = 0.1 * u.MHz # Step of the pumping 0.01
# IF_center=0.1973e9
# freqs = np.arange(IF_center-span/2, IF_center+span/2, df) #sets of frequencies

fmin= 99.42e6
fmax=99.74e6
df=0.02* u.MHz
freqs=np.arange(fmin, fmax+df/2, df)

amp_factor_array=np.array([1.35]) 

freqs_dict={}

freqs_dict[amp_factor_array[0]]=freqs
#freqs_dict[amp_factor_array[1]]=freqs

freqs_dict
# Out:
# {1.35: array([99420000., 99440000., 99460000., 99480000., 99500000., 99520000.,
#         99540000., 99560000., 99580000., 99600000., 99620000., 99640000.,
#         99660000., 99680000., 99700000., 99720000., 99740000.])}

# %%
#Parameters

Readout_Len= 50_000    #Readout length in ns 
init_Readout_Len=Readout_Len

Readout_Delay = 1_000_000 //4 # Delay before the first readout in ns (convert from clockcycle)

Offset_IF=0  #

nb_desired_jumps=10
nb_points_between_jumps=5000

nb_angle=100
n_avg=10

init_points_delay=16 # initial delay for the first test 

init_nruns=250_000 #number of runs for the first test
threshold=5e-4 #threshold to say that the state is vacuum 

save_data=False
cooldown_date=Cooldown_Date #top folder 
device="Run01" #second folder 
name="104_parameter_IQ" # third folder 
meastype="0p25_amp_single_Readout_length" #Final file name

# %%
# %%time
#The idea is that this program is used to get a first quick estimates. Therefore, it should be launched with a few numbers of nb_desired_jumps
# Moreover, we should use quite a high threshold, because anyway below the threshold, we will fix the readout_len to 50_000
# %matplotlib qt 



Data={} #dictionnary to hold all the data 


for i in range(len(amp_factor_array)):

    amp_factor=amp_factor_array[i]
    freqs=freqs_dict[amp_factor] 
    Data[amp_factor]={}

    for idx,IF_pump in enumerate(freqs) :
        print("########################### Frequency "+str(IF_pump+LO_fluxline)+"########################### "+str(idx/len(freqs)))

        Data[amp_factor][IF_pump]={}

        IF_resonator=(LO_fluxline+IF_pump)/2-LO_readout #demodulate at half of the pump IF by default                                                    
        I,Q,rot_I,rot_Q,time, points_delay, vaccum, n_runs, jumps, counter=Update_single_IQ_trace(config,IF_pump,IF_resonator,Offset_IF,amp_factor,qm,nb_desired_jumps,nb_points_between_jumps,init_points_delay=init_points_delay,nb_angle=100,n_avg=10,init_Readout_Len=init_Readout_Len,init_nruns=init_nruns,threshold=threshold )

        #Saving the data
        Data[amp_factor][IF_pump]["I"]=I
        Data[amp_factor][IF_pump]["Q"]=Q
        Data[amp_factor][IF_pump]["rot_I"]=rot_I
        Data[amp_factor][IF_pump]["rot_Q"]=rot_Q
        Data[amp_factor][IF_pump]["jumps"]=jumps
        Data[amp_factor][IF_pump]["counter"]=counter
        Data[amp_factor][IF_pump]["n_runs"]=n_runs
        Data[amp_factor][IF_pump]["time"]=time
        Data[amp_factor][IF_pump]["vaccum"]=vaccum
        Data[amp_factor][IF_pump]["points_delay"]=points_delay #returned in ns 
    
if save_data:
    datadict={}
    datadict["freqs_dict"]=freqs_dict
    datadict["Readout_Len"]=Readout_Len
    datadict["Readout_Delay"]=Readout_Delay*4
    datadict["octave_output_gain"]=octave_output_gain
    datadict["Offset_IF"]=Offset_IF
    datadict["amp_factor_array"]=amp_factor_array
    datadict["nb_desired_jumps"]=nb_desired_jumps
    datadict["nb_points_between_jumps"]=nb_points_between_jumps 
    datadict["Data"]=Data
    datadict["config"]=config

    
    an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)
# Out:
# ########################### Frequency 8699420000.0########################### 0.0
# ########### Iteration number : 1 ##########
# The program is initalized with :
# A readout length of 50000 ns
# The Number of points  250000
# An initial point delay  6.4e-05 ms
# Time for iteration  0.20840000000000003 min
# 2023-05-13 12:07:29,038 - qm - INFO - Flags:
# 2023-05-13 12:07:29,039 - qm - INFO - Sending program to QOP
# 2023-05-13 12:07:29,928 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1626.460332104855 uV
# Jumps found 0
# ########### Iteration number : 2 ##########
# no jumps found found
# New number of points  250000
# New points delay  0.0015999999999999999 ms
# Time for iteration  0.215 min
# 2023-05-13 12:07:44,363 - qm - INFO - Flags:
# 2023-05-13 12:07:44,364 - qm - INFO - Sending program to QOP
# 2023-05-13 12:07:44,829 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1629.7690016092524 uV
# Jumps found 0
# ########### Iteration number : 3 ##########
# no jumps found found
# New number of points  250000
# New points delay  0.16 ms
# Time for iteration  0.875 min
# 2023-05-13 12:08:00,217 - qm - INFO - Flags:
# 2023-05-13 12:08:00,218 - qm - INFO - Sending program to QOP
# 2023-05-13 12:08:01,053 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1627.9615482963072 uV
# Jumps found 0
# ########### Iteration number : 4 ##########
# no jumps found found
# New number of points  250000
# New points delay  1.5999999999999999 ms
# Time for iteration  6.875 min
# 2023-05-13 12:08:55,461 - qm - INFO - Flags:
# 2023-05-13 12:08:55,462 - qm - INFO - Sending program to QOP
# 2023-05-13 12:08:55,934 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1628.9108940173362 uV
# Jumps found 4
# ########### Iteration number : 5 ##########
# New number of points  50000
# New points delay  20.574915999999998 ms
# Time for iteration  17.187430000000003 min
# ########################### Frequency 8699440000.0########################### 0.058823529411764705
# ########### Iteration number : 1 ##########
# The program is initalized with :
# A readout length of 50000 ns
# The Number of points  250000
# An initial point delay  6.4e-05 ms
# Time for iteration  0.20840000000000003 min
# 2023-05-13 12:15:50,881 - qm - INFO - Flags:
# 2023-05-13 12:15:50,881 - qm - INFO - Sending program to QOP
# 2023-05-13 12:15:51,330 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1578.1750243875529 uV
# Jumps found 0
# ########### Iteration number : 2 ##########
# no jumps found found
# New number of points  250000
# New points delay  0.0015999999999999999 ms
# Time for iteration  0.215 min
# 2023-05-13 12:16:06,425 - qm - INFO - Flags:
# 2023-05-13 12:16:06,425 - qm - INFO - Sending program to QOP
# 2023-05-13 12:16:07,267 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1574.6469879209158 uV
# Jumps found 0
# ########### Iteration number : 3 ##########
# no jumps found found
# New number of points  250000
# New points delay  0.16 ms
# Time for iteration  0.875 min
# 2023-05-13 12:16:22,327 - qm - INFO - Flags:
# 2023-05-13 12:16:22,327 - qm - INFO - Sending program to QOP
# 2023-05-13 12:16:22,803 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1576.2305212066806 uV
# Jumps found 0
# ########### Iteration number : 4 ##########
# no jumps found found
# New number of points  250000
# New points delay  1.5999999999999999 ms
# Time for iteration  6.875 min
# 2023-05-13 12:17:17,760 - qm - INFO - Flags:
# 2023-05-13 12:17:17,761 - qm - INFO - Sending program to QOP
# 2023-05-13 12:17:18,602 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1582.6483134191878 uV
# Jumps found 3
# ########### Iteration number : 5 ##########
# New number of points  50000
# New points delay  27.449887999999998 ms
# Time for iteration  22.916573333333336 min
# ########################### Frequency 8699460000.0########################### 0.11764705882352941
# ########### Iteration number : 1 ##########
# The program is initalized with :
# A readout length of 50000 ns
# The Number of points  250000
# An initial point delay  6.4e-05 ms
# Time for iteration  0.20840000000000003 min
# 2023-05-13 12:24:13,118 - qm - INFO - Flags:
# 2023-05-13 12:24:13,118 - qm - INFO - Sending program to QOP
# 2023-05-13 12:24:13,585 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1535.2473981183819 uV
# Jumps found 0
# ########### Iteration number : 2 ##########
# no jumps found found
# New number of points  250000
# New points delay  0.0015999999999999999 ms
# Time for iteration  0.215 min
# 2023-05-13 12:24:28,527 - qm - INFO - Flags:
# 2023-05-13 12:24:28,527 - qm - INFO - Sending program to QOP
# 2023-05-13 12:24:29,407 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1522.697554509894 uV
# Jumps found 1
# ########### Iteration number : 3 ##########
# New number of points  50000
# New points delay  2.529988 ms
# Time for iteration  2.1499900000000003 min
# 2023-05-13 12:24:44,403 - qm - INFO - Flags:
# 2023-05-13 12:24:44,404 - qm - INFO - Sending program to QOP
# 2023-05-13 12:24:44,858 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1530.0708374354813 uV
# Jumps found 7
# ########### Iteration number : 4 ##########
# New number of points  50000
# New points delay  3.63562 ms
# Time for iteration  3.0713500000000002 min
# 2023-05-13 12:26:55,783 - qm - INFO - Flags:
# 2023-05-13 12:26:55,784 - qm - INFO - Sending program to QOP
# 2023-05-13 12:26:56,273 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1528.8651535053637 uV
# Jumps found 6
# ########### Iteration number : 5 ##########
# New number of points  50000
# New points delay  6.092575999999999 ms
# Time for iteration  5.118813333333334 min
# 2023-05-13 12:30:02,337 - qm - INFO - Flags:
# 2023-05-13 12:30:02,338 - qm - INFO - Sending program to QOP
# 2023-05-13 12:30:02,790 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1531.4735791808764 uV
# Jumps found 7
# ########### Iteration number : 6 ##########
# New number of points  50000
# New points delay  8.724931999999999 ms
# Time for iteration  7.312443333333333 min
# 2023-05-13 12:35:11,886 - qm - INFO - Flags:
# 2023-05-13 12:35:11,887 - qm - INFO - Sending program to QOP
# 2023-05-13 12:35:12,351 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1529.6319527956673 uV
# Jumps found 19
# Success
# ########################### Frequency 8699480000.0########################### 0.17647058823529413
# ########### Iteration number : 1 ##########
# The program is initalized with :
# A readout length of 50000 ns
# The Number of points  250000
# An initial point delay  6.4e-05 ms
# Time for iteration  0.20840000000000003 min
# 2023-05-13 12:42:33,056 - qm - INFO - Flags:
# 2023-05-13 12:42:33,056 - qm - INFO - Sending program to QOP
# 2023-05-13 12:42:33,895 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1471.676265718092 uV
# Jumps found 1
# ########### Iteration number : 2 ##########
# New number of points  50000
# New points delay  2.4545879999999998 ms
# Time for iteration  2.087156666666667 min
# 2023-05-13 12:42:48,668 - qm - INFO - Flags:
# 2023-05-13 12:42:48,668 - qm - INFO - Sending program to QOP
# 2023-05-13 12:42:49,439 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1479.865741566468 uV
# Jumps found 14
# Success
# ########################### Frequency 8699500000.0########################### 0.23529411764705882
# ########### Iteration number : 1 ##########
# The program is initalized with :
# A readout length of 50000 ns
# The Number of points  250000
# An initial point delay  6.4e-05 ms
# Time for iteration  0.20840000000000003 min
# 2023-05-13 12:44:56,158 - qm - INFO - Flags:
# 2023-05-13 12:44:56,159 - qm - INFO - Sending program to QOP
# 2023-05-13 12:44:56,961 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1428.5254399928972 uV
# Jumps found 0
# ########### Iteration number : 2 ##########
# no jumps found found
# New number of points  250000
# New points delay  0.0015999999999999999 ms
# Time for iteration  0.215 min
# 2023-05-13 12:45:11,677 - qm - INFO - Flags:
# 2023-05-13 12:45:11,678 - qm - INFO - Sending program to QOP
# 2023-05-13 12:45:12,126 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1436.9480269284986 uV
# Jumps found 1
# ########### Iteration number : 3 ##########
# New number of points  50000
# New points delay  2.529988 ms
# Time for iteration  2.1499900000000003 min
# 2023-05-13 12:45:27,296 - qm - INFO - Flags:
# 2023-05-13 12:45:27,297 - qm - INFO - Sending program to QOP
# 2023-05-13 12:45:28,077 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1417.3027220637143 uV
# Jumps found 52
# Success
# ########################### Frequency 8699520000.0########################### 0.29411764705882354
# ########### Iteration number : 1 ##########
# The program is initalized with :
# A readout length of 50000 ns
# The Number of points  250000
# An initial point delay  6.4e-05 ms
# Time for iteration  0.20840000000000003 min
# 2023-05-13 12:47:38,677 - qm - INFO - Flags:
# 2023-05-13 12:47:38,678 - qm - INFO - Sending program to QOP
# 2023-05-13 12:47:39,495 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1365.679150006166 uV
# Jumps found 23
# Success
# ########################### Frequency 8699540000.0########################### 0.35294117647058826
# ########### Iteration number : 1 ##########
# The program is initalized with :
# A readout length of 50000 ns
# The Number of points  250000
# An initial point delay  6.4e-05 ms
# Time for iteration  0.20840000000000003 min
# 2023-05-13 12:47:54,214 - qm - INFO - Flags:
# 2023-05-13 12:47:54,214 - qm - INFO - Sending program to QOP
# 2023-05-13 12:47:55,073 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1300.492879481047 uV
# Jumps found 94
# Success
# ########################### Frequency 8699560000.0########################### 0.4117647058823529
# ########### Iteration number : 1 ##########
# The program is initalized with :
# A readout length of 50000 ns
# The Number of points  250000
# An initial point delay  6.4e-05 ms
# Time for iteration  0.20840000000000003 min
# 2023-05-13 12:48:09,795 - qm - INFO - Flags:
# 2023-05-13 12:48:09,796 - qm - INFO - Sending program to QOP
# 2023-05-13 12:48:10,620 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1233.4805540818402 uV
# Jumps found 315
# Success
# ########################### Frequency 8699580000.0########################### 0.47058823529411764
# ########### Iteration number : 1 ##########
# The program is initalized with :
# A readout length of 50000 ns
# The Number of points  250000
# An initial point delay  6.4e-05 ms
# Time for iteration  0.20840000000000003 min
# 2023-05-13 12:48:25,012 - qm - INFO - Flags:
# 2023-05-13 12:48:25,013 - qm - INFO - Sending program to QOP
# 2023-05-13 12:48:25,491 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 1137.1549396902674 uV
# Jumps found 1074
# Success
# ########################### Frequency 8699600000.0########################### 0.5294117647058824
# ########### Iteration number : 1 ##########
# The program is initalized with :
# A readout length of 50000 ns
# The Number of points  250000
# An initial point delay  6.4e-05 ms
# Time for iteration  0.20840000000000003 min
# 2023-05-13 12:48:40,571 - qm - INFO - Flags:
# 2023-05-13 12:48:40,572 - qm - INFO - Sending program to QOP
# 2023-05-13 12:48:41,025 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 997.6977093300336 uV
# Jumps found 3354
# Success
# ########################### Frequency 8699620000.0########################### 0.5882352941176471
# ########### Iteration number : 1 ##########
# The program is initalized with :
# A readout length of 50000 ns
# The Number of points  250000
# An initial point delay  6.4e-05 ms
# Time for iteration  0.20840000000000003 min
# 2023-05-13 12:48:55,979 - qm - INFO - Flags:
# 2023-05-13 12:48:55,980 - qm - INFO - Sending program to QOP
# 2023-05-13 12:48:56,448 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 814.50036062314 uV
# Jumps found 5759
# Success
# ########################### Frequency 8699640000.0########################### 0.6470588235294118
# ########### Iteration number : 1 ##########
# The program is initalized with :
# A readout length of 50000 ns
# The Number of points  250000
# An initial point delay  6.4e-05 ms
# Time for iteration  0.20840000000000003 min
# 2023-05-13 12:49:11,376 - qm - INFO - Flags:
# 2023-05-13 12:49:11,376 - qm - INFO - Sending program to QOP
# 2023-05-13 12:49:12,217 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 643.3100020839197 uV
# Jumps found 6723
# Success
# ########################### Frequency 8699660000.0########################### 0.7058823529411765
# ########### Iteration number : 1 ##########
# The program is initalized with :
# A readout length of 50000 ns
# The Number of points  250000
# An initial point delay  6.4e-05 ms
# Time for iteration  0.20840000000000003 min
# 2023-05-13 12:49:27,008 - qm - INFO - Flags:
# 2023-05-13 12:49:27,009 - qm - INFO - Sending program to QOP
# 2023-05-13 12:49:27,482 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 391.85087415771477 uV
# vaccum state
# ########################### Frequency 8699680000.0########################### 0.7647058823529411
# ########### Iteration number : 1 ##########
# The program is initalized with :
# A readout length of 50000 ns
# The Number of points  250000
# An initial point delay  6.4e-05 ms
# Time for iteration  0.20840000000000003 min
# 2023-05-13 12:49:42,602 - qm - INFO - Flags:
# 2023-05-13 12:49:42,603 - qm - INFO - Sending program to QOP
# 2023-05-13 12:49:43,062 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 265.4909569730503 uV
# vaccum state
# ########################### Frequency 8699700000.0########################### 0.8235294117647058
# ########### Iteration number : 1 ##########
# The program is initalized with :
# A readout length of 50000 ns
# The Number of points  250000
# An initial point delay  6.4e-05 ms
# Time for iteration  0.20840000000000003 min
# 2023-05-13 12:49:57,907 - qm - INFO - Flags:
# 2023-05-13 12:49:57,908 - qm - INFO - Sending program to QOP
# 2023-05-13 12:49:58,800 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 172.0407875929219 uV
# vaccum state
# ########################### Frequency 8699720000.0########################### 0.8823529411764706
# ########### Iteration number : 1 ##########
# The program is initalized with :
# A readout length of 50000 ns
# The Number of points  250000
# An initial point delay  6.4e-05 ms
# Time for iteration  0.20840000000000003 min
# 2023-05-13 12:50:13,498 - qm - INFO - Flags:
# 2023-05-13 12:50:13,499 - qm - INFO - Sending program to QOP
# 2023-05-13 12:50:13,963 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 131.4475547189019 uV
# vaccum state
# ########################### Frequency 8699740000.0########################### 0.9411764705882353
# ########### Iteration number : 1 ##########
# The program is initalized with :
# A readout length of 50000 ns
# The Number of points  250000
# An initial point delay  6.4e-05 ms
# Time for iteration  0.20840000000000003 min
# 2023-05-13 12:50:28,854 - qm - INFO - Flags:
# 2023-05-13 12:50:28,855 - qm - INFO - Sending program to QOP
# 2023-05-13 12:50:29,320 - qm - INFO - Executing program
# Out_of_qm
# Execution stopped by user!
# signal average 94.70100328453076 uV
# vaccum state
# Wall time: 43min 15s

# %% [markdown]
# ## Saving the finding parameters

# %%
cooldown_date=Cooldown_Date #top folder   
device="second_order" #second folder 
name="Finding_parameters_multiple_freq" # third folder 
meastype="1p35_10jumps" #Final file name 

datadict={}
datadict["Readout_Len"]=Readout_Len
datadict["freqs_dict"]=freqs_dict
datadict["Readout_Delay"]=Readout_Delay*4
datadict["Offset_IF"]=Offset_IF
datadict["amp_factor_array"]=amp_factor_array
datadict["nb_desired_jumps"]=nb_desired_jumps
datadict["nb_points_between_jumps"]=nb_points_between_jumps 
datadict["Data"]=Data
datadict["octave_output_gain"]=octave_output_gain
datadict["config"]=config

an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)
# Out:
# saving

# %%
#Loading data 
filepath=r"X:\Users\beaulieu\Data\Run01\131\2023_05_05\second_order\Finding_parameters_multiple_freq\0p95_test_1.npz"

npzfile=np.load(filepath,allow_pickle=True)
npzfile["multidata"][()]

Data=npzfile["multidata"][()]["Data"]
freqs_dict=npzfile["multidata"][()]["freqs_dict"]
amp_factor_array=npzfile["multidata"][()]["amp_factor_array"]

# %% [markdown]
# ## Plotting multiple runs
#
# Plotting the results of the program to find the different optimap parameters

# %%
#Plotting all 
# %matplotlib qt 

n_bin=250 #bin size for the histogram 
figsize=(14,15)
fontsize=4
n_angle=100 #number of angles for the rotation 
n_avg=10 #number of average
dpi=300


amp_factor=amp_factor_array[0]
freqs=freqs_dict[amp_factor]

for idx in range(len(freqs)):
    
    IF_pump=freqs[idx]
    I=Data[amp_factor][freqs[idx]]["I"]
    Q=Data[amp_factor][freqs[idx]]["Q"]
    time=Data[amp_factor][freqs[idx]]["time"]

    plot_init_av_single(I,Q,time*1e-9,n_avg,n_bin,n_angle,figsize,fontsize,dpi)
# Out:
# Average signal : 0.0002280665332922363
# Average signal : 0.00022784347710083015
# Average signal : 0.00023428938965332026
# Average signal : 0.00034125892631103525
# Average signal : 0.0006244246285510254
# Average signal : 0.0006326655815026858
# Average signal : 0.0005293483862756348
# Average signal : 0.0004183897804394531
# Average signal : 0.0003252163883447265
# Average signal : 0.0002549833372863769
# Average signal : 0.00022748373052612305
# Average signal : 0.00022670278230712887
# Average signal : 0.00022755055088500973

# %%
plt.close("all")

# %%
# Plotting movie or single frame 
# %matplotlib qt

#Select what to plot 
idx=10 # Frame to plot 
amp_factor=1.15
freqs=freqs_dict[amp_factor] # freqecies

bin_size=100
fontsize=5
figsize=(4,12)
FileName=r"X:\Users\beaulieu\Data\Run01\131\2023_05_05\second_order\Plotting\1p15_finding_parameters"
movie=True
n_avg=10 # Number of average

def create_frame(idx,Data,FileName,bin_size,fontsize,movie=False):

    points_delay=Data[amp_factor][freqs[idx]]["points_delay"]*1e-6
    n_runs=Data[amp_factor][freqs[idx]]['n_runs']
    jumps=Data[amp_factor][freqs[idx]]["jumps"]
    vaccum=Data[amp_factor][freqs[idx]]["vaccum"]
    
    rot_I=Data[amp_factor][freqs[idx]]["rot_I"]
    rot_Q=Data[amp_factor][freqs[idx]]["rot_Q"]
    time=Data[amp_factor][freqs[idx]]["time"]
    
    #average_data
    average_I,average_Q,time_average=an.average_data(rot_I,rot_Q,time,n_avg)
    rot_I=average_I
    rot_Q=average_Q
    time=time_average

    fig= plt.figure(figsize=figsize,dpi=200)

    ax = plt.subplot(311)
    ax.plot(rot_I[0],rot_Q[0],".",markersize=2)
    ax.set_title('Pump Frequency '+str(freqs[idx])+ "GHz"+" Frame: "+str(idx),fontsize=fontsize)
    ax.set_xlabel("I [$\mu V$]",fontsize=fontsize)
    ax.set_ylabel("Q [$\mu V$]",fontsize=fontsize)
    ax.tick_params(axis='x', labelsize=fontsize)
    ax.tick_params(axis='y', labelsize=fontsize)


    ax=plt.subplot(312)
    ax.set_title('Number of runs:'+str(n_runs)+ " Points_delay :"+str(points_delay)+" ms",fontsize=fontsize)
    plt.plot(time,rot_I[0], ".", markersize=2)
    plt.xlabel("Time [s]",fontsize=fontsize)
    plt.ylabel("Phase",fontsize=fontsize)
    ax.tick_params(axis='x', labelsize=fontsize)
    ax.tick_params(axis='y', labelsize=fontsize)


    ax = plt.subplot(313)
    ax.set_title('Number of jumps:'+str(len(jumps))+" Vaccum = "+str(vaccum),fontsize=fontsize)
    ax.hist2d(rot_I[0],rot_Q[0],bins=bin_size)
    ax.set_xlabel("I [$\mu V$]",fontsize=fontsize)
    ax.set_ylabel("Q [$\mu V$]",fontsize=fontsize)
    ax.tick_params(axis='x', labelsize=fontsize)
    ax.tick_params(axis='y', labelsize=fontsize)
    ax.set_ylim(-0.0025, 0.0025) 
    ax.set_xlim(-0.0025, 0.0025)
    ax.set_facecolor(color=(68/255,1/255,84/255))
    
    if movie:
        plt.savefig(FileName+f'/img_{idx}.png', 
                        transparent = False,  
                        facecolor = 'white'
                       )    
        plt.close()
    

if movie==True :
    for idx in range(len(freqs)):
        create_frame(idx,Data,FileName,bin_size,fontsize,movie=True)
else:
    create_frame(idx,Data,FileName,bin_size,fontsize,movie=movie)

# %% [markdown]
# ## Plotting the Liouivillian gap

# %%
nb_angle=150
n_avg=10
corr_length=500

Processed_Data=an.Extract_second_order_gap(Data,amp_factor_array,freqs_dict,nb_angle,n_avg,corr_length)
# Out:
# 0

# %%
# %matplotlib qt
idx=0
amp_factor=amp_factor_array[idx]
freqs=freqs_dict[amp_factor]

for idx in range(len(freqs)):
    
    if Processed_Data[amp_factor][freqs[idx]]["fit"]:

        gap=Processed_Data[amp_factor][freqs[idx]]["gap"]
        coeff=Processed_Data[amp_factor][freqs[idx]]["fit_coeff"]
        time=Processed_Data[amp_factor][freqs[idx]]["time"]
        I=Processed_Data[amp_factor][freqs[idx]]["I"]
        y_fitted=Processed_Data[amp_factor][freqs[idx]]["y_fitted"]
        corr_list=Processed_Data[amp_factor][freqs[idx]]["corr_list"]

        fontsize=8
        fig, axs = plt.subplots( nrows=2, ncols=1, figsize=(5,10),dpi=100)
        ax=axs[1]
        ax.set_title("$\lambda= $"+str(round(gap,2)))
        ax.plot(time[0:corr_length],corr_list[0:corr_length],".")
        ax.plot(time[0:corr_length],y_fitted)
        ax.set_xlabel("time [s]")
        ax.set_ylabel("Autocorelation [Normalized]")
        
        ax=axs[0]
        ax.set_title("Pump= "+str(freqs[idx]) +" Iteration :" +str(idx))
        ax.plot(time,I*1e3,".")
        ax.set_xlabel("time [s]")
        ax.set_ylabel("I [mv]")


    else:
        print("No fit")
        time=Processed_Data[amp_factor][freqs[idx]]["time"]
        corr_list=Processed_Data[amp_factor][freqs[idx]]["corr_list"]
        
        
        
        fontsize=8
        fig, axs = plt.subplots( nrows=1, ncols=1, figsize=(5,5),dpi=100)
        ax=axs
        ax.set_title("Pump= "+str(freqs[idx]) +" Iteration :" +str(idx) + " No fit")
        ax.plot(time[0:corr_length],corr_list[0:corr_length])
        ax.set_xlabel("time [s]")
        ax.set_ylabel("Autocorelation [Normalized]")
# Out:
# No fit

# %%
plt.close("all")

# %%
# %matplotlib inline

amp_factor=amp_factor_array[0]
freqs=freqs_dict[amp_factor]

gap_array=[]
freq_gap_array=[]

for idx in range(len(freqs)):
    
    if Processed_Data[amp_factor][freqs[idx]]["fit"]:
        gap_array.append(Processed_Data[amp_factor][freqs[idx]]["gap"])
        freq_gap_array.append(freqs[idx])
        
gap_array=np.array(gap_array)
freq_gap_array=np.array(freq_gap_array)
        
        

# figsize=(5,4)

fontsize=8
figsize=(5,4)
fig, axs = plt.subplots( nrows=1, ncols=1, figsize=(5,5),dpi=200)

axs.plot(freq_gap_array/1e9,gap_array,'.-',alpha=.9, lw=.5, ms=8)
axs.set_xlabel("Pump frequency (IF)",fontsize=fontsize)
axs.set_ylabel("Louivillian gap",fontsize=fontsize)
axs.tick_params(axis='x', labelsize=fontsize)
axs.tick_params(axis='y', labelsize=fontsize)
axs.set_yscale('log')

# %% [markdown]
# ## Extract the Parameters

# %%
# If loaded 
filepath=r"X:\Users\beaulieu\Data\Run01\131\2023_05_05\second_order\Finding_parameters_multiple_freq\1p25_100jumps.npz"

npzfile=np.load(filepath,allow_pickle=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_41888\2608927232.py in <module>
#       2 filepath=r"X:\Users\beaulieu\Data\Run01\131\2023_05_05\second_order\Finding_parameters_multiple_freq\1p25_100jumps.npz"
#       3
# ----> 4 npzfile=np.load(filepath,allow_pickle=True)
#
# ~\Anaconda3\envs\Labber\lib\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415             own_fid = False
#     416         else:
# --> 417             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418             own_fid = True
#     419
#
# FileNotFoundError: [Errno 2] No such file or directory: 'X:\\Users\\beaulieu\\Data\\Run01\\131\\2023_05_05\\second_order\\Finding_parameters_multiple_freq\\1p25_100jumps.npz'

# %%
Parameters={}
Parameters["Readout_Delay"]=npzfile["multidata"][()]["Readout_Delay"]
Parameters["Offset_IF"]=npzfile["multidata"][()]["Offset_IF"]
Parameters["amp_factor_array"]=npzfile["multidata"][()]["amp_factor_array"]
Parameters["freqs_dict"]=npzfile["multidata"][()]["freqs_dict"]
Parameters["Readout_Len"]=npzfile["multidata"][()]["Readout_Len"]

#Setting the parameters for the measurement 
n_Data=npzfile["multidata"][()]["Data"]

# %%
# n_Data[1.25][99180000.0]["points_delay"]=5324544
# n_Data[1.25][99180000.0]["n_runs"]=25000
# n_Data[1.25][99180000.0]["jumps"]=np.array([ 184,  250,  560, 1075, 1567, 1886])

# %%
# Based on the previous collected information, we now want to select the readout length and time 

#Sets the default if the delay is smaller than 4
nb_desired_jumps=1000
nb_points_between_jumps=5000


Parameters={}
Total_time_vec=[]

#General parameters 
Parameters["Readout_Delay"]=npzfile["multidata"][()]["Readout_Delay"]
Parameters["Offset_IF"]=npzfile["multidata"][()]["Offset_IF"]
Parameters["amp_factor_array"]=npzfile["multidata"][()]["amp_factor_array"]
Parameters["freqs_dict"]=npzfile["multidata"][()]["freqs_dict"]
Parameters["Readout_Len"]=npzfile["multidata"][()]["Readout_Len"]

# New parameters
Parameters["nb_points_between_jumps"]=nb_points_between_jumps
Parameters["nb_desired_jumps"]=nb_desired_jumps




#Define certain parameters 
Readout_Len=Parameters["Readout_Len"]
amp_factor_array=Parameters["amp_factor_array"]
freqs_dict=Parameters["freqs_dict"]

for j in range(len(amp_factor_array)):
   
    amp_factor=amp_factor_array[j]
    Total_time_vec=[]
    Parameters[amp_factor]={}
    freqs=freqs_dict[amp_factor]
    
    for i in range(len(freqs)):

    
        IF_pump=freqs[i] # For each frequency 
        Parameters[amp_factor][IF_pump]={} 

        points_delay=n_Data[amp_factor][IF_pump]["points_delay"]
        n_runs=n_Data[amp_factor][IF_pump]["n_runs"]
        vaccum=n_Data[amp_factor][IF_pump]["vaccum"]
        jumps=n_Data[amp_factor][IF_pump]["jumps"]
        time=n_Data[amp_factor][IF_pump]["time"]
      
        #If we are in the vaccum case, we assign the minimum delay and the proper number of points 
        if vaccum:
            Parameters[amp_factor][IF_pump]["points_delay"]=16//4 # minimum readout 
            Parameters[amp_factor][IF_pump]["n_runs"]=nb_points_between_jumps*nb_desired_jumps

            Total_time=Parameters[amp_factor][IF_pump]["n_runs"]*(Parameters[amp_factor][IF_pump]["points_delay"]*4+Parameters["Readout_Len"])*1e-9
            Total_time_vec.append(Total_time)

            Parameters[amp_factor][IF_pump]["Total_time"]=np.around(Total_time/60, decimals=2)
            Parameters[amp_factor][IF_pump]["i"]=i

        else :

            time_per_jump=(time[-1]-time[0])/len(jumps)    
            update_points_delay= int((time_per_jump/ nb_points_between_jumps-Readout_Len)//4)

            update_n_runs=int(nb_points_between_jumps*nb_desired_jumps)


            if update_points_delay <=4:
                update_points_delay=16//4
                update_n_runs=int(nb_points_between_jumps*nb_desired_jumps)

            Parameters[amp_factor][IF_pump]["n_runs"]=int(update_n_runs)
            Parameters[amp_factor][IF_pump]["points_delay"]=int(update_points_delay)

            Total_time=int(Readout_Len+4*update_points_delay)*int(update_n_runs)*1e-9 # total time in seconds
            Total_time_vec.append(Total_time)

            Parameters[amp_factor][IF_pump]["Total_time"]=np.around(Total_time/60, decimals=2)
            Parameters[amp_factor][IF_pump]["i"]=i

    print("The estimated time for the measurement is {} min".format(sum(Total_time_vec)/60))
Parameters
# Out:
# 99140000.0
# 99160000.0
# 99180000.0
# 99200000.0
# 99220000.0
# 99240000.0
# 99260000.0
# 99280000.0
# 99300000.0
# 99320000.0
# 99340000.0
# 99360000.0
# 99380000.0
# 99400000.0
# 99420000.0
# 99440000.0
# 99460000.0
# 99480000.0
# 99500000.0
# 99520000.0
# 99540000.0
# 99560000.0
# 99580000.0
# 99600000.0
# 99620000.0
# 99640000.0
# 99660000.0
# 99680000.0
# 99700000.0
# The estimated time for the measurement is 120.87199999999999 min
# {'Readout_Delay': 1000000,
#  'Offset_IF': 0,
#  'amp_factor_array': array([0.85]),
#  'freqs_dict': {0.85: array([99140000., 99160000., 99180000., 99200000., 99220000., 99240000.,
#          99260000., 99280000., 99300000., 99320000., 99340000., 99360000.,
#          99380000., 99400000., 99420000., 99440000., 99460000., 99480000.,
#          99500000., 99520000., 99540000., 99560000., 99580000., 99600000.,
#          99620000., 99640000., 99660000., 99680000., 99700000.])},
#  'Readout_Len': 50000,
#  'nb_points_between_jumps': 5000,
#  'nb_desired_jumps': 1000,
#  0.85: {99140000.0: {'points_delay': 4,
#    'n_runs': 5000000,
#    'Total_time': 4.17,
#    'i': 0},
#   99160000.0: {'points_delay': 4,
#    'n_runs': 5000000,
#    'Total_time': 4.17,
#    'i': 1},
#   99180000.0: {'points_delay': 4,
#    'n_runs': 5000000,
#    'Total_time': 4.17,
#    'i': 2},
#   99200000.0: {'points_delay': 4,
#    'n_runs': 5000000,
#    'Total_time': 4.17,
#    'i': 3},
#   99220000.0: {'points_delay': 4,
#    'n_runs': 5000000,
#    'Total_time': 4.17,
#    'i': 4},
#   99240000.0: {'points_delay': 4,
#    'n_runs': 5000000,
#    'Total_time': 4.17,
#    'i': 5},
#   99260000.0: {'points_delay': 4,
#    'n_runs': 5000000,
#    'Total_time': 4.17,
#    'i': 6},
#   99280000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 4.17,
#    'i': 7},
#   99300000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 4.17,
#    'i': 8},
#   99320000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 4.17,
#    'i': 9},
#   99340000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 4.17,
#    'i': 10},
#   99360000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 4.17,
#    'i': 11},
#   99380000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 4.17,
#    'i': 12},
#   99400000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 4.17,
#    'i': 13},
#   99420000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 4.17,
#    'i': 14},
#   99440000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 4.17,
#    'i': 15},
#   99460000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 4.17,
#    'i': 16},
#   99480000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 4.17,
#    'i': 17},
#   99500000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 4.17,
#    'i': 18},
#   99520000.0: {'points_delay': 4,
#    'n_runs': 5000000,
#    'Total_time': 4.17,
#    'i': 19},
#   99540000.0: {'points_delay': 4,
#    'n_runs': 5000000,
#    'Total_time': 4.17,
#    'i': 20},
#   99560000.0: {'points_delay': 4,
#    'n_runs': 5000000,
#    'Total_time': 4.17,
#    'i': 21},
#   99580000.0: {'points_delay': 4,
#    'n_runs': 5000000,
#    'Total_time': 4.17,
#    'i': 22},
#   99600000.0: {'points_delay': 4,
#    'n_runs': 5000000,
#    'Total_time': 4.17,
#    'i': 23},
#   99620000.0: {'points_delay': 4,
#    'n_runs': 5000000,
#    'Total_time': 4.17,
#    'i': 24},
#   99640000.0: {'points_delay': 4,
#    'n_runs': 5000000,
#    'Total_time': 4.17,
#    'i': 25},
#   99660000.0: {'points_delay': 4,
#    'n_runs': 5000000,
#    'Total_time': 4.17,
#    'i': 26},
#   99680000.0: {'points_delay': 4,
#    'n_runs': 5000000,
#    'Total_time': 4.17,
#    'i': 27},
#   99700000.0: {'points_delay': 4,
#    'n_runs': 5000000,
#    'Total_time': 4.17,
#    'i': 28}}}

# %% [markdown]
# ## Parameters for faster

# %%
## New parameters for faster 

Readout_Len=10_000
amp_factor=1.35

fmin= 99.54e6
fmax=99.76e6
df=0.02* u.MHz
freqs=np.arange(fmin, fmax+df/2, df)

nb_points_between_jumps=5000
nb_desired_jumps=1000


Parameters={}
Parameters["Readout_Delay"]=10_000
Parameters["Offset_IF"]=0

amp_factor_array=np.array([amp_factor]) 

Parameters["amp_factor_array"]=amp_factor_array

freqs_dict={}
freqs_dict[amp_factor_array[0]]=freqs

Parameters["freqs_dict"]=freqs_dict
Parameters["Readout_Len"]=Readout_Len
# New parameters
Parameters["nb_points_between_jumps"]=nb_points_between_jumps
Parameters["nb_desired_jumps"]=nb_desired_jumps


for j in range(len(amp_factor_array)):
   
    amp_factor=amp_factor_array[j]
    Total_time_vec=[]
    Parameters[amp_factor]={}
    freqs=freqs_dict[amp_factor]
    
    for i in range(len(freqs)):

    
        IF_pump=freqs[i] # For each frequency 
        Parameters[amp_factor][IF_pump]={} 

      
        update_points_delay=16//4
        update_n_runs=int(nb_points_between_jumps*nb_desired_jumps)

        Parameters[amp_factor][IF_pump]["n_runs"]=int(update_n_runs)
        Parameters[amp_factor][IF_pump]["points_delay"]=int(update_points_delay)

        Total_time=int(Readout_Len+4*update_points_delay)*int(update_n_runs)*1e-9 # total time in seconds
        Total_time_vec.append(Total_time)

        Parameters[amp_factor][IF_pump]["Total_time"]=np.around(Total_time/60, decimals=2)
        Parameters[amp_factor][IF_pump]["i"]=i




print("The estimated time for the measurement is {} min".format(sum(Total_time_vec)/60))
print(freqs_dict)
Parameters
# Out:
# The estimated time for the measurement is 10.016 min
# {1.35: array([99540000., 99560000., 99580000., 99600000., 99620000., 99640000.,
#        99660000., 99680000., 99700000., 99720000., 99740000., 99760000.])}
# {'Readout_Delay': 10000,
#  'Offset_IF': 0,
#  'amp_factor_array': array([1.35]),
#  'freqs_dict': {1.35: array([99540000., 99560000., 99580000., 99600000., 99620000., 99640000.,
#          99660000., 99680000., 99700000., 99720000., 99740000., 99760000.])},
#  'Readout_Len': 10000,
#  'nb_points_between_jumps': 5000,
#  'nb_desired_jumps': 1000,
#  1.35: {99540000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 0},
#   99560000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 1},
#   99580000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 2},
#   99600000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 3},
#   99620000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 4},
#   99640000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 5},
#   99660000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 6},
#   99680000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 7},
#   99700000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 8},
#   99720000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 9},
#   99740000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 10},
#   99760000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 11}}}

# %%
Parameters[amp_factor][99380000]["points_delay"]=657006
Parameters[amp_factor][99380000]["Total_time"]=int(Readout_Len+4*657006)*int(1250000)*1e-9/60 

Parameters[amp_factor][99400000]["points_delay"]=404889
Parameters[amp_factor][99400000]["Total_time"]=int(Readout_Len+4*404889)*int(1250000)*1e-9/60

Parameters[amp_factor][99420000]["points_delay"]=152259
Parameters[amp_factor][99420000]["Total_time"]=int(Readout_Len+4*152259)*int(1250000)*1e-9/60

Parameters[amp_factor][99440000]["points_delay"]=44422
Parameters[amp_factor][99440000]["Total_time"]=int(Readout_Len+4*44422)*int(1250000)*1e-9/60

# %%
# Modification
time_vec=[]
freqs=Parameters["freqs_dict"][amp_factor]
for i in range(len(freqs)):
    time_vec.append(Parameters[amp_factor][freqs[i]]["Total_time"])
    
sum(time_vec)
# Out:
# 124.6480000000001

# %%
Parameters
# Out:
# {'Readout_Delay': 10000,
#  'Offset_IF': 0,
#  'amp_factor_array': array([1.35]),
#  'freqs_dict': {1.35: array([99540000., 99560000., 99580000., 99600000., 99620000., 99640000.,
#          99660000., 99680000., 99700000., 99720000., 99740000., 99760000.])},
#  'Readout_Len': 10000,
#  'nb_points_between_jumps': 5000,
#  'nb_desired_jumps': 1000,
#  1.35: {99540000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 0},
#   99560000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 1},
#   99580000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 2},
#   99600000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 3},
#   99620000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 4},
#   99640000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 5},
#   99660000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 6},
#   99680000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 7},
#   99700000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 8},
#   99720000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 9},
#   99740000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 10},
#   99760000.0: {'n_runs': 5000000,
#    'points_delay': 4,
#    'Total_time': 0.83,
#    'i': 11}}}

# %%
Parameters
# Out:
# {'Readout_Delay': 1000000,
#  'Offset_IF': 0,
#  'amp_factor_array': array([1.25]),
#  'freqs_dict': {1.25: array([99000000., 99020000., 99040000., 99060000., 99080000., 99100000.,
#          99120000., 99140000., 99160000., 99180000., 99200000., 99220000.,
#          99240000., 99260000., 99280000., 99300000., 99320000., 99340000.,
#          99360000., 99380000., 99400000., 99420000., 99440000., 99460000.,
#          99480000., 99500000., 99520000., 99540000., 99560000., 99580000.,
#          99600000., 99620000., 99640000., 99660000., 99680000., 99700000.,
#          99720000., 99740000.])},
#  'Readout_Len': 50000,
#  'nb_points_between_jumps': 5000,
#  'nb_desired_jumps': 100,
#  1.25: {99000000.0: {'points_delay': 4,
#    'n_runs': 500000,
#    'Total_time': 0.42,
#    'i': 0},
#   99020000.0: {'points_delay': 4,
#    'n_runs': 500000,
#    'Total_time': 0.42,
#    'i': 1},
#   99040000.0: {'points_delay': 4,
#    'n_runs': 500000,
#    'Total_time': 0.42,
#    'i': 2},
#   99060000.0: {'points_delay': 4,
#    'n_runs': 500000,
#    'Total_time': 0.42,
#    'i': 3},
#   99080000.0: {'n_runs': 500000,
#    'points_delay': 1202407,
#    'Total_time': 40.5,
#    'i': 4},
#   99100000.0: {'n_runs': 500000,
#    'points_delay': 1202407,
#    'Total_time': 40.5,
#    'i': 5},
#   99120000.0: {'n_runs': 500000,
#    'points_delay': 1081136,
#    'Total_time': 20.87,
#    'i': 6},
#   99140000.0: {'n_runs': 500000,
#    'points_delay': 1081136,
#    'Total_time': 36.45,
#    'i': 7},
#   99160000.0: {'n_runs': 500000,
#    'points_delay': 1062280,
#    'Total_time': 35.83,
#    'i': 8},
#   99180000.0: {'n_runs': 500000,
#    'points_delay': 1202407,
#    'Total_time': 40.496900000000004,
#    'i': 9},
#   99200000.0: {'n_runs': 500000,
#    'points_delay': 1164115,
#    'Total_time': 39.22,
#    'i': 10},
#   99220000.0: {'n_runs': 500000,
#    'points_delay': 1506134,
#    'Total_time': 50.62,
#    'i': 11},
#   99240000.0: {'n_runs': 500000,
#    'points_delay': 2049991,
#    'Total_time': 68.75,
#    'i': 12},
#   99260000.0: {'n_runs': 500000,
#    'points_delay': 1291582,
#    'Total_time': 43.47,
#    'i': 13},
#   99280000.0: {'n_runs': 500000,
#    'points_delay': 1202407,
#    'Total_time': 40.496900000000004,
#    'i': 14},
#   99300000.0: {'n_runs': 500000,
#    'points_delay': 1884536,
#    'Total_time': 63.23,
#    'i': 15},
#   99320000.0: {'n_runs': 500000,
#    'points_delay': 1202407,
#    'Total_time': 40.496900000000004,
#    'i': 16},
#   99340000.0: {'n_runs': 500000,
#    'points_delay': 1202407,
#    'Total_time': 40.496900000000004,
#    'i': 17},
#   99360000.0: {'n_runs': 500000,
#    'points_delay': 1552398,
#    'Total_time': 52.16,
#    'i': 18},
#   99380000.0: {'n_runs': 500000,
#    'points_delay': 657006,
#    'Total_time': 22.32,
#    'i': 19},
#   99400000.0: {'n_runs': 500000,
#    'points_delay': 404889,
#    'Total_time': 13.91,
#    'i': 20},
#   99420000.0: {'n_runs': 500000,
#    'points_delay': 152259,
#    'Total_time': 5.49,
#    'i': 21},
#   99440000.0: {'n_runs': 500000,
#    'points_delay': 44422,
#    'Total_time': 1.9,
#    'i': 22},
#   99460000.0: {'n_runs': 500000,
#    'points_delay': 4,
#    'Total_time': 0.42,
#    'i': 23},
#   99480000.0: {'n_runs': 500000,
#    'points_delay': 4,
#    'Total_time': 0.42,
#    'i': 24},
#   99500000.0: {'n_runs': 500000,
#    'points_delay': 4,
#    'Total_time': 0.42,
#    'i': 25},
#   99520000.0: {'n_runs': 500000,
#    'points_delay': 4,
#    'Total_time': 0.42,
#    'i': 26},
#   99540000.0: {'n_runs': 500000,
#    'points_delay': 4,
#    'Total_time': 0.42,
#    'i': 27},
#   99560000.0: {'n_runs': 500000,
#    'points_delay': 4,
#    'Total_time': 0.42,
#    'i': 28},
#   99580000.0: {'points_delay': 4,
#    'n_runs': 500000,
#    'Total_time': 0.42,
#    'i': 29},
#   99600000.0: {'points_delay': 4,
#    'n_runs': 500000,
#    'Total_time': 0.42,
#    'i': 30},
#   99620000.0: {'points_delay': 4,
#    'n_runs': 500000,
#    'Total_time': 0.42,
#    'i': 31},
#   99640000.0: {'points_delay': 4,
#    'n_runs': 500000,
#    'Total_time': 0.42,
#    'i': 32},
#   99660000.0: {'points_delay': 4,
#    'n_runs': 500000,
#    'Total_time': 0.42,
#    'i': 33},
#   99680000.0: {'points_delay': 4,
#    'n_runs': 500000,
#    'Total_time': 0.42,
#    'i': 34},
#   99700000.0: {'points_delay': 4,
#    'n_runs': 500000,
#    'Total_time': 0.42,
#    'i': 35},
#   99720000.0: {'points_delay': 4,
#    'n_runs': 500000,
#    'Total_time': 0.42,
#    'i': 36},
#   99740000.0: {'points_delay': 4,
#    'n_runs': 500000,
#    'Total_time': 0.42,
#    'i': 37}}}

# %% [markdown]
# ### Save the parameters

# %%
## Saving the parameters

cooldown_date=Cooldown_Date #top folder   
device="second_order" #second folder 
name="parameters_multiple_freq" # third folder 
meastype="1p35_1000jumps_fast" #Final file name 

datadict={}
datadict["Parameters"]=Parameters
an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)
# Out:
# saving

# %%
#Loading the parameters
filepath=r"X:\Users\beaulieu\Data\Run01\131\2023_05_05\second_order\parameters_multiple_freq\1p25_100jumps.npz"

npzfile=np.load(filepath,allow_pickle=True)
npzfile["multidata"][()]

Parameters=npzfile["multidata"][()]["Parameters"]

# %% [markdown]
# # Run full measurement based on parameters
#
# Using the parameters defined in the previous dictionnary, we run the program for each frequency

# %%
# %%time
# %matplotlib qt

#Saving parameters 
save_data=False 
cooldown_date="2023_03_31" #top folder 
device="Run01" #second folder 
name="104_program_IQ" # third folder 
meastype="0p25_amp_single_Readout_length" #Final file name 

#general parmeters 
freqs_dict=Parameters["freqs_dict"]
Readout_Delay =int(Parameters["Readout_Delay"]//4)
Offset_IF=int(Parameters["Offset_IF"])
amp_factor_array=Parameters['amp_factor_array']
Readout_Len=int(Parameters["Readout_Len"])
config,qm=update_readout_lenght(Readout_Len,config,qmm)
    
Data_full={}

#for each pump frequency 

for j in range(len(amp_factor_array)):
    
    amp_factor=amp_factor_array[j]
    freqs=freqs_dict[amp_factor]
    Data_full[amp_factor]={}
    
    for idx in range(len(freqs)):

        IF_pump=float(freqs[idx])

        Data_full[amp_factor][IF_pump]={}

        #Parameters for taking a single trace 
        IF_resonator=(LO_fluxline+IF_pump)/2-LO_readout

        points_delay=int(Parameters[amp_factor][IF_pump]["points_delay"])
        n_runs=int(Parameters[amp_factor][IF_pump]["n_runs"])


        #Run the program 
        time, I, Q =single_IQ_trace(IF_pump,IF_resonator,Offset_IF,amp_factor,n_runs,Readout_Delay,points_delay,Readout_Len,qm)

        Data_full[amp_factor][IF_pump]["I"]=I
        Data_full[amp_factor][IF_pump]["Q"]=Q
        Data_full[amp_factor][IF_pump]["time"]=time

        print(IF_pump)
        print(idx/len(freqs))
        time_package.sleep(1)
        plt.close()
    
if save_data:

    # Saving the data 
    datadict={}
    datadict["freqs_dict"]=freqs_dict
    datadict["amp_factor_array"]=amp_factor_array
    datadict["Data"]=Data_full
    datadict["configuration"]=config
    datadict["Parameters"]=Parameters

    an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=r"C:\Users\hqclabo\Documents\Data\gbeaulieu\Two_Photon\\")
# Out:
# 2023-05-14 17:58:52,612 - qm - INFO - Flags:
# 2023-05-14 17:58:52,613 - qm - INFO - Sending program to QOP
# 2023-05-14 17:58:52,742 - qm - INFO - Executing program
# 99540000.0
# 0.0
# Execution stopped by user!
# 2023-05-14 17:59:55,244 - qm - INFO - Flags:
# 2023-05-14 17:59:55,244 - qm - INFO - Sending program to QOP
# 2023-05-14 17:59:55,381 - qm - INFO - Executing program
# 99560000.0
# 0.08333333333333333
# Execution stopped by user!
# 2023-05-14 18:00:58,843 - qm - INFO - Flags:
# 2023-05-14 18:00:58,843 - qm - INFO - Sending program to QOP
# 2023-05-14 18:00:58,972 - qm - INFO - Executing program
# 99580000.0
# 0.16666666666666666
# Execution stopped by user!
# 2023-05-14 18:01:58,934 - qm - INFO - Flags:
# 2023-05-14 18:01:58,935 - qm - INFO - Sending program to QOP
# 2023-05-14 18:01:59,061 - qm - INFO - Executing program
# 99600000.0
# 0.25
# Execution stopped by user!
# 2023-05-14 18:02:58,914 - qm - INFO - Flags:
# 2023-05-14 18:02:58,915 - qm - INFO - Sending program to QOP
# 2023-05-14 18:02:59,048 - qm - INFO - Executing program
# 99620000.0
# 0.3333333333333333
# Execution stopped by user!
# 2023-05-14 18:03:59,143 - qm - INFO - Flags:
# 2023-05-14 18:03:59,143 - qm - INFO - Sending program to QOP
# 2023-05-14 18:03:59,656 - qm - INFO - Executing program
# 99640000.0
# 0.4166666666666667
# Execution stopped by user!
# 2023-05-14 18:04:59,999 - qm - INFO - Flags:
# 2023-05-14 18:05:00,000 - qm - INFO - Sending program to QOP
# 2023-05-14 18:05:00,129 - qm - INFO - Executing program
# 99660000.0
# 0.5
# Execution stopped by user!
# 2023-05-14 18:06:03,256 - qm - INFO - Flags:
# 2023-05-14 18:06:03,256 - qm - INFO - Sending program to QOP
# 2023-05-14 18:06:03,703 - qm - INFO - Executing program
# 99680000.0
# 0.5833333333333334
# Execution stopped by user!
# 2023-05-14 18:07:05,209 - qm - INFO - Flags:
# 2023-05-14 18:07:05,210 - qm - INFO - Sending program to QOP
# 2023-05-14 18:07:05,338 - qm - INFO - Executing program
# 99700000.0
# 0.6666666666666666
# Execution stopped by user!
# 2023-05-14 18:08:07,369 - qm - INFO - Flags:
# 2023-05-14 18:08:07,369 - qm - INFO - Sending program to QOP
# 2023-05-14 18:08:07,488 - qm - INFO - Executing program
# 99720000.0
# 0.75
# Execution stopped by user!
# 2023-05-14 18:09:10,935 - qm - INFO - Flags:
# 2023-05-14 18:09:10,936 - qm - INFO - Sending program to QOP
# 2023-05-14 18:09:11,069 - qm - INFO - Executing program
# 99740000.0
# 0.8333333333333334
# Execution stopped by user!
# 2023-05-14 18:10:13,703 - qm - INFO - Flags:
# 2023-05-14 18:10:13,703 - qm - INFO - Sending program to QOP
# 2023-05-14 18:10:13,831 - qm - INFO - Executing program
# 99760000.0
# 0.9166666666666666
# Execution stopped by user!
# Wall time: 12min 21s

# %% [markdown]
# ## Saving the data

# %%
# Saving the data 
cooldown_date=Cooldown_Date #top folder   
device="second_order" #second folder 
name="measurement_freq" # third folder 
meastype="1p35_1000jumps_fast" #Final file name 


datadict={}


datadict={}
datadict["freqs_dict"]=freqs_dict
datadict["amp_factor_array"]=amp_factor_array
datadict["Data"]=Data_full
datadict["configuration"]=config
datadict["Parameters"]=Parameters

an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)
# Out:
# saving

# %%
#Loading the data 
filepath=r"X:\Users\beaulieu\Data\Run01\131\2023_05_05\second_order\measurement_freq\1p35\1p35_100jumps.npz"

npzfile=np.load(filepath,allow_pickle=True)

Data_full=npzfile["multidata"][()]["Data"]
freqs_dict=npzfile["multidata"][()]["freqs_dict"]
amp_factor_array=npzfile["multidata"][()]["amp_factor_array"]

# %% [markdown]
# ## Ploting for multiple runs

# %% [markdown]
# ## Plotting the Liouvillian gap

# %%
# %matplotlib qt
nb_angle=150
n_avg=10
corr_length=100

Processed_Data=an.Extract_second_order_gap(Data_full,amp_factor_array,freqs_dict,nb_angle,n_avg,corr_length)
# Out:
# 0

# %%
#Plotting the exponential decay 

# %matplotlib qt
idx=0
amp_factor=amp_factor_array[idx]
freqs=freqs_dict[amp_factor]

for idx in range(len(freqs)):
    
    
    if Processed_Data[amp_factor][freqs[idx]]["fit"]:

        gap=Processed_Data[amp_factor][freqs[idx]]["gap"]
        coeff=Processed_Data[amp_factor][freqs[idx]]["fit_coeff"]
        time=Processed_Data[amp_factor][freqs[idx]]["time"]
        I=Processed_Data[amp_factor][freqs[idx]]["I"]
        y_fitted=Processed_Data[amp_factor][freqs[idx]]["y_fitted"]
        corr_list=Processed_Data[amp_factor][freqs[idx]]["corr_list"]

        fontsize=8
        fig, axs = plt.subplots( nrows=2, ncols=1, figsize=(5,10),dpi=100)
        ax=axs[1]
        ax.set_title("$\lambda= $"+str(round(gap,2)))
        ax.plot(time[0:corr_length],corr_list[0:corr_length],".")
        ax.plot(time[0:corr_length],y_fitted)
        ax.set_xlabel("time [s]")
        ax.set_ylabel("Autocorelation [Normalized]")
        
        ax=axs[0]
        ax.set_title("Pump= "+str(freqs[idx]) +" Iteration :" +str(idx))
        ax.plot(time,I*1e3,".")
        ax.set_xlabel("time [s]")
        ax.set_ylabel("I [mv]")


    else:
        print("No fit")
        time=Processed_Data[amp_factor][freqs[idx]]["time"]
        corr_list=Processed_Data[amp_factor][freqs[idx]]["corr_list"]
        
        
        
        fontsize=8
        fig, axs = plt.subplots( nrows=1, ncols=1, figsize=(5,5),dpi=100)
        ax=axs
        ax.set_title("Pump= "+str(freqs[idx]) +" Iteration :" +str(idx) + " No fit")
        ax.plot(time[0:corr_length],corr_list[0:corr_length])
        ax.set_xlabel("time [s]")
        ax.set_ylabel("Autocorelation [Normalized]")
# Out:
# No fit
# No fit
# No fit
# No fit
# No fit
# No fit
# No fit

# %%
plt.close("all")

# %%
#Plotting the gap 

# %matplotlib inline

center_freq=4.34799e9*2
Gi=0.6

fontsize=8
figsize=(5,4)
fig, axs = plt.subplots( ncols=2, figsize=(14,6),dpi=300)

for j in range(len(amp_factor_array)):
    
    amp_factor=amp_factor_array[j]
    freqs=freqs_dict[amp_factor]
    gap_array=[]
    freq_gap_array=[]
    
    for idx in range(len(freqs)):

        if Processed_Data[amp_factor][freqs[idx]]["fit"]:
            gap_array.append(Processed_Data[amp_factor][freqs[idx]]["gap"])
            freq_gap_array.append(freqs[idx])
        
    gap_array=np.array(gap_array)
    freq_gap_array=np.array(freq_gap_array)
    
    ax=axs[0]
    ax.plot(freq_gap_array/1e9,gap_array,".-",label=f'Pump={amp_factor:.1f}', alpha=.9, lw=.5, ms=8)    
    ax=axs[1]
    Gx=amp_factor
    ax.plot( ((freq_gap_array+LO_fluxline)-center_freq)*Gi/Gx,gap_array,".-",label=f'Pump={amp_factor:.1f}', alpha=.9, lw=.5, ms=8)
  
ax=axs[0]
ax.set_xlabel("Pump frequency (IF)",fontsize=fontsize)
ax.set_ylabel("Louivillian gap",fontsize=fontsize)
ax.tick_params(axis='x', labelsize=fontsize)
ax.tick_params(axis='y', labelsize=fontsize)  
ax.legend(fontsize=fontsize)
ax.set_yscale('log')

ax=axs[1]
ax.set_title("Normalized")
ax.set_ylabel("Louivillian gap",fontsize=fontsize)
ax.tick_params(axis='x', labelsize=fontsize)
ax.tick_params(axis='y', labelsize=fontsize) 
ax.set_xlabel('$\Delta\cdot$F')
ax.legend(fontsize=fontsize)
ax.set_yscale('log')

# %% [markdown]
# ## Plotting the IQ blobs

# %%
# %matplotlib qt

idx=5
amp_factor=1.35
freqs=freqs_dict[amp_factor] # freqecies


bin_size=150
fontsize=8
FileName=r"X:\Users\beaulieu\Data\Run01\131\2023_05_05\second_order\Plotting\1p35_measurement"
movie=True
figsize=(4,12)

def create_frame(idx,Processed_Data,FileName,bin_size,fontsize,figsize,movie=False):

    IF_pump=freqs[idx]
    time=Processed_Data[amp_factor][freqs[idx]]["time"]
    I=Processed_Data[amp_factor][freqs[idx]]["I"]
    Q=Processed_Data[amp_factor][freqs[idx]]["Q"]

    fig= plt.figure(figsize=figsize,dpi=300)

    ax = plt.subplot(311)
    ax.plot(I,Q,".",markersize=2)
    ax.set_title('Pump Frequency '+str(freqs[idx])+ "GHz"+" Frame: "+str(idx),fontsize=fontsize)
    ax.set_xlabel("I [$\mu V$]",fontsize=fontsize)
    ax.set_ylabel("Q [$\mu V$]",fontsize=fontsize)
    ax.tick_params(axis='x', labelsize=fontsize)
    ax.tick_params(axis='y', labelsize=fontsize)
    ax.set_ylim(-0.002, 0.002) 
    ax.set_xlim(-0.002, 0.002)

    ax=plt.subplot(312)
    plt.plot(time,I, ".", markersize=2)
    plt.xlabel("Time [s]",fontsize=fontsize)
    plt.ylabel("Phase",fontsize=fontsize)
    ax.tick_params(axis='x', labelsize=fontsize)
    ax.tick_params(axis='y', labelsize=fontsize)


    ax = plt.subplot(313)
    ax.hist2d(I,Q,bins=bin_size)
    ax.set_xlabel("I [$\mu V$]",fontsize=fontsize)
    ax.set_ylabel("Q [$\mu V$]",fontsize=fontsize)
    ax.set_ylim(-0.0025, 0.0025) 
    ax.set_xlim(-0.0025, 0.0025)
    ax.set_facecolor(color=(68/255,1/255,84/255))
    
    
    if movie:
        plt.savefig(FileName+f'/img_{idx}.png', 
                        transparent = False,  
                        facecolor = 'white'
                       )    
        plt.close()
    
if movie==True :
    for idx in range(len(freqs)):
        create_frame(idx,Processed_Data,FileName,bin_size,fontsize,figsize,movie=True)
else:
    create_frame(idx,Processed_Data,FileName,bin_size,fontsize,figsize,movie=movie)

# %% [markdown]
# ## Older

# %%
# %matplotlib qt
idx=22
bin_size=150
fontsize=8
FileName=r"C:\Users\HQClabo\Documents\Data\gbeaulieu\Two_Photon\2023_03_31\Run01\104_plotting\0p25_amp_single_Readout_length"
movie=True
figsize=(4,12)

def create_frame(idx,Data_full_av,FileName,bin_size,fontsize,figsize,movie=False):

    IF_pump=freqs[idx]
    I=Data_full_av[IF_pump]["I"]
    Q=Data_full_av[IF_pump]["Q"]
    time=Data_full_av[IF_pump]["time"]

    fig= plt.figure(figsize=figsize,dpi=300)

    ax = plt.subplot(311)
    ax.plot(I[0,:],Q[0,:],".",markersize=2)
    ax.set_title('Pump Frequency '+str(freqs[idx])+ "GHz"+" Frame: "+str(idx),fontsize=fontsize)
    ax.set_xlabel("I [$\mu V$]",fontsize=fontsize)
    ax.set_ylabel("Q [$\mu V$]",fontsize=fontsize)
    ax.tick_params(axis='x', labelsize=fontsize)
    ax.tick_params(axis='y', labelsize=fontsize)
    ax.set_ylim(-0.002, 0.002) 
    ax.set_xlim(-0.002, 0.002)

    ax=plt.subplot(312)
    plt.plot(time,I[0,:], ".", markersize=2)
    plt.xlabel("Time [s]",fontsize=fontsize)
    plt.ylabel("Phase",fontsize=fontsize)
    ax.tick_params(axis='x', labelsize=fontsize)
    ax.tick_params(axis='y', labelsize=fontsize)


    ax = plt.subplot(313)
    ax.hist2d(I[0,:],Q[0,:],bins=bin_size)
    ax.set_xlabel("I [$\mu V$]",fontsize=fontsize)
    ax.set_ylabel("Q [$\mu V$]",fontsize=fontsize)
    ax.set_ylim(-0.0025, 0.0025) 
    ax.set_xlim(-0.0025, 0.0025)
    ax.set_facecolor(color=(68/255,1/255,84/255))
    
    
    if movie:
        plt.savefig(FileName+f'/img_{idx}.png', 
                        transparent = False,  
                        facecolor = 'white'
                       )    
        plt.close()
    
if movie==True :
    for idx in range(len(freqs)):
        create_frame(idx,Data_full_av,FileName,bin_size,fontsize,figsize,movie=True)
else:
    create_frame(idx,Data,FileName,bin_size,fontsize,figsize,movie=movie)

# %%
# Rotation and average of all the datas 

# %matplotlib inline
nb_angle=150
n_avg=10
threshold=5e-4

Data_full_av={}

for j in range(len(amp_factor_array)):
    
    amp_factor=amp_factor_array[j]
    freqs_dict[amp_factor]=freqs
    Data_full_av[amp_factor]={}
    
    for i in range(len(freqs)):

        vaccum=False 
        IF_pump=float(freqs[i])
        Data_full_av[amp_factor][IF_pump]={}

        I=np.reshape(Data_full[amp_factor][IF_pump]["I"],(1, Data_full[amp_factor][IF_pump]["I"].shape[0]))
        Q=np.reshape(Data_full[amp_factor][IF_pump]["Q"],(1, Data_full[amp_factor][IF_pump]["Q"].shape[0]))
        time=Data_full[IF_pump]["time"]
        rot_I,rot_Q=an.rotate_data(I,Q,nb_angle)
        average_I,average_Q,time_average=an.average_data(rot_I,rot_Q,time,n_avg)

        Data_full_av[IF_pump]["I"]=average_I
        Data_full_av[IF_pump]["Q"]=average_Q
        Data_full_av[IF_pump]["time"]=time_average

        av = np.mean(abs(average_I))
        if av<threshold:
            vaccum=True

        Data_full_av[IF_pump]["vaccum"]=vaccum

    Data_full_av[IF_pump]["freqs"]=freqs

# %%
zero_crossings=[]

for i in range(len(freqs)):
    IF_pump=freqs[i]
    average_I=Data_full_av[IF_pump]["I"]
    average_Q=Data_full_av[IF_pump]["Q"]
    time_average=Data_full_av[IF_pump]["time"]
    vaccum=Data_full_av[IF_pump]["vaccum"]
    
    time_average=time_average.reshape(1,time_average.shape[0])
    average_I_norm = average_I/np.max(abs(average_I))

    average_I_reduced=average_I_norm[(average_I_norm>=0.25) + (average_I_norm<=-0.25)]
    time_average_reduced=time_average[(average_I_norm>=0.25) + (average_I_norm<=-0.25)]

    if vaccum is not True: 
        zero_crossings.append(len( np.where(np.diff(np.sign(average_I_reduced)))[0])) #finds the idx of crossing through zero 
    else:
        zero_crossings.append(0)

# %%
Processed_Data=an.Extract_second_order_gap(Data,amp_factor_array,freqs_dict,nb_angle,n_avg,corr_length)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29496\3591475132.py in <module>
# ----> 1 Processed_Data=an.Extract_second_order_gap(Data,amp_factor_array,freqs_dict,nb_angle,n_avg,corr_length)
#
# NameError: name 'amp_factor_array' is not defined
