# %% [markdown]
# # Import package

# %%
from qm.QuantumMachinesManager import QuantumMachinesManager
from qm.octave import *
from qm.qua import *
from qm import generate_qua_script

#General os library 
import os
import time
import sys


import matplotlib.pyplot as plt
from qualang_tools.units import unit
from set_octave import get_L0_and_IF
from configuration_exi_vac import *
from qm import SimulationConfig, LoopbackInterface
from qualang_tools.units import unit
from qualang_tools.loops import from_array
u = unit()
from qualang_tools.plot import interrupt_on_close
from qualang_tools.results import progress_counter, fetching_tool
from qualang_tools.addons.variables import assign_variables_to_element

#Path for HQCPC7 
sys.path.append(r'C:\Users\HQClabo\Documents\Code\QuantumMachine\Guillaume\NonLinearRes_calib_30_03_2023\Analysis_Function\NonLinearRes')
sys.path.append(r'C:\Users\HQClabo\Documents\Code\QuantumMachine\Guillaume\NonLinearRes_calib_30_03_2023\Drivers\Drivers') #path for the analysis function

#Path for HQC PC15 
# sys.path.append(r'C:\Users\hqclabo\Documents\Code\gbeaulieu\Analysis_Function\NonLinearRes')
# sys.path.append(r'C:\Users\hqclabo\Documents\Code\gbeaulieu\Drivers')
import AnFunc as an # analysis function
#import AnFunc as an 
import scipy.io
from scipy import signal 
from scipy.optimize import curve_fit

# %%
def update_readout_lenght(Readout_Len,config,qmm):
    """ Macro to update the readout length in the configuration file"""
    
    config["pulses"]["zero_pulse"]["length"]=Readout_Len
    config["integration_weights"]["cosine_weights"]["cosine"][0]=(1.0, Readout_Len)
    config["integration_weights"]["cosine_weights"]["sine"][0]=(0.0, Readout_Len)
    config["integration_weights"]["sine_weights"]["cosine"][0]=(0.0, Readout_Len)
    config["integration_weights"]["sine_weights"]["sine"][0]=(1.0, Readout_Len)
    config["integration_weights"]["minus_sine_weights"]["cosine"][0]=(0.0, Readout_Len)
    config["integration_weights"]["minus_sine_weights"]["sine"][0]=(-1.0, Readout_Len)


    #Update the config with the modified values above 
    qm = qmm.open_qm(config)
    
    return config, qm


def update_pulse_amplitude(pulse_amp,config,qmm):
    config["waveforms"]["twoPhoton_wf"]['sample']=pulse_amp
    
    #Update the config with the modified values above 
    qm = qmm.open_qm(config)
    
    return config, qm

def update_two_photon_lenght(twoPhoton_len,config,qmm):
    """ Update the length of the fluxline pulse in the configuration file"""
    config["pulses"]["twoPhoton"]["length"]=twoPhoton_len


    #Update the config with the modified values above 
    qm = qmm.open_qm(config)
    
    return config, qm

def update_time_of_flight(time_of_flight,config,qmm):
    """ Update the time_of_flight of the qm in the configuration file """
    config["elements"]["resonator"]["time_of_flight"]=time_of_flight
    
    qm=qmm.open_qm(config)
    
    return config, qm



def update_offset(offset_1, offset_2,config,qmm):
    """ Update the input offsets of the qm in the configuration file """
    
    config['controllers']["con1"]["analog_inputs"][1]['offset']=offset_1
    config['controllers']["con1"]["analog_inputs"][2]['offset']=offset_2
    
    
    qm=qmm.open_qm(config)
    
    return config, qm



def First_jump_single_freq(Readout_Len, amp_factor, amp_factor_high, IF_pump, IF_right, LO_diff, pump_step, n_repetition, n_empty,n_full, n_return, cooldown_time,wait_pump_step,qm): 

    """ Take as input :

    Readout_Len : length of the readout that should be the same as defined in the configuration file. Here, it is necessary for the conversion to volt
    amp_factor : multiplication factor to the pump pulse amplitude 
    amp_factor_high : multiplication factor the pump pulse to bring the system to a high photon state 
    IF_pump : IF frequency of the pump - to be measured at - necessary to update the config frequency 
    IF_right : Starting IF frequency for sweeping the pump  
    LO_diff ; LO_fluxline/2-Lo_readout is the difference between the LO to more easily update the readout frequency
    n_repetition : number of times the program is repeated to get an average 
    n_empty : number of measurements when the pulse is low amplitude 
    n_full : number of measurements when the pulse is high amplitude 
    cooldown_time : waiting time between repetitions in nb of cycles 
    wait_pump_step : waiting time after updating the frequency of the pump 
    qm : quantum machine 
    """ 
    n_runs=n_empty+n_full 

    with program() as IQ_blobs:


        n_rep = declare(int)
        i = declare(int)
        I = declare(fixed)
        Q = declare(fixed)
        I_st = declare_stream()
        Q_st = declare_stream()
        f_st= declare_stream()
        f = declare(int)
        n_rep_st=declare_stream()
        f_readout= declare(int)

        #Allows corrrect ordering of pulse 
        assign_variables_to_element("resonator", I,Q) 

        #Loop on the repetition 
        with for_(n_rep, 0, n_rep < n_repetition, n_rep + 1):


            #Play the first pulse of the sticky to set the pump frequency to define the amplitude 
            update_frequency("fluxline", IF_right)
            play("pumping"*amp(amp_factor_high), "fluxline") # bring the fluxline to the right 

            #Frequency downsweep
            with for_(f, IF_right, f>IF_pump, f-pump_step):

                assign(f_readout,LO_diff+f/2) #update the readout frequency 
                update_frequency("resonator",f_readout) # Change the IF frequency of the resonator to demodulate more precisely 

                #update the pump frequency
                update_frequency("fluxline", f, keep_phase=True)
                play("pumping"*amp(0), "fluxline")

                #Collect one readout     
                measure(
                    "fake_readout",
                    "resonator",
                    None,
                    dual_demod.full("cos", "out1", "sin", "out2", I),
                    dual_demod.full("minus_sin", "out1", "cos", "out2", Q),
                )


                wait(wait_pump_step) #time that will be waited after playing the pump 

                save(I, I_st)
                save(Q, Q_st)
                save(f, f_st) 

            #set the new amplitude lower amplitude 
            play("pumping"*amp(amp_factor-amp_factor_high), "fluxline") 

            # Performs n_full readout to observe the decay 
            with for_(i, 0, i < n_full, i + 1):
                play("pumping" * amp(0), 'fluxline') 

                measure(
                "fake_readout",
                "resonator",
                None,
                dual_demod.full("cos", "out1", "sin", "out2", I),
                dual_demod.full("minus_sin", "out1", "cos", "out2", Q),
                )

                save(I, I_st)
                save(Q, Q_st)



            ramp_to_zero("fluxline")  #ramp the pump to zero  
            wait(cooldown_time) #Wait a certain cooldown time
            save(n_rep, n_rep_st)


        with stream_processing():

            I_st.with_timestamps().save_all("I")
            Q_st.with_timestamps().save_all("Q")
            n_rep_st.save("n_rep")
            f_st.save("f") 

    simulation = False    

    if simulation:
        simulation_config = SimulationConfig(
            duration=50000, simulation_interface=LoopbackInterface([("con1", 3, "con1", 1)])
        )

        job = qmm.simulate(config, IQ_blobs, simulation_config)
        job.get_simulated_samples().con1.plot(analog_ports={'1','2','3','4' },digital_ports={'1'})


    else : 

        job = qm.execute(IQ_blobs)
        results = fetching_tool(job, data_list=["I", "Q","n_rep"], mode="live")

        fig = plt.figure()
        interrupt_on_close(fig, job)  #  Interrupts the job when closing the figure

        while results.is_processing():

            I, Q, n_rep = results.fetch_all()

            time_vec=I["timestamp"]
            I = u.demod2volts(I["value"], Readout_Len) #diviser par la duree du pulse Readout_lEN 
            Q = u.demod2volts(Q["value"], Readout_Len)


            #Plotting the average 
            if len(I)>n_runs:

                #Datas are capted continously and then transfer into a 2D matrix and averaged
                it=len(I)//n_runs
                I_2d=I[0:it*n_runs].reshape((it,n_runs))
                Q_2d=Q[0:it*n_runs].reshape((it,n_runs))
                norm_2d=np.sqrt(I_2d**2+Q_2d**2)

                plt.subplot(211)
                fig.suptitle("IF_pump "+str(IF_pump)+" ite :"+str(n_rep))
                plt.cla()
                plt.plot(np.angle(I_2d[it-1,:]+1j*Q_2d[it-1,:]), ".", markersize=2)
                
                #plt.plot(time_vec[0:n_runs],I_2d[it-1,:],".",markersize=2)
                plt.plot([n_empty,n_empty], [-np.pi, np.pi],'r')
                plt.xlabel("Nb points")
                plt.ylabel("phase")
                plt.pause(0.1)


                plt.subplot(212)
                av=np.mean(norm_2d,axis=0) 
                plt.subplot(313)
                plt.cla()
                plt.plot(time_vec[0:n_runs]*1e-9,av*1e3,".",markersize=2)
                plt.xlabel("time [s]")
                plt.ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")

    # Returns average signal and time in ns and n_return number of trajectories 
    return av,time_vec[0:n_runs],I_2d[0:n_return,:], Q_2d[0:n_return, :]

# %% [markdown]
# # OPX configuration

# %%
#Octave & OPX configuration 
Saving_Path=r"\\sb1files\HQC\Users\beaulieu\Data\Run01\131\\"
Cooldown_Date="2023_06_01"

opx_ip = '128.178.175.167'
opx_port = 81
octave_ip = '128.178.175.167'
octave_port = 53


octave_config = QmOctaveConfig()
octave_config.set_calibration_db(os.getcwd()) #Path to the calibration database 

octave_config.add_device_info('octave1', octave_ip, octave_port) #Add a device refered to as octave 1
octave_config.set_opx_octave_mapping([('con1', 'octave1')])  # set default mapping between analog outputs of OPX and the octave


qmm = QuantumMachinesManager(host=opx_ip, port=opx_port, octave=octave_config)
qm = qmm.open_qm(config)

octave_output_gain=-10

#Mixers for the fluxline 
qmm.octave_manager.set_clock("octave1", ClockType.External, ClockFrequency.MHZ_10) # External clock on the octave 
qm.octave.set_lo_source("fluxline", OctaveLOSource.Internal) # Use internal LO for the fluxline 
qm.octave.set_lo_frequency("fluxline", LO_fluxline)  # Set the frequency of the LO 
qm.octave.set_rf_output_gain("fluxline", octave_output_gain)  # can set gain from -10dB to 20dB
qm.octave.set_rf_output_mode("fluxline", RFOutputMode.on)  # The LO output is always on (could change to a trigger)  #RFOutputMode.trig_normal

#Mixers for the resonator 
qm.octave.set_qua_element_octave_rf_in_port("resonator", "octave1", 1) #input port 1 is set for the resonator 
qm.octave.set_downconversion("resonator", lo_source=RFInputLOSource.Internal)  # The LO for the demodulation is the interal LO  
qm.octave.set_lo_frequency("resonator", LO_readout)  # assign the LO inside the octave to element
# Out:
# 2023-06-29 09:51:08,597 - qm - INFO - Performing health check
# 2023-06-29 09:51:08,608 - qm - WARNING -   HC Warning: Potential hardware issue with QSync in controller con1, multiple controllers sync cannot be guaranteed, please inform QM
# 2023-06-29 09:51:08,609 - qm - INFO - Health check passed

# %%
#Setting the gain
gain=0
config['controllers']['con1']['analog_inputs'][1]["gain_db"]=gain
config['controllers']['con1']['analog_inputs'][2]["gain_db"]=gain
qm = qmm.open_qm(config)

#time of flight
time_of_flight=24
config, qm=update_time_of_flight(time_of_flight,config,qmm)

# Pump amplitude 
pulse_amp=0.125
config,qm=update_pulse_amplitude(pulse_amp,config,qmm)


#Based on the other setting
offset_1=0.0180632734375
offset_2=0.015605841992187498
config,qm=update_offset(offset_1, offset_2,config,qmm)

# %% [markdown]
# # Display parameter

# %%
print("LO of resonator : {} GHz".format(config['elements']['resonator']["mixInputs"]["lo_frequency"]/1e9))
print("IF of resonator : {} GHz".format(config['elements']['resonator']['intermediate_frequency']/1e9))
print("Time of flight of resonator : {} ns".format(config['elements']['resonator']['time_of_flight']))
print("Readout time resonator : {} ns".format(config["pulses"]["zero_pulse"]["length"]))
print("LO of fluxline: {} GHz".format(config['elements']['fluxline']["mixInputs"]["lo_frequency"]/1e9))
print("IF of fluxline : {} GHz".format(config['elements']['fluxline']['intermediate_frequency']/1e9))
print("Ramping time of fluxline : {} ns".format(config['elements']['fluxline']['hold_offset']))
print("Fluxline pulse time : {} ns".format(config["pulses"]["twoPhoton"]["length"]))
print("Fluxline amplitude : {} V".format(config["waveforms"]["twoPhoton_wf"]['sample']))
# Out:
# LO of resonator : 4.3 GHz
# IF of resonator : 0.318 GHz
# Time of flight of resonator : 24 ns
# Readout time resonator : 2000 ns
# LO of fluxline: 8.6 GHz
# IF of fluxline : 0.0995 GHz
# Ramping time of fluxline : {'duration': 5000} ns
# Fluxline pulse time : 1000 ns
# Fluxline amplitude : 0.125 V

# %% [markdown]
# # Testing the pump

# %%
#Mixer Calibration 
#Calibration of the fluxline mixer for the pump 
qm.octave.calibrate_element("fluxline", [get_L0_and_IF(config, "fluxline")])  
qm = qmm.open_qm(config)

qm.octave.calibrate_element("resonator", [get_L0_and_IF(config, "resonator")])  
qm = qmm.open_qm(config)
# Out:
# 2023-06-21 00:20:10,433 - qm - INFO - Flags:
# 2023-06-21 00:20:10,433 - qm - INFO - Compiling program
# 2023-06-21 00:20:12,955 - qm - INFO - Sending pre-compiled program to QOP
# 2023-06-21 00:20:16,580 - qm - INFO - Flags:
# 2023-06-21 00:20:16,581 - qm - INFO - Compiling program
# 2023-06-21 00:20:18,955 - qm - INFO - Sending pre-compiled program to QOP

# %%
#Mixer Calibration 
#Calibration of the fluxline mixer 
qm.octave.calibrate_element("fluxline", [get_L0_and_IF(config, "fluxline")])  
qm = qmm.open_qm(config)
# Out:
# 2023-04-27 17:18:23,167 - qm - INFO - Flags:
# 2023-04-27 17:18:23,168 - qm - INFO - Compiling program
# 2023-04-27 17:18:25,903 - qm - INFO - Sending pre-compiled program to QOP

# %%
# Testing the pump 
with program() as TwoPhoton:
    with infinite_loop_():
        play("pumping"*amp(0.1), 'fluxline')
        
job = qm.execute(TwoPhoton)
# Out:
# 2023-04-21 16:14:28,195 - qm - INFO - Flags:
# 2023-04-21 16:14:28,196 - qm - INFO - Sending program to QOP
# 2023-04-21 16:14:28,224 - qm - INFO - Executing program

# %%
#Two stop the two photon pumping 
job.halt()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19188\1902721406.py in <module>
#       1 #Two stop the two photon pumping
# ----> 2 job.halt()
#
# NameError: name 'job' is not defined

# %% [markdown]
# # Single frequency sticky

# %%
# %matplotlib qt 
freqs_dict={}
Readout_Len=50_000
config,qm=update_readout_lenght(Readout_Len,config,qmm)
twoPhoton_len=50_000 # for the upmeasurement, the twophoton pulse length should be roughly the same as the readout len 
config,qm=update_two_photon_lenght(twoPhoton_len,config,qmm)

amp_factor_array=np.array([1.15]) #Prefactor of the amplitude 
amp_factor=amp_factor_array[0]
amp_factor_high_array=np.array([1.5]) #Prefactor of the amplitude 
amp_factor_high=amp_factor_high_array[0]


n_repetition=1_000 #number of repetitions 
n_empty=100 #number of readout to do while sweeping the frequency 
n_full=10_000 #number of pump on readout to do 
n_return=100 # must be smaller then number of repetition and is the number of trajectories to returns 


freqs_dict[amp_factor]=np.array([ 94e6]) # final frequency 
IF_right=99.8e6 # Starting frequency 

IF_pump=freqs_dict[amp_factor][0] #select the frequency from the array 


pump_step=(IF_right-IF_pump)/n_empty
LO_diff=LO_fluxline/2-LO_readout # need to perform this substraction outside of the qua program to avoid having numbers larger than the int allowed 
n_runs=n_empty+n_full # Total number of readout to do 

wait_pump_step=16//4 #w aiting time after having played the pump
cooldown_time=5_000//4

av,time,I, Q=First_jump_single_freq(Readout_Len, amp_factor, amp_factor_high, IF_pump, IF_right, LO_diff, pump_step, n_repetition, n_empty,n_full, n_return, cooldown_time,wait_pump_step,qm)
            
        
            
Data={}
Data[amp_factor]={}
Data[amp_factor][IF_pump]={}
Data[amp_factor][IF_pump]["value"]=av
Data[amp_factor][IF_pump]["time"]=time
Data[amp_factor][IF_pump]["I"]=I
Data[amp_factor][IF_pump]["Q"]=Q
# Out:
# 2023-06-29 16:37:39,532 - qm - INFO - Flags:
# 2023-06-29 16:37:39,533 - qm - INFO - Sending program to QOP
# 2023-06-29 16:37:41,397 - qm - INFO - Executing program
# Execution stopped by user!

# %% [markdown]
# ## Plotting for single frequency

# %%
# %matplotlib inline
number_avg=1
Processed_Data=an.Extract_vac_exc_gap(Data,amp_factor_array,freqs_dict,n_empty,number_avg)

amp_factor=amp_factor_array[0]
freqs=freqs_dict[amp_factor]

for idx in range(len(freqs)):
    
    if Processed_Data[amp_factor][freqs[idx]]["fit"]:

        gap=Processed_Data[amp_factor][freqs[idx]]["gap"]
        coeff=Processed_Data[amp_factor][freqs[idx]]["fit_coeff"]
        time_fit=Processed_Data[amp_factor][freqs[idx]]["time_fit"]
        y_fitted=Processed_Data[amp_factor][freqs[idx]]["y_fitted"]
        av_fit=Processed_Data[amp_factor][freqs[idx]]["av_fit"]

        fontsize=8
        fig, axs = plt.subplots( nrows=2, ncols=1, figsize=(8,10),dpi=100)

        #Plotting the measurement 
        ax=axs[0]
        ax.set_title("Average "+str(n_repetition))
        ax.plot(time*1e-9,av*1e3,".")
        #ax.plot([Pump_Delay*4*1e-9,Pump_Delay*4*1e-9],[0, max(av*1e3)],"r")
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")

        ax=axs[1]
        ax.set_title("$\lambda= $"+str(gap))
        ax.plot(time_fit,av_fit,".")
        ax.plot(time_fit,y_fitted)
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")



    else:
        print("No fit")
        time_fit=Processed_Data[amp_factor][freqs[idx]]["time_fit"]
        av_fit=Processed_Data[amp_factor][freqs[idx]]["av_fit"]
        
        fontsize=8
        fig, axs = plt.subplots( nrows=2, ncols=1, figsize=(8,10),dpi=100)

        #Plotting the measurement 
        ax=axs[0]
        ax.set_title("Average "+str(n_repetition))
        ax.plot(time*1e-9,av*1e3)
        #ax.plot([Pump_Delay*4*1e-9,Pump_Delay*4*1e-9],[0, max(av*1e3)],"r")
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")

        ax=axs[1]
        ax.set_title("Pump= "+str(freqs[idx]) +" Iteration :" +str(idx) + " No fit")
        ax.plot(time_fit,av_fit)
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")

# %% [markdown]
# ## Saving for single frequency

# %%
#Saving the data
cooldown_date=Cooldown_Date #top folder 
device="excit_to_vac" #second folder 
name="Single_freq" # third folder 
meastype="test" #Final file name 

datadict={}
#Configuration file copy 
datadict["LO_fluxline"]=LO_fluxline
datadict["LO_readout"]=LO_readout

#Saving of parameters 

datadict["octave_output_gain"]=octave_output_gain


datadict["IF_right"]=IF_right
datadict["n_empty"]=n_empty
datadict["n_repetition"]=n_repetition
datadict["n_full"]=n_full

datadict["amp_factor_array"]=amp_factor_array
datadict["amp_factor_array_high"]=amp_factor_high_array

datadict["Readout_Len"]=Readout_Len
datadict["cooldown_time"]=cooldown_time
datadict["wait_pump_step"]=wait_pump_step

#Saving of data 
datadict["freqs_dict"]=freqs_dict 
datadict["Data"]=Data
datadict["config"]=config

an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)

# %%
#loading the data 
filepath=r"\\sb1files\HQC\Users\beaulieu\Data\Run01\104\2023_04_14\excit_to_vac\Single_freq\test.npz"

npzfile=np.load(filepath,allow_pickle=True)
npzfile["multidata"][()]
freqs_dict=npzfile["multidata"][()]["freqs_dict"]
Data=npzfile["multidata"][()]["Data"]
amp_factor_array=npzfile["multidata"][()]["amp_factor_array"]
n_empty=npzfile["multidata"][()]["n_empty"]

# %% [markdown]
# # Multiple frequencies of single measurement

# %%
#Select the frequencies 
freqs_dict={}


fmin=99.05e6
fmax=99.2e6
df=0.01* u.MHz
freqs=np.arange(fmin, fmax+df/2, df)

freqs
# Out:
# array([99050000., 99060000., 99070000., 99080000., 99090000., 99100000.,
#        99110000., 99120000., 99130000., 99140000., 99150000., 99160000.,
#        99170000., 99180000., 99190000., 99200000.])

# %%
# %matplotlib qt 
Readout_Len=50_000
config,qm=update_readout_lenght(Readout_Len,config,qmm)
config,qm=update_two_photon_lenght(Readout_Len,config,qmm)

amp_factor_array=np.array([1.05]) #Prefactor of the amplitude 
amp_factor=amp_factor_array[0]
amp_factor_high_array=np.array([1.5]) #Prefactor of the amplitude 
amp_factor_high=amp_factor_high_array[0]


n_repetition=500 #number of repetitions 
n_empty=100 #number of readout to do while sweeping the frequency 
n_full=10_000 #number of pump on readout to do 
n_return=100 # must be smaller then number of repetition and is the number of trajectories to returns 

IF_right=99.8e6 # Starting frequency 

LO_diff=LO_fluxline/2-LO_readout # need to perform this substraction outside of the qua program to avoid having numbers larger than the int allowed 
n_runs=n_empty+n_full # Total number of readout to do 

wait_pump_step=16//4 #w aiting time after having played the pump
cooldown_time=5_000//4

freqs_dict[amp_factor]=freqs #select the first row 

#Saving the data
save_Data=False
cooldown_date=Cooldown_Date #top folder 
device="excit_to_vac" #second folder 
name="Multiple_freq" # third folder 
meastype="0p3_amp_test" #Final file name 


print("The different frequency {}".format(freqs))
Expected_time=(Readout_Len*n_runs*1e-9*n_repetition+n_repetition*cooldown_time*4*1e-9)/60*len(freqs)
print("The expected time : {} min".format(Expected_time))
# Out:
# The different frequency [99050000. 99060000. 99070000. 99080000. 99090000. 99100000. 99110000.
#  99120000. 99130000. 99140000. 99150000. 99160000. 99170000. 99180000.
#  99190000. 99200000.]
# The expected time : 67.334 min

# %%
# %%time
Data={} #dictionnary to hold all the data 
Data[amp_factor]={}
for idx,IF_pump in enumerate(freqs) :
    
    print("########################### Frequency "+str(IF_pump+LO_fluxline)+"########################### "+str(idx/len(freqs)))

    
    pump_step=(IF_right-IF_pump)/n_empty
    
    av,time,I, Q=First_jump_single_freq(Readout_Len, amp_factor, amp_factor_high, IF_pump, IF_right, LO_diff, pump_step, n_repetition, n_empty,n_full, n_return, cooldown_time,wait_pump_step,qm)
    plt.close()
    
    Data[amp_factor][IF_pump]={}
    Data[amp_factor][IF_pump]["value"]=av
    Data[amp_factor][IF_pump]["time"]=time
    Data[amp_factor][IF_pump]["I"]=I
    Data[amp_factor][IF_pump]["Q"]=Q
    
if save_Data:
    
    datadict={}
    datadict["LO_fluxline"]=LO_fluxline
    datadict["LO_readout"]=LO_readout

    #Saving of parameters 

    daadict["octave_output_gain"]=octave_output_gain


    datadict["IF_right"]=IF_right
    datadict["n_empty"]=n_empty
    datadict["n_repetition"]=n_repetition
    datadict["n_full"]=n_full

    datadict["amp_factor_array"]=amp_factor_array
    datadict["amp_factor_array_high"]=amp_factor_high_array

    datadict["Readout_Len"]=Readout_Len
    datadict["cooldown_time"]=cooldown_time
    datadict["wait_pump_step"]=wait_pump_step

    #Saving of data 
    datadict["freqs_dict"]=freqs_dict
    datadict["Data"]=Data
    datadict["config"]=config
    
    an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)
# Out:
# ########################### Frequency 8699050000.0########################### 0.0
# 2023-06-29 13:31:43,917 - qm - INFO - Flags:
# 2023-06-29 13:31:43,917 - qm - INFO - Sending program to QOP
# 2023-06-29 13:31:45,782 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8699060000.0########################### 0.0625
# 2023-06-29 13:36:02,438 - qm - INFO - Flags:
# 2023-06-29 13:36:02,439 - qm - INFO - Sending program to QOP
# 2023-06-29 13:36:04,306 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8699070000.0########################### 0.125
# 2023-06-29 13:40:20,885 - qm - INFO - Flags:
# 2023-06-29 13:40:20,886 - qm - INFO - Sending program to QOP
# 2023-06-29 13:40:22,280 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8699080000.0########################### 0.1875
# 2023-06-29 13:44:38,956 - qm - INFO - Flags:
# 2023-06-29 13:44:38,957 - qm - INFO - Sending program to QOP
# 2023-06-29 13:44:40,386 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8699090000.0########################### 0.25
# 2023-06-29 13:48:57,302 - qm - INFO - Flags:
# 2023-06-29 13:48:57,303 - qm - INFO - Sending program to QOP
# 2023-06-29 13:48:58,709 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8699100000.0########################### 0.3125
# 2023-06-29 13:53:16,070 - qm - INFO - Flags:
# 2023-06-29 13:53:16,071 - qm - INFO - Sending program to QOP
# 2023-06-29 13:53:17,501 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8699110000.0########################### 0.375
# 2023-06-29 13:57:34,193 - qm - INFO - Flags:
# 2023-06-29 13:57:34,193 - qm - INFO - Sending program to QOP
# 2023-06-29 13:57:35,975 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8699120000.0########################### 0.4375
# 2023-06-29 14:01:51,667 - qm - INFO - Flags:
# 2023-06-29 14:01:51,667 - qm - INFO - Sending program to QOP
# 2023-06-29 14:01:53,597 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8699130000.0########################### 0.5
# 2023-06-29 14:06:10,187 - qm - INFO - Flags:
# 2023-06-29 14:06:10,188 - qm - INFO - Sending program to QOP
# 2023-06-29 14:06:12,128 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8699140000.0########################### 0.5625
# 2023-06-29 14:10:29,605 - qm - INFO - Flags:
# 2023-06-29 14:10:29,605 - qm - INFO - Sending program to QOP
# 2023-06-29 14:10:31,086 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8699150000.0########################### 0.625
# 2023-06-29 14:14:47,385 - qm - INFO - Flags:
# 2023-06-29 14:14:47,386 - qm - INFO - Sending program to QOP
# 2023-06-29 14:14:48,831 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8699160000.0########################### 0.6875
# 2023-06-29 14:19:05,545 - qm - INFO - Flags:
# 2023-06-29 14:19:05,546 - qm - INFO - Sending program to QOP
# 2023-06-29 14:19:07,308 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8699170000.0########################### 0.75
# 2023-06-29 14:23:23,629 - qm - INFO - Flags:
# 2023-06-29 14:23:23,629 - qm - INFO - Sending program to QOP
# 2023-06-29 14:23:25,058 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8699180000.0########################### 0.8125
# 2023-06-29 14:27:40,822 - qm - INFO - Flags:
# 2023-06-29 14:27:40,823 - qm - INFO - Sending program to QOP
# 2023-06-29 14:27:42,329 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8699190000.0########################### 0.875
# 2023-06-29 14:31:59,126 - qm - INFO - Flags:
# 2023-06-29 14:31:59,126 - qm - INFO - Sending program to QOP
# 2023-06-29 14:32:00,627 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8699200000.0########################### 0.9375
# 2023-06-29 14:36:16,374 - qm - INFO - Flags:
# 2023-06-29 14:36:16,375 - qm - INFO - Sending program to QOP
# 2023-06-29 14:36:18,220 - qm - INFO - Executing program
# Execution stopped by user!
# Wall time: 1h 8min 51s

# %% [markdown]
# ## Saving for multiple frequencies

# %%
#Saving the data
cooldown_date=Cooldown_Date#top folder 
device="excit_to_vac" #second folder 
name="Multiple_freq" # third folder 
meastype="1p05_9905_992_0p01_fast" #Final file name 

datadict={}
#Configuration file copy 
datadict["LO_fluxline"]=LO_fluxline
datadict["LO_readout"]=LO_readout

#Saving of parameters 
datadict["octave_output_gain"]=octave_output_gain

datadict["IF_right"]=IF_right
datadict["n_empty"]=n_empty
datadict["n_repetition"]=n_repetition
datadict["n_full"]=n_full

datadict["amp_factor_array"]=amp_factor_array
datadict["amp_factor_array_high"]=amp_factor_high_array

datadict["Readout_Len"]=Readout_Len
datadict["cooldown_time"]=cooldown_time
datadict["wait_pump_step"]=wait_pump_step

#Saving of data 
datadict["freqs_dict"]=freqs_dict
datadict["Data"]=Data
datadict["config"]=config

an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)
# Out:
# saving

# %%
#loading the data 
filepath=r"X:\Users\beaulieu\Data\Run01\131\2023_05_05\excit_to_vac\Multiple_freq\0p95\0p95_94_9p24_0p1_fast.npz"

npzfile=np.load(filepath,allow_pickle=True)
npzfile["multidata"][()]
freqs_dict=npzfile["multidata"][()]["freqs_dict"]
Data=npzfile["multidata"][()]["Data"]
amp_factor_array=npzfile["multidata"][()]["amp_factor_array"]
n_empty=npzfile["multidata"][()]["n_empty"]

# %%
freqs_array=npzfile["multidata"][()]["freqs_array"]
freqs_dict={}
freqs_dict[amp_factor_array[0]]=freqs_array[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17344\2851891010.py in <module>
# ----> 1 freqs_array=npzfile["multidata"][()]["freqs_array"]
#       2 freqs_dict={}
#       3 freqs_dict[amp_factor_array[0]]=freqs_array[0]
#
# KeyError: 'freqs_array'

# %%
freqs_dict
# Out:
# {0.6: array([1.910e+08, 1.912e+08, 1.914e+08, 1.916e+08, 1.918e+08, 1.920e+08,
#         1.922e+08, 1.924e+08, 1.926e+08, 1.928e+08, 1.930e+08, 1.932e+08,
#         1.934e+08, 1.936e+08, 1.938e+08, 1.940e+08, 1.942e+08, 1.944e+08,
#         1.946e+08, 1.948e+08, 1.950e+08, 1.952e+08, 1.954e+08])}

# %% [markdown]
# ## Ploting for multiple frequencies

# %%
# %matplotlib qt
#Plot all 
number_avg=1
Processed_Data=an.Extract_vac_exc_gap(Data,amp_factor_array,freqs_dict,n_empty,number_avg)
amp_factor=amp_factor_array[0]
freqs=freqs_dict[amp_factor]

for idx in range(len(freqs)):
    
    if Processed_Data[amp_factor][freqs[idx]]["fit"]:

        gap=Processed_Data[amp_factor][freqs[idx]]["gap"]
        coeff=Processed_Data[amp_factor][freqs[idx]]["fit_coeff"]
        time_fit=Processed_Data[amp_factor][freqs[idx]]["time_fit"]
        y_fitted=Processed_Data[amp_factor][freqs[idx]]["y_fitted"]
        av_fit=Processed_Data[amp_factor][freqs[idx]]["av_fit"]
        
        
        fontsize=8
        fig, axs = plt.subplots( nrows=2, ncols=1, figsize=(5,10),dpi=100)
        
        av=Data[amp_factor][freqs[idx]]["value"]
        time=Data[amp_factor][freqs[idx]]["time"]
        
        ax=axs[0]
        ax.set_title("Average "+str(n_repetition))
        ax.plot(time*1e-9,av*1e3,".")
        #ax.plot([Pump_Delay*4*1e-9,Pump_Delay*4*1e-9],[0, max(av*1e3)],"r")
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")
        
        ax=axs[1]
        ax.set_title("Pump= "+str(freqs[idx]) +" Iteration :" +str(idx)+" $\lambda= $"+str(round(gap,2)))
        ax.plot(time_fit,av_fit,".")
        ax.plot(time_fit,y_fitted)
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")

    else:
        print("No fit")
        time_fit=Processed_Data[amp_factor][freqs[idx]]["time_fit"]
        av_fit=Processed_Data[amp_factor][freqs[idx]]["av_fit"]
        fontsize=8
        fig, axs = plt.subplots( nrows=1, ncols=1, figsize=(5,5),dpi=100)
        ax=axs
        ax.set_title("Pump= "+str(freqs[idx]) +" Iteration :" +str(idx) + " No fit")
        ax.plot(time_fit,av_fit,".")
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")
# Out:
# No fit

# %%
plt.close("all")

# %% [markdown]
# ## Extracting the Liouvillian gap

# %%
# %matplotlib inline


amp_factor=amp_factor_array[0]
freqs=freqs_dict[amp_factor]

gap_array=[]
freq_gap_array=[]

for idx in range(len(freqs)):
    
    if Processed_Data[amp_factor][freqs[idx]]["fit"]:
        gap_array.append(Processed_Data[amp_factor][freqs[idx]]["gap"])
        freq_gap_array.append(freqs[idx])
        
gap_array=np.array(gap_array)
freq_gap_array=np.array(freq_gap_array)
        
# figsize=(5,4)

fontsize=8
figsize=(5,4)
fig, axs = plt.subplots( nrows=1, ncols=1, figsize=(5,5),dpi=200)

axs.plot(freq_gap_array/1e9,gap_array,'.-',alpha=.9, lw=.5, ms=8)
axs.set_xlabel("Pump frequency (IF)",fontsize=fontsize)
axs.set_ylabel("Louivillian gap",fontsize=fontsize)
axs.tick_params(axis='x', labelsize=fontsize)
axs.tick_params(axis='y', labelsize=fontsize)
ax.set_ylim((10**(-4),10**4))
axs.set_yscale('log')

# %% [markdown]
# # Multiple amplitudes with multiple frequencies
#
# Runs the previous measurement but for multiple amplitudes
#
# Since the gap has different size, we want different frequency arrays for different amplitudes

# %%
#Select the frequencies & amplitudes factors 

#Sets of amplitude factors 
amp_factor_array=np.array([0.5, 0.6]) 

fmin=192e6
fmax=195.5e6
df=2* u.MHz
freqs_array_1=np.arange(fmin, fmax+df/2, df)

fmin=191e6
fmax=195.5e6
df=3* u.MHz
freqs_array_2=np.arange(fmin, fmax+df/2, df)

freqs_dict={}
freqs_dict[0.5]=freqs_array_1
freqs_dict[0.6]=freqs_array_2

#calculate the total number of frequencies 
number_frequencies=0
for i in range(len(amp_factor_array)):
    number_frequencies+=len(freqs_dict[amp_factor_array[i]])

    
#IF centers 
# IF_center=[0.1957e9, 0.19565e9]

# span=0.1 * u.MHz # Span of the pumping 
# df = 0.02* u.MHz # Step of the pumping 0.01

# freqs_array=np.zeros((len(amp_factor_array),round(span/df)))

# for i in range(len(amp_factor_array)):
#     freqs_array[i,:]=np.arange(IF_center[i]-span/2, IF_center[i]+span/2, df) #sets of frequencies



freqs_dict
# Out:
# {0.5: array([1.92e+08, 1.94e+08, 1.96e+08]), 0.6: array([1.91e+08, 1.94e+08])}

# %%
# %matplotlib qt 

Readout_Len=50_000
config,qm=update_readout_lenght(Readout_Len,config,qmm)
config,qm=update_two_photon_lenght(Readout_Len,config,qmm)

n_repetition=10 #number of repetitions 
n_empty=100 #number of readout to do while sweeping the frequency 
n_full=20_000 #number of pump on readout to do 
n_return=1 # must be smaller then number of repetition and is the number of trajectories to returns 

IF_right=196e6 # Starting frequency 

LO_diff=LO_fluxline/2-LO_readout # need to perform this substraction outside of the qua program to avoid having numbers larger than the int allowed 
n_runs=n_empty+n_full # Total number of readout to do 

wait_pump_step=16//4 #w aiting time after having played the pump
cooldown_time=5_000//4

save_Data=False
#Saving the data
cooldown_date=Cooldown_Date #top folder 
device="excit_to_vac" #second folder 
name="Multiple_freq" # third folder 
meastype="test" #Final file name 


Expected_time=(Readout_Len*n_runs*1e-9*n_repetition+n_repetition*(cooldown_time*4*1e-9))/60*( number_frequencies)
print("The expected time : {} min".format(Expected_time))
# Out:
# The expected time : 0.8375041666666667 min

# %%
Data={} #dictionnary to hold all the data 

for i in range(len(amp_factor_array)):

    amp_factor=amp_factor_array[i]
    freqs=freqs_dict[amp_factor] #select the frequency 
    
    #freqs=freqs_array[0,:] #
    
    print("####################################### Amplitude "+str(amp_factor)+"######################################## ")
   
    Data[amp_factor]={}
          
    for idx,IF_pump in enumerate(freqs):

        print("########################### Frequency "+str(IF_pump+LO_fluxline)+"########################### "+str(idx/len(freqs)))

        pump_step=(IF_right-IF_pump)/n_empty

        av,time,I, Q=First_jump_single_freq(Readout_Len, amp_factor, amp_factor_high, IF_pump, IF_right, LO_diff, pump_step, n_repetition, n_empty,n_full, n_return, cooldown_time,wait_pump_step,qm)
        plt.close()
     
        
        Data[amp_factor][IF_pump]={}
        Data[amp_factor][IF_pump]["value"]=av
        Data[amp_factor][IF_pump]["time"]=time
        Data[amp_factor][IF_pump]["I"]=I
        Data[amp_factor][IF_pump]["Q"]=Q
        
        
if save_Data:
    
    datadict={}
    datadict["LO_fluxline"]=LO_fluxline
    datadict["LO_readout"]=LO_readout

    #Saving of parameters 
    daadict["octave_output_gain"]=octave_output_gain


    datadict["IF_right"]=IF_right
    datadict["n_empty"]=n_empty
    datadict["n_repetition"]=n_repetition
    datadict["n_full"]=n_full

    datadict["amp_factor_array"]=amp_factor_array
    datadict["amp_factor_array_high"]=amp_factor_high_array

    datadict["Readout_Len"]=Readout_Len
    datadict["cooldown_time"]=cooldown_time
    datadict["wait_pump_step"]=wait_pump_step

    #Saving of data 
    datadict["freqs_dict"]=freqs_dict
    
    datadict["Data"]=Data
    datadict["config"]=config
    
    an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)
# Out:
# ####################################### Amplitude 0.5########################################
# ########################### Frequency 8692000000.0########################### 0.0
# 2023-04-28 15:56:19,240 - qm - INFO - Flags:
# 2023-04-28 15:56:19,240 - qm - INFO - Sending program to QOP
# 2023-04-28 15:56:21,025 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8694000000.0########################### 0.3333333333333333
# 2023-04-28 15:56:31,612 - qm - INFO - Flags:
# 2023-04-28 15:56:31,612 - qm - INFO - Sending program to QOP
# 2023-04-28 15:56:32,982 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696000000.0########################### 0.6666666666666666
# 2023-04-28 15:56:44,204 - qm - INFO - Flags:
# 2023-04-28 15:56:44,205 - qm - INFO - Sending program to QOP
# 2023-04-28 15:56:46,013 - qm - INFO - Executing program
# Execution stopped by user!
# ####################################### Amplitude 0.6########################################
# ########################### Frequency 8691000000.0########################### 0.0
# 2023-04-28 15:56:56,759 - qm - INFO - Flags:
# 2023-04-28 15:56:56,760 - qm - INFO - Sending program to QOP
# 2023-04-28 15:56:58,143 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8694000000.0########################### 0.5
# 2023-04-28 15:57:09,169 - qm - INFO - Flags:
# 2023-04-28 15:57:09,169 - qm - INFO - Sending program to QOP
# 2023-04-28 15:57:10,947 - qm - INFO - Executing program
# Execution stopped by user!

# %% [markdown]
# ## Saving for multiple amplitudes

# %%
#Saving the data 
cooldown_date=Cooldown_Date #top folder 
device="vac_to_excit" #second folder 
name="Multiple_amp" # third folder 
meastype="Test_2" #Final file name 

datadict={}
datadict["LO_fluxline"]=LO_fluxline
datadict["IF_fluxline"]=IF_pump
datadict["IF_readout"]=IF_resonator
datadict["LO_readout"]=LO_readout

datadict["octave_output_gain"]=octave_output_gain

datadict["n_empty"]=n_empty
datadict["n_repetition"]=n_repetition
datadict["n_full"]=n_full
datadict["amp_factor_array"]=amp_factor_array
datadict["Offset_IF"]=Offset_IF
datadict["Readout_Len"]=Readout_Len
datadict["Pump_Delay"]=Pump_Delay
datadict["cooldown_time"]=cooldown_time
datadict["Data"]=Data
datadict["freqs_dict"]=freqs_dict
datadict["config"]=config

an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)

# %%
#Loading the data 
filepath= r"\\sb1files\HQC\Users\beaulieu\Data\Run01\104\2023_04_14\vac_to_excit\Multiple_amp\Test_crap.npz"

npzfile=np.load(filepath,allow_pickle=True)
#npzfile["multidata"][()]

n_empty=npzfile["multidata"][()]["n_empty"]
Data=npzfile["multidata"][()]["Data"]
freqs_array=npzfile["multidata"][()]["freqs_array"]
amp_factor_array=npzfile["multidata"][()]["amp_factor_array"]

# %% [markdown]
# ## Plotting for multiple amplitudes

# %%
# %matplotlib qt
#Plot all 
number_avg=10
Processed_Data=an.Extract_vac_exc_gap(Data,amp_factor_array,freqs_dict,n_empty,number_avg)
j=0
amp_factor=amp_factor_array[j]
freqs=freqs_dict[amp_factor]


for idx in range(len(freqs)):
    
    if Processed_Data[amp_factor][freqs[idx]]["fit"]:

        gap=Processed_Data[amp_factor][freqs[idx]]["gap"]
        coeff=Processed_Data[amp_factor][freqs[idx]]["fit_coeff"]
        time_fit=Processed_Data[amp_factor][freqs[idx]]["time_fit"]
        y_fitted=Processed_Data[amp_factor][freqs[idx]]["y_fitted"]
        av_fit=Processed_Data[amp_factor][freqs[idx]]["av_fit"]

        fontsize=8
        fig, axs = plt.subplots( nrows=1, ncols=1, figsize=(5,5),dpi=100)
        ax=axs
        ax.set_title("Pump= "+str(freqs[idx]) +" Iteration :" +str(idx)+" $\lambda= $"+str(round(gap,2)))
        ax.plot(time_fit,av_fit)
        ax.plot(time_fit,y_fitted)
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")



    else:
        print("No fit")
        time_fit=Processed_Data[amp_factor][freqs[idx]]["time_fit"]
        av_fit=Processed_Data[amp_factor][freqs[idx]]["av_fit"]
        fontsize=8
        fig, axs = plt.subplots( nrows=1, ncols=1, figsize=(5,5),dpi=100)
        ax=axs
        ax.set_title("Pump= "+str(freqs[idx]) +" Iteration :" +str(idx) + " No fit")
        ax.plot(time_fit,av_fit)
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")

# %% [markdown]
# ## Extracting the Liouivillian gap

# %%
# %matplotlib inline

center_freq=4.34799e9*2
Gi=0.6

fontsize=8
figsize=(5,4)
fig, axs = plt.subplots( ncols=2, figsize=(14,6))

for j in range(len(amp_factor_array)):
    
    amp_factor=amp_factor_array[j]
    freqs=freqs_dict[amp_factor]
    gap_array=[]
    freq_gap_array=[]
    
    for idx in range(len(freqs)):

        if Processed_Data[amp_factor][freqs[idx]]["fit"]:
            gap_array.append(Processed_Data[amp_factor][freqs[idx]]["gap"])
            freq_gap_array.append(freqs[idx])
        
    gap_array=np.array(gap_array)
    freq_gap_array=np.array(freq_gap_array)
    
    ax=axs[0]
    ax.plot(freq_gap_array/1e9,gap_array,".-",label=f'Pump={amp_factor:.1f}', alpha=.9, lw=.5, ms=8)    
    ax=axs[1]
    Gx=amp_factor
    ax.plot( ((freq_gap_array+LO_fluxline)-center_freq)*Gi/Gx,gap_array,".-",label=f'Pump={amp_factor:.1f}', alpha=.9, lw=.5, ms=8)
  
ax=axs[0]
ax.set_xlabel("Pump frequency (IF)",fontsize=fontsize)
ax.set_ylabel("Louivillian gap",fontsize=fontsize)
ax.tick_params(axis='x', labelsize=fontsize)
ax.tick_params(axis='y', labelsize=fontsize)  
ax.legend(fontsize=fontsize)
ax.set_yscale('log')

ax=axs[1]
ax.set_title("Normalized")
ax.set_ylabel("Louivillian gap",fontsize=fontsize)
ax.tick_params(axis='x', labelsize=fontsize)
ax.tick_params(axis='y', labelsize=fontsize) 
ax.set_xlabel('$\Delta\cdot$F')
ax.legend(fontsize=fontsize)
ax.set_yscale('log')

# %% [markdown]
# # Finding parameters single amplitude

# %%
def func(t, A, B, Λ):
    return A + B * np.exp( - Λ * t)


def Finding_Parameters_Signle(Parameters,Readout_Len, amp_factor, amp_factor_high, IF_pump, IF_right, LO_diff, pump_step, n_repetition, n_empty,n_full,n_full_min,n_full_max,cooldown_time,qm):


    n_runs=n_empty+n_full
    
    av,time,I, Q=First_jump_single_freq(Readout_Len, amp_factor, amp_factor_high, IF_pump, IF_right, LO_diff, pump_step, n_repetition, n_empty,n_full, 1, cooldown_time,wait_pump_step,qm)
    plt.close()
  
    #Select the data to fit and normalize it 
    idx_pump_start=n_empty+1
    time_w_pump=time[idx_pump_start:] # time after the pmup 
    number=len(time_w_pump) # how much data to consider fit 
    time_fit=time[idx_pump_start:]*1e-9-time[idx_pump_start]*1e-9 #time after the pump substracted by the time of the pump to set to zero
    av_fit=av[idx_pump_start:idx_pump_start+number]#normalize data 
    av_fit=av_fit  
    av_fit=av_fit /max(av_fit)


    #In case we re in the vacuum 
    if np.mean(av[idx_pump_start:idx_pump_start+number])*1e3<0.45:

        Parameters[amp_factor][IF_pump]["time_fit_1"]=time_fit
        Parameters[amp_factor][IF_pump]["av_fit_1"]=av_fit
        Parameters[amp_factor][IF_pump]["fit"]=False
        Parameters[amp_factor][IF_pump]["n_full_1"]=n_full 
       
        
       



    # fitting
    else:
        try:
            popt, pcov = curve_fit(func, time_fit, av_fit, p0 = [1, 0, 100] )
            y_fitted = popt[0]+  popt[1] * np.exp(-popt[2] * time_fit)



            time_rec=3.5/(popt[2])# we try to get at least two times the value of the gap 
            n_full=int(round(time_rec*1e9/Readout_Len))


            if n_full<n_full_min:
                n_full=int(n_full_min)

            elif n_full>n_full_max:
                n_full=int(n_full_max)
                
            print(n_full)


            Parameters[amp_factor][IF_pump]["gap_1"]=popt[2]
            Parameters[amp_factor][IF_pump]["fit_coeff_1"]=popt
            Parameters[amp_factor][IF_pump]["fit_1"]=True
            Parameters[amp_factor][IF_pump]["y_fitted_1"]=y_fitted
            Parameters[amp_factor][IF_pump]["time_fit_1"]=time_fit
            Parameters[amp_factor][IF_pump]["av_fit_1"]=av_fit 
            Parameters[amp_factor][IF_pump]["n_full_1"]=n_full 
           

            #Based on the results, we find the parameters for a second time    
            av,time,I, Q=First_jump_single_freq(Readout_Len, amp_factor, amp_factor_high, IF_pump, IF_right, LO_diff, pump_step, n_repetition, n_empty,n_full, 1, cooldown_time,wait_pump_step,qm)
            plt.close()

            idx_pump_start=n_empty+1
            time_w_pump=time[idx_pump_start:] # time after the pmup 
            number=len(time_w_pump) # how much data to consider fit 
            time_fit=time[idx_pump_start:]*1e-9-time[idx_pump_start]*1e-9 #time after the pump substracted by the time of the pump to set to zero
            av_fit=av[idx_pump_start:idx_pump_start+number]#normalize data 
            av_fit=av_fit  
            av_fit=av_fit /max(av_fit)

            popt, pcov = curve_fit(func, time_fit, av_fit, p0 = [1, 0, 0.01] )
            y_fitted = popt[0]+  popt[1] * np.exp(-popt[2] * time_fit)


            time_rec=3.5/(popt[2])# we try to get at least two times the value of the gap 
            n_full=int(round(time_rec*1e9/Readout_Len))


            if n_full<n_full_min:
                n_full=n_full_min

            elif n_full>n_full_max:
                n_full=n_full_max 

            print(n_full)

        

            Parameters[amp_factor][IF_pump]["gap_2"]=popt[2]
            Parameters[amp_factor][IF_pump]["fit_coeff_2"]=popt
            Parameters[amp_factor][IF_pump]["fit_2"]=True
            Parameters[amp_factor][IF_pump]["y_fitted_2"]=y_fitted
            Parameters[amp_factor][IF_pump]["time_fit_2"]=time_fit
            Parameters[amp_factor][IF_pump]["av_fit_2"]=av_fit 
            Parameters[amp_factor][IF_pump]["n_full_2"]=n_full 
        



        #if cannot fit 
        except RuntimeError:

            Parameters[amp_factor][IF_pump]["time_fit_1"]=time_fit
            Parameters[amp_factor][IF_pump]["av_fit_1"]=av_fit
            Parameters[amp_factor][IF_pump]["fit"]=False
            Parameters[amp_factor][IF_pump]["n_full_1"]=n_full 


    return Parameters

# %%
# %matplotlib qt


n_full_min=200 
n_full_max=20_000


Readout_Len=50_000
config,qm=update_readout_lenght(Readout_Len,config,qmm)
config,qm=update_two_photon_lenght(Readout_Len,config,qmm)

n_repetition=100 #number of repetitions 
n_empty=100 #number of readout to do while sweeping the frequency 
n_full=2000 #number of pump on readout to do 


IF_right=99.8e6 # Starting frequency 


wait_pump_step=16//4 #w aiting time after having played the pump
cooldown_time=5_000//4


LO_diff=LO_fluxline/2-LO_readout # need to perform this substraction outside of the qua program to avoid having numbers larger than the int allowed 
n_runs=n_empty+n_full # Total number of readout to do 

amp_factor_array=np.array([1.15]) #Prefactor of the amplitude 
amp_factor=amp_factor_array[0]
amp_factor_high_array=np.array([1.5]) #Prefactor of the amplitude 
amp_factor_high=amp_factor_high_array[0]

fmin=94e6
fmax=99.2e6 ##9.2 
df=0.1* u.MHz
freqs=np.arange(fmin, fmax+df/2, df)

freqs_dict={}
freqs_dict[amp_factor]=freqs


#Keep the fitting parameters 
Parameters={}
Parameters[amp_factor]={}
Parameters[amp_factor]["amp_factor_high"]=amp_factor_high
Parameters[amp_factor]["IF_right"]=IF_right
Parameters[amp_factor]["n_empty"]=n_empty
Parameters[amp_factor]["n_full"]=n_full 
Parameters[amp_factor]["n_repetition"]=n_repetition
Parameters[amp_factor]["n_full_min"]=n_full_min
Parameters[amp_factor]["n_full_max"]=n_full_max
Parameters[amp_factor]["cooldown_time"]=cooldown_time
Parameters[amp_factor]["Readout_Len"]=Readout_Len


for idx,IF_pump in enumerate(freqs) :
    
    print("########################### Frequency "+str(IF_pump)+"########################### "+str(idx/len(freqs)))
    
    pump_step=(IF_right-IF_pump)/n_empty
    
    Parameters[amp_factor][IF_pump]={}
    Parameters=Finding_Parameters_Signle(Parameters,Readout_Len, amp_factor, amp_factor_high, IF_pump, IF_right, LO_diff, pump_step, n_repetition, n_empty,n_full,n_full_min,n_full_max,cooldown_time,qm)
# Out:
# ########################### Frequency 94000000.0########################### 0.0
# 2023-06-29 16:38:06,060 - qm - INFO - Flags:
# 2023-06-29 16:38:06,061 - qm - INFO - Sending program to QOP
# 2023-06-29 16:38:07,431 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 94100000.0########################### 0.018867924528301886
# 2023-06-29 16:38:18,854 - qm - INFO - Flags:
# 2023-06-29 16:38:18,855 - qm - INFO - Sending program to QOP
# 2023-06-29 16:38:20,202 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 94200000.0########################### 0.03773584905660377
# 2023-06-29 16:38:31,647 - qm - INFO - Flags:
# 2023-06-29 16:38:31,647 - qm - INFO - Sending program to QOP
# 2023-06-29 16:38:33,049 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 94300000.0########################### 0.05660377358490566
# 2023-06-29 16:38:44,680 - qm - INFO - Flags:
# 2023-06-29 16:38:44,681 - qm - INFO - Sending program to QOP
# 2023-06-29 16:38:46,608 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 94400000.0########################### 0.07547169811320754
# 2023-06-29 16:38:57,711 - qm - INFO - Flags:
# 2023-06-29 16:38:57,711 - qm - INFO - Sending program to QOP
# 2023-06-29 16:38:59,610 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 94500000.0########################### 0.09433962264150944
# 2023-06-29 16:39:10,626 - qm - INFO - Flags:
# 2023-06-29 16:39:10,627 - qm - INFO - Sending program to QOP
# 2023-06-29 16:39:12,127 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 94600000.0########################### 0.11320754716981132
# 2023-06-29 16:39:23,543 - qm - INFO - Flags:
# 2023-06-29 16:39:23,544 - qm - INFO - Sending program to QOP
# 2023-06-29 16:39:25,410 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 94700000.0########################### 0.1320754716981132
# 2023-06-29 16:39:36,451 - qm - INFO - Flags:
# 2023-06-29 16:39:36,452 - qm - INFO - Sending program to QOP
# 2023-06-29 16:39:37,971 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 94800000.0########################### 0.1509433962264151
# 2023-06-29 16:39:49,473 - qm - INFO - Flags:
# 2023-06-29 16:39:49,474 - qm - INFO - Sending program to QOP
# 2023-06-29 16:39:50,926 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 94900000.0########################### 0.16981132075471697
# 2023-06-29 16:40:02,477 - qm - INFO - Flags:
# 2023-06-29 16:40:02,478 - qm - INFO - Sending program to QOP
# 2023-06-29 16:40:03,918 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 95000000.0########################### 0.18867924528301888
# 2023-06-29 16:40:15,454 - qm - INFO - Flags:
# 2023-06-29 16:40:15,455 - qm - INFO - Sending program to QOP
# 2023-06-29 16:40:17,301 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 95100000.0########################### 0.20754716981132076
# 2023-06-29 16:40:28,430 - qm - INFO - Flags:
# 2023-06-29 16:40:28,431 - qm - INFO - Sending program to QOP
# 2023-06-29 16:40:30,222 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 95200000.0########################### 0.22641509433962265
# 2023-06-29 16:40:41,376 - qm - INFO - Flags:
# 2023-06-29 16:40:41,377 - qm - INFO - Sending program to QOP
# 2023-06-29 16:40:42,767 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 95300000.0########################### 0.24528301886792453
# 2023-06-29 16:40:54,249 - qm - INFO - Flags:
# 2023-06-29 16:40:54,250 - qm - INFO - Sending program to QOP
# 2023-06-29 16:40:55,598 - qm - INFO - Executing program
# Execution stopped by user!
# 200
# 2023-06-29 16:41:07,216 - qm - INFO - Flags:
# 2023-06-29 16:41:07,216 - qm - INFO - Sending program to QOP
# 2023-06-29 16:41:09,055 - qm - INFO - Executing program
# Execution stopped by user!
# 200
# ########################### Frequency 95400000.0########################### 0.2641509433962264
# 2023-06-29 16:41:11,118 - qm - INFO - Flags:
# 2023-06-29 16:41:11,118 - qm - INFO - Sending program to QOP
# 2023-06-29 16:41:12,941 - qm - INFO - Executing program
# Execution stopped by user!
# 200
# 2023-06-29 16:41:24,039 - qm - INFO - Flags:
# 2023-06-29 16:41:24,039 - qm - INFO - Sending program to QOP
# 2023-06-29 16:41:25,506 - qm - INFO - Executing program
# Execution stopped by user!
# 200
# ########################### Frequency 95500000.0########################### 0.2830188679245283
# 2023-06-29 16:41:27,902 - qm - INFO - Flags:
# 2023-06-29 16:41:27,903 - qm - INFO - Sending program to QOP
# 2023-06-29 16:41:29,699 - qm - INFO - Executing program
# Execution stopped by user!
# 200
# 2023-06-29 16:41:40,952 - qm - INFO - Flags:
# 2023-06-29 16:41:40,953 - qm - INFO - Sending program to QOP
# 2023-06-29 16:41:42,398 - qm - INFO - Executing program
# Execution stopped by user!
# 200
# ########################### Frequency 95600000.0########################### 0.3018867924528302
# 2023-06-29 16:41:44,836 - qm - INFO - Flags:
# 2023-06-29 16:41:44,837 - qm - INFO - Sending program to QOP
# 2023-06-29 16:41:46,253 - qm - INFO - Executing program
# Execution stopped by user!
# 200
# 2023-06-29 16:41:57,578 - qm - INFO - Flags:
# 2023-06-29 16:41:57,580 - qm - INFO - Sending program to QOP
# 2023-06-29 16:41:59,505 - qm - INFO - Executing program
# Execution stopped by user!
# 200
# ########################### Frequency 95700000.0########################### 0.32075471698113206
# 2023-06-29 16:42:01,597 - qm - INFO - Flags:
# 2023-06-29 16:42:01,598 - qm - INFO - Sending program to QOP
# 2023-06-29 16:42:03,091 - qm - INFO - Executing program
# Execution stopped by user!
# 200
# 2023-06-29 16:42:14,682 - qm - INFO - Flags:
# 2023-06-29 16:42:14,683 - qm - INFO - Sending program to QOP
# 2023-06-29 16:42:16,163 - qm - INFO - Executing program
# Execution stopped by user!
# 200
# ########################### Frequency 95800000.0########################### 0.33962264150943394
# 2023-06-29 16:42:18,646 - qm - INFO - Flags:
# 2023-06-29 16:42:18,647 - qm - INFO - Sending program to QOP
# 2023-06-29 16:42:20,050 - qm - INFO - Executing program
# Execution stopped by user!
# 200
# 2023-06-29 16:42:31,542 - qm - INFO - Flags:
# 2023-06-29 16:42:31,543 - qm - INFO - Sending program to QOP
# 2023-06-29 16:42:33,313 - qm - INFO - Executing program
# Execution stopped by user!
# 211
# ########################### Frequency 95900000.0########################### 0.3584905660377358
# 2023-06-29 16:42:35,380 - qm - INFO - Flags:
# 2023-06-29 16:42:35,380 - qm - INFO - Sending program to QOP
# 2023-06-29 16:42:36,879 - qm - INFO - Executing program
# Execution stopped by user!
# 232
# 2023-06-29 16:42:48,535 - qm - INFO - Flags:
# 2023-06-29 16:42:48,535 - qm - INFO - Sending program to QOP
# 2023-06-29 16:42:50,032 - qm - INFO - Executing program
# Execution stopped by user!
# 200
# ########################### Frequency 96000000.0########################### 0.37735849056603776
# 2023-06-29 16:42:52,494 - qm - INFO - Flags:
# 2023-06-29 16:42:52,495 - qm - INFO - Sending program to QOP
# 2023-06-29 16:42:53,975 - qm - INFO - Executing program
# Execution stopped by user!
# 276
# 2023-06-29 16:43:05,529 - qm - INFO - Flags:
# 2023-06-29 16:43:05,530 - qm - INFO - Sending program to QOP
# 2023-06-29 16:43:06,992 - qm - INFO - Executing program
# Execution stopped by user!
# 339
# ########################### Frequency 96100000.0########################### 0.39622641509433965
# 2023-06-29 16:43:09,653 - qm - INFO - Flags:
# 2023-06-29 16:43:09,654 - qm - INFO - Sending program to QOP
# 2023-06-29 16:43:11,050 - qm - INFO - Executing program
# Execution stopped by user!
# 337
# 2023-06-29 16:43:22,413 - qm - INFO - Flags:
# 2023-06-29 16:43:22,414 - qm - INFO - Sending program to QOP
# 2023-06-29 16:43:23,769 - qm - INFO - Executing program
# Execution stopped by user!
# 275
# ########################### Frequency 96200000.0########################### 0.41509433962264153
# 2023-06-29 16:43:26,877 - qm - INFO - Flags:
# 2023-06-29 16:43:26,878 - qm - INFO - Sending program to QOP
# 2023-06-29 16:43:28,351 - qm - INFO - Executing program
# Execution stopped by user!
# 391
# 2023-06-29 16:43:39,707 - qm - INFO - Flags:
# 2023-06-29 16:43:39,708 - qm - INFO - Sending program to QOP
# 2023-06-29 16:43:41,184 - qm - INFO - Executing program
# Execution stopped by user!
# 398
# ########################### Frequency 96300000.0########################### 0.4339622641509434
# 2023-06-29 16:43:44,482 - qm - INFO - Flags:
# 2023-06-29 16:43:44,482 - qm - INFO - Sending program to QOP
# 2023-06-29 16:43:45,951 - qm - INFO - Executing program
# Execution stopped by user!
# 448
# 2023-06-29 16:43:57,569 - qm - INFO - Flags:
# 2023-06-29 16:43:57,569 - qm - INFO - Sending program to QOP
# 2023-06-29 16:43:59,005 - qm - INFO - Executing program
# Execution stopped by user!
# 560
# ########################### Frequency 96400000.0########################### 0.4528301886792453
# 2023-06-29 16:44:02,777 - qm - INFO - Flags:
# 2023-06-29 16:44:02,778 - qm - INFO - Sending program to QOP
# 2023-06-29 16:44:04,568 - qm - INFO - Executing program
# Execution stopped by user!
# 556
# 2023-06-29 16:44:15,767 - qm - INFO - Flags:
# 2023-06-29 16:44:15,768 - qm - INFO - Sending program to QOP
# 2023-06-29 16:44:17,557 - qm - INFO - Executing program
# Execution stopped by user!
# 656
# ########################### Frequency 96500000.0########################### 0.4716981132075472
# 2023-06-29 16:44:21,367 - qm - INFO - Flags:
# 2023-06-29 16:44:21,368 - qm - INFO - Sending program to QOP
# 2023-06-29 16:44:22,857 - qm - INFO - Executing program
# Execution stopped by user!
# 875
# 2023-06-29 16:44:34,326 - qm - INFO - Flags:
# 2023-06-29 16:44:34,326 - qm - INFO - Sending program to QOP
# 2023-06-29 16:44:35,827 - qm - INFO - Executing program
# Execution stopped by user!
# 575
# ########################### Frequency 96600000.0########################### 0.49056603773584906
# 2023-06-29 16:44:41,517 - qm - INFO - Flags:
# 2023-06-29 16:44:41,518 - qm - INFO - Sending program to QOP
# 2023-06-29 16:44:42,980 - qm - INFO - Executing program
# Execution stopped by user!
# 749
# 2023-06-29 16:44:54,484 - qm - INFO - Flags:
# 2023-06-29 16:44:54,485 - qm - INFO - Sending program to QOP
# 2023-06-29 16:44:55,930 - qm - INFO - Executing program
# Execution stopped by user!
# 971
# ########################### Frequency 96700000.0########################### 0.5094339622641509
# 2023-06-29 16:45:01,067 - qm - INFO - Flags:
# 2023-06-29 16:45:01,067 - qm - INFO - Sending program to QOP
# 2023-06-29 16:45:02,458 - qm - INFO - Executing program
# Execution stopped by user!
# 1224
# 2023-06-29 16:45:14,028 - qm - INFO - Flags:
# 2023-06-29 16:45:14,028 - qm - INFO - Sending program to QOP
# 2023-06-29 16:45:15,375 - qm - INFO - Executing program
# Execution stopped by user!
# 1257
# ########################### Frequency 96800000.0########################### 0.5283018867924528
# 2023-06-29 16:45:22,865 - qm - INFO - Flags:
# 2023-06-29 16:45:22,866 - qm - INFO - Sending program to QOP
# 2023-06-29 16:45:24,358 - qm - INFO - Executing program
# Execution stopped by user!
# 1679
# 2023-06-29 16:45:35,795 - qm - INFO - Flags:
# 2023-06-29 16:45:35,795 - qm - INFO - Sending program to QOP
# 2023-06-29 16:45:37,288 - qm - INFO - Executing program
# Execution stopped by user!
# 1050
# ########################### Frequency 96900000.0########################### 0.5471698113207547
# 2023-06-29 16:45:47,271 - qm - INFO - Flags:
# 2023-06-29 16:45:47,272 - qm - INFO - Sending program to QOP
# 2023-06-29 16:45:48,755 - qm - INFO - Executing program
# Execution stopped by user!
# 2189
# 2023-06-29 16:46:00,234 - qm - INFO - Flags:
# 2023-06-29 16:46:00,234 - qm - INFO - Sending program to QOP
# 2023-06-29 16:46:01,717 - qm - INFO - Executing program
# Execution stopped by user!
# 1624
# ########################### Frequency 97000000.0########################### 0.5660377358490566
# 2023-06-29 16:46:14,367 - qm - INFO - Flags:
# 2023-06-29 16:46:14,368 - qm - INFO - Sending program to QOP
# 2023-06-29 16:46:15,815 - qm - INFO - Executing program
# Execution stopped by user!
# 3359
# 2023-06-29 16:46:27,386 - qm - INFO - Flags:
# 2023-06-29 16:46:27,387 - qm - INFO - Sending program to QOP
# 2023-06-29 16:46:28,812 - qm - INFO - Executing program
# Execution stopped by user!
# 2101
# ########################### Frequency 97100000.0########################### 0.5849056603773585
# 2023-06-29 16:46:47,230 - qm - INFO - Flags:
# 2023-06-29 16:46:47,231 - qm - INFO - Sending program to QOP
# 2023-06-29 16:46:48,695 - qm - INFO - Executing program
# Execution stopped by user!
# 4600
# 2023-06-29 16:47:00,180 - qm - INFO - Flags:
# 2023-06-29 16:47:00,181 - qm - INFO - Sending program to QOP
# 2023-06-29 16:47:01,615 - qm - INFO - Executing program
# Execution stopped by user!
# 2382
# ########################### Frequency 97200000.0########################### 0.6037735849056604
# 2023-06-29 16:47:26,346 - qm - INFO - Flags:
# 2023-06-29 16:47:26,347 - qm - INFO - Sending program to QOP
# 2023-06-29 16:47:27,834 - qm - INFO - Executing program
# Execution stopped by user!
# 4204
# 2023-06-29 16:47:39,447 - qm - INFO - Flags:
# 2023-06-29 16:47:39,448 - qm - INFO - Sending program to QOP
# 2023-06-29 16:47:40,944 - qm - INFO - Executing program
# Execution stopped by user!
# 2789
# ########################### Frequency 97300000.0########################### 0.6226415094339622
# 2023-06-29 16:48:03,838 - qm - INFO - Flags:
# 2023-06-29 16:48:03,838 - qm - INFO - Sending program to QOP
# 2023-06-29 16:48:05,327 - qm - INFO - Executing program
# Execution stopped by user!
# 2309
# 2023-06-29 16:48:16,664 - qm - INFO - Flags:
# 2023-06-29 16:48:16,664 - qm - INFO - Sending program to QOP
# 2023-06-29 16:48:18,159 - qm - INFO - Executing program
# Execution stopped by user!
# 2278
# ########################### Frequency 97400000.0########################### 0.6415094339622641
# 2023-06-29 16:48:31,143 - qm - INFO - Flags:
# 2023-06-29 16:48:31,143 - qm - INFO - Sending program to QOP
# 2023-06-29 16:48:32,643 - qm - INFO - Executing program
# Execution stopped by user!
# 5286
# 2023-06-29 16:48:44,186 - qm - INFO - Flags:
# 2023-06-29 16:48:44,187 - qm - INFO - Sending program to QOP
# 2023-06-29 16:48:45,670 - qm - INFO - Executing program
# Execution stopped by user!
# 4186
# ########################### Frequency 97500000.0########################### 0.660377358490566
# 2023-06-29 16:49:13,948 - qm - INFO - Flags:
# 2023-06-29 16:49:13,949 - qm - INFO - Sending program to QOP
# 2023-06-29 16:49:15,293 - qm - INFO - Executing program
# Execution stopped by user!
# 6665
# 2023-06-29 16:49:26,747 - qm - INFO - Flags:
# 2023-06-29 16:49:26,747 - qm - INFO - Sending program to QOP
# 2023-06-29 16:49:28,647 - qm - INFO - Executing program
# Execution stopped by user!
# 4276
# ########################### Frequency 97600000.0########################### 0.6792452830188679
# 2023-06-29 16:50:03,512 - qm - INFO - Flags:
# 2023-06-29 16:50:03,512 - qm - INFO - Sending program to QOP
# 2023-06-29 16:50:05,020 - qm - INFO - Executing program
# Execution stopped by user!
# 20000
# 2023-06-29 16:50:16,764 - qm - INFO - Flags:
# 2023-06-29 16:50:16,764 - qm - INFO - Sending program to QOP
# 2023-06-29 16:50:18,263 - qm - INFO - Executing program
# Execution stopped by user!
# 7918
# ########################### Frequency 97700000.0########################### 0.6981132075471698
# 2023-06-29 16:52:00,913 - qm - INFO - Flags:
# 2023-06-29 16:52:00,913 - qm - INFO - Sending program to QOP
# 2023-06-29 16:52:02,405 - qm - INFO - Executing program
# Execution stopped by user!
# 9557
# 2023-06-29 16:52:13,896 - qm - INFO - Flags:
# 2023-06-29 16:52:13,897 - qm - INFO - Sending program to QOP
# 2023-06-29 16:52:15,772 - qm - INFO - Executing program
# Execution stopped by user!
# 8289
# ########################### Frequency 97800000.0########################### 0.7169811320754716
# 2023-06-29 16:53:05,074 - qm - INFO - Flags:
# 2023-06-29 16:53:05,074 - qm - INFO - Sending program to QOP
# 2023-06-29 16:53:06,527 - qm - INFO - Executing program
# Execution stopped by user!
# 7087
# 2023-06-29 16:53:18,058 - qm - INFO - Flags:
# 2023-06-29 16:53:18,058 - qm - INFO - Sending program to QOP
# 2023-06-29 16:53:19,550 - qm - INFO - Executing program
# Execution stopped by user!
# 7778
# ########################### Frequency 97900000.0########################### 0.7358490566037735
# 2023-06-29 16:53:57,001 - qm - INFO - Flags:
# 2023-06-29 16:53:57,001 - qm - INFO - Sending program to QOP
# 2023-06-29 16:53:58,494 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 98000000.0########################### 0.7547169811320755
# 2023-06-29 16:54:10,026 - qm - INFO - Flags:
# 2023-06-29 16:54:10,026 - qm - INFO - Sending program to QOP
# 2023-06-29 16:54:11,516 - qm - INFO - Executing program
# Execution stopped by user!
# 20000
# 2023-06-29 16:54:23,019 - qm - INFO - Flags:
# 2023-06-29 16:54:23,019 - qm - INFO - Sending program to QOP
# 2023-06-29 16:54:24,505 - qm - INFO - Executing program
# Execution stopped by user!
# 14027
# ########################### Frequency 98100000.0########################### 0.7735849056603774
# 2023-06-29 16:56:07,392 - qm - INFO - Flags:
# 2023-06-29 16:56:07,393 - qm - INFO - Sending program to QOP
# 2023-06-29 16:56:08,830 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 98200000.0########################### 0.7924528301886793
# 2023-06-29 16:56:20,362 - qm - INFO - Flags:
# 2023-06-29 16:56:20,362 - qm - INFO - Sending program to QOP
# 2023-06-29 16:56:21,786 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 98300000.0########################### 0.8113207547169812
# 2023-06-29 16:56:33,327 - qm - INFO - Flags:
# 2023-06-29 16:56:33,328 - qm - INFO - Sending program to QOP
# 2023-06-29 16:56:35,174 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 98400000.0########################### 0.8301886792452831
# 2023-06-29 16:56:46,208 - qm - INFO - Flags:
# 2023-06-29 16:56:46,209 - qm - INFO - Sending program to QOP
# 2023-06-29 16:56:47,592 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 98500000.0########################### 0.8490566037735849
# 2023-06-29 16:56:59,019 - qm - INFO - Flags:
# 2023-06-29 16:56:59,020 - qm - INFO - Sending program to QOP
# 2023-06-29 16:57:00,758 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 98600000.0########################### 0.8679245283018868
# 2023-06-29 16:57:11,899 - qm - INFO - Flags:
# 2023-06-29 16:57:11,900 - qm - INFO - Sending program to QOP
# 2023-06-29 16:57:13,574 - qm - INFO - Executing program
# Execution stopped by user!
# 8298
# 2023-06-29 16:57:24,778 - qm - INFO - Flags:
# 2023-06-29 16:57:24,779 - qm - INFO - Sending program to QOP
# 2023-06-29 16:57:26,300 - qm - INFO - Executing program
# Execution stopped by user!
# 20000
# ########################### Frequency 98700000.0########################### 0.8867924528301887
# 2023-06-29 16:58:09,625 - qm - INFO - Flags:
# 2023-06-29 16:58:09,626 - qm - INFO - Sending program to QOP
# 2023-06-29 16:58:11,421 - qm - INFO - Executing program
# Execution stopped by user!
# 4987
# 2023-06-29 16:58:22,591 - qm - INFO - Flags:
# 2023-06-29 16:58:22,592 - qm - INFO - Sending program to QOP
# 2023-06-29 16:58:24,369 - qm - INFO - Executing program
# Execution stopped by user!
# 16330
# ########################### Frequency 98800000.0########################### 0.9056603773584906
# 2023-06-29 16:58:50,654 - qm - INFO - Flags:
# 2023-06-29 16:58:50,655 - qm - INFO - Sending program to QOP
# 2023-06-29 16:58:52,141 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 98900000.0########################### 0.9245283018867925
# 2023-06-29 16:59:03,741 - qm - INFO - Flags:
# 2023-06-29 16:59:03,742 - qm - INFO - Sending program to QOP
# 2023-06-29 16:59:05,214 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 99000000.0########################### 0.9433962264150944
# 2023-06-29 16:59:16,534 - qm - INFO - Flags:
# 2023-06-29 16:59:16,535 - qm - INFO - Sending program to QOP
# 2023-06-29 16:59:17,996 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 99100000.0########################### 0.9622641509433962
# 2023-06-29 16:59:29,352 - qm - INFO - Flags:
# 2023-06-29 16:59:29,352 - qm - INFO - Sending program to QOP
# 2023-06-29 16:59:30,774 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 99200000.0########################### 0.9811320754716981
# 2023-06-29 16:59:42,315 - qm - INFO - Flags:
# 2023-06-29 16:59:42,316 - qm - INFO - Sending program to QOP
# 2023-06-29 16:59:43,681 - qm - INFO - Executing program
# Execution stopped by user!
# 494
# 2023-06-29 16:59:55,321 - qm - INFO - Flags:
# 2023-06-29 16:59:55,322 - qm - INFO - Sending program to QOP
# 2023-06-29 16:59:56,687 - qm - INFO - Executing program
# Execution stopped by user!
# 20000

# %% [markdown]
# ## Plotting Parameters

# %%
# %matplotlib qt
#Plot all 
amp_factor=amp_factor_array[0]
freqs=freqs_dict[amp_factor]

for idx in range(len(freqs)):
  
    if "fit_2" in Parameters[amp_factor][freqs[idx]]:

        gap=Parameters[amp_factor][freqs[idx]]["gap_2"]
        time_fit=Parameters[amp_factor][freqs[idx]]["time_fit_2"]
        y_fitted=Parameters[amp_factor][freqs[idx]]["y_fitted_2"]
        av_fit=Parameters[amp_factor][freqs[idx]]["av_fit_2"]

        fontsize=8
        fig, axs = plt.subplots( nrows=1, ncols=1, figsize=(5,5),dpi=100)
        ax=axs
        ax.set_title("Pump= "+str(freqs[idx]) +" Iteration :" +str(idx)+" $\lambda= $"+str(round(gap,2)))
        ax.plot(time_fit,av_fit,".")
        ax.plot(time_fit,y_fitted)
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")



    else:
        print("No fit")
        print(freqs[idx])
        time_fit=Parameters[amp_factor][freqs[idx]]["time_fit_1"]
        av_fit=Parameters[amp_factor][freqs[idx]]["av_fit_1"]
        fontsize=8
        fig, axs = plt.subplots( nrows=1, ncols=1, figsize=(5,5),dpi=100)
        ax=axs
        ax.set_title("Pump= "+str(freqs[idx]) +" Iteration :" +str(idx) + " No fit")
        ax.plot(time_fit,av_fit,".")
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_53108\576887814.py in <module>
#       8     if "fit_2" in Parameters[amp_factor][freqs[idx]]:
#       9
# ---> 10         gap=Parameters[amp_factor][freqs[idx]]["gap_2"]
#      11         time_fit=Parameters[amp_factor][freqs[idx]]["time_fit_2"]
#      12         y_fitted=Parameters[amp_factor][freqs[idx]]["y_fitted_2"]
#
# KeyError: 'gap_2'

# %%
plt.close("all")
# Out:
# Execution stopped by user!

# %% [markdown]
# ## Modifying parameters

# %%
freqs
# Out:
# array([94500000., 94600000., 94700000., 94800000., 94900000., 95000000.,
#        95100000., 95200000., 95300000., 95400000., 95500000., 95600000.,
#        95700000., 95800000., 95900000., 96000000., 96100000., 96200000.,
#        96300000., 96400000., 96500000., 96600000., 96700000., 96800000.,
#        96900000., 97000000., 97100000., 97200000., 97300000., 97400000.,
#        97500000., 97600000., 97700000., 97800000., 97900000., 98000000.,
#        98100000., 98200000., 98300000., 98400000., 98500000., 98600000.,
#        98700000., 98800000., 98900000., 99000000., 99100000., 99200000.])

# %%
fmin=94e6
fmax=95.1e6 ##9.2 
df=0.1* u.MHz
freqs_change_min=np.arange(fmin, fmax+df/2, df)
print(freqs_change_min)
# Out:
# [94000000. 94100000. 94200000. 94300000. 94400000. 94500000. 94600000.
#  94700000. 94800000. 94900000. 95000000. 95100000.]

# %%
for f in freqs_change_min:
    Parameters[amp_factor][f]["fit_2"]=True
    Parameters[amp_factor][f]["n_full_2"]=n_full_min=200

# %% [markdown]
# ## Saving Parameters

# %%
cooldown_date=Cooldown_Date #top folder 
device="exc_to_vac" #second folder 
name="Finding_Parameters" # third folder 
meastype="1p15_994_992_3p5times" #Final file name 

datadict={}
datadict["LO_fluxline"]=LO_fluxline
datadict["IF_fluxline"]=IF_pump

datadict["LO_readout"]=LO_readout
datadict["octave_output_gain"]=octave_output_gain

datadict["amp_factor_array"]=amp_factor_array

datadict["cooldown_time"]=cooldown_time
datadict["Parameters"]=Parameters
datadict["config"]=config
datadict["freqs_dict"]=freqs_dict 

an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)
# Out:
# saving

# %%
#Loading parameters 

filepath= r"X:\Users\beaulieu\Data\Run01\131\2023_06_01\exc_to_vac\Finding_Parameters\1p15_994_992_3p5times.npz"

npzfile=np.load(filepath,allow_pickle=True)
#npzfile["multidata"][()]

Parameters=npzfile["multidata"][()]["Parameters"]
freqs_dict=npzfile["multidata"][()]["freqs_dict"]
amp_factor_array=npzfile["multidata"][()]["amp_factor_array"]

# %% [markdown]
# # Run Based on Parameters

# %%
amp_factor=amp_factor_array[0]
freqs=freqs_dict[amp_factor]


n_repetition=500 #number of repetitions that we want 
n_return=n_repetition # we saveeveverything 
n_default=50_000 # if we have no fit, we go for 5000 


Readout_Len= Parameters[amp_factor]["Readout_Len"]
n_empty= Parameters[amp_factor]["n_empty"]
cooldown_time=Parameters[amp_factor]["cooldown_time"]
amp_factor_high=Parameters[amp_factor]["amp_factor_high"]
IF_right=Parameters[amp_factor]["IF_right"]


Readout_Len=50_000
config,qm=update_readout_lenght(Readout_Len,config,qmm)
config,qm=update_two_photon_lenght(Readout_Len,config,qmm)

LO_diff=LO_fluxline/2-LO_readout 

# Calculation fo the time 
time_list=[]
for idx,IF_pump in enumerate(freqs) :
    if "fit_2" in Parameters[amp_factor][IF_pump]:
        n_full=Parameters[amp_factor][IF_pump]["n_full_2"]
        n_runs=n_full+n_empty
        time_list.append((Readout_Len*n_runs*1e-9*n_repetition+n_repetition*cooldown_time*4*1e-9)/60)
        
    else:
        n_full=n_default
        n_runs=n_full+n_empty
        time_list.append((Readout_Len*n_runs*1e-9*n_repetition+n_repetition*cooldown_time*4*1e-9)/60)

print("Expeceted time {}".format(sum(time_list)))
# Out:
# Expeceted time 282.9897083333334

# %%
# %%time
Data={} #dictionnary to hold all the data 
Data[amp_factor]={}
for idx,IF_pump in enumerate(freqs) :
    
    print("########################### Frequency "+str(IF_pump+LO_fluxline)+"########################### "+str(idx/len(freqs)))
    
    #If we have an initial fit we select the number of full based on the 
    if "fit_2" in Parameters[amp_factor][IF_pump]:
        n_full=Parameters[amp_factor][IF_pump]["n_full_2"]
    else :
        n_full=n_default 

    
    pump_step=(IF_right-IF_pump)/n_empty
    
    av,time,I, Q=First_jump_single_freq(Readout_Len, amp_factor, amp_factor_high, IF_pump, IF_right, LO_diff, pump_step, n_repetition, n_empty,n_full, n_return, cooldown_time,wait_pump_step,qm)
    plt.close()
    
    Data[amp_factor][IF_pump]={}
    Data[amp_factor][IF_pump]["value"]=av
    Data[amp_factor][IF_pump]["time"]=time
    Data[amp_factor][IF_pump]["I"]=I
    Data[amp_factor][IF_pump]["Q"]=Q
# Out:
# ########################### Frequency 8694500000.0########################### 0.0
# 2023-06-29 11:33:33,459 - qm - INFO - Flags:
# 2023-06-29 11:33:33,460 - qm - INFO - Sending program to QOP
# 2023-06-29 11:33:34,798 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8694600000.0########################### 0.020833333333333332
# 2023-06-29 11:33:51,071 - qm - INFO - Flags:
# 2023-06-29 11:33:51,072 - qm - INFO - Sending program to QOP
# 2023-06-29 11:33:52,437 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8694700000.0########################### 0.041666666666666664
# 2023-06-29 11:34:08,683 - qm - INFO - Flags:
# 2023-06-29 11:34:08,683 - qm - INFO - Sending program to QOP
# 2023-06-29 11:34:10,460 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8694800000.0########################### 0.0625
# 2023-06-29 11:34:26,281 - qm - INFO - Flags:
# 2023-06-29 11:34:26,282 - qm - INFO - Sending program to QOP
# 2023-06-29 11:34:28,088 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8694900000.0########################### 0.08333333333333333
# 2023-06-29 11:34:43,933 - qm - INFO - Flags:
# 2023-06-29 11:34:43,934 - qm - INFO - Sending program to QOP
# 2023-06-29 11:34:45,692 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695000000.0########################### 0.10416666666666667
# 2023-06-29 11:35:01,573 - qm - INFO - Flags:
# 2023-06-29 11:35:01,574 - qm - INFO - Sending program to QOP
# 2023-06-29 11:35:03,041 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695100000.0########################### 0.125
# 2023-06-29 11:35:19,339 - qm - INFO - Flags:
# 2023-06-29 11:35:19,340 - qm - INFO - Sending program to QOP
# 2023-06-29 11:35:20,794 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695200000.0########################### 0.14583333333333334
# 2023-06-29 11:35:37,091 - qm - INFO - Flags:
# 2023-06-29 11:35:37,092 - qm - INFO - Sending program to QOP
# 2023-06-29 11:35:38,552 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695300000.0########################### 0.16666666666666666
# 2023-06-29 11:35:54,757 - qm - INFO - Flags:
# 2023-06-29 11:35:54,758 - qm - INFO - Sending program to QOP
# 2023-06-29 11:35:56,602 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695400000.0########################### 0.1875
# 2023-06-29 11:36:12,505 - qm - INFO - Flags:
# 2023-06-29 11:36:12,506 - qm - INFO - Sending program to QOP
# 2023-06-29 11:36:14,367 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695500000.0########################### 0.20833333333333334
# 2023-06-29 11:36:30,082 - qm - INFO - Flags:
# 2023-06-29 11:36:30,083 - qm - INFO - Sending program to QOP
# 2023-06-29 11:36:31,963 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695600000.0########################### 0.22916666666666666
# 2023-06-29 11:36:47,881 - qm - INFO - Flags:
# 2023-06-29 11:36:47,882 - qm - INFO - Sending program to QOP
# 2023-06-29 11:36:49,727 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695700000.0########################### 0.25
# 2023-06-29 11:37:05,650 - qm - INFO - Flags:
# 2023-06-29 11:37:05,651 - qm - INFO - Sending program to QOP
# 2023-06-29 11:37:07,158 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695800000.0########################### 0.2708333333333333
# 2023-06-29 11:37:23,417 - qm - INFO - Flags:
# 2023-06-29 11:37:23,417 - qm - INFO - Sending program to QOP
# 2023-06-29 11:37:24,907 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695900000.0########################### 0.2916666666666667
# 2023-06-29 11:37:41,252 - qm - INFO - Flags:
# 2023-06-29 11:37:41,252 - qm - INFO - Sending program to QOP
# 2023-06-29 11:37:42,755 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696000000.0########################### 0.3125
# 2023-06-29 11:37:58,862 - qm - INFO - Flags:
# 2023-06-29 11:37:58,863 - qm - INFO - Sending program to QOP
# 2023-06-29 11:38:00,756 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696100000.0########################### 0.3333333333333333
# 2023-06-29 11:38:16,603 - qm - INFO - Flags:
# 2023-06-29 11:38:16,604 - qm - INFO - Sending program to QOP
# 2023-06-29 11:38:18,415 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696200000.0########################### 0.3541666666666667
# 2023-06-29 11:38:34,284 - qm - INFO - Flags:
# 2023-06-29 11:38:34,285 - qm - INFO - Sending program to QOP
# 2023-06-29 11:38:35,765 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696300000.0########################### 0.375
# 2023-06-29 11:38:52,174 - qm - INFO - Flags:
# 2023-06-29 11:38:52,174 - qm - INFO - Sending program to QOP
# 2023-06-29 11:38:53,655 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696400000.0########################### 0.3958333333333333
# 2023-06-29 11:39:09,954 - qm - INFO - Flags:
# 2023-06-29 11:39:09,955 - qm - INFO - Sending program to QOP
# 2023-06-29 11:39:11,781 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696500000.0########################### 0.4166666666666667
# 2023-06-29 11:39:27,735 - qm - INFO - Flags:
# 2023-06-29 11:39:27,736 - qm - INFO - Sending program to QOP
# 2023-06-29 11:39:29,642 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696600000.0########################### 0.4375
# 2023-06-29 11:39:45,632 - qm - INFO - Flags:
# 2023-06-29 11:39:45,633 - qm - INFO - Sending program to QOP
# 2023-06-29 11:39:47,096 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696700000.0########################### 0.4583333333333333
# 2023-06-29 11:40:03,294 - qm - INFO - Flags:
# 2023-06-29 11:40:03,294 - qm - INFO - Sending program to QOP
# 2023-06-29 11:40:04,789 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696800000.0########################### 0.4791666666666667
# 2023-06-29 11:40:21,123 - qm - INFO - Flags:
# 2023-06-29 11:40:21,124 - qm - INFO - Sending program to QOP
# 2023-06-29 11:40:22,956 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8696900000.0########################### 0.5
# 2023-06-29 11:40:38,895 - qm - INFO - Flags:
# 2023-06-29 11:40:38,896 - qm - INFO - Sending program to QOP
# 2023-06-29 11:40:40,381 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8697000000.0########################### 0.5208333333333334
# 2023-06-29 11:41:00,148 - qm - INFO - Flags:
# 2023-06-29 11:41:00,148 - qm - INFO - Sending program to QOP
# 2023-06-29 11:41:01,976 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8697100000.0########################### 0.5416666666666666
# 2023-06-29 11:41:28,450 - qm - INFO - Flags:
# 2023-06-29 11:41:28,451 - qm - INFO - Sending program to QOP
# 2023-06-29 11:41:29,914 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8697200000.0########################### 0.5625
# 2023-06-29 11:41:53,191 - qm - INFO - Flags:
# 2023-06-29 11:41:53,191 - qm - INFO - Sending program to QOP
# 2023-06-29 11:41:54,692 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8697300000.0########################### 0.5833333333333334
# 2023-06-29 11:42:19,104 - qm - INFO - Flags:
# 2023-06-29 11:42:19,104 - qm - INFO - Sending program to QOP
# 2023-06-29 11:42:20,466 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8697400000.0########################### 0.6041666666666666
# 2023-06-29 11:42:42,448 - qm - INFO - Flags:
# 2023-06-29 11:42:42,449 - qm - INFO - Sending program to QOP
# 2023-06-29 11:42:44,214 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8697500000.0########################### 0.625
# 2023-06-29 11:43:15,536 - qm - INFO - Flags:
# 2023-06-29 11:43:15,537 - qm - INFO - Sending program to QOP
# 2023-06-29 11:43:16,867 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8697600000.0########################### 0.6458333333333334
# 2023-06-29 11:43:58,754 - qm - INFO - Flags:
# 2023-06-29 11:43:58,755 - qm - INFO - Sending program to QOP
# 2023-06-29 11:44:00,184 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8697700000.0########################### 0.6666666666666666
# 2023-06-29 11:44:38,671 - qm - INFO - Flags:
# 2023-06-29 11:44:38,671 - qm - INFO - Sending program to QOP
# 2023-06-29 11:44:40,506 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8697800000.0########################### 0.6875
# 2023-06-29 11:45:18,636 - qm - INFO - Flags:
# 2023-06-29 11:45:18,637 - qm - INFO - Sending program to QOP
# 2023-06-29 11:45:20,043 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8697900000.0########################### 0.7083333333333334
# 2023-06-29 11:46:12,205 - qm - INFO - Flags:
# 2023-06-29 11:46:12,206 - qm - INFO - Sending program to QOP
# 2023-06-29 11:46:14,080 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8698000000.0########################### 0.7291666666666666
# 2023-06-29 11:47:49,856 - qm - INFO - Flags:
# 2023-06-29 11:47:49,856 - qm - INFO - Sending program to QOP
# 2023-06-29 11:47:51,269 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8698100000.0########################### 0.75
# 2023-06-29 11:49:48,702 - qm - INFO - Flags:
# 2023-06-29 11:49:48,702 - qm - INFO - Sending program to QOP
# 2023-06-29 11:49:50,176 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8698200000.0########################### 0.7708333333333334
# 2023-06-29 11:51:46,694 - qm - INFO - Flags:
# 2023-06-29 11:51:46,695 - qm - INFO - Sending program to QOP
# 2023-06-29 11:51:48,136 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8698300000.0########################### 0.7916666666666666
# 2023-06-29 11:53:19,498 - qm - INFO - Flags:
# 2023-06-29 11:53:19,498 - qm - INFO - Sending program to QOP
# 2023-06-29 11:53:20,909 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8698400000.0########################### 0.8125
# 2023-06-29 11:56:19,392 - qm - INFO - Flags:
# 2023-06-29 11:56:19,393 - qm - INFO - Sending program to QOP
# 2023-06-29 11:56:20,755 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8698500000.0########################### 0.8333333333333334
# 2023-06-29 11:59:43,229 - qm - INFO - Flags:
# 2023-06-29 11:59:43,230 - qm - INFO - Sending program to QOP
# 2023-06-29 11:59:45,103 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8698600000.0########################### 0.8541666666666666
# 2023-06-29 12:04:12,529 - qm - INFO - Flags:
# 2023-06-29 12:04:12,529 - qm - INFO - Sending program to QOP
# 2023-06-29 12:04:14,424 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8698700000.0########################### 0.875
# 2023-06-29 12:08:59,475 - qm - INFO - Flags:
# 2023-06-29 12:08:59,475 - qm - INFO - Sending program to QOP
# 2023-06-29 12:09:01,376 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8698800000.0########################### 0.8958333333333334
# 2023-06-29 12:17:33,644 - qm - INFO - Flags:
# 2023-06-29 12:17:33,644 - qm - INFO - Sending program to QOP
# 2023-06-29 12:17:35,524 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8698900000.0########################### 0.9166666666666666
# 2023-06-29 12:24:14,160 - qm - INFO - Flags:
# 2023-06-29 12:24:14,161 - qm - INFO - Sending program to QOP
# 2023-06-29 12:24:15,600 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8699000000.0########################### 0.9375
# 2023-06-29 12:32:49,465 - qm - INFO - Flags:
# 2023-06-29 12:32:49,465 - qm - INFO - Sending program to QOP
# 2023-06-29 12:32:50,949 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8699100000.0########################### 0.9583333333333334
# 2023-06-29 12:42:09,534 - qm - INFO - Flags:
# 2023-06-29 12:42:09,534 - qm - INFO - Sending program to QOP
# 2023-06-29 12:42:11,030 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8699200000.0########################### 0.9791666666666666
# 2023-06-29 12:50:45,247 - qm - INFO - Flags:
# 2023-06-29 12:50:45,248 - qm - INFO - Sending program to QOP
# 2023-06-29 12:50:47,105 - qm - INFO - Executing program
# Execution stopped by user!
# Wall time: 1h 34min 11s

# %% [markdown]
# ## Saving

# %%
#Saving the data
cooldown_date=Cooldown_Date#top folder 
device="excit_to_vac" #second folder 
name="Multiple_freq" # third folder 
meastype="1p05_9945_992_0p1" #Final file name 

datadict={}
#Configuration file copy 
datadict["LO_fluxline"]=LO_fluxline
datadict["LO_readout"]=LO_readout

#Saving of parameters 
datadict["octave_output_gain"]=octave_output_gain

datadict["IF_right"]=IF_right
datadict["n_empty"]=n_empty
datadict["n_repetition"]=n_repetition
datadict["n_full"]=n_full

datadict["amp_factor_array"]=amp_factor_array
datadict["amp_factor_array_high"]=amp_factor_high_array

datadict["Readout_Len"]=Readout_Len
datadict["cooldown_time"]=cooldown_time
datadict["wait_pump_step"]=wait_pump_step

#Saving of data 
datadict["freqs_dict"]=freqs_dict
datadict["Data"]=Data
datadict["config"]=config

an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)
# Out:
# saving in new directory

# %% [markdown]
# ## Plotting

# %%
# %matplotlib qt
#Plot all 
number_avg=1
Processed_Data=an.Extract_vac_exc_gap(Data,amp_factor_array,freqs_dict,n_empty,number_avg)
amp_factor=amp_factor_array[0]
freqs=freqs_dict[amp_factor]

for idx in range(len(freqs)):
    
    if Processed_Data[amp_factor][freqs[idx]]["fit"]:

        gap=Processed_Data[amp_factor][freqs[idx]]["gap"]
        coeff=Processed_Data[amp_factor][freqs[idx]]["fit_coeff"]
        time_fit=Processed_Data[amp_factor][freqs[idx]]["time_fit"]
        y_fitted=Processed_Data[amp_factor][freqs[idx]]["y_fitted"]
        av_fit=Processed_Data[amp_factor][freqs[idx]]["av_fit"]
        
        
        fontsize=8
        fig, axs = plt.subplots( nrows=2, ncols=1, figsize=(5,10),dpi=100)
        
        av=Data[amp_factor][freqs[idx]]["value"]
        time=Data[amp_factor][freqs[idx]]["time"]
        
        ax=axs[0]
        ax.set_title("Average "+str(n_repetition))
        ax.plot(time*1e-9,av*1e3,".")
        #ax.plot([Pump_Delay*4*1e-9,Pump_Delay*4*1e-9],[0, max(av*1e3)],"r")
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")
        
        ax=axs[1]
        ax.set_title("Pump= "+str(freqs[idx]) +" Iteration :" +str(idx)+" $\lambda= $"+str(round(gap,2)))
        ax.plot(time_fit,av_fit,".")
        ax.plot(time_fit,y_fitted)
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")

    else:
        print("No fit")
        time_fit=Processed_Data[amp_factor][freqs[idx]]["time_fit"]
        av_fit=Processed_Data[amp_factor][freqs[idx]]["av_fit"]
        fontsize=8
        fig, axs = plt.subplots( nrows=1, ncols=1, figsize=(5,5),dpi=100)
        ax=axs
        ax.set_title("Pump= "+str(freqs[idx]) +" Iteration :" +str(idx) + " No fit")
        ax.plot(time_fit,av_fit,".")
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")

# %% [markdown]
# ## Single measurement
#
# Initial code with change in duration. However, doing like this saturates the memory, if you are trying to do relatively long measurement

# %% [markdown]
# ![image.png](attachment:d215a4ca-a547-44cb-ac32-e10effe4f621.png)
#
# I think I can make this new measurement by implementing a sticky where the sticky with a high amplitude of 1 and then, we subtract to a low amplitude. As long as the high to low amplitude is down quickly enough, it should be good. But then, we need to move this to another folder

# %%
# %matplotlib qt

def First_jump_single_freq(Readout_Len, amp_factor, amp_factor_high, IF_pump, IF_resonator, Offset_IF,Pump_Delay, n_repetition, n_empty,n_full, cooldown_time,qm): 

    """ Take as input :

    Readout_Len : length of the readout that should be the same as defined in the configuration file. Here, it is necessary for the conversion to volt
    amp_factor : multiplication factor to the pump pulse amplitude 
    amp_factor_high : multiplication factor the pump pulse to bring the system to a high photon state 
    IF_pump : IF frequency of the pump -> necessary to update the config frequency 
    IF_resonator : If_frequency of the resonator -> necessary to update the config frequency 
    Offset_IF : general ofset if the IF of the resonator is not center 
    Pump_Delay ; time during which the pump low amplitude pump is on.  -- could be removed 
    n_repetition : number of times the program is repeated to get an average 
    n_empty : number of measurements when the pulse is low amplitude 
    n_full : number of measurements when the pulse is high amplitude 
    cooldown_time : waiting time between repetitions in nb of cycles 
    qm : quantum machine 
    """ 

    with program() as IQ_blobs:

        n = declare(int)
        n_rep = declare(int)
        i = declare(int)
        I = declare(fixed)
        Q = declare(fixed)
        I_st = declare_stream()
        Q_st = declare_stream()
        f = declare(int)
        n_rep_st=declare_stream()

        assign_variables_to_element("resonator", I,Q) 

        #Update the demodulation frequency 
        update_frequency("resonator",IF_resonator+Offset_IF) 
        update_frequency("fluxline",IF_pump)

        #Loop on the repetition 
        with for_(n_rep, 0, n_rep < n_repetition, n_rep + 1):

            #Loop on the repetition 
            with for_(i, 0, i < np.round((n_empty*(Readout_Len+300))/twoPhoton_len)+1, i + 1):
                play("pumping" * amp(amp_factor_high), 'fluxline')  

            with for_(i, 0, i < np.round((n_full*(Readout_Len+300))/twoPhoton_len)+1, i + 1):
                play("pumping" * amp(amp_factor), 'fluxline')  



            #Demodulation measurements 
            with for_(n, 0, n < n_runs, n + 1):

                #Demodulate n time 
                measure(
                    "fake_readout",
                    "resonator",
                    None,
                    dual_demod.full("cos", "out1", "sin", "out2", I),
                    dual_demod.full("minus_sin", "out1", "cos", "out2", Q),
                )

                save(I, I_st)
                save(Q, Q_st)

            save(n_rep, n_rep_st)

            wait(cooldown_time) #wait the cooldown 

        with stream_processing():
            I_st.with_timestamps().save_all("I")
            Q_st.with_timestamps().save_all("Q")
            n_rep_st.save("n_rep")



    simulation = False     

    if simulation:
        simulation_config = SimulationConfig(
            duration=50000, simulation_interface=LoopbackInterface([("con1", 3, "con1", 1)])
        )

        job = qmm.simulate(config, IQ_blobs, simulation_config)
        job.get_simulated_samples().con1.plot(analog_ports={'1','2','3','4' },digital_ports={'1','3'})

    else:

        job = qm.execute(IQ_blobs)
        results = fetching_tool(job, data_list=["I", "Q","n_rep"], mode="live")

        fig = plt.figure()
        interrupt_on_close(fig, job)  #  Interrupts the job when closing the figure

        while results.is_processing():

            I, Q, n_rep = results.fetch_all()

            time=I["timestamp"]
            I = u.demod2volts(I["value"], Readout_Len) #diviser par la duree du pulse Readout_lEN 
            Q = u.demod2volts(Q["value"], Readout_Len)


            #Plotting the average 
            if len(I)>n_runs:

                #Datas are capted continously and then transfer into a 2D matrix and averaged
                it=len(I)//n_runs
                I_2d=I[0:it*n_runs].reshape((it,n_runs))
                Q_2d=Q[0:it*n_runs].reshape((it,n_runs))
                norm_2d=np.sqrt(I_2d**2+Q_2d**2)

                plt.subplot(211)
                fig.suptitle("IF_pump "+str(IF_pump)+" ite :"+str(n_rep))
                plt.cla()
                plt.plot(np.angle(I_2d[it-1,:]+1j*Q_2d[it-1,:]), ".", markersize=2)
                plt.plot([n_empty,n_empty], [-np.pi, np.pi],'r')
                plt.xlabel("Nb points")
                plt.ylabel("phase")
                plt.pause(0.1)


                plt.subplot(212)
                av=np.mean(norm_2d,axis=0) 
                plt.subplot(313)
                plt.cla()
                plt.plot(time[0:n_runs]*1e-9,av*1e3,".",markersize=2)
                plt.xlabel("time [s]")
                plt.ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")
                
                
    # Returns average signal and time in ns 
    return av,time[0:n_runs]

# %%
# %matplotlib qt
Readout_Len=50_000
config,qm=update_readout_lenght(Readout_Len,config,qmm)


amp_factor_array=np.array([0.3]) #Prefactor of the amplitude 
amp_factor=amp_factor_array[0]

amp_factor_high_array=np.array([1.0]) #Prefactor of the amplitude 
amp_factor_high=amp_factor_high_array[0]


#Update the pump IF frequency 
freqs_array=np.array([[ 0.1950e9]]) # defines the IF of the pump  0.19565
IF_pump=freqs_array[0,0] #select the frequency from the array 
IF_resonator=(LO_fluxline+IF_pump)/2-LO_readout #demodulate at half of the pump IF by default 

n_repetition=100 #number of repetitions 

n_empty=5_000 #number of vaccum readout to do 
Pump_Delay = n_empty*(Readout_Len+300)//4  #time for the pump to be on low amp 
n_full=30_000 #number of pump on readout to do 
n_runs=n_empty+n_full # Total number of readout to do 

cooldown_time=1_000_000_000//4 #cooldown time before each repetition to go back to vacuum  #cooldown time before each repetition to go back to vacuum 
Offset_IF=0  

av,time=First_jump_single_freq(Readout_Len, amp_factor,amp_factor_high, IF_pump, IF_resonator, Offset_IF,Pump_Delay, n_repetition, n_empty,n_full, cooldown_time,qm)

Data={}
Data[amp_factor]={}
Data[amp_factor][IF_pump]={}
Data[amp_factor][IF_pump]["value"]=av
Data[amp_factor][IF_pump]["time"]=time
# Out:
# 2023-04-24 13:36:12,938 - qm - INFO - Flags:
# 2023-04-24 13:36:12,938 - qm - INFO - Sending program to QOP
# 2023-04-24 13:36:13,416 - qm - INFO - Executing program
# Execution stopped by user!

# %% [markdown]
# ## Plotting for single frequency

# %%
# %matplotlib inline
number_avg=10
Processed_Data=an.Extract_vac_exc_gap(Data,amp_factor_array,freqs_array,Pump_Delay,number_avg)

amp_factor=amp_factor_array[0]
freqs=freqs_array[0,:]

for idx in range(len(freqs)):
    
    if Processed_Data[amp_factor][freqs[idx]]["fit"]:

        gap=Processed_Data[amp_factor][freqs[idx]]["gap"]
        coeff=Processed_Data[amp_factor][freqs[idx]]["fit_coeff"]
        time_fit=Processed_Data[amp_factor][freqs[idx]]["time_fit"]
        y_fitted=Processed_Data[amp_factor][freqs[idx]]["y_fitted"]
        av_fit=Processed_Data[amp_factor][freqs[idx]]["av_fit"]

        fontsize=8
        fig, axs = plt.subplots( nrows=2, ncols=1, figsize=(8,10),dpi=100)

        #Plotting the measurement 
        ax=axs[0]
        ax.set_title("Average "+str(n_repetition))
        ax.plot(time*1e-9,av*1e3,".")
        #ax.plot([Pump_Delay*4*1e-9,Pump_Delay*4*1e-9],[0, max(av*1e3)],"r")
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")

        ax=axs[1]
        ax.set_title("$\lambda= $"+str(gap))
        ax.plot(time_fit,av_fit,".")
        ax.plot(time_fit,y_fitted)
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")



    else:
        print("No fit")
        time_fit=Processed_Data[amp_factor][freqs[idx]]["time_fit"]
        av_fit=Processed_Data[amp_factor][freqs[idx]]["av_fit"]
        
        fontsize=8
        fig, axs = plt.subplots( nrows=2, ncols=1, figsize=(8,10),dpi=100)

        #Plotting the measurement 
        ax=axs[0]
        ax.set_title("Average "+str(n_repetition))
        ax.plot(time*1e-9,av*1e3)
        #ax.plot([Pump_Delay*4*1e-9,Pump_Delay*4*1e-9],[0, max(av*1e3)],"r")
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")

        ax=axs[1]
        ax.set_title("Pump= "+str(freqs[idx]) +" Iteration :" +str(idx) + " No fit")
        ax.plot(time_fit,av_fit)
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")

# %% [markdown]
# ## Saving for a single frequency

# %%
#Saving the data
cooldown_date=Cooldown_Date #top folder 
device="excit_to_vac" #second folder 
name="Single_freq" # third folder 
meastype="test" #Final file name 

datadict={}
#Configuration file copy 
datadict["LO_fluxline"]=LO_fluxline
datadict["IF_fluxline"]=IF_pump
datadict["IF_readout"]=IF_resonator
datadict["LO_readout"]=LO_readout

#Saving of parameters 
datadict["n_empty"]=n_empty
datadict["n_repetition"]=n_repetition
datadict["n_full"]=n_full
datadict["amp_factor_array"]=amp_factor_array
datadict["amp_factor_array_high"]=amp_factor_high_array
datadict["Offset_IF"]=Offset_IF
datadict["Readout_Len"]=Readout_Len
datadict["Pump_Delay"]=Pump_Delay
datadict["cooldown_time"]=cooldown_time

#Saving of data 
datadict["freqs_array"]=freqs_array 
datadict["Data"]=Data
datadict["config"]=config

# %%
an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)
# Out:
# saving in new directory

# %%
#loading the data 
filepath=r"\\sb1files\HQC\Users\beaulieu\Data\Run01\104\2023_04_14\excit_to_vac\Single_freq\test.npz"

npzfile=np.load(filepath,allow_pickle=True)
npzfile["multidata"][()]
freqs_array=npzfile["multidata"][()]["freqs_array"]
Data=npzfile["multidata"][()]["Data"]
amp_factor_array=npzfile["multidata"][()]["amp_factor_array"]
Pump_Delay=npzfile["multidata"][()]["Pump_Delay"]

# %% [markdown]
# ## Multiple frequencies of single measurement with dual demodualtion

# %%
#Select the frequencies 

span=1.3 * u.MHz # Span of the pumping 
df = 0.1* u.MHz # Step of the pumping 0.01
IF_center=0.1954e9 

freqs_array = np.array([np.arange(IF_center-span/2, IF_center+span/2, df)]) #sets of frequencies


fmin=0.1956e9
fmax=0.1958e9
df=0.01* u.MHz
freqs_array=np.array([np.arange(fmin, fmax+df/2, df)])

freqs=freqs_array[0,:] #select the first row 

freqs
# Out:
# array([1.9560e+08, 1.9561e+08, 1.9562e+08, 1.9563e+08, 1.9564e+08,
#        1.9565e+08, 1.9566e+08, 1.9567e+08, 1.9568e+08, 1.9569e+08,
#        1.9570e+08, 1.9571e+08, 1.9572e+08, 1.9573e+08, 1.9574e+08,
#        1.9575e+08, 1.9576e+08, 1.9577e+08, 1.9578e+08, 1.9579e+08,
#        1.9580e+08])

# %%
# %matplotlib qt
Readout_Len=50_000
config,qm=update_readout_lenght(Readout_Len,config,qmm)

amp_factor_array=np.array([0.3]) #Prefactor of the amplitude 
amp_factor=amp_factor_array[0]

amp_factor_high_array=np.array([1.9]) #Prefactor of the amplitude 
amp_factor_high=amp_factor_high_array[0]

n_repetition=25 #number of repetitions 

n_empty=10_000 #number of vaccum readout to do 
Pump_Delay = n_empty*(Readout_Len+300)//4  #time for the pump to be off 
n_full=30_000 #number of pump on readout to do 
n_runs=n_empty+n_full # Total number of readout to do 

cooldown_time=1_000_000_000//4 #cooldown time before each repetition to go back to vacuum 
Offset_IF=0  


save_Data=True
#Saving the data
cooldown_date=Cooldown_Date #top folder 
device="excit_to_vac" #second folder 
name="Multiple_freq" # third folder 
meastype="0p3_amp_test" #Final file name 


print("The different frequency {}".format(freqs))
Expected_time=(Readout_Len*n_runs*1e-9*n_repetition+n_repetition*(cooldown_time*4*1e-9+Pump_Delay*4*1e-9))/60*len(freqs)
print("The expected time : {} min".format(Expected_time))
# Out:
# The different frequency [1.9560e+08 1.9561e+08 1.9562e+08 1.9563e+08 1.9564e+08 1.9565e+08
#  1.9566e+08 1.9567e+08 1.9568e+08 1.9569e+08 1.9570e+08 1.9571e+08
#  1.9572e+08 1.9573e+08 1.9574e+08 1.9575e+08 1.9576e+08 1.9577e+08
#  1.9578e+08 1.9579e+08 1.9580e+08]
# The expected time : 30.65125 min

# %%
# %%time


Data={} #dictionnary to hold all the data 
Data[amp_factor]={}
for idx,IF_pump in enumerate(freqs) :
    
    print("########################### Frequency "+str(IF_pump+LO_fluxline)+"########################### "+str(idx/len(freqs)))

    IF_resonator=(LO_fluxline+IF_pump)/2-LO_readout #demodulate at half of the pump IF by default 
    
    av, time=First_jump_single_freq(Readout_Len, amp_factor, amp_factor_high, IF_pump, IF_resonator, Offset_IF,Pump_Delay, n_repetition, n_empty,n_full, cooldown_time,qm)
    plt.close()
    
    Data[amp_factor][IF_pump]={}
    Data[amp_factor][IF_pump]["value"]=av
    Data[amp_factor][IF_pump]["time"]=time
    
    
if save_Data:
    
    datadict={}
    datadict["LO_fluxline"]=LO_fluxline
    datadict["IF_fluxline"]=IF_pump
    datadict["IF_readout"]=IF_resonator
    datadict["LO_readout"]=LO_readout


    datadict["n_empty"]=n_empty
    datadict["n_repetition"]=n_repetition
    datadict["n_full"]=n_full
    datadict["amp_factor_array"]=amp_factor_array
    datadict["amp_factor_array_high"]=amp_factor_high_array
    datadict["Offset_IF"]=Offset_IF
    datadict["Readout_Len"]=Readout_Len
    datadict["Pump_Delay"]=Pump_Delay
    datadict["cooldown_time"]=cooldown_time
    datadict["Data"]=Data
    datadict["freqs_array"]=freqs_array
    datadict["config"]=config
    
    an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)
# Out:
# ########################### Frequency 8695600000.0########################### 0.0
# 2023-04-24 12:23:13,021 - qm - INFO - Flags:
# 2023-04-24 12:23:13,022 - qm - INFO - Sending program to QOP
# 2023-04-24 12:23:13,470 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695610000.0########################### 0.047619047619047616
# 2023-04-24 12:24:30,065 - qm - INFO - Flags:
# 2023-04-24 12:24:30,066 - qm - INFO - Sending program to QOP
# 2023-04-24 12:24:30,534 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695620000.0########################### 0.09523809523809523
# 2023-04-24 12:25:47,369 - qm - INFO - Flags:
# 2023-04-24 12:25:47,369 - qm - INFO - Sending program to QOP
# 2023-04-24 12:25:48,213 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695630000.0########################### 0.14285714285714285
# 2023-04-24 12:27:04,372 - qm - INFO - Flags:
# 2023-04-24 12:27:04,372 - qm - INFO - Sending program to QOP
# 2023-04-24 12:27:04,828 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695640000.0########################### 0.19047619047619047
# 2023-04-24 12:28:21,395 - qm - INFO - Flags:
# 2023-04-24 12:28:21,395 - qm - INFO - Sending program to QOP
# 2023-04-24 12:28:21,838 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695650000.0########################### 0.23809523809523808
# 2023-04-24 12:29:38,584 - qm - INFO - Flags:
# 2023-04-24 12:29:38,584 - qm - INFO - Sending program to QOP
# 2023-04-24 12:29:39,044 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695660000.0########################### 0.2857142857142857
# 2023-04-24 12:30:55,802 - qm - INFO - Flags:
# 2023-04-24 12:30:55,803 - qm - INFO - Sending program to QOP
# 2023-04-24 12:30:56,258 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695670000.0########################### 0.3333333333333333
# 2023-04-24 12:32:12,796 - qm - INFO - Flags:
# 2023-04-24 12:32:12,796 - qm - INFO - Sending program to QOP
# 2023-04-24 12:32:13,246 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695680000.0########################### 0.38095238095238093
# 2023-04-24 12:33:30,045 - qm - INFO - Flags:
# 2023-04-24 12:33:30,045 - qm - INFO - Sending program to QOP
# 2023-04-24 12:33:30,486 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695690000.0########################### 0.42857142857142855
# 2023-04-24 12:34:47,005 - qm - INFO - Flags:
# 2023-04-24 12:34:47,005 - qm - INFO - Sending program to QOP
# 2023-04-24 12:34:47,464 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695700000.0########################### 0.47619047619047616
# 2023-04-24 12:36:04,467 - qm - INFO - Flags:
# 2023-04-24 12:36:04,467 - qm - INFO - Sending program to QOP
# 2023-04-24 12:36:04,932 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695710000.0########################### 0.5238095238095238
# 2023-04-24 12:37:21,343 - qm - INFO - Flags:
# 2023-04-24 12:37:21,343 - qm - INFO - Sending program to QOP
# 2023-04-24 12:37:22,149 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695720000.0########################### 0.5714285714285714
# 2023-04-24 12:38:38,501 - qm - INFO - Flags:
# 2023-04-24 12:38:38,501 - qm - INFO - Sending program to QOP
# 2023-04-24 12:38:38,965 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695730000.0########################### 0.6190476190476191
# 2023-04-24 12:39:55,869 - qm - INFO - Flags:
# 2023-04-24 12:39:55,869 - qm - INFO - Sending program to QOP
# 2023-04-24 12:39:56,333 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695740000.0########################### 0.6666666666666666
# 2023-04-24 12:41:12,724 - qm - INFO - Flags:
# 2023-04-24 12:41:12,724 - qm - INFO - Sending program to QOP
# 2023-04-24 12:41:13,179 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695750000.0########################### 0.7142857142857143
# 2023-04-24 12:42:29,827 - qm - INFO - Flags:
# 2023-04-24 12:42:29,827 - qm - INFO - Sending program to QOP
# 2023-04-24 12:42:30,612 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695760000.0########################### 0.7619047619047619
# 2023-04-24 12:43:46,701 - qm - INFO - Flags:
# 2023-04-24 12:43:46,701 - qm - INFO - Sending program to QOP
# 2023-04-24 12:43:47,131 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695770000.0########################### 0.8095238095238095
# 2023-04-24 12:45:03,868 - qm - INFO - Flags:
# 2023-04-24 12:45:03,868 - qm - INFO - Sending program to QOP
# 2023-04-24 12:45:04,774 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695780000.0########################### 0.8571428571428571
# 2023-04-24 12:46:21,142 - qm - INFO - Flags:
# 2023-04-24 12:46:21,142 - qm - INFO - Sending program to QOP
# 2023-04-24 12:46:21,605 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695790000.0########################### 0.9047619047619048
# 2023-04-24 12:47:38,541 - qm - INFO - Flags:
# 2023-04-24 12:47:38,542 - qm - INFO - Sending program to QOP
# 2023-04-24 12:47:39,409 - qm - INFO - Executing program
# Execution stopped by user!
# ########################### Frequency 8695800000.0########################### 0.9523809523809523
# 2023-04-24 12:48:55,662 - qm - INFO - Flags:
# 2023-04-24 12:48:55,662 - qm - INFO - Sending program to QOP
# 2023-04-24 12:48:56,466 - qm - INFO - Executing program
# Execution stopped by user!
# saving
# Wall time: 27min

# %% [markdown]
# ## Saving for multiple frequencies

# %%
#Saving the data 
cooldown_date=Cooldown_Date #top folder 
device="excit_to_vac" #second folder 
name="Multiple_freq" # third folder 
meastype="test" #Final file name 

datadict={}
datadict["LO_fluxline"]=LO_fluxline
datadict["IF_fluxline"]=IF_pump
datadict["IF_readout"]=IF_resonator
datadict["LO_readout"]=LO_readout


datadict["n_empty"]=n_empty
datadict["n_repetition"]=n_repetition
datadict["n_full"]=n_full
datadict["amp_factor_array"]=amp_factor_array
datadict["amp_factor_array_high"]=amp_factor_high_array
datadict["Offset_IF"]=Offset_IF
datadict["Readout_Len"]=Readout_Len
datadict["Pump_Delay"]=Pump_Delay
datadict["cooldown_time"]=cooldown_time
datadict["Data"]=Data
datadict["config"]=config
datadict["freqs_dict"]=freqs_array

an.save_with_numpy(datadict, meastype, name, device, cooldown_date, filepath=Saving_Path)
# Out:
# saving in new directory

# %%
#Loading the data 

filepath= r"\\sb1files\HQC\Users\beaulieu\Data\Run01\104\2023_04_14\excit_to_vac\Multiple_freq\0p3_amp_test.npz"

npzfile=np.load(filepath,allow_pickle=True)
#npzfile["multidata"][()]

Pump_Delay=npzfile["multidata"][()]["Pump_Delay"]
Data=npzfile["multidata"][()]["Data"]
freqs_array=npzfile["multidata"][()]["freqs_array"]
amp_factor_array=npzfile["multidata"][()]["amp_factor_array"]
amp_factor_array_high=npzfile["multidata"][()]["amp_factor_array_high"]

# %% [markdown]
# ## Plotting for multiple frequencies

# %%
# %matplotlib qt
#Plot all 
number_avg=10
Processed_Data=an.Extract_vac_exc_gap(Data,amp_factor_array,freqs_array,Pump_Delay,number_avg)
amp_factor=amp_factor_array[0]
freqs=freqs_array[0,:]

for idx in range(len(freqs)):
    
    if Processed_Data[amp_factor][freqs[idx]]["fit"]:

        gap=Processed_Data[amp_factor][freqs[idx]]["gap"]
        coeff=Processed_Data[amp_factor][freqs[idx]]["fit_coeff"]
        time_fit=Processed_Data[amp_factor][freqs[idx]]["time_fit"]
        y_fitted=Processed_Data[amp_factor][freqs[idx]]["y_fitted"]
        av_fit=Processed_Data[amp_factor][freqs[idx]]["av_fit"]
        
        
        fontsize=8
        fig, axs = plt.subplots( nrows=2, ncols=1, figsize=(5,10),dpi=100)
        
        av=Data[amp_factor][freqs[idx]]["value"]
        time=Data[amp_factor][freqs[idx]]["time"]
        
        ax=axs[0]
        ax.set_title("Average "+str(n_repetition))
        ax.plot(time*1e-9,av*1e3,".")
        #ax.plot([Pump_Delay*4*1e-9,Pump_Delay*4*1e-9],[0, max(av*1e3)],"r")
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")
        
        ax=axs[1]
        ax.set_title("Pump= "+str(freqs[idx]) +" Iteration :" +str(idx)+" $\lambda= $"+str(round(gap,2)))
        ax.plot(time_fit,av_fit)
        ax.plot(time_fit,y_fitted)
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")



    else:
        print("No fit")
        time_fit=Processed_Data[amp_factor][freqs[idx]]["time_fit"]
        av_fit=Processed_Data[amp_factor][freqs[idx]]["av_fit"]
        fontsize=8
        fig, axs = plt.subplots( nrows=1, ncols=1, figsize=(5,5),dpi=100)
        ax=axs
        ax.set_title("Pump= "+str(freqs[idx]) +" Iteration :" +str(idx) + " No fit")
        ax.plot(time_fit,av_fit)
        ax.set_xlabel("time [s]")
        ax.set_ylabel("$\sqrt{I^2 + Q^2}$ (average) [mV]")
# Out:
# No fit

# %% [markdown]
# ## Extracting the Liouvillian gap

# %%
# %matplotlib inline


amp_factor=amp_factor_array[0]
freqs=freqs_array[0,:]

gap_array=[]
freq_gap_array=[]

for idx in range(len(freqs)):
    
    if Processed_Data[amp_factor][freqs[idx]]["fit"]:
        gap_array.append(Processed_Data[amp_factor][freqs[idx]]["gap"])
        freq_gap_array.append(freqs[idx])
        
gap_array=np.array(gap_array)
freq_gap_array=np.array(freq_gap_array)
        
        

# figsize=(5,4)

fontsize=8
figsize=(5,4)
fig, axs = plt.subplots( nrows=1, ncols=1, figsize=(5,5),dpi=200)

axs.plot(freq_gap_array/1e9,gap_array,'.-',alpha=.9, lw=.5, ms=8)
axs.set_xlabel("Pump frequency (IF)",fontsize=fontsize)
axs.set_ylabel("Louivillian gap",fontsize=fontsize)
axs.tick_params(axis='x', labelsize=fontsize)
axs.tick_params(axis='y', labelsize=fontsize)

# %%
# %matplotlib qt

Readout_Len=50_000
config,qm=update_readout_lenght(Readout_Len,config,qmm)


amp_factor_array=np.array([0.6]) #Prefactor of the amplitude 
amp_factor=amp_factor_array[0]

amp_factor_high_array=np.array([1]) #Prefactor of the amplitude 
amp_factor_high=amp_factor_high_array[0]


#Update the pump IF frequency 
freqs_array=np.array([[ 0.19565e9]]) # defines the IF of the pump  
IF_pump=freqs_array[0,0]
IF_resonator=(LO_fluxline+IF_pump)/2-LO_readout #demodulate at half of the pump IF by default 

n_repetition=20 #number of repetitions 

n_empty=5_000 #number of vaccum readout to do 
Pump_Delay = n_empty*(Readout_Len+300)//4  #time for the pump to be off 
n_full=30_000 #number of pump on readout to do 
n_runs=n_empty+n_full # Total number of readout to do 

cooldown_time=5_000_000//4 #cooldown time before each repetition to go back to vacuum 
Offset_IF=0  


with program() as IQ_blobs:

    n = declare(int)
    n_rep = declare(int)
    i = declare(int)
    I = declare(fixed)
    Q = declare(fixed)
    I_st = declare_stream()
    Q_st = declare_stream()
    f = declare(int)
    n_rep_st=declare_stream()

    assign_variables_to_element("resonator", I,Q) 

    #Update the demodulation frequency 
    update_frequency("resonator",IF_resonator+Offset_IF) 
    update_frequency("fluxline",IF_pump)
    
    #Loop on the repetition 
    with for_(n_rep, 0, n_rep < n_repetition, n_rep + 1):

        #Loop on the repetition 
        with for_(i, 0, i < np.round((n_empty*(Readout_Len+300))/twoPhoton_len)+1, i + 1):
            play("pumping" * amp(amp_factor_high), 'fluxline')  

        with for_(i, 0, i < np.round((n_full*(Readout_Len+300))/twoPhoton_len)+1, i + 1):
            play("pumping" * amp(amp_factor), 'fluxline')  



        #Demodulation measurements 
        with for_(n, 0, n < n_runs, n + 1):

            #Demodulate n time 
            measure(
                "fake_readout",
                "resonator",
                None,
                dual_demod.full("cos", "out1", "sin", "out2", I),
                dual_demod.full("minus_sin", "out1", "cos", "out2", Q),
            )

            save(I, I_st)
            save(Q, Q_st)

        save(n_rep, n_rep_st)

        wait(cooldown_time) #wait the cooldown 

    with stream_processing():
        I_st.with_timestamps().save_all("I")
        Q_st.with_timestamps().save_all("Q")
        n_rep_st.save("n_rep")



simulation = False     

if simulation:
    simulation_config = SimulationConfig(
        duration=50000, simulation_interface=LoopbackInterface([("con1", 3, "con1", 1)])
    )

    job = qmm.simulate(config, IQ_blobs, simulation_config)
    job.get_simulated_samples().con1.plot(analog_ports={'1','2','3','4' },digital_ports={'1','3'})

else:

    job = qm.execute(IQ_blobs)
    results = fetching_tool(job, data_list=["I", "Q","n_rep"], mode="live")

    fig = plt.figure()
    interrupt_on_close(fig, job)  #  Interrupts the job when closing the figure

    while results.is_processing():
        I, Q, n_rep = results.fetch_all()

        #dt=(I["timestamp"][1]-I["timestamp"][0])*1e-9 #time between sucessive points
        time=I["timestamp"]
        I = u.demod2volts(I["value"], Readout_Len) #diviser par la duree du pulse Readout_lEN 
        Q = u.demod2volts(Q["value"], Readout_Len)

        plt.subplot(211)
        plt.cla()
        fig.suptitle("IF_pump "+str(IF_pump)+" ite :"+str(n_rep))
        plt.plot(I[:min(len(I), len(Q))], Q[:min(len(I), len(Q))], ".", markersize=2)
        plt.xlabel("I")
        plt.ylabel("Q")
        plt.axis("equal")
        plt.subplot(212)
        plt.cla()
        plt.plot(np.angle(I[:min(len(I), len(Q))]+1j*Q[:min(len(I), len(Q))]), ".", markersize=2)
        #plt.plot(I**2+Q**2,".",markersize=2)
        plt.plot([n_empty,n_empty], [-np.pi, np.pi],'r')
        plt.xlabel("Nb points")
        plt.ylabel("phase")
        plt.pause(0.1)
# Out:
# 2023-04-21 18:02:13,192 - qm - INFO - Flags:
# 2023-04-21 18:02:13,193 - qm - INFO - Sending program to QOP
# 2023-04-21 18:02:13,748 - qm - INFO - Executing program
# Execution stopped by user!

# %%
I_2d=I.reshape((n_repetition,n_runs))
Q_2d=Q.reshape((n_repetition,n_runs))
time_2d=time.reshape((n_repetition,n_runs))

norm_2d=np.sqrt(I_2d**2+Q_2d**2)
#We reset the timer to zero for each idx
time_2d=(time_2d.transpose()-time_2d[:,0]).transpose()

# %%
# %matplotlib inline
idx=4
fontsize=7
fig, axs = plt.subplots( nrows=2, ncols=1, figsize=(5,10),dpi=100)

ax=axs[0]
ax.set_title("Iteration :" + str(idx))
ax.plot(time_2d[idx,:]*1e-9,norm_2d[idx,:])
ax.plot([Pump_Delay*4*1e-9,Pump_Delay*4*1e-9],[0, max(norm_2d[idx,:])],"r")
ax.set_ylabel(r'$I^2 + Q^2$ (single traj) [V]',fontsize=fontsize)
ax.set_xlabel("time [s]",fontsize=fontsize)
#average over all axis :
ax=axs[1]
ax.set_title("Average")
av=np.mean(norm_2d,axis=0)
ax.plot(time_2d[0,:]*1e-9,av)
ax.plot([Pump_Delay*4*1e-9,Pump_Delay*4*1e-9],[0, max(norm_2d[idx,:])],"r")
ax.set_xlabel("time [s]")
ax.set_ylabel("r'$I^2 + Q^2$ (average) [V]")
# Out:
# Text(0, 0.5, "r'$I^2 + Q^2$ (average) [V]")
